# %% [markdown]
# # Analyze results after treebank alignment

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('paper')
sns.set_style('white')

# %%
import pickle

# %%
import ne_evaluate_mentions as nem

# %% [markdown]
# ## Get token data

# %%
tokens_ner_with_upos_feats = pd.read_csv('align/spmrl_tokens_df.csv.gz', compression='gzip').reset_index()

# %%
tok_gold_dev  = tokens_ner_with_upos_feats[tokens_ner_with_upos_feats.set=='dev']
tok_gold_train = tokens_ner_with_upos_feats[tokens_ner_with_upos_feats.set=='train']
tok_gold_test = tokens_ner_with_upos_feats[tokens_ner_with_upos_feats.set=='test']

# %%
tok_gold_dev_sents =   tok_gold_dev.groupby('sent_id')[['misc_token_str', 'biose']].apply(lambda x: x.values.tolist())
tok_gold_train_sents = tok_gold_train.groupby('sent_id')[['misc_token_str', 'biose']].apply(lambda x: x.values.tolist())
tok_gold_test_sents =  tok_gold_test.groupby('sent_id')[['misc_token_str', 'biose']].apply(lambda x: x.values.tolist())
tok_gold_test_sents.head()
# Out:
# sent_id
# 5439    [[הכל, O], [נושאים, O], [עמם, O], [את, O], [כי...
# 5440    [[אומר, O], [מזכיר, O], [התק"ם, S-ORG], [,, O]...
# 5441    [[לא, O], [ייתכן, O], [שעולה, O], [יבוא, O], [...
# 5442    [[לא, O], [ייתכן, O], [שהוא, O], [יירד, O], [מ...
# 5443    [[לכן, O], [קבענו, O], [עיקרון, O], [שצריכה, O...
# dtype: object

# %%
tok_gold_dev_mentions = nem.sents_to_mentions  (tok_gold_dev_sents  )
tok_gold_train_mentions = nem.sents_to_mentions(tok_gold_train_sents)
tok_gold_test_mentions = nem.sents_to_mentions (tok_gold_test_sents )

tok_gold_dev_mentions[:10]
# Out:
# [(1, 'מתאילנד', 'GPE', 1),
#  (1, 'לישראל', 'GPE', 1),
#  (2, 'בוועדת העבודה והרווחה', 'ORG', 1),
#  (2, 'הכנסת', 'ORG', 1),
#  (3, 'אורה נמיר', 'PER', 1),
#  (3, 'מערך', 'ORG', 1),
#  (3, 'לישראל', 'GPE', 1),
#  (3, 'מתאילנד', 'GPE', 1),
#  (4, 'האוצר', 'ORG', 1),
#  (4, 'משרד העבודה והרווחה', 'ORG', 1)]

# %% [markdown]
# ## Get morpheme data

# %%
dropped = [5438, 5444, 5445, 5446, 5448, 5449, 5450, 5451, 5453, 5459]

# %%
spdf = pd.read_csv('align/spdf_fixed.csv.gz', compression='gzip')

# %%
o_morph_gold_dev_sents   =   spdf[spdf.set=='dev'].groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
o_morph_gold_train_sents =   spdf[spdf.set=='train'].groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
o_morph_gold_test_sents  =   spdf[spdf.set=='test'].groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
o_morph_gold_test_sents.head()
# Out:
# sent_id
# 5438    [[אחרים, O], [ב, O], [ה, B-ORG], [תנועה, I-ORG...
# 5439    [[הכל, O], [נושאים, O], [עמ, O], [הם, O], [את,...
# 5440    [[אומר, O], [מזכיר, O], [התק"ם, S-ORG], [,, O]...
# 5441    [[לא, O], [ייתכן, O], [ש, O], [עולה, O], [יבוא...
# 5442    [[לא, O], [ייתכן, O], [ש, O], [הוא, O], [יירד,...
# dtype: object

# %%
spdf = spdf[(~spdf.sent_id.isin(dropped))]

# %%
morph_gold_dev  = spdf[spdf.set=='dev']
morph_gold_train = spdf[spdf.set=='train']
morph_gold_test = spdf[spdf.set=='test']

# %%
morph_gold_dev_sents   =   morph_gold_dev.groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
morph_gold_train_sents = morph_gold_train.groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
morph_gold_test_sents  =  morph_gold_test.groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
morph_gold_test_sents.head()
# Out:
# sent_id
# 5439    [[הכל, O], [נושאים, O], [עמ, O], [הם, O], [את,...
# 5440    [[אומר, O], [מזכיר, O], [התק"ם, S-ORG], [,, O]...
# 5441    [[לא, O], [ייתכן, O], [ש, O], [עולה, O], [יבוא...
# 5442    [[לא, O], [ייתכן, O], [ש, O], [הוא, O], [יירד,...
# 5443    [[לכן, O], [קבענו, O], [עיקרון, O], [ש, O], [צ...
# dtype: object

# %%
morph_gold_dev_mentions = nem.sents_to_mentions  (morph_gold_dev_sents  )
morph_gold_train_mentions = nem.sents_to_mentions(morph_gold_train_sents)
morph_gold_test_mentions = nem.sents_to_mentions (morph_gold_test_sents )

morph_gold_test_mentions[:10]
# Out:
# [(5440, 'התק"ם', 'ORG', 1),
#  (5440, 'מוקי צור', 'PER', 1),
#  (5441, 'צה"ל', 'ORG', 1),
#  (5447, 'ה מחלקה ל התיישבות', 'ORG', 1),
#  (5460, 'חגי בז', 'PER', 1),
#  (5460, 'בריה"ם', 'GPE', 1),
#  (5460, 'ה קיבוץ ה ארצי', 'ORG', 1),
#  (5465, 'ה קיבוץ ה דתי', 'ORG', 1),
#  (5465, 'אריה קרול', 'PER', 1),
#  (5466, 'ה תנועה ה קיבוצית', 'ORG', 1)]

# %% [markdown]
# ## Evaluate mentions

# %%
def eval_pred_mentions(preds, gold_mentions, gold_sents, drop_from_pred=[], drop_from_gold=[]):
    #print(preds_path)
    pred_sents_l = [[i, list(zip(toks, bs))] 
                    for i, (toks, bs) 
                    in zip(gold_sents.index.drop(drop_from_gold), (zip(preds[0][2], preds[0][3]))) 
                    if i not in drop_from_pred]
    toks = [[tok for tok, bs in p[1]] for p in pred_sents_l]
    def subfinder(mylist, pattern):
        matches = []
        for i in range(len(mylist)):
            if mylist[i] == pattern[0] and mylist[i:i+len(pattern)] == pattern:
                matches.append(pattern)
        return matches

    split_mentions = [[x[1].split(' ') for x in gold_mentions if x[0]==i] 
                      for i in gold_sents.index.drop(drop_from_gold)
                      if i not in drop_from_gold]
    present = []
    for spl, tok in zip(split_mentions, toks):
        mid = []
        for ment in spl:
            mid.append(len(subfinder(tok, ment))>0)
        present.append(sum(mid))
    print([(i, x) for i, x in enumerate(zip(present, [len(spl) for spl in split_mentions])) if x[1]-x[0]>=2])
    #print(toks[231])
    print ('only', round(sum(present)/len(gold_mentions), 2), 'available mentions (due to different segmentation)')
    pred_sents = pd.Series(index=[idx for idx, s in pred_sents_l], data=[s for idx, s in pred_sents_l])
    pred_mentions = nem.sents_to_mentions(pred_sents)
    return nem.evaluate_mentions(gold_mentions, pred_mentions)

# %% [markdown]
# ### Evaluate morphemes

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
morph_gold_sents = (o_morph_gold_test_sents, o_morph_gold_dev_sents, o_morph_gold_test_sents)
morph_gold_extra_preds = (morph_gold_test_mentions, morph_gold_dev_mentions, morph_gold_test_mentions)
pred_set = ('gold_test', 'yap_dev', 'yap_test')
drop_from_pred = ([dropped], [], [])
drop_from_gold = ([], [], dropped)
morph_res = []
for ep in sorted(glob.glob('results/new_outputs/*morph*-extra_preds-*')):
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), morph_gold_extra_preds[i], morph_gold_sents[i], drop_from_pred[i], drop_from_gold[i])]
    morph_res.append(res)
# Out:
# results/new_outputs/treebank_morphemes-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 764 found, 395 correct.
# Precision: 0.42
# Recall:    0.52
# F1:        0.47
# FP ex.: ['חסילונים מורתחים', 'נוורסון צלפו', 'הרצליה', 'ברית ה מועצות', 'ניו יורק']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes-0-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 368 found, 181 correct.
# Precision: 0.36
# Recall:    0.49
# F1:        0.42
# FP ex.: ['ה שדולה ה פרו', 'קרן ה מדע', 'טקסס', 'ירושלים', 'אסמי ה דגנים']
# FN ex.: ['רשות שדות ה תעופה', 'ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'שירות ה תעסוקה']
# results/new_outputs/treebank_morphemes-0-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 713 found, 340 correct.
# Precision: 0.37
# Recall:    0.48
# F1:        0.41
# FP ex.: ['נוורסון צלפו', 'הרצליה', 'ברית ה מועצות', 'ניו יורק', 'פירורי לחם מתובלים']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 961 found, 541 correct.
# Precision: 0.58
# Recall:    0.56
# F1:        0.57
# FP ex.: ['דן', 'ספורטינג', 'הרצליה', 'קלניניגרד תיירות', 'וולגה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes-1-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 448 found, 227 correct.
# Precision: 0.46
# Recall:    0.51
# F1:        0.48
# FP ex.: ['גאנט', 'ירושלים', 'אבידוב', 'קרן גון', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'שירות ה תעסוקה', 'דווייט מקדונלד']
# results/new_outputs/treebank_morphemes-1-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 849 found, 395 correct.
# Precision: 0.42
# Recall:    0.47
# F1:        0.44
# FP ex.: ['ספורטינג', 'הרצליה', 'קלניניגרד תיירות', 'ד שמעון', 'וולגה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 908 found, 697 correct.
# Precision: 0.75
# Recall:    0.77
# F1:        0.76
# FP ex.: ['צומת', 'נצרת עילית', 'טאקומה', 'קפיאס', 'ה אירופי ל מחזיקות גביע']
# FN ex.: ['פרגו', 'באירה מאר', 'ראן', 'גיילס', 'ה וועדה ל מינוי שופטים']
# results/new_outputs/treebank_morphemes-10-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 413 found, 306 correct.
# Precision: 0.61
# Recall:    0.74
# F1:        0.67
# FP ex.: ['גאנט', 'בקליפורניה', 'ירושלים', 'אבידוב', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes-10-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 822 found, 559 correct.
# Precision: 0.6
# Recall:    0.68
# F1:        0.64
# FP ex.: ['לסמפדוריה', 'צומת', 'ה איטליה', 'נצרת עילית', 'קפיאס']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 938 found, 714 correct.
# Precision: 0.77
# Recall:    0.76
# F1:        0.76
# FP ex.: ['קפיאס', 'אמאדורה', 'כפר בלום', 'פטוציני אלפרדו', 'צומת']
# FN ex.: ['פרגו', 'באירה מאר', 'גיילס', 'ה וועדה ל מינוי שופטים', 'רשף נכסים']
# results/new_outputs/treebank_morphemes-11-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 420 found, 306 correct.
# Precision: 0.61
# Recall:    0.73
# F1:        0.67
# FP ex.: ['גאנט', 'פומפידו', 'בקליפורניה', 'ירושלים', 'אבידוב']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# results/new_outputs/treebank_morphemes-11-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 833 found, 573 correct.
# Precision: 0.62
# Recall:    0.69
# F1:        0.65
# FP ex.: ['ה הרצליה', 'ה גליל', 'לסמפדוריה', 'קפיאס', 'אן באסטן']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'רוברטו באגו']
# results/new_outputs/treebank_morphemes-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 874 found, 645 correct.
# Precision: 0.69
# Recall:    0.74
# F1:        0.71
# FP ex.: ['נשיפה', 'צומת', 'ראגו עגל', 'טאקומה', 'נצרת עילית']
# FN ex.: ['שפיים', 'פרגו', 'באירה מאר', 'ויאלי', 'ה וועדה ל מינוי שופטים']
# results/new_outputs/treebank_morphemes-2-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 450 found, 313 correct.
# Precision: 0.63
# Recall:    0.7
# F1:        0.66
# FP ex.: ['קרן ה מדע', 'גאנט', 'יטמן', 'לימים', 'ירושלים']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes-2-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 845 found, 560 correct.
# Precision: 0.6
# Recall:    0.66
# F1:        0.63
# FP ex.: ['חומי עור', 'ה גליל', 'צומת', 'נשיפה', 'באשדוד']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 979 found, 650 correct.
# Precision: 0.7
# Recall:    0.66
# F1:        0.68
# FP ex.: ['ראגו עגל', 'קימצו', 'נצרת עילית', 'קפיאס', 'אמאדורה']
# FN ex.: ['פרגו', 'באירה מאר', 'ה וועדה ל מינוי שופטים', 'רשף נכסים', 'ת"א']
# results/new_outputs/treebank_morphemes-3-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 484 found, 314 correct.
# Precision: 0.63
# Recall:    0.65
# F1:        0.64
# FP ex.: ['גאנט', 'יטמן', 'אינטלקטואל רודני', 'לימים', 'ירושלים']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "']
# results/new_outputs/treebank_morphemes-3-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 952 found, 550 correct.
# Precision: 0.59
# Recall:    0.58
# F1:        0.58
# FP ex.: ['קימצו', 'קנטור', 'כללותה', 'הרצליה', 'הלן']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'רוברטו באגו']
# results/new_outputs/treebank_morphemes-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 899 found, 684 correct.
# Precision: 0.73
# Recall:    0.76
# F1:        0.75
# FP ex.: ['ה נסיכויות ה מאוחדות', 'טאקומה', 'קפיאס', 'אמאדורה', 'כפר בלום']
# FN ex.: ['שפיים', 'פרגו', 'באירה מאר', 'ה וועדה ל מינוי שופטים', 'מוצי']
# results/new_outputs/treebank_morphemes-4-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 417 found, 303 correct.
# Precision: 0.61
# Recall:    0.73
# F1:        0.66
# FP ex.: ['מעמקי ה מערב ה תיכון', 'בקליפורניה', 'ירושלים', 'אבידוב', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes-4-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 784 found, 545 correct.
# Precision: 0.59
# Recall:    0.7
# F1:        0.64
# FP ex.: ['ה נסיכויות ה מאוחדות', 'ה גליל', 'קפיאס', 'אן באסטן', 'כפר בלום']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 913 found, 691 correct.
# Precision: 0.74
# Recall:    0.76
# F1:        0.75
# FP ex.: ['ה לשכה ו ראשי ה וועדים ה מחוזיים', 'ראגו עגל', 'טאקומה', 'נאגטס', 'פינת אלנבי']
# FN ex.: ['ה וועדה ל מינוי שופטים', 'רשף נכסים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'ה מינהל']
# results/new_outputs/treebank_morphemes-5-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 411 found, 310 correct.
# Precision: 0.62
# Recall:    0.75
# F1:        0.68
# FP ex.: ['גאנט', 'ירושלים', 'אבידוב', 'שיקאגו', 'גורג']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes-5-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 793 found, 543 correct.
# Precision: 0.58
# Recall:    0.68
# F1:        0.63
# FP ex.: ['ה לשכה ו ראשי ה וועדים ה מחוזיים', 'ה גליל', 'לסמפדוריה', 'באשדוד', 'פינת אלנבי']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 863 found, 482 correct.
# Precision: 0.52
# Recall:    0.56
# F1:        0.54
# FP ex.: ['נגמר', 'נוורסון צלפו', 'כפר בלום', 'קנטור', 'קוויאר']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes-6-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 392 found, 208 correct.
# Precision: 0.42
# Recall:    0.53
# F1:        0.47
# FP ex.: ['איובה שילמה', 'מרכז ה וועידות', 'לימים', 'גורג ה מסכן', 'ירושלים']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'שירות ה תעסוקה', 'קרן מקארתור']
# results/new_outputs/treebank_morphemes-6-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 830 found, 403 correct.
# Precision: 0.43
# Recall:    0.49
# F1:        0.46
# FP ex.: ['נגמר', 'נוורסון צלפו', 'כפר בלום', 'קנטור', 'הרצליה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 959 found, 593 correct.
# Precision: 0.64
# Recall:    0.62
# F1:        0.63
# FP ex.: ['ה תקנים', 'בן - סרוק', 'כפר בלום', 'הרצליה', 'פונגי אלה - קרמה']
# FN ex.: ['שפיים', 'פרגו', 'באירה מאר', 'ה וועדה ל מינוי שופטים', 'קישינב']
# results/new_outputs/treebank_morphemes-7-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 434 found, 242 correct.
# Precision: 0.49
# Recall:    0.56
# F1:        0.52
# FP ex.: ['טקסס', 'ירושלים', 'אבידוב', 'שיקאגו', 'הראל']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'שירות ה תעסוקה', 'קרן מקארתור']
# results/new_outputs/treebank_morphemes-7-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 841 found, 449 correct.
# Precision: 0.48
# Recall:    0.53
# F1:        0.51
# FP ex.: ['ה תקנים', 'הרצליה', 'ה אירופה', 'סאברס', 'ניו יורק']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 829 found, 646 correct.
# Precision: 0.69
# Recall:    0.78
# F1:        0.73
# FP ex.: ['צומת', 'ראגו עגל', 'טאקומה', 'נאגטס', 'אמאדורה']
# FN ex.: ['פרגו', 'באירה מאר', 'ויאלי', 'ה וועדה ל מינוי שופטים', 'מוצי']
# results/new_outputs/treebank_morphemes-8-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 396 found, 300 correct.
# Precision: 0.6
# Recall:    0.76
# F1:        0.67
# FP ex.: ['גאנט', 'יטמן', 'בקליפורניה', 'ירושלים', 'פורד']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'ה מלחמה ה קרה']
# results/new_outputs/treebank_morphemes-8-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 790 found, 560 correct.
# Precision: 0.6
# Recall:    0.71
# F1:        0.65
# FP ex.: ['באשדוד', 'נאגטס', 'אן באסטן', 'אמאדורה', 'ה מזרחי']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'רוברטו באגו']
# results/new_outputs/treebank_morphemes-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 866 found, 654 correct.
# Precision: 0.7
# Recall:    0.76
# F1:        0.73
# FP ex.: ['צומת', 'ראגו עגל', 'ה אירופי ל מחזיקות גביע', 'כפר בלום', 'אמאדורה']
# FN ex.: ['פרגו', 'באירה מאר', 'ראן', 'גיילס', 'ה וועדה ל מינוי שופטים']
# results/new_outputs/treebank_morphemes-9-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 412 found, 302 correct.
# Precision: 0.61
# Recall:    0.73
# F1:        0.66
# FP ex.: ['גאנט', 'אינטלקטואל רודני', 'בקליפורניה', 'לימים', 'ירושלים']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes-9-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 799 found, 546 correct.
# Precision: 0.59
# Recall:    0.68
# F1:        0.63
# FP ex.: ['ה גליל', 'בית - ה משפט ל ה ערעורים ידון', 'אן באסטן', 'כפר בלום', 'ה אירופי ל מחזיקות גביע']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'רוברטו באגו']

# %%
defaults = {"use_word": True, "use_pos": False, "embedding_matrix": None, 
"embed_dim": 70, "trainable": True, "input_dropout": False, "stack_lstm": 1,
"epochs": 100, "early_stopping": True, "patience": 20, "min_delta": 0.0001,
"use_char": False, "crf": False, "add_random_embedding": True, "pretrained_embed_dim": 300,
"stack_cross": False, "stack_double": False, "rec_dropout": 0.1,
"validation_split": 0.1}

# %%
morph_conf_gold_dev_res = pickle.load(open('results/new_outputs/treebank_morphemes_conf_res_preds_hist.pkl', 'rb'))
morph_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0] } for i, x in enumerate(morph_conf_gold_dev_res)]
morph_conf_gold_dev_res
# Out:
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False},
#   'results': (51.43603133159269, 39.558232931726906, 44.72190692395005)},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True},
#   'results': (51.01522842639594, 40.36144578313253, 45.06726457399103)},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (73.20675105485233, 69.67871485943775, 71.39917695473251)},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (69.5906432748538, 71.6867469879518, 70.62314540059347)},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (76.0, 57.22891566265061, 65.29209621993127)},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (75.74123989218329, 56.42570281124498, 64.67203682393557)},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False},
#   'results': (59.75, 47.99196787148594, 53.22939866369711)},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True},
#   'results': (55.989583333333336, 43.17269076305221, 48.75283446712018)},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (85.25, 68.47389558232932, 75.94654788418708)},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (79.21478060046189, 68.87550200803213, 73.68421052631578)},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (77.11171662125341, 56.827309236947784, 65.4335260115607)},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (76.8, 57.831325301204814, 65.97938144329896)}]

# %%
conf_i = {x['conf']: x['config'] for x in morph_conf_gold_dev_res}
for r in morph_res:
    r['config'] = conf_i[r['conf']]
    
morph_res = morph_res+morph_conf_gold_dev_res

# %%
for r in morph_res:
    r['unit'] = 'morpheme'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]
morph_res[0]
# Out:
# {'pred_set': 'gold_test',
#  'conf': 0,
#  'results': [42.42749731471536, 51.70157068062827, 46.60766961651917],
#  'config': {'crf': True,
#   'use_pos': False,
#   'use_word': True,
#   'embedding_matrix': None,
#   'embed_dim': 70,
#   'trainable': True,
#   'input_dropout': False,
#   'stack_lstm': 1,
#   'epochs': 100,
#   'early_stopping': True,
#   'patience': 20,
#   'min_delta': 0.0001,
#   'use_char': False,
#   'add_random_embedding': True,
#   'pretrained_embed_dim': 300,
#   'stack_cross': False,
#   'stack_double': False,
#   'rec_dropout': 0.1,
#   'validation_split': 0.1},
#  'unit': 'morpheme'}

# %%
def get_results_df(res):
    dict_res = []
    
    for r in res:
        dr = {}
        dr['pred_set'] = r['pred_set']
        dr['unit'] = r['unit']
        dr['prec'], dr['recall'], dr['f1'] = r['results']
        dr.update(r['config'])
        dict_res.append(dr)
    rdf = pd.DataFrame(dict_res)
    return rdf

rdf = get_results_df(morph_res)
rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  46.607670          False     0.0001        20  ...  51.701571
# 1     100  41.801386          False     0.0001        20  ...  49.184783
# 2     100  41.362530          False     0.0001        20  ...  47.685835
# 3     100  57.188161          False     0.0001        20  ...  56.295525
# 4     100  47.991543          False     0.0001        20  ...  50.669643
#
#   stack_cross  stack_double  stack_lstm  trainable      unit  use_char  \
# 0       False         False           1       True  morpheme     False
# 1       False         False           1       True  morpheme     False
# 2       False         False           1       True  morpheme     False
# 3       False         False           1       True  morpheme     False
# 4       False         False           1       True  morpheme     False
#
#    use_pos  use_word validation_split
# 0    False      True              0.1
# 1    False      True              0.1
# 2    False      True              0.1
# 3     True      True              0.1
# 4     True      True              0.1
#
# [5 rows x 24 columns]

# %%
rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix']).f1.max().unstack()
# Out:
# embedding_matrix                 None  pretrained_token_ft  yap_ft_sg
# pred_set  use_pos use_char
# gold_dev  False   False     44.721907            70.623145  71.399177
#                   True      53.229399            73.684211  75.946548
#           True    False     45.067265            64.672037  65.292096
#                   True      48.752834            65.979381  65.433526
# gold_test False   False     46.607670            68.062827  71.468144
#                   True      53.734671            72.787980  73.409091
#           True    False     57.188161            74.945770  74.754098
#                   True      62.751323            76.404494  75.802066
# yap_dev   False   False     41.801386            63.951120  66.033755
#                   True      46.741573            66.373626  67.114094
#           True    False     47.991543            68.206821  66.229508
#                   True      51.931330            66.666667  67.178924
# yap_test  False   False     41.362530            58.417419  63.063063
#                   True      45.769449            63.121387  65.078443
#           True    False     44.382022            62.993039  63.556851
#                   True      50.677201            64.965986  63.776383

# %% [markdown]
# ### Evaluate tokens

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
tok_gold_sents = (tok_gold_test_sents, tok_gold_dev_sents, tok_gold_test_sents)
tok_gold_extra_preds = (tok_gold_test_mentions, tok_gold_dev_mentions, tok_gold_test_mentions)
pred_set = ('gold_test', 'yap_dev', 'yap_test')

tok_res = []
for ep in sorted(glob.glob('results/new_outputs/*tokens*-extra_preds-*')):
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), tok_gold_extra_preds[i], tok_gold_sents[i])]
    tok_res.append(res)
# Out:
# results/new_outputs/treebank_tokens-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 877 found, 332 correct.
# Precision: 0.36
# Recall:    0.38
# F1:        0.37
# FP ex.: ['רמת השרון', 'נגמר', 'יעקב', 'הלאומים', 'ד שמעון']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'מייקל האקט']
# results/new_outputs/treebank_tokens-0-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 442 found, 178 correct.
# Precision: 0.36
# Recall:    0.4
# F1:        0.38
# FP ex.: ['מיניאפוליס', 'והניירות המונפקים', 'בשטחים', 'סמית - ריצרדסון', 'התבוננתי']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'בקליפורניה', 'סילבר']
# results/new_outputs/treebank_tokens-0-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 877 found, 332 correct.
# Precision: 0.36
# Recall:    0.38
# F1:        0.37
# FP ex.: ['רמת השרון', 'נגמר', 'יעקב', 'הלאומים', 'ד שמעון']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'מייקל האקט']
# results/new_outputs/treebank_tokens-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 906 found, 484 correct.
# Precision: 0.52
# Recall:    0.53
# F1:        0.53
# FP ex.: ['רמת השרון', 'בשלל אפקטים', 'דייזי', 'בבלוטות תימוס', 'ניו יורק']
# FN ex.: ['פרגו', 'לסמפדוריה', 'בוסטון סלטיקס', 'דזידרי', 'לה קוצינה']
# results/new_outputs/treebank_tokens-1-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 423 found, 224 correct.
# Precision: 0.45
# Recall:    0.53
# F1:        0.49
# FP ex.: ['במפרץ הפרסי', 'טקסס', 'מניו', 'מקארתור', 'פוליטים']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'בקליפורניה']
# results/new_outputs/treebank_tokens-1-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 823 found, 413 correct.
# Precision: 0.44
# Recall:    0.5
# F1:        0.47
# FP ex.: ['רמת השרון', 'בשלל אפקטים', 'הקרמלין', 'דייזי', 'פלר']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'רוברטו באגו']
# results/new_outputs/treebank_tokens-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 962 found, 675 correct.
# Precision: 0.73
# Recall:    0.7
# F1:        0.71
# FP ex.: ['פינת אלנבי', 'פטוציני אלפרדו', 'אמאדורה', 'וינה', 'ארגון מטרייה']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'למינהל', 'המינהל']
# results/new_outputs/treebank_tokens-10-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 448 found, 350 correct.
# Precision: 0.7
# Recall:    0.78
# F1:        0.74
# FP ex.: ['גאנט', 'פומפידו', 'סן סימון', 'מסצוסטס', 'הראל']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'סילבר']
# results/new_outputs/treebank_tokens-10-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 893 found, 623 correct.
# Precision: 0.67
# Recall:    0.7
# F1:        0.68
# FP ex.: ['פינת אלנבי', 'פטוציני אלפרדו', 'מינוס', 'אמאדורה', 'וינה']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'למינהל']
# results/new_outputs/treebank_tokens-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 970 found, 684 correct.
# Precision: 0.73
# Recall:    0.71
# F1:        0.72
# FP ex.: ['רמת השרון', 'פינת אלנבי', 'טרטוריה', 'קפיאס', 'אמאדורה']
# FN ex.: ['פרגו', 'באירה מאר', 'המינהל', 'רוסיה', 'בוסטון סלטיקס']
# results/new_outputs/treebank_tokens-11-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 457 found, 334 correct.
# Precision: 0.67
# Recall:    0.73
# F1:        0.7
# FP ex.: ['גאנט', 'פומפידו', 'גורג המסכן', 'ריצארדס', 'מסצוסטס']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'סילבר']
# results/new_outputs/treebank_tokens-11-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 914 found, 633 correct.
# Precision: 0.68
# Recall:    0.69
# F1:        0.69
# FP ex.: ['רמת השרון', 'פינת אלנבי', 'טרטוריה', 'קפיאס', 'אמאדורה']
# FN ex.: ['פרגו', 'הסאנס', 'גיילס', 'המינהל', 'ת"א']
# results/new_outputs/treebank_tokens-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 772 found, 546 correct.
# Precision: 0.59
# Recall:    0.71
# F1:        0.64
# FP ex.: ['רמת השרון', 'ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'וינה']
# FN ex.: ['פרגו', 'ת"א', 'ובית - המשפט העליון', 'דזידרי', 'לה קוצינה']
# results/new_outputs/treebank_tokens-2-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 382 found, 311 correct.
# Precision: 0.62
# Recall:    0.81
# F1:        0.71
# FP ex.: ['הבריקה', 'הארץ', 'גאנט', 'פומפידו', 'לינד']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המלחמה', 'בשירות התעסוקה']
# results/new_outputs/treebank_tokens-2-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 772 found, 546 correct.
# Precision: 0.59
# Recall:    0.71
# F1:        0.64
# FP ex.: ['רמת השרון', 'ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'וינה']
# FN ex.: ['פרגו', 'ת"א', 'ובית - המשפט העליון', 'דזידרי', 'לה קוצינה']
# results/new_outputs/treebank_tokens-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 872 found, 596 correct.
# Precision: 0.64
# Recall:    0.68
# F1:        0.66
# FP ex.: ['ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'אחים נחום', 'וינה']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'הכשרת הישוב']
# results/new_outputs/treebank_tokens-3-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 450 found, 325 correct.
# Precision: 0.65
# Recall:    0.72
# F1:        0.68
# FP ex.: ['מסצוסטס', 'ובשוטרים', 'מקארתור', 'באנחה', 'חטיבת " הראל']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'סילבר']
# results/new_outputs/treebank_tokens-3-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 872 found, 596 correct.
# Precision: 0.64
# Recall:    0.68
# F1:        0.66
# FP ex.: ['ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'אחים נחום', 'וינה']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'הכשרת הישוב']
# results/new_outputs/treebank_tokens-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 976 found, 685 correct.
# Precision: 0.74
# Recall:    0.7
# F1:        0.72
# FP ex.: ['פינת אלנבי', 'דן', 'אנגלו סקסון פיתוח', 'קפיאס', 'אמאדורה']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'המינהל']
# results/new_outputs/treebank_tokens-4-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 484 found, 345 correct.
# Precision: 0.69
# Recall:    0.71
# F1:        0.7
# FP ex.: ['גאנט', 'פומפידו', 'פוליטים', 'חטיבת " הראל', 'יונה']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'סילבר', 'המלחמה']
# results/new_outputs/treebank_tokens-4-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 932 found, 637 correct.
# Precision: 0.68
# Recall:    0.68
# F1:        0.68
# FP ex.: ['פינת אלנבי', 'המדור', 'קפיאס', 'מינוס', 'אמאדורה']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'המינהל']
# results/new_outputs/treebank_tokens-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 935 found, 658 correct.
# Precision: 0.71
# Recall:    0.7
# F1:        0.71
# FP ex.: ['ראגו עגל', 'דן', 'פינת אלנבי', 'קפיאס', 'אמאדורה']
# FN ex.: ['פרגו', 'באירה מאר', 'גיילס', 'הכשרת הישוב', 'המינהל']
# results/new_outputs/treebank_tokens-5-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 442 found, 326 correct.
# Precision: 0.65
# Recall:    0.74
# F1:        0.69
# FP ex.: ['גאנט', 'פומפידו', 'ריצארדס', 'מסצוסטס', 'מקארתור']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'סילבר']
# results/new_outputs/treebank_tokens-5-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 858 found, 608 correct.
# Precision: 0.65
# Recall:    0.71
# F1:        0.68
# FP ex.: ['פינת אלנבי', 'קפיאס', 'מינוס', 'אמאדורה', 'פטוציני אלפרדו']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'הכשרת הישוב']
# results/new_outputs/treebank_tokens-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 656 found, 349 correct.
# Precision: 0.37
# Recall:    0.53
# F1:        0.44
# FP ex.: ['ארליך', 'משפט השלום', 'עו', 'פינת אלנבי', 'לאט']
# FN ex.: ['פרגו', 'לסמפדוריה', 'בוסטון', 'בוסטון סלטיקס', 'מייקל האקט']
# results/new_outputs/treebank_tokens-6-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 338 found, 186 correct.
# Precision: 0.37
# Recall:    0.55
# F1:        0.44
# FP ex.: ['טקסס', 'סמית - ריצרדסון', 'איתן', 'סקרים', 'למושל']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'ויליאם וולד']
# results/new_outputs/treebank_tokens-6-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 656 found, 349 correct.
# Precision: 0.37
# Recall:    0.53
# F1:        0.44
# FP ex.: ['ארליך', 'משפט השלום', 'עו', 'פינת אלנבי', 'לאט']
# FN ex.: ['פרגו', 'לסמפדוריה', 'בוסטון', 'בוסטון סלטיקס', 'מייקל האקט']
# results/new_outputs/treebank_tokens-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 862 found, 501 correct.
# Precision: 0.54
# Recall:    0.58
# F1:        0.56
# FP ex.: ['רמת השרון', 'דייזי', 'הצפון - מזרחי', 'סאברס', 'ניו יורק']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'ובית - המשפט העליון']
# results/new_outputs/treebank_tokens-7-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 411 found, 239 correct.
# Precision: 0.48
# Recall:    0.58
# F1:        0.53
# FP ex.: ['טקסס', 'גאנט', 'פורד', 'לנקובסקי', 'פוליטים']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'בקליפורניה']
# results/new_outputs/treebank_tokens-7-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 777 found, 425 correct.
# Precision: 0.46
# Recall:    0.55
# F1:        0.5
# FP ex.: ['רמת השרון', 'ל"ספורט הארץ', 'דייזי', 'לפארמה', 'קורוואזיה']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'ובית - המשפט העליון']
# results/new_outputs/treebank_tokens-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 854 found, 641 correct.
# Precision: 0.69
# Recall:    0.75
# F1:        0.72
# FP ex.: ['פינת אלנבי', 'טרטוריה', 'אמאדורה', 'משיוויון', 'ו"ייצגו']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'למינהל', 'המינהל']
# results/new_outputs/treebank_tokens-8-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 398 found, 321 correct.
# Precision: 0.64
# Recall:    0.81
# F1:        0.72
# FP ex.: ['סנאטור', 'רצח הנזירות', 'אילת', 'דלאנו רוזוולט', 'לינד']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'קרן מקארתור']
# results/new_outputs/treebank_tokens-8-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 854 found, 641 correct.
# Precision: 0.69
# Recall:    0.75
# F1:        0.72
# FP ex.: ['פינת אלנבי', 'טרטוריה', 'אמאדורה', 'משיוויון', 'ו"ייצגו']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'למינהל', 'המינהל']
# results/new_outputs/treebank_tokens-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 829 found, 610 correct.
# Precision: 0.66
# Recall:    0.74
# F1:        0.69
# FP ex.: ['רמת השרון', 'יהודית', 'פינת אלנבי', 'טרטוריה', 'וקוטגים']
# FN ex.: ['פרגו', 'ויאלי', 'הסאנס', 'גיילס', 'הכשרת הישוב']
# results/new_outputs/treebank_tokens-9-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 412 found, 322 correct.
# Precision: 0.65
# Recall:    0.78
# F1:        0.71
# FP ex.: ['גאנט', 'ואיה', 'מקסיקאיים', 'מסצוסטס', 'הראל']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'קרן מקארתור']
# results/new_outputs/treebank_tokens-9-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 829 found, 610 correct.
# Precision: 0.66
# Recall:    0.74
# F1:        0.69
# FP ex.: ['רמת השרון', 'יהודית', 'פינת אלנבי', 'טרטוריה', 'וקוטגים']
# FN ex.: ['פרגו', 'ויאלי', 'הסאנס', 'גיילס', 'הכשרת הישוב']

# %%
tok_res
# Out:
# [{'pred_set': 'gold_test',
#   'conf': 0,
#   'results': [35.660580021482275, 37.8563283922463, 36.725663716814154]},
#  {'pred_set': 'yap_dev',
#   'conf': 0,
#   'results': [35.671342685370746, 40.27149321266968, 37.832093517534545]},
#  {'pred_set': 'yap_test',
#   'conf': 0,
#   'results': [35.660580021482275, 37.8563283922463, 36.725663716814154]},
#  {'pred_set': 'gold_test',
#   'conf': 1,
#   'results': [51.98711063372718, 53.42163355408388, 52.694610778443106]},
#  {'pred_set': 'yap_dev',
#   'conf': 1,
#   'results': [44.88977955911824, 52.95508274231678, 48.59002169197397]},
#  {'pred_set': 'yap_test',
#   'conf': 1,
#   'results': [44.3609022556391, 50.18226002430134, 47.092360319270234]},
#  {'pred_set': 'gold_test',
#   'conf': 10,
#   'results': [72.50268528464017, 70.16632016632016, 71.31537242472267]},
#  {'pred_set': 'yap_dev',
#   'conf': 10,
#   'results': [70.14028056112225, 78.125, 73.91763463569167]},
#  {'pred_set': 'yap_test',
#   'conf': 10,
#   'results': [66.9172932330827, 69.76483762597985, 68.31140350877193]},
#  {'pred_set': 'gold_test',
#   'conf': 11,
#   'results': [73.46938775510205, 70.51546391752578, 71.9621251972646]},
#  {'pred_set': 'yap_dev',
#   'conf': 11,
#   'results': [66.93386773547094, 73.08533916849015, 69.8744769874477]},
#  {'pred_set': 'yap_test',
#   'conf': 11,
#   'results': [67.99140708915145, 69.25601750547045, 68.6178861788618]},
#  {'pred_set': 'gold_test',
#   'conf': 2,
#   'results': [58.64661654135338, 70.72538860103627, 64.12213740458014]},
#  {'pred_set': 'yap_dev',
#   'conf': 2,
#   'results': [62.32464929859719, 81.41361256544502, 70.60158910329172]},
#  {'pred_set': 'yap_test',
#   'conf': 2,
#   'results': [58.64661654135338, 70.72538860103627, 64.12213740458014]},
#  {'pred_set': 'gold_test',
#   'conf': 3,
#   'results': [64.0171858216971, 68.34862385321101, 66.1120354963949]},
#  {'pred_set': 'yap_dev',
#   'conf': 3,
#   'results': [65.13026052104209, 72.22222222222221, 68.4931506849315]},
#  {'pred_set': 'yap_test',
#   'conf': 3,
#   'results': [64.0171858216971, 68.34862385321101, 66.1120354963949]},
#  {'pred_set': 'gold_test',
#   'conf': 4,
#   'results': [73.57679914070891, 70.1844262295082, 71.84058730991086]},
#  {'pred_set': 'yap_dev',
#   'conf': 4,
#   'results': [69.13827655310621, 71.28099173553719, 70.19328585961343]},
#  {'pred_set': 'yap_test',
#   'conf': 4,
#   'results': [68.42105263157895, 68.34763948497854, 68.38432635534085]},
#  {'pred_set': 'gold_test',
#   'conf': 5,
#   'results': [70.67669172932331, 70.37433155080214, 70.5251875669882]},
#  {'pred_set': 'yap_dev',
#   'conf': 5,
#   'results': [65.33066132264528, 73.7556561085973, 69.28799149840596]},
#  {'pred_set': 'yap_test',
#   'conf': 5,
#   'results': [65.3061224489796, 70.86247086247086, 67.9709334823924]},
#  {'pred_set': 'gold_test',
#   'conf': 6,
#   'results': [37.486573576799145, 53.20121951219512, 43.982356647763076]},
#  {'pred_set': 'yap_dev',
#   'conf': 6,
#   'results': [37.27454909819639, 55.02958579881657, 44.44444444444444]},
#  {'pred_set': 'yap_test',
#   'conf': 6,
#   'results': [37.486573576799145, 53.20121951219512, 43.982356647763076]},
#  {'pred_set': 'gold_test',
#   'conf': 7,
#   'results': [53.81310418904404, 58.12064965197216, 55.88399330730619]},
#  {'pred_set': 'yap_dev',
#   'conf': 7,
#   'results': [47.89579158316633, 58.15085158150851, 52.52747252747252]},
#  {'pred_set': 'yap_test',
#   'conf': 7,
#   'results': [45.64983888292159, 54.69755469755469, 49.765807962529266]},
#  {'pred_set': 'gold_test',
#   'conf': 8,
#   'results': [68.85069817400644, 75.05854800936767, 71.82072829131653]},
#  {'pred_set': 'yap_dev',
#   'conf': 8,
#   'results': [64.32865731462925, 80.65326633165829, 71.57190635451506]},
#  {'pred_set': 'yap_test',
#   'conf': 8,
#   'results': [68.85069817400644, 75.05854800936767, 71.82072829131653]},
#  {'pred_set': 'gold_test',
#   'conf': 9,
#   'results': [65.52094522019334, 73.58262967430639, 69.31818181818183]},
#  {'pred_set': 'yap_dev',
#   'conf': 9,
#   'results': [64.52905811623246, 78.15533980582524, 70.69154774972557]},
#  {'pred_set': 'yap_test',
#   'conf': 9,
#   'results': [65.52094522019334, 73.58262967430639, 69.31818181818183]}]

# %%
tok_conf_gold_dev_res = pickle.load(open('results/new_outputs/treebank_tokens_conf_res_preds_hist.pkl', 'rb'))
tok_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0] } for i, x in enumerate(tok_conf_gold_dev_res)]
tok_conf_gold_dev_res
# Out:
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False},
#   'results': (38.146551724137936, 35.47094188376754, 36.7601246105919)},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True},
#   'results': (51.25858123569794, 44.88977955911824, 47.863247863247864)},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (75.66265060240964, 62.925851703406806, 68.7089715536105)},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (67.56756756756756, 65.13026052104209, 66.32653061224488)},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (67.44639376218323, 69.33867735470942, 68.3794466403162)},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (69.29637526652452, 65.13026052104209, 67.14876033057851)},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False},
#   'results': (53.31412103746398, 37.07414829659319, 43.73522458628841)},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True},
#   'results': (57.45192307692307, 47.89579158316633, 52.24043715846993)},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (76.97841726618705, 64.32865731462925, 70.08733624454148)},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (74.31192660550458, 64.92985971943888, 69.30481283422459)},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (75.6989247311828, 70.54108216432866, 73.02904564315352)},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (71.15384615384616, 66.73346693386773, 68.8728024819028)}]

# %%
conf_i = {x['conf']: x['config'] for x in tok_conf_gold_dev_res}
for r in tok_res:
    r['config'] = conf_i[r['conf']]
    
tok_res = tok_res+tok_conf_gold_dev_res

# %%
for r in tok_res:
    r['unit'] = 'token'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]

# %%
tok_res[0]
# Out:
# {'pred_set': 'gold_test',
#  'conf': 0,
#  'results': [35.660580021482275, 37.8563283922463, 36.725663716814154],
#  'config': {'crf': True,
#   'use_pos': False,
#   'use_word': True,
#   'embedding_matrix': None,
#   'embed_dim': 70,
#   'trainable': True,
#   'input_dropout': False,
#   'stack_lstm': 1,
#   'epochs': 100,
#   'early_stopping': True,
#   'patience': 20,
#   'min_delta': 0.0001,
#   'use_char': False,
#   'add_random_embedding': True,
#   'pretrained_embed_dim': 300,
#   'stack_cross': False,
#   'stack_double': False,
#   'rec_dropout': 0.1,
#   'validation_split': 0.1},
#  'unit': 'token'}

# %%
tok_rdf = get_results_df(tok_res)
tok_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  36.725664          False     0.0001        20  ...  37.856328
# 1     100  37.832094          False     0.0001        20  ...  40.271493
# 2     100  36.725664          False     0.0001        20  ...  37.856328
# 3     100  52.694611          False     0.0001        20  ...  53.421634
# 4     100  48.590022          False     0.0001        20  ...  52.955083
#
#   stack_cross  stack_double  stack_lstm  trainable   unit  use_char  use_pos  \
# 0       False         False           1       True  token     False    False
# 1       False         False           1       True  token     False    False
# 2       False         False           1       True  token     False    False
# 3       False         False           1       True  token     False     True
# 4       False         False           1       True  token     False     True
#
#    use_word validation_split
# 0      True              0.1
# 1      True              0.1
# 2      True              0.1
# 3      True              0.1
# 4      True              0.1
#
# [5 rows x 24 columns]

# %%
rdf = pd.concat([rdf,tok_rdf])

# %%
rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix               None       pretrained_token_ft        \
# unit                       morpheme token            morpheme token
# pred_set  use_pos use_char
# gold_dev  False   False        44.7  36.8                70.6  66.3
#                   True         53.2  43.7                73.7  69.3
#           True    False        45.1  47.9                64.7  67.1
#                   True         48.8  52.2                66.0  68.9
# gold_test False   False        46.6  36.7                68.1  66.1
#                   True         53.7  44.0                72.8  69.3
#           True    False        57.2  52.7                74.9  70.5
#                   True         62.8  55.9                76.4  72.0
# yap_dev   False   False        41.8  37.8                64.0  68.5
#                   True         46.7  44.4                66.4  70.7
#           True    False        48.0  48.6                68.2  69.3
#                   True         51.9  52.5                66.7  69.9
# yap_test  False   False        41.4  36.7                58.4  66.1
#                   True         45.8  44.0                63.1  69.3
#           True    False        44.4  47.1                63.0  68.0
#                   True         50.7  49.8                65.0  68.6
#
# embedding_matrix           token_ft_sg yap_ft_sg
# unit                             token  morpheme
# pred_set  use_pos use_char
# gold_dev  False   False           68.7      71.4
#                   True            70.1      75.9
#           True    False           68.4      65.3
#                   True            73.0      65.4
# gold_test False   False           64.1      71.5
#                   True            71.8      73.4
#           True    False           71.8      74.8
#                   True            71.3      75.8
# yap_dev   False   False           70.6      66.0
#                   True            71.6      67.1
#           True    False           70.2      66.2
#                   True            73.9      67.2
# yap_test  False   False           64.1      63.1
#                   True            71.8      65.1
#           True    False           68.4      63.6
#                   True            68.3      63.8

# %% [markdown]
# ### Evaluate morphemes fixed

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
morph_fixed_gold_sents = (morph_gold_test_sents, morph_gold_dev_sents, morph_gold_test_sents)
pred_set = ('gold_test', 'yap_dev', 'yap_test')

morph_fixed_res = []
for ep in sorted(glob.glob('results/new_outputs/*morphemes_fixed*-extra_preds-*')):
    print(ep)
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), morph_gold_extra_preds[i], morph_fixed_gold_sents[i])]
    morph_fixed_res.append(res)
# Out:
# results/new_outputs/treebank_morphemes_fixed-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 843 found, 438 correct.
# Precision: 0.47
# Recall:    0.52
# F1:        0.49
# FP ex.: ['בית ה משפט ה מחוזי ב נצרת', 'בושלו', 'כפר בלום', 'רגשנית', 'הרצליה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed-0-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 400 found, 184 correct.
# Precision: 0.37
# Recall:    0.46
# F1:        0.41
# FP ex.: ['אינטלקטואל רודני', 'אסמי ה דגנים', 'מג"ב חשו אל', 'קטמון נפלה', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'שירות ה תעסוקה', 'דווייט מקדונלד']
# results/new_outputs/treebank_morphemes_fixed-0-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 804 found, 360 correct.
# Precision: 0.39
# Recall:    0.45
# F1:        0.41
# FP ex.: ['בית ה משפט ה מחוזי ב נצרת', 'בושלו', 'רגשנית', 'הרצליה', 'פונגי אלה - קרמה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 939 found, 572 correct.
# Precision: 0.61
# Recall:    0.61
# F1:        0.61
# FP ex.: ['ה תקנים', 'בית ה משפט ה מחוזי ב נצרת', 'דן', 'ספורטינג', 'הרצליה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed-1-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 425 found, 230 correct.
# Precision: 0.46
# Recall:    0.54
# F1:        0.5
# FP ex.: ['טקסס', 'ירושלים', 'אבידוב', 'שיקאגו', 'הראל']
# FN ex.: ['רשות שדות ה תעופה', 'ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'שירות ה תעסוקה']
# results/new_outputs/treebank_morphemes_fixed-1-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 824 found, 413 correct.
# Precision: 0.44
# Recall:    0.5
# F1:        0.47
# FP ex.: ['ה תקנים', 'ספורטינג', 'הרצליה', 'ד שמעון', 'וולגה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 859 found, 669 correct.
# Precision: 0.72
# Recall:    0.78
# F1:        0.75
# FP ex.: ['טאקומה', 'פטוציני אלפרדו', 'להחתימו', 'ה ארץ', 'הרצליה']
# FN ex.: ['פרגו', 'ויאלי', 'ה וועדה ל מינוי שופטים', 'סן אנטוניו', 'מוצי']
# results/new_outputs/treebank_morphemes_fixed-10-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 387 found, 301 correct.
# Precision: 0.6
# Recall:    0.78
# F1:        0.68
# FP ex.: ['קרן ה מדע', 'פומפידו', 'בקליפורניה', 'ירושלים', 'אבידוב']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# results/new_outputs/treebank_morphemes_fixed-10-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 751 found, 528 correct.
# Precision: 0.57
# Recall:    0.7
# F1:        0.63
# FP ex.: ['נצרת עילית', 'פטוציני אלפרדו', 'אן באסטן', 'הרצליה', 'הקליפרס']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 970 found, 719 correct.
# Precision: 0.77
# Recall:    0.74
# F1:        0.76
# FP ex.: ['ה לשכה ו ראשי ה וועדים ה מחוזיים', 'טאקומה', 'פטוציני אלפרדו', 'קפיאס', 'כפר בלום']
# FN ex.: ['פרגו', 'באירה מאר', 'גיילס', 'ה וועדה ל מינוי שופטים', 'ת"א']
# results/new_outputs/treebank_morphemes_fixed-11-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 449 found, 324 correct.
# Precision: 0.65
# Recall:    0.72
# F1:        0.68
# FP ex.: ['גאנט', 'בקליפורניה', 'ירושלים', 'אבידוב', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed-11-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 903 found, 581 correct.
# Precision: 0.62
# Recall:    0.64
# F1:        0.63
# FP ex.: ['ה לשכה ו ראשי ה וועדים ה מחוזיים', 'ה גליל', 'לסמפדוריה', 'צומת', 'באשדוד']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 911 found, 653 correct.
# Precision: 0.7
# Recall:    0.72
# F1:        0.71
# FP ex.: ['ראגו עגל', 'טאקומה', 'נאגטס', 'נצרת עילית', 'אמאדורה']
# FN ex.: ['שפיים', 'פרגו', 'באירה מאר', 'ויאלי', 'ראן']
# results/new_outputs/treebank_morphemes_fixed-2-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 454 found, 315 correct.
# Precision: 0.63
# Recall:    0.69
# F1:        0.66
# FP ex.: ['יטמן', 'בקליפורניה', 'ירושלים', 'אבידוב', 'איתן']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# results/new_outputs/treebank_morphemes_fixed-2-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 873 found, 565 correct.
# Precision: 0.61
# Recall:    0.65
# F1:        0.63
# FP ex.: ['ה גליל', 'בית - ה משפט ל ה ערעורים ידון', 'מזרח - ליטא לפולין', 'נצרת עילית', 'נאגטס']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 828 found, 628 correct.
# Precision: 0.67
# Recall:    0.76
# F1:        0.71
# FP ex.: ['ראגו עגל', 'טאקומה', 'נצרת עילית', 'אמאדורה', 'כפר בלום']
# FN ex.: ['שפיים', 'פרגו', 'ראן', 'ה וועדה ל מינוי שופטים', 'ת"א']
# results/new_outputs/treebank_morphemes_fixed-3-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 406 found, 305 correct.
# Precision: 0.61
# Recall:    0.75
# F1:        0.67
# FP ex.: ['גאנט', 'אינטלקטואל רודני', 'ירושלים', 'אבידוב', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed-3-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 787 found, 538 correct.
# Precision: 0.58
# Recall:    0.68
# F1:        0.63
# FP ex.: ['ה גליל', 'בית - ה משפט ל ה ערעורים ידון', 'נצרת עילית', 'אן באסטן', 'כפר בלום']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 951 found, 689 correct.
# Precision: 0.74
# Recall:    0.72
# F1:        0.73
# FP ex.: ['ה לשכה ו ראשי ה וועדים ה מחוזיים', 'צומת', 'טאקומה', 'פטוציני אלפרדו', 'להחתימו']
# FN ex.: ['שפיים', 'פרגו', 'באירה מאר', 'ה וועדה ל מינוי שופטים', 'מוצי']
# results/new_outputs/treebank_morphemes_fixed-4-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 449 found, 317 correct.
# Precision: 0.64
# Recall:    0.71
# F1:        0.67
# FP ex.: ['גאנט', 'בקליפורניה', 'ירושלים', 'אבידוב', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'ה מלחמה ה קרה', 'מענק " גאונות "']
# results/new_outputs/treebank_morphemes_fixed-4-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 873 found, 565 correct.
# Precision: 0.61
# Recall:    0.65
# F1:        0.63
# FP ex.: ['ה לשכה ו ראשי ה וועדים ה מחוזיים', 'ה גליל', 'צומת', 'בית - ה משפט ל ה ערעורים ידון', 'פטוציני אלפרדו']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 910 found, 681 correct.
# Precision: 0.73
# Recall:    0.75
# F1:        0.74
# FP ex.: ['ראגו עגל', 'טאקומה', 'קפיאס', 'אמאדורה', 'כפר בלום']
# FN ex.: ['פרגו', 'באירה מאר', 'גיילס', 'ה וועדה ל מינוי שופטים', 'סן אנטוניו']
# results/new_outputs/treebank_morphemes_fixed-5-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 404 found, 290 correct.
# Precision: 0.58
# Recall:    0.72
# F1:        0.64
# FP ex.: ['גאנט', 'בקליפורניה', 'ירושלים', 'אבידוב', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed-5-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 827 found, 531 correct.
# Precision: 0.57
# Recall:    0.64
# F1:        0.6
# FP ex.: ['ה הרצליה', 'ה גליל', 'לסמפדוריה', 'באשדוד', 'עו']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 787 found, 500 correct.
# Precision: 0.54
# Recall:    0.64
# F1:        0.58
# FP ex.: ['פרפורמרית', 'ה נסיכויות ה מאוחדות', 'ה זמרת וייזל - קפסוטו', 'נגמר', 'דיפרנסיאס']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed-6-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 338 found, 202 correct.
# Precision: 0.41
# Recall:    0.6
# F1:        0.48
# FP ex.: ['טקסס', 'ה רווחה', 'ירושלים', 'שיקאגו', 'יונה נלהבת']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'ויליאם וולד', 'סילבר', 'שירות ה תעסוקה']
# results/new_outputs/treebank_morphemes_fixed-6-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 748 found, 420 correct.
# Precision: 0.45
# Recall:    0.56
# F1:        0.5
# FP ex.: ['פרפורמרית', 'ה נסיכויות ה מאוחדות', 'ה גליל', 'בית - ה משפט ל ה ערעורים ידון', 'דאגו איסטרלינג']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 946 found, 570 correct.
# Precision: 0.61
# Recall:    0.6
# F1:        0.61
# FP ex.: ['בית ה משפט ה מחוזי ב נצרת', 'דן', 'כפר בלום', 'ספורטינג', 'הרצליה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed-7-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 424 found, 250 correct.
# Precision: 0.5
# Recall:    0.59
# F1:        0.54
# FP ex.: ['טקסס', 'ירושלים', 'אבידוב', 'שיקאגו', 'הראל']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'שירות ה תעסוקה', 'דווייט מקדונלד']
# results/new_outputs/treebank_morphemes_fixed-7-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 831 found, 425 correct.
# Precision: 0.46
# Recall:    0.51
# F1:        0.48
# FP ex.: ['ספורטינג', 'הרצליה', 'וולגה', 'ניו יורק', 'סאברס']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 872 found, 667 correct.
# Precision: 0.72
# Recall:    0.76
# F1:        0.74
# FP ex.: ['עגבניות', 'ראגו עגל', 'ה אירופי ל מחזיקות גביע', 'לוואדיאקוס', 'ה מזרחי']
# FN ex.: ['פרגו', 'באירה מאר', 'ראן', 'ה וועדה ל מינוי שופטים', 'מוצי']
# results/new_outputs/treebank_morphemes_fixed-8-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 431 found, 312 correct.
# Precision: 0.63
# Recall:    0.72
# F1:        0.67
# FP ex.: ['יטמן', 'אינטלקטואל רודני', 'בקליפורניה', 'ירושלים', 'איתן']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed-8-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 851 found, 565 correct.
# Precision: 0.61
# Recall:    0.66
# F1:        0.63
# FP ex.: ['עגבניות', 'ה גליל', 'בית - ה משפט ל ה ערעורים ידון', 'מזרח - ליטא לפולין', 'גבת והישווה']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'רוברטו באגו']
# results/new_outputs/treebank_morphemes_fixed-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 851 found, 653 correct.
# Precision: 0.7
# Recall:    0.77
# F1:        0.73
# FP ex.: ['ראגו עגל', 'פינת אלנבי', 'נצרת עילית', 'אמאדורה', 'גשר יבשתי']
# FN ex.: ['פרגו', 'ויאלי', 'גיילס', 'ה וועדה ל מינוי שופטים', 'מוצי']
# results/new_outputs/treebank_morphemes_fixed-9-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 414 found, 311 correct.
# Precision: 0.62
# Recall:    0.75
# F1:        0.68
# FP ex.: ['גאנט', 'אינטלקטואל רודני', 'לימים', 'ירושלים', 'אבידוב']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed-9-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 808 found, 556 correct.
# Precision: 0.6
# Recall:    0.69
# F1:        0.64
# FP ex.: ['ה גליל', 'בית - ה משפט ל ה ערעורים ידון', 'פינת אלנבי', 'נצרת עילית', 'אן באסטן']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'רוברטו באגו']

# %%
from itertools import islice

def get_preds_from_preds(preds, sents=morph_gold_dev_sents, truncate=80):
    i=0
    xtoks = []
    xpreds = []
    for sent in sents:
        t = []
        p = []
        for tok, b in islice(sent, truncate):
            t.append(tok)
            p.append(preds[i])
            i+=1
        xtoks.append(t)
        xpreds.append(p)

    preds_preds = [[None, None, xtoks, xpreds]]
    return preds_preds

# %%
morph_fixed_conf_gold_dev_res_o = pickle.load(open('results/new_outputs/treebank_morphemes_fixed_conf_res_preds_hist.pkl', 'rb'))
morph_fixed_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'conlleval_results': x[1][0], 
      'results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] } 
     for i, x in enumerate(morph_fixed_conf_gold_dev_res_o)]
morph_fixed_conf_gold_dev_res
# Out:
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 411 found, 212 correct.
# Precision: 0.43
# Recall:    0.52
# F1:        0.47
# FP ex.: ['אינטלקטואל רודני', 'אסמי ה דגנים', 'מג"ב חשו אל', 'הנ ל צוותות חשיבה שמרניים', 'קטמון נפלה']
# FN ex.: ['כריסטין טוד ויטמן', 'שירות ה תעסוקה', 'דווייט מקדונלד', 'קרן מקארתור', 'משטרת מיניאפוליס']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 357 found, 206 correct.
# Precision: 0.41
# Recall:    0.58
# F1:        0.48
# FP ex.: ['טקסס', 'ירושלים', 'שיקאגו', 'הראל', 'קטמון']
# FN ex.: ['רשות שדות ה תעופה', 'בוש', 'כריסטין טוד ויטמן', 'ניו גרסי', 'סילבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 460 found, 354 correct.
# Precision: 0.71
# Recall:    0.77
# F1:        0.74
# FP ex.: ['ירושלים', 'התבוננתי', 'שיקאגו', 'יונה נלהבת', 'הראל']
# FN ex.: ['כריסטין טוד ויטמן', 'סילבר', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 414 found, 341 correct.
# Precision: 0.68
# Recall:    0.82
# F1:        0.75
# FP ex.: ['גאנט', 'דלאנו רוזוולט', 'אינטלקטואל רודני', 'לינד', 'ה קטיף']
# FN ex.: ['סילבר', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 389 found, 293 correct.
# Precision: 0.59
# Recall:    0.75
# F1:        0.66
# FP ex.: ['גאנט', 'ירושלים', 'שיקאגו', 'ה פלמ"ח', 'ש צה"ל']
# FN ex.: ['בוש', 'כריסטין טוד ויטמן', 'ניו גרסי', 'סילבר', 'דווייט מקדונלד']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 352 found, 275 correct.
# Precision: 0.55
# Recall:    0.78
# F1:        0.65
# FP ex.: ['גאנט', 'אילת', 'ענתבי', 'ירושלים', 'מחוז פאריס']
# FN ex.: ['בוש', 'כריסטין טוד ויטמן', 'ניו גרסי', 'סילבר', 'דווייט מקדונלד']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 346 found, 232 correct.
# Precision: 0.47
# Recall:    0.67
# F1:        0.55
# FP ex.: ['טקסס', 'ירושלים', 'שיקאגו', 'יונה נלהבת', 'מסצוסטס']
# FN ex.: ['ויליאם וולד', 'סילבר', 'שירות ה תעסוקה', 'דווייט מקדונלד', 'קרן מקארתור']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 368 found, 223 correct.
# Precision: 0.45
# Recall:    0.61
# F1:        0.52
# FP ex.: ['טקסס', 'ירושלים', 'שיקאגו', 'הראל', 'אלן']
# FN ex.: ['בוש', 'כריסטין טוד ויטמן', 'ניו גרסי', 'סילבר', 'שירות ה תעסוקה']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 427 found, 346 correct.
# Precision: 0.69
# Recall:    0.81
# F1:        0.75
# FP ex.: ['ה רפובליקאית', 'אינטלקטואל רודני', 'לינד', 'ירושלים', 'מחוז פאריס']
# FN ex.: ['כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 424 found, 351 correct.
# Precision: 0.7
# Recall:    0.83
# F1:        0.76
# FP ex.: ['גאנט', 'אילת', 'אינטלקטואל רודני', 'לינד', 'ואיה']
# FN ex.: ['סילבר', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 332 found, 280 correct.
# Precision: 0.56
# Recall:    0.84
# F1:        0.67
# FP ex.: ['קרן ה מדע', 'פומפידו', 'אילת', 'ענתבי', 'ירושלים']
# FN ex.: ['בוש', 'כריסטין טוד ויטמן', 'ניו גרסי', 'סילבר', 'דווייט מקדונלד']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 401 found, 313 correct.
# Precision: 0.63
# Recall:    0.78
# F1:        0.7
# FP ex.: ['גאנט', 'ירושלים', 'שיקאגו', 'אלי', 'איובה']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'דווייט מקדונלד', 'קרן מקארתור']
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False, 'patience': 10},
#   'conlleval_results': (50.96153846153846,
#    42.570281124497996,
#    46.389496717724285),
#   'results': [42.570281124497996, 51.58150851581509, 46.64466446644665]},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True, 'patience': 10},
#   'conlleval_results': (56.94444444444444,
#    41.164658634538156,
#    47.78554778554779),
#   'results': [41.365461847389554, 57.70308123249299, 48.18713450292397]},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (73.18087318087319,
#    70.68273092369478,
#    71.91011235955057),
#   'results': [71.08433734939759, 76.95652173913044, 73.90396659707724]},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (79.2056074766355, 68.07228915662651, 73.2181425485961),
#   'results': [68.47389558232932, 82.3671497584541, 74.78070175438597]},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (71.32530120481928,
#    59.43775100401606,
#    64.84118291347207),
#   'results': [58.835341365461844, 75.32133676092545, 66.06538895152198]},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (75.48209366391184,
#    55.020080321285135,
#    63.64692218350755),
#   'results': [55.22088353413655, 78.125, 64.70588235294117]},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False, 'patience': 10},
#   'conlleval_results': (66.28571428571428,
#    46.58634538152611,
#    54.71698113207547),
#   'results': [46.58634538152611, 67.05202312138728, 54.976303317535546]},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True, 'patience': 10},
#   'conlleval_results': (59.62566844919787,
#    44.77911646586345,
#    51.146788990825684),
#   'results': [44.77911646586345, 60.597826086956516, 51.501154734411095]},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (79.95391705069125,
#    69.67871485943775,
#    74.46351931330472),
#   'results': [69.47791164658635, 81.0304449648712, 74.8108108108108]},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (79.63800904977376,
#    70.68273092369478,
#    74.8936170212766),
#   'results': [70.48192771084338, 82.78301886792453, 76.13882863340564]},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (81.44927536231884,
#    56.42570281124498,
#    66.66666666666667),
#   'results': [56.22489959839358, 84.33734939759037, 67.46987951807229]},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (76.34146341463415,
#    62.85140562248996,
#    68.94273127753304),
#   'results': [62.85140562248996, 78.05486284289277, 69.6329254727475]}]

# %% [raw]
# x = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0],
#       'mention_results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] }
#      for i, x in enumerate(morph_fixed_conf_gold_dev_res_o)]

# %%
conf_i = {x['conf']: x['config'] for x in morph_fixed_conf_gold_dev_res}
for r in morph_fixed_res:
    r['config'] = conf_i[r['conf']]
    
morph_fixed_res = morph_fixed_res+morph_fixed_conf_gold_dev_res

# %%
for r in morph_fixed_res:
    r['unit'] = 'morpheme_fixed'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]

# %%
morph_fixed_res[0]
# Out:
# {'pred_set': 'gold_test',
#  'conf': 0,
#  'results': [47.046186895810955, 51.95729537366548, 49.379932356257044],
#  'config': {'crf': True,
#   'use_pos': False,
#   'patience': 10,
#   'use_word': True,
#   'embedding_matrix': None,
#   'embed_dim': 70,
#   'trainable': True,
#   'input_dropout': False,
#   'stack_lstm': 1,
#   'epochs': 100,
#   'early_stopping': True,
#   'min_delta': 0.0001,
#   'use_char': False,
#   'add_random_embedding': True,
#   'pretrained_embed_dim': 300,
#   'stack_cross': False,
#   'stack_double': False,
#   'rec_dropout': 0.1,
#   'validation_split': 0.1},
#  'unit': 'morpheme_fixed'}

# %%
morph_fixed_rdf = get_results_df(morph_fixed_res)
morph_fixed_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  49.379932          False     0.0001        10  ...  51.957295
# 1     100  40.979955          False     0.0001        10  ...  46.000000
# 2     100  41.498559          False     0.0001        10  ...  44.776119
# 3     100  61.176471          False     0.0001        10  ...  60.915868
# 4     100  49.837486          False     0.0001        10  ...  54.117647
#
#   stack_cross  stack_double  stack_lstm  trainable            unit  use_char  \
# 0       False         False           1       True  morpheme_fixed     False
# 1       False         False           1       True  morpheme_fixed     False
# 2       False         False           1       True  morpheme_fixed     False
# 3       False         False           1       True  morpheme_fixed     False
# 4       False         False           1       True  morpheme_fixed     False
#
#    use_pos  use_word validation_split
# 0    False      True              0.1
# 1    False      True              0.1
# 2    False      True              0.1
# 3     True      True              0.1
# 4     True      True              0.1
#
# [5 rows x 24 columns]

# %%
morph_fixed_rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix                     None pretrained_token_ft      yap_ft_sg
# unit                       morpheme_fixed      morpheme_fixed morpheme_fixed
# pred_set  use_pos use_char
# gold_dev  False   False              46.6                74.8           73.9
#                   True               55.0                76.1           74.8
#           True    False              48.2                64.7           66.1
#                   True               51.5                69.6           67.5
# gold_test False   False              49.4                71.4           70.9
#                   True               58.2                73.3           74.0
#           True    False              61.2                74.0           73.2
#                   True               60.7                75.6           74.7
# yap_dev   False   False              41.0                67.5           66.2
#                   True               48.3                68.2           67.2
#           True    False              49.8                64.3           66.9
#                   True               54.2                68.4           68.0
# yap_test  False   False              41.5                62.6           62.6
#                   True               50.0                63.9           63.4
#           True    False              47.1                60.4           62.6
#                   True               48.2                63.4           62.8

# %% [markdown]
# ### Evaluate morphemes fixed

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
morph_fixed_gold_sents = (morph_gold_test_sents, morph_gold_dev_sents, morph_gold_test_sents)
pred_set = ('gold_test', 'yap_dev', 'yap_test')

morph_fixed2_res = []
for ep in sorted(glob.glob('results/new_outputs/*morphemes_fixed2*-extra_preds-*')):
    print(ep)
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), morph_gold_extra_preds[i], morph_fixed_gold_sents[i])]
    morph_fixed2_res.append(res)
# Out:
# results/new_outputs/treebank_morphemes_fixed2-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 617 found, 365 correct.
# Precision: 0.39
# Recall:    0.59
# F1:        0.47
# FP ex.: ['אל ה קיסר', 'צומת', 'עו', 'לאט', 'אמאדורה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed2-0-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 306 found, 158 correct.
# Precision: 0.32
# Recall:    0.52
# F1:        0.39
# FP ex.: ['ה שדולה ה פרו', 'טקסס', 'ירושלים', 'איתן', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'ויליאם וולד', 'סילבר', 'שירות ה תעסוקה']
# results/new_outputs/treebank_morphemes_fixed2-0-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 582 found, 304 correct.
# Precision: 0.33
# Recall:    0.52
# F1:        0.4
# FP ex.: ['אל ה קיסר', 'ה גליל', 'עו', 'לאט', 'אן באסטן']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed2-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 940 found, 549 correct.
# Precision: 0.59
# Recall:    0.58
# F1:        0.59
# FP ex.: ['ספורטינג', 'הרצליה', 'וולגה', 'ניו יורק', 'סאברס']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'בוסטון', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed2-1-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 431 found, 237 correct.
# Precision: 0.48
# Recall:    0.55
# F1:        0.51
# FP ex.: ['טקסס', 'אלן', 'ירושלים', 'אבידוב', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'דווייט מקדונלד', 'קרן מקארתור']
# results/new_outputs/treebank_morphemes_fixed2-1-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 825 found, 410 correct.
# Precision: 0.44
# Recall:    0.5
# F1:        0.47
# FP ex.: ['ספורטינג', 'הרצליה', 'ד שמעון', 'וולגה', 'סאברס']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed2-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 914 found, 699 correct.
# Precision: 0.75
# Recall:    0.76
# F1:        0.76
# FP ex.: ['נצרת עילית', 'טאקומה', 'נאגטס', 'קפיאס', 'אמאדורה']
# FN ex.: ['פרגו', 'באירה מאר', 'גיילס', 'ה וועדה ל מינוי שופטים', 'רשף נכסים']
# results/new_outputs/treebank_morphemes_fixed2-10-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 405 found, 308 correct.
# Precision: 0.62
# Recall:    0.76
# F1:        0.68
# FP ex.: ['גאנט', 'בקליפורניה', 'ירושלים', 'אבידוב', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed2-10-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 819 found, 561 correct.
# Precision: 0.6
# Recall:    0.68
# F1:        0.64
# FP ex.: ['ה גליל', 'קפיאס', 'אן באסטן', 'אמאדורה', 'נוי דורטמונד']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed2-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 960 found, 713 correct.
# Precision: 0.77
# Recall:    0.74
# F1:        0.75
# FP ex.: ['ראגו עגל', 'טאקומה', 'פטוציני אלפרדו', 'אמאדורה', 'כפר בלום']
# FN ex.: ['פרגו', 'באירה מאר', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed2-11-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 430 found, 311 correct.
# Precision: 0.62
# Recall:    0.72
# F1:        0.67
# FP ex.: ['גאנט', 'פומפידו', 'בקליפורניה', 'ירושלים', 'אבידוב']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'שירות ה תעסוקה', 'קרן מקארתור']
# results/new_outputs/treebank_morphemes_fixed2-11-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 868 found, 572 correct.
# Precision: 0.61
# Recall:    0.66
# F1:        0.64
# FP ex.: ['ה גליל', 'לסמפדוריה', 'באשדוד', 'נצרת עילית', 'קפיאס']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'רוברטו באגו']
# results/new_outputs/treebank_morphemes_fixed2-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 820 found, 645 correct.
# Precision: 0.69
# Recall:    0.79
# F1:        0.74
# FP ex.: ['צומת', 'נצרת עילית', 'טאקומה', 'אמאדורה', 'כפר בלום']
# FN ex.: ['שפיים', 'פרגו', 'באירה מאר', 'ויאלי', 'ראן']
# results/new_outputs/treebank_morphemes_fixed2-2-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 410 found, 294 correct.
# Precision: 0.59
# Recall:    0.72
# F1:        0.65
# FP ex.: ['גאנט', 'יטמן', 'בקליפורניה', 'ירושלים', 'איתן']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed2-2-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 807 found, 563 correct.
# Precision: 0.6
# Recall:    0.7
# F1:        0.65
# FP ex.: ['ה גליל', 'בית - ה משפט ל ה ערעורים ידון', 'נצרת עילית', 'אן באסטן', 'כפר בלום']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed2-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 774 found, 591 correct.
# Precision: 0.63
# Recall:    0.76
# F1:        0.69
# FP ex.: ['צומת', 'ראגו עגל', 'אמאדורה', 'צומת', '1920']
# FN ex.: ['שפיים', 'פרגו', 'באירה מאר', 'ויאלי', 'ה וועדה ל מינוי שופטים']
# results/new_outputs/treebank_morphemes_fixed2-3-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 373 found, 289 correct.
# Precision: 0.58
# Recall:    0.77
# F1:        0.66
# FP ex.: ['ה ירושלים', 'ה מערב ה תיכון ה אמריקאי', 'דלאנו רוזוולט', 'לינד', 'אבידוב']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed2-3-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 735 found, 502 correct.
# Precision: 0.54
# Recall:    0.68
# F1:        0.6
# FP ex.: ['ה גליל', 'לסמפדוריה', 'בית - ה משפט ל ה ערעורים ידון', 'אירה מאר', 'אן באסטן']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ה משפטים', 'ת"א']
# results/new_outputs/treebank_morphemes_fixed2-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 879 found, 679 correct.
# Precision: 0.73
# Recall:    0.77
# F1:        0.75
# FP ex.: ['טאקומה', 'קפיאס', 'להחתימו', 'כפר בלום', 'גורגונזולה']
# FN ex.: ['שפיים', 'פרגו', 'באירה מאר', 'גיילס', 'ה וועדה ל מינוי שופטים']
# results/new_outputs/treebank_morphemes_fixed2-4-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 393 found, 299 correct.
# Precision: 0.6
# Recall:    0.76
# F1:        0.67
# FP ex.: ['גאנט', 'בקליפורניה', 'ירושלים', 'אבידוב', 'שיקאגו']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# results/new_outputs/treebank_morphemes_fixed2-4-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 777 found, 536 correct.
# Precision: 0.58
# Recall:    0.69
# F1:        0.63
# FP ex.: ['ה גליל', 'בית - ה משפט ל ה ערעורים ידון', 'נצרת עילית', 'קפיאס', 'אן באסטן']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed2-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 963 found, 702 correct.
# Precision: 0.75
# Recall:    0.73
# F1:        0.74
# FP ex.: ['ה לשכה ו ראשי ה וועדים ה מחוזיים', 'צומת', 'ראגו עגל', 'דן', 'נאגטס']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'ה מינהל']
# results/new_outputs/treebank_morphemes_fixed2-5-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 437 found, 309 correct.
# Precision: 0.62
# Recall:    0.71
# F1:        0.66
# FP ex.: ['גאנט', 'ירושלים', 'אבידוב', 'שיקאגו', 'הראל']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# results/new_outputs/treebank_morphemes_fixed2-5-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 876 found, 559 correct.
# Precision: 0.6
# Recall:    0.64
# F1:        0.62
# FP ex.: ['ה לשכה ו ראשי ה וועדים ה מחוזיים', 'ה גליל', 'לסמפדוריה', 'בית - ה משפט ל ה ערעורים ידון', 'ה ארץ ישראל']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed2-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 654 found, 416 correct.
# Precision: 0.45
# Recall:    0.64
# F1:        0.52
# FP ex.: ['דאגו איסטרלינג', 'עו', 'יובנטוס', 'ארגון מטרייה', 'ה קליפרס']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed2-6-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 324 found, 200 correct.
# Precision: 0.4
# Recall:    0.62
# F1:        0.49
# FP ex.: ['מרכז ה וועידות', 'ירושלים', 'שיקאגו', 'יונה נלהבת', 'הראל']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'שירות ה תעסוקה', 'דווייט מקדונלד']
# results/new_outputs/treebank_morphemes_fixed2-6-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 616 found, 345 correct.
# Precision: 0.37
# Recall:    0.56
# F1:        0.45
# FP ex.: ['ה גליל', 'בית - ה משפט ל ה ערעורים ידון', 'בית לאדמו"ר', 'עו', 'דאגו איסטרלינג']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים']
# results/new_outputs/treebank_morphemes_fixed2-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 968 found, 580 correct.
# Precision: 0.62
# Recall:    0.6
# F1:        0.61
# FP ex.: ['דן', 'כפר בלום', 'ספורטינג', 'הרצליה', 'וולגה']
# FN ex.: ['שפיים', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed2-7-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 425 found, 238 correct.
# Precision: 0.48
# Recall:    0.56
# F1:        0.52
# FP ex.: ['גאנט', 'ירושלים', 'אבידוב', 'שיקאגו', 'מסצוסטס']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed2-7-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 862 found, 439 correct.
# Precision: 0.47
# Recall:    0.51
# F1:        0.49
# FP ex.: ['ברית ה מועצות ו -', 'ספורטינג', 'הרצליה', 'ה אירופה', 'וולגה']
# FN ex.: ['שפיים', 'פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed2-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 866 found, 673 correct.
# Precision: 0.72
# Recall:    0.78
# F1:        0.75
# FP ex.: ['ה לשכה ו ראשי ה וועדים ה מחוזיים', 'ראגו עגל', 'נצרת עילית', 'אחים נחום', 'ה מזרחי']
# FN ex.: ['פרגו', 'באירה מאר', 'ויאלי', 'ראן', 'גיילס']
# results/new_outputs/treebank_morphemes_fixed2-8-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 400 found, 300 correct.
# Precision: 0.6
# Recall:    0.75
# F1:        0.67
# FP ex.: ['יטמן', 'בקליפורניה', 'ירושלים', 'שיקאגו', 'יונה נלהבת']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון']
# results/new_outputs/treebank_morphemes_fixed2-8-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 835 found, 575 correct.
# Precision: 0.62
# Recall:    0.69
# F1:        0.65
# FP ex.: ['בית - ה משפט ל ה ערעורים ידון', 'נצרת עילית', 'אן באסטן', 'אחים נחום', 'ה מזרחי']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'רוברטו באגו']
# results/new_outputs/treebank_morphemes_fixed2-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 909 found, 659 correct.
# Precision: 0.71
# Recall:    0.72
# F1:        0.72
# FP ex.: ['ראגו עגל', 'פינת אלנבי', 'נאגטס', 'אמאדורה', 'אחים נחום']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'בוסטון']
# results/new_outputs/treebank_morphemes_fixed2-9-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 441 found, 318 correct.
# Precision: 0.64
# Recall:    0.72
# F1:        0.68
# FP ex.: ['גאנט', 'יטמן', 'לימים', 'ירושלים', 'אבידוב']
# FN ex.: ['ניו גרסי', 'כריסטין טוד ויטמן', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# results/new_outputs/treebank_morphemes_fixed2-9-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 876 found, 560 correct.
# Precision: 0.6
# Recall:    0.64
# F1:        0.62
# FP ex.: ['מזרח - ליטא לפולין', 'באשדוד', 'פינת אלנבי', 'נאגטס', 'אן באסטן']
# FN ex.: ['פרגו', 'ה וועדה ל מינוי שופטים', 'ת"א', 'ה וועדה ל בחירת שופטים', 'רוברטו באגו']

# %%
morph_fixed2_conf_gold_dev_res_o = pickle.load(open('results/new_outputs/treebank_morphemes_fixed2_conf_res_preds_hist.pkl', 'rb'))
morph_fixed2_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'conlleval_results': x[1][0], 
      'results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] } 
     for i, x in enumerate(morph_fixed2_conf_gold_dev_res_o)]
morph_fixed2_conf_gold_dev_res
# Out:
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 316 found, 184 correct.
# Precision: 0.37
# Recall:    0.58
# F1:        0.45
# FP ex.: ['ה שדולה ה פרו', 'טקסס', 'ירושלים', 'איתן', 'שיקאגו']
# FN ex.: ['כריסטין טוד ויטמן', 'ויליאם וולד', 'סילבר', 'שירות ה תעסוקה', 'דווייט מקדונלד']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 452 found, 297 correct.
# Precision: 0.6
# Recall:    0.66
# F1:        0.63
# FP ex.: ['טקסס', 'ירושלים', 'שיקאגו', 'קטמון', 'מקארתור']
# FN ex.: ['סילבר', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 416 found, 327 correct.
# Precision: 0.66
# Recall:    0.79
# F1:        0.72
# FP ex.: ['גאנט', 'ירושלים', 'התבוננתי', 'שיקאגו', 'יונה נלהבת']
# FN ex.: ['כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 383 found, 324 correct.
# Precision: 0.65
# Recall:    0.85
# F1:        0.74
# FP ex.: ['הבריקה', 'ה מערב ה תיכון ה אמריקאי', 'דלאנו רוזוולט', 'לינד', 'ניו יורק']
# FN ex.: ['סילבר', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 430 found, 364 correct.
# Precision: 0.73
# Recall:    0.85
# F1:        0.78
# FP ex.: ['גאנט', 'הרי בראדלו', 'לינד', 'כוכב ה כדורסל ה מהולל', 'גנאדאס דל ואיה']
# FN ex.: ['סילבר', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "', 'הארקין']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 461 found, 370 correct.
# Precision: 0.74
# Recall:    0.8
# F1:        0.77
# FP ex.: ['גאנט', 'ירושלים', 'שיקאגו', 'הראל', 'קטמון']
# FN ex.: ['מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "', 'ה קונסוליה ה ישראלית ב שיקאגו', 'מרכז ה מידע ל זכויות ה אדם ב ה שטחים']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 331 found, 229 correct.
# Precision: 0.46
# Recall:    0.69
# F1:        0.55
# FP ex.: ['מרכז ה וועידות', 'ירושלים', 'איתן', 'שיקאגו', 'יונה נלהבת']
# FN ex.: ['סילבר', 'שירות ה תעסוקה', 'דווייט מקדונלד', 'קרן מקארתור', 'מנזר סן סימון']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 451 found, 300 correct.
# Precision: 0.6
# Recall:    0.67
# F1:        0.63
# FP ex.: ['גאנט', 'ירושלים', 'שיקאגו', 'מסצוסטס', 'הראל']
# FN ex.: ['שירות ה תעסוקה', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 405 found, 338 correct.
# Precision: 0.68
# Recall:    0.83
# F1:        0.75
# FP ex.: ['דה פלפואה', 'לינד', 'נווה - מונוסון', 'ירושלים', 'מחוז פאריס']
# FN ex.: ['כריסטין טוד ויטמן', 'סילבר', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 443 found, 356 correct.
# Precision: 0.71
# Recall:    0.8
# F1:        0.76
# FP ex.: ['גאנט', 'ואיה', 'ירושלים', 'קרן גון', 'שיקאגו']
# FN ex.: ['כריסטין טוד ויטמן', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 432 found, 368 correct.
# Precision: 0.74
# Recall:    0.85
# F1:        0.79
# FP ex.: ['גאנט', 'לינד', 'ירושלים', 'מחוז פאריס', 'ניו יורק']
# FN ex.: ['קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה', 'מענק " גאונות "', 'ממשלת ריימון באר']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 451 found, 374 correct.
# Precision: 0.75
# Recall:    0.83
# F1:        0.79
# FP ex.: ['בקעה', 'גאנט', 'לינד', 'ירושלים', 'מחוז פאריס']
# FN ex.: ['כריסטין טוד ויטמן', 'שירות ה תעסוקה', 'קרן מקארתור', 'מנזר סן סימון', 'ה מלחמה ה קרה']
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False, 'patience': 10},
#   'conlleval_results': (56.44171779141104,
#    36.94779116465863,
#    44.66019417475727),
#   'results': [36.94779116465863, 58.22784810126582, 45.208845208845204]},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True, 'patience': 10},
#   'conlleval_results': (64.14686825053995,
#    59.63855421686747,
#    61.810613943808534),
#   'results': [59.63855421686747, 65.7079646017699, 62.52631578947367]},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (75.86206896551724,
#    66.26506024096386,
#    70.73954983922829),
#   'results': [65.66265060240963, 78.60576923076923, 71.55361050328227]},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (76.77725118483413,
#    65.06024096385542,
#    70.43478260869566),
#   'results': [65.06024096385542, 84.59530026109661, 73.5527809307605]},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (81.53153153153153,
#    72.69076305220884,
#    76.85774946921444),
#   'results': [73.09236947791165, 84.65116279069768, 78.44827586206897]},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (77.03549060542797,
#    74.09638554216868,
#    75.53735926305015),
#   'results': [74.29718875502009, 80.26030368763557, 77.16371220020855]},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False, 'patience': 10},
#   'conlleval_results': (67.95252225519289,
#    45.98393574297189,
#    54.85029940119761),
#   'results': [45.98393574297189, 69.18429003021149, 55.24728588661038]},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True, 'patience': 10},
#   'conlleval_results': (66.29711751662971,
#    60.040160642570285,
#    63.013698630136986),
#   'results': [60.24096385542169, 66.51884700665188, 63.224446786090624]},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (81.77458033573141,
#    68.47389558232932,
#    74.53551912568307),
#   'results': [67.8714859437751, 83.4567901234568, 74.86157253599114]},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (78.24175824175825,
#    71.4859437751004,
#    74.71143756558237),
#   'results': [71.4859437751004, 80.36117381489842, 75.66418703506909]},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (83.14606741573034,
#    74.29718875502009,
#    78.47295864262989),
#   'results': [73.89558232931726, 85.18518518518519, 79.13978494623655]},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (80.56155507559394,
#    74.8995983935743,
#    77.62747138397502),
#   'results': [75.1004016064257, 82.92682926829268, 78.81981032665965]}]

# %% [raw]
# x = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0],
#       'mention_results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] }
#      for i, x in enumerate(morph_fixed_conf_gold_dev_res_o)]

# %%
conf_i = {x['conf']: x['config'] for x in morph_fixed2_conf_gold_dev_res}
for r in morph_fixed2_res:
    r['config'] = conf_i[r['conf']]
    
morph_fixed2_res = morph_fixed2_res+morph_fixed2_conf_gold_dev_res

# %%
for r in morph_fixed2_res:
    r['unit'] = 'morpheme_fixed2'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]

# %%
morph_fixed2_rdf = get_results_df(morph_fixed2_res)
morph_fixed2_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  47.157623          False     0.0001        10  ...  59.157212
# 1     100  39.303483          False     0.0001        10  ...  51.633987
# 2     100  40.185063          False     0.0001        10  ...  52.233677
# 3     100  58.685195          False     0.0001        10  ...  58.404255
# 4     100  51.022605          False     0.0001        10  ...  54.988399
#
#   stack_cross  stack_double  stack_lstm  trainable             unit  use_char  \
# 0       False         False           1       True  morpheme_fixed2     False
# 1       False         False           1       True  morpheme_fixed2     False
# 2       False         False           1       True  morpheme_fixed2     False
# 3       False         False           1       True  morpheme_fixed2     False
# 4       False         False           1       True  morpheme_fixed2     False
#
#    use_pos  use_word validation_split
# 0    False      True              0.1
# 1    False      True              0.1
# 2    False      True              0.1
# 3     True      True              0.1
# 4     True      True              0.1
#
# [5 rows x 24 columns]

# %%
morph_fixed2_rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix                      None pretrained_token_ft       yap_ft_sg
# unit                       morpheme_fixed2     morpheme_fixed2 morpheme_fixed2
# pred_set  use_pos use_char
# gold_dev  False   False               45.2                73.6            71.6
#                   True                55.2                75.7            74.9
#           True    False               62.5                77.2            78.4
#                   True                63.2                78.8            79.1
# gold_test False   False               47.2                69.3            73.7
#                   True                52.5                71.6            74.9
#           True    False               58.7                74.1            75.0
#                   True                61.1                75.4            75.8
# yap_dev   False   False               39.3                66.4            64.8
#                   True                48.7                67.7            66.8
#           True    False               51.0                66.1            67.1
#                   True                51.6                67.0            68.2
# yap_test  False   False               40.2                60.3            64.8
#                   True                44.6                62.0            65.1
#           True    False               46.7                61.9            62.8
#                   True                49.0                63.6            64.1

# %% [markdown]
# ### Evaluate tokens fixed

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
pred_set = ('gold_test', 'yap_dev', 'yap_test')

tokens_fixed2_res = []
for ep in sorted(glob.glob('results/new_outputs/*tokens_fixed2*-extra_preds-*')):
    print(ep)
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), tok_gold_extra_preds[i], tok_gold_sents[i])]
    tokens_fixed2_res.append(res)
# Out:
# results/new_outputs/treebank_tokens_fixed2-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 741 found, 328 correct.
# Precision: 0.35
# Recall:    0.44
# F1:        0.39
# FP ex.: ['בפיו', 'במנת האנטיפסטו', 'הפומבי', 'רוסיה', 'לעמותה']
# FN ex.: ['פרגו', 'לסמפדוריה', 'רוברטו באגו', 'מייקל האקט', 'ובית - המשפט העליון']
# results/new_outputs/treebank_tokens_fixed2-0-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 385 found, 168 correct.
# Precision: 0.34
# Recall:    0.44
# F1:        0.38
# FP ex.: ['במפרץ הפרסי', 'מחזוריות הפילנטרופיה', 'החינוך למצוינות', 'לדיאלקטיקה', 'החברה קדישא לדחוף']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'בקליפורניה']
# results/new_outputs/treebank_tokens_fixed2-0-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 741 found, 328 correct.
# Precision: 0.35
# Recall:    0.44
# F1:        0.39
# FP ex.: ['בפיו', 'במנת האנטיפסטו', 'הפומבי', 'רוסיה', 'לעמותה']
# FN ex.: ['פרגו', 'לסמפדוריה', 'רוברטו באגו', 'מייקל האקט', 'ובית - המשפט העליון']
# results/new_outputs/treebank_tokens_fixed2-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 1036 found, 510 correct.
# Precision: 0.55
# Recall:    0.49
# F1:        0.52
# FP ex.: ['רמת השרון', 'לייעול העבודה', 'הקיסר ברומא', 'בבלוטות תימוס', 'ניו יורק']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'ובית - המשפט העליון']
# results/new_outputs/treebank_tokens_fixed2-1-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 490 found, 237 correct.
# Precision: 0.47
# Recall:    0.48
# F1:        0.48
# FP ex.: ['טקסס', 'פומפידו', 'האמריקאי', 'פמיניזם ותיאוריה', 'פוליטים']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'בקליפורניה']
# results/new_outputs/treebank_tokens_fixed2-1-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 948 found, 421 correct.
# Precision: 0.45
# Recall:    0.44
# F1:        0.45
# FP ex.: ['רמת השרון', 'ספורטינג', 'לייעול העבודה', 'הקיסר ברומא', 'לדידי']
# FN ex.: ['לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'רוברטו באגו', 'ובית - המשפט העליון']
# results/new_outputs/treebank_tokens_fixed2-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 918 found, 683 correct.
# Precision: 0.73
# Recall:    0.74
# F1:        0.74
# FP ex.: ['פינת אלנבי', 'פטוציני אלפרדו', 'אמאדורה', 'ותשלם למינהל', 'הלאומים']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'למינהל']
# results/new_outputs/treebank_tokens_fixed2-10-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 420 found, 334 correct.
# Precision: 0.67
# Recall:    0.8
# F1:        0.73
# FP ex.: ['גאנט', 'פורד', 'מניו', 'חטיבת " הראל', 'שפתיי']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'סילבר', 'המלחמה']
# results/new_outputs/treebank_tokens_fixed2-10-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 838 found, 618 correct.
# Precision: 0.66
# Recall:    0.74
# F1:        0.7
# FP ex.: ['פינת אלנבי', 'פטוציני אלפרדו', 'אמאדורה', 'בהרצליה פיתוח', 'הלאומים']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'למינהל']
# results/new_outputs/treebank_tokens_fixed2-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 904 found, 667 correct.
# Precision: 0.72
# Recall:    0.74
# F1:        0.73
# FP ex.: ['רמת השרון', 'פינת אלנבי', 'קפיאס', 'אמאדורה', 'פטוציני אלפרדו']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'הכשרת הישוב']
# results/new_outputs/treebank_tokens_fixed2-11-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 419 found, 335 correct.
# Precision: 0.67
# Recall:    0.8
# F1:        0.73
# FP ex.: ['גאנט', 'פומפידו', 'לינד', 'דלאנו רוזוולט', 'אילת']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'סילבר', 'המלחמה']
# results/new_outputs/treebank_tokens_fixed2-11-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 819 found, 600 correct.
# Precision: 0.64
# Recall:    0.73
# F1:        0.69
# FP ex.: ['רמת השרון', 'טולוז', 'פינת אלנבי', 'קפיאס', 'אמאדורה']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'גיילס', 'הכשרת הישוב']
# results/new_outputs/treebank_tokens_fixed2-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 881 found, 612 correct.
# Precision: 0.66
# Recall:    0.69
# F1:        0.68
# FP ex.: ['ראגו עגל', 'טרטוריה', 'פינת אלנבי', 'אמאדורה', 'ביפו']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'למינהל', 'המינהל']
# results/new_outputs/treebank_tokens_fixed2-2-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 442 found, 333 correct.
# Precision: 0.67
# Recall:    0.75
# F1:        0.71
# FP ex.: ['גאנט', 'פומפידו', 'מסצוסטס', 'חטיבת " הראל', 'יונה']
# FN ex.: ['הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'בשירות התעסוקה', 'ממשרד החוץ']
# results/new_outputs/treebank_tokens_fixed2-2-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 881 found, 612 correct.
# Precision: 0.66
# Recall:    0.69
# F1:        0.68
# FP ex.: ['ראגו עגל', 'טרטוריה', 'פינת אלנבי', 'אמאדורה', 'ביפו']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'למינהל', 'המינהל']
# results/new_outputs/treebank_tokens_fixed2-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 749 found, 553 correct.
# Precision: 0.59
# Recall:    0.74
# F1:        0.66
# FP ex.: ['רמת השרון', 'ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'בנווה - אביבים']
# FN ex.: ['פרגו', 'בוסטון', 'בוסטון סלטיקס', 'ובית - המשפט העליון', 'דזידרי']
# results/new_outputs/treebank_tokens_fixed2-3-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 391 found, 308 correct.
# Precision: 0.62
# Recall:    0.79
# F1:        0.69
# FP ex.: ['דה פלפואה', 'אילת', 'דלאנו רוזוולט', 'לינד', 'למקורות']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'המלחמה']
# results/new_outputs/treebank_tokens_fixed2-3-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 749 found, 553 correct.
# Precision: 0.59
# Recall:    0.74
# F1:        0.66
# FP ex.: ['רמת השרון', 'ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'בנווה - אביבים']
# FN ex.: ['פרגו', 'בוסטון', 'בוסטון סלטיקס', 'ובית - המשפט העליון', 'דזידרי']
# results/new_outputs/treebank_tokens_fixed2-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 902 found, 636 correct.
# Precision: 0.68
# Recall:    0.71
# F1:        0.69
# FP ex.: ['פינת אלנבי', 'דן', 'גן', 'אמאדורה', 'הישוב שוהם']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'לסמפדוריה', 'הכשרת הישוב']
# results/new_outputs/treebank_tokens_fixed2-4-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 422 found, 329 correct.
# Precision: 0.66
# Recall:    0.78
# F1:        0.71
# FP ex.: ['גאנט', 'פומפידו', 'פורד', 'סן סימון', 'מסצוסטס']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'סילבר']
# results/new_outputs/treebank_tokens_fixed2-4-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 829 found, 583 correct.
# Precision: 0.63
# Recall:    0.7
# F1:        0.66
# FP ex.: ['פינת אלנבי', 'גן', 'אמאדורה', 'הישוב שוהם', 'סטאנדארד ליאז']
# FN ex.: ['פרגו', 'ת"א', 'בוסטון סלטיקס', 'ובית - המשפט העליון', 'דזידרי']
# results/new_outputs/treebank_tokens_fixed2-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 888 found, 632 correct.
# Precision: 0.68
# Recall:    0.71
# F1:        0.69
# FP ex.: ['טולוז', 'פינת אלנבי', 'פטוציני אלפרדו', 'אמאדורה', 'בית - כנסת']
# FN ex.: ['פרגו', 'הסאנס', 'גיילס', 'הכשרת הישוב', 'למינהל']
# results/new_outputs/treebank_tokens_fixed2-5-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 426 found, 327 correct.
# Precision: 0.66
# Recall:    0.77
# F1:        0.71
# FP ex.: ['גאנט', 'פומפידו', 'מסצוסטס', 'בלב ירושלים המערבית', 'ריצארדס']
# FN ex.: ['הבית הלבן', 'המיליציה הצרפתית', 'סילבר', 'המלחמה', 'בשירות התעסוקה']
# results/new_outputs/treebank_tokens_fixed2-5-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 821 found, 577 correct.
# Precision: 0.62
# Recall:    0.7
# F1:        0.66
# FP ex.: ['טולוז', 'פינת אלנבי', 'פטוציני אלפרדו', 'אמאדורה', 'בית - כנסת']
# FN ex.: ['פרגו', 'ת"א', 'רוברטו באגו', 'ובית - המשפט העליון', 'דזידרי']
# results/new_outputs/treebank_tokens_fixed2-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 867 found, 373 correct.
# Precision: 0.4
# Recall:    0.43
# F1:        0.41
# FP ex.: ['רמת השרון', 'ל"ספורט הארץ', 'נשכחים ההם', 'בכפר בלום', 'וינגרט']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'רוברטו באגו']
# results/new_outputs/treebank_tokens_fixed2-6-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 446 found, 203 correct.
# Precision: 0.41
# Recall:    0.46
# F1:        0.43
# FP ex.: ['טקסס', 'הברית', 'גאנט', 'בממשלת ריימון באר', 'ועין']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'בקליפורניה']
# results/new_outputs/treebank_tokens_fixed2-6-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 867 found, 373 correct.
# Precision: 0.4
# Recall:    0.43
# F1:        0.41
# FP ex.: ['רמת השרון', 'ל"ספורט הארץ', 'נשכחים ההם', 'בכפר בלום', 'וינגרט']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'רוברטו באגו']
# results/new_outputs/treebank_tokens_fixed2-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 1064 found, 503 correct.
# Precision: 0.54
# Recall:    0.47
# F1:        0.5
# FP ex.: ['רמת השרון', 'ספורטינג', 'לפארמה', 'קורוואזיה', 'בבלוטות תימוס']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'ובית - המשפט העליון']
# results/new_outputs/treebank_tokens_fixed2-7-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 492 found, 243 correct.
# Precision: 0.49
# Recall:    0.49
# F1:        0.49
# FP ex.: ['טקסס', 'גאנט', 'האמריקאי', 'ניו יורק טיימס', 'שדות התעופה']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'בקליפורניה']
# results/new_outputs/treebank_tokens_fixed2-7-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 1005 found, 446 correct.
# Precision: 0.48
# Recall:    0.44
# F1:        0.46
# FP ex.: ['רמת השרון', 'נאסיונאל', 'בטייבה', 'ספורטינג', 'לפארמה']
# FN ex.: ['פרגו', 'לסמפדוריה', 'ת"א', 'בוסטון סלטיקס', 'רוברטו באגו']
# results/new_outputs/treebank_tokens_fixed2-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 892 found, 646 correct.
# Precision: 0.69
# Recall:    0.72
# F1:        0.71
# FP ex.: ['ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'משיוויון', 'אמסלם']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'למינהל', 'המינהל']
# results/new_outputs/treebank_tokens_fixed2-8-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 457 found, 348 correct.
# Precision: 0.7
# Recall:    0.76
# F1:        0.73
# FP ex.: ['גאנט', 'פורד', 'התבוננתי', 'מסצוסטס', 'ובשוטרים']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'קרן מקארתור']
# results/new_outputs/treebank_tokens_fixed2-8-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 892 found, 646 correct.
# Precision: 0.69
# Recall:    0.72
# F1:        0.71
# FP ex.: ['ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'משיוויון', 'אמסלם']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'למינהל', 'המינהל']
# results/new_outputs/treebank_tokens_fixed2-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 847 found, 627 correct.
# Precision: 0.67
# Recall:    0.74
# F1:        0.71
# FP ex.: ['טולוז', 'ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'ליוסטון']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'למינהל', 'המינהל']
# results/new_outputs/treebank_tokens_fixed2-9-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 439 found, 330 correct.
# Precision: 0.66
# Recall:    0.75
# F1:        0.7
# FP ex.: ['גאנט', 'ואיה', 'ריצארדס', 'מסצוסטס', 'וייטנאם']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'קרן מקארתור']
# results/new_outputs/treebank_tokens_fixed2-9-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 847 found, 627 correct.
# Precision: 0.67
# Recall:    0.74
# F1:        0.71
# FP ex.: ['טולוז', 'ראגו עגל', 'פינת אלנבי', 'אמאדורה', 'ליוסטון']
# FN ex.: ['פרגו', 'באירה מאר', 'הסאנס', 'למינהל', 'המינהל']

# %%
tokens_fixed2_conf_gold_dev_res_o = pickle.load(open('results/new_outputs/treebank_tokens_fixed2_conf_res_preds_hist.pkl', 'rb'))
tokens_fixed2_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'conlleval_results': x[1][0], 
      'results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0], sents=tok_gold_dev_sents), tok_gold_dev_mentions, tok_gold_dev_sents)] } 
     for i, x in enumerate(tokens_fixed2_conf_gold_dev_res_o)]
tokens_fixed2_conf_gold_dev_res
# Out:
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 385 found, 168 correct.
# Precision: 0.34
# Recall:    0.44
# F1:        0.38
# FP ex.: ['במפרץ הפרסי', 'מחזוריות הפילנטרופיה', 'החינוך למצוינות', 'לדיאלקטיקה', 'החברה קדישא לדחוף']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'בקליפורניה']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 500 found, 274 correct.
# Precision: 0.55
# Recall:    0.55
# F1:        0.55
# FP ex.: ['טקסס', 'אבי', 'האמריקאי', 'ואיה', 'אבידוב']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'סילבר', 'המלחמה']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 442 found, 333 correct.
# Precision: 0.67
# Recall:    0.75
# F1:        0.71
# FP ex.: ['גאנט', 'פומפידו', 'מסצוסטס', 'חטיבת " הראל', 'יונה']
# FN ex.: ['הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'בשירות התעסוקה', 'ממשרד החוץ']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 391 found, 308 correct.
# Precision: 0.62
# Recall:    0.79
# F1:        0.69
# FP ex.: ['דה פלפואה', 'אילת', 'דלאנו רוזוולט', 'לינד', 'למקורות']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'המלחמה']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 440 found, 355 correct.
# Precision: 0.71
# Recall:    0.81
# F1:        0.76
# FP ex.: ['גאנט', 'סן סימון', 'מסצוסטס', 'הראל', 'מקארתור']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'בשירות התעסוקה']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 450 found, 348 correct.
# Precision: 0.7
# Recall:    0.77
# F1:        0.73
# FP ex.: ['גאנט', 'מסצוסטס', 'בלב ירושלים המערבית', 'טובייה החי', 'ריצארדס']
# FN ex.: ['הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'בשירות התעסוקה', 'מנזר סן סימון']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 446 found, 203 correct.
# Precision: 0.41
# Recall:    0.46
# F1:        0.43
# FP ex.: ['טקסס', 'הברית', 'גאנט', 'בממשלת ריימון באר', 'ועין']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'בקליפורניה']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 504 found, 278 correct.
# Precision: 0.56
# Recall:    0.55
# F1:        0.55
# FP ex.: ['טקסס', 'גאנט', 'האמריקאי', 'ניו יורק טיימס', 'ואיה']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'בקליפורניה', 'המלחמה']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 457 found, 348 correct.
# Precision: 0.7
# Recall:    0.76
# F1:        0.73
# FP ex.: ['גאנט', 'פורד', 'התבוננתי', 'מסצוסטס', 'ובשוטרים']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'קרן מקארתור']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 439 found, 330 correct.
# Precision: 0.66
# Recall:    0.75
# F1:        0.7
# FP ex.: ['גאנט', 'ואיה', 'ריצארדס', 'מסצוסטס', 'וייטנאם']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'קרן מקארתור']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 440 found, 360 correct.
# Precision: 0.72
# Recall:    0.82
# F1:        0.77
# FP ex.: ['גאנט', 'דלאנו רוזוולט', 'אילת', 'בארץ', 'פורד']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'המיליציה הצרפתית', 'המלחמה', 'קרן מקארתור']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 445 found, 363 correct.
# Precision: 0.73
# Recall:    0.82
# F1:        0.77
# FP ex.: ['גאנט', 'דלאנו רוזוולט', 'לינד', 'אילת', 'בארץ']
# FN ex.: ['בית המשפט הבין - לאומי', 'הבית הלבן', 'כריסטין טוד ויטמן', 'המיליציה הצרפתית', 'המלחמה']
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False},
#   'conlleval_results': (41.959798994974875,
#    33.46693386773547,
#    37.23522853957636),
#   'results': [33.66733466933868, 43.63636363636363, 38.00904977375565]},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True},
#   'conlleval_results': (53.606237816764136,
#    55.11022044088176,
#    54.347826086956516),
#   'results': [54.90981963927856, 54.800000000000004, 54.854854854854864]},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (69.23076923076923,
#    66.73346693386773,
#    67.95918367346938),
#   'results': [66.73346693386773, 75.3393665158371, 70.77577045696069]},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (71.22969837587007,
#    61.523046092184366,
#    66.02150537634408),
#   'results': [61.72344689378757, 78.77237851662404, 69.21348314606742]},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (76.78958785249458, 70.94188376753507, 73.75),
#   'results': [71.14228456913828, 80.68181818181817, 75.61235356762514]},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (73.73949579831933, 70.34068136272545, 72.0),
#   'results': [69.73947895791584, 77.33333333333333, 73.34035827186513]},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False},
#   'conlleval_results': (44.469026548672566,
#    40.28056112224449,
#    42.27129337539432),
#   'results': [40.6813627254509, 45.51569506726457, 42.96296296296297]},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True},
#   'conlleval_results': (54.74308300395256,
#    55.51102204408818,
#    55.12437810945274),
#   'results': [55.71142284569138, 55.158730158730165, 55.43369890329012]},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (73.13432835820896,
#    68.7374749498998,
#    70.86776859504133),
#   'results': [69.73947895791584, 76.14879649890591, 72.80334728033473]},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (73.4375, 65.93186372745491, 69.48257655755016),
#   'results': [66.13226452905812, 75.17084282460137, 70.36247334754798]},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (78.38427947598254,
#    71.9438877755511,
#    75.02612330198536),
#   'results': [72.14428857715431, 81.81818181818183, 76.67731629392972]},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (79.25764192139738,
#    72.74549098196393,
#    75.86206896551724),
#   'results': [72.74549098196393, 81.57303370786518, 76.90677966101696]}]

# %% [raw]
# x = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0],
#       'mention_results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] }
#      for i, x in enumerate(morph_fixed_conf_gold_dev_res_o)]

# %%
conf_i = {x['conf']: x['config'] for x in tokens_fixed2_conf_gold_dev_res}
for r in tokens_fixed2_res:
    r['config'] = conf_i[r['conf']]
    
tokens_fixed2_res = tokens_fixed2_res+tokens_fixed2_conf_gold_dev_res

# %%
for r in tokens_fixed2_res:
    r['unit'] = 'tokens_fixed2'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]

# %%
tokens_fixed2_rdf = get_results_df(tokens_fixed2_res)
tokens_fixed2_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  39.234450          False     0.0001        20  ...  44.264507
# 1     100  38.009050          False     0.0001        20  ...  43.636364
# 2     100  39.234450          False     0.0001        20  ...  44.264507
# 3     100  51.855618          False     0.0001        20  ...  49.227799
# 4     100  47.927199          False     0.0001        20  ...  48.367347
#
#   stack_cross  stack_double  stack_lstm  trainable           unit  use_char  \
# 0       False         False           1       True  tokens_fixed2     False
# 1       False         False           1       True  tokens_fixed2     False
# 2       False         False           1       True  tokens_fixed2     False
# 3       False         False           1       True  tokens_fixed2     False
# 4       False         False           1       True  tokens_fixed2     False
#
#    use_pos  use_word validation_split
# 0    False      True              0.1
# 1    False      True              0.1
# 2    False      True              0.1
# 3     True      True              0.1
# 4     True      True              0.1
#
# [5 rows x 24 columns]

# %%
tokens_fixed2_rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix                    None pretrained_token_ft   token_ft_sg
# unit                       tokens_fixed2       tokens_fixed2 tokens_fixed2
# pred_set  use_pos use_char
# gold_dev  False   False             38.0                69.2          70.8
#                   True              43.0                70.4          72.8
#           True    False             54.9                73.3          75.6
#                   True              55.4                76.9          76.7
# gold_test False   False             39.2                65.8          67.5
#                   True              41.5                70.5          70.9
#           True    False             51.9                69.5          69.4
#                   True              50.4                72.7          73.9
# yap_dev   False   False             38.0                69.2          70.8
#                   True              43.0                70.4          72.8
#           True    False             47.9                70.7          71.4
#                   True              49.0                73.0          72.7
# yap_test  False   False             39.2                65.8          67.5
#                   True              41.5                70.5          70.9
#           True    False             44.8                65.9          66.3
#                   True              46.1                68.6          69.9

# %%
f2rdf = pd.concat([morph_fixed2_rdf,tokens_fixed2_rdf])
f2rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix                      None               pretrained_token_ft  \
# unit                       morpheme_fixed2 tokens_fixed2     morpheme_fixed2
# pred_set  use_pos use_char
# gold_dev  False   False               45.2          38.0                73.6
#                   True                55.2          43.0                75.7
#           True    False               62.5          54.9                77.2
#                   True                63.2          55.4                78.8
# gold_test False   False               47.2          39.2                69.3
#                   True                52.5          41.5                71.6
#           True    False               58.7          51.9                74.1
#                   True                61.1          50.4                75.4
# yap_dev   False   False               39.3          38.0                66.4
#                   True                48.7          43.0                67.7
#           True    False               51.0          47.9                66.1
#                   True                51.6          49.0                67.0
# yap_test  False   False               40.2          39.2                60.3
#                   True                44.6          41.5                62.0
#           True    False               46.7          44.8                61.9
#                   True                49.0          46.1                63.6
#
# embedding_matrix                           token_ft_sg       yap_ft_sg
# unit                       tokens_fixed2 tokens_fixed2 morpheme_fixed2
# pred_set  use_pos use_char
# gold_dev  False   False             69.2          70.8            71.6
#                   True              70.4          72.8            74.9
#           True    False             73.3          75.6            78.4
#                   True              76.9          76.7            79.1
# gold_test False   False             65.8          67.5            73.7
#                   True              70.5          70.9            74.9
#           True    False             69.5          69.4            75.0
#                   True              72.7          73.9            75.8
# yap_dev   False   False             69.2          70.8            64.8
#                   True              70.4          72.8            66.8
#           True    False             70.7          71.4            67.1
#                   True              73.0          72.7            68.2
# yap_test  False   False             65.8          67.5            64.8
#                   True              70.5          70.9            65.1
#           True    False             65.9          66.3            62.8
#                   True              68.6          69.9            64.1
