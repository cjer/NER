# %% [markdown]
# # Analyze results after treebank alignment

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('paper')
sns.set_style('white')

# %%
import pickle

# %%
import ne_evaluate_mentions as nem

# %% [markdown]
# ## Get token data

# %%
tokens_ner_with_upos_feats = pd.read_csv('align/spmrl_tokens_df.csv.gz', compression='gzip').reset_index()

# %%
tok_gold_dev  = tokens_ner_with_upos_feats[tokens_ner_with_upos_feats.set=='dev']
tok_gold_train = tokens_ner_with_upos_feats[tokens_ner_with_upos_feats.set=='train']
tok_gold_test = tokens_ner_with_upos_feats[tokens_ner_with_upos_feats.set=='test']

# %%
tok_gold_dev_sents =   tok_gold_dev.groupby('sent_id')[['misc_token_str', 'biose']].apply(lambda x: x.values.tolist())
tok_gold_train_sents = tok_gold_train.groupby('sent_id')[['misc_token_str', 'biose']].apply(lambda x: x.values.tolist())
tok_gold_test_sents =  tok_gold_test.groupby('sent_id')[['misc_token_str', 'biose']].apply(lambda x: x.values.tolist())
tok_gold_test_sents.head()
# Out:
# sent_id
# 5439    [[הכל, O], [נושאים, O], [עמם, O], [את, O], [כי...
# 5440    [[אומר, O], [מזכיר, O], [התק"ם, S-ORG], [,, O]...
# 5441    [[לא, O], [ייתכן, O], [שעולה, O], [יבוא, O], [...
# 5442    [[לא, O], [ייתכן, O], [שהוא, O], [יירד, O], [מ...
# 5443    [[לכן, O], [קבענו, O], [עיקרון, O], [שצריכה, O...
# dtype: object

# %%
tok_gold_dev_mentions = nem.sents_to_mentions  (tok_gold_dev_sents  )
tok_gold_train_mentions = nem.sents_to_mentions(tok_gold_train_sents)
tok_gold_test_mentions = nem.sents_to_mentions (tok_gold_test_sents )

tok_gold_dev_mentions[:10]
# Out:
# [(1, 'מתאילנד', 'GPE', 1),
#  (1, 'לישראל', 'GPE', 1),
#  (2, 'בוועדת העבודה והרווחה', 'ORG', 1),
#  (2, 'הכנסת', 'ORG', 1),
#  (3, 'אורה נמיר', 'PER', 1),
#  (3, 'מערך', 'ORG', 1),
#  (3, 'לישראל', 'GPE', 1),
#  (3, 'מתאילנד', 'GPE', 1),
#  (4, 'האוצר', 'ORG', 1),
#  (4, 'משרד העבודה והרווחה', 'ORG', 1)]

# %%
len(tok_gold_train_sents), len(tok_gold_dev_sents), len(tok_gold_test_sents)
# Out:
# (4937, 500, 706)

# %%
len(tok_gold_train), len(tok_gold_dev), len(tok_gold_test)
# Out:
# (93504, 8531, 12619)

# %%
len(tok_gold_train_mentions), len(tok_gold_dev_mentions), len(tok_gold_test_mentions)
# Out:
# (6275, 499, 931)

# %% [markdown]
# ## Get morpheme data

# %%
dropped = [5438, 5444, 5445, 5446, 5448, 5449, 5450, 5451, 5453, 5459]

# %%
spdf = pd.read_csv('align/spdf_fixed.csv.gz', compression='gzip')

# %%
o_morph_gold_dev_sents   =   spdf[spdf.set=='dev'].groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
o_morph_gold_train_sents =   spdf[spdf.set=='train'].groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
o_morph_gold_test_sents  =   spdf[spdf.set=='test'].groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
o_morph_gold_test_sents.head()
# Out:
# sent_id
# 5438    [[אחרים, O], [ב, O], [ה, B-ORG], [תנועה, I-ORG...
# 5439    [[הכל, O], [נושאים, O], [עמ, O], [הם, O], [את,...
# 5440    [[אומר, O], [מזכיר, O], [התק"ם, S-ORG], [,, O]...
# 5441    [[לא, O], [ייתכן, O], [ש, O], [עולה, O], [יבוא...
# 5442    [[לא, O], [ייתכן, O], [ש, O], [הוא, O], [יירד,...
# dtype: object

# %%
spdf = spdf[(~spdf.sent_id.isin(dropped))]

# %%
morph_gold_dev  = spdf[spdf.set=='dev']
morph_gold_train = spdf[spdf.set=='train']
morph_gold_test = spdf[spdf.set=='test']

# %%
morph_gold_dev_sents   =   morph_gold_dev.groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
morph_gold_train_sents = morph_gold_train.groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
morph_gold_test_sents  =  morph_gold_test.groupby('sent_id')[['form', 'biose']].apply(lambda x: x.values.tolist())
morph_gold_test_sents.head()
# Out:
# sent_id
# 5439    [[הכל, O], [נושאים, O], [עמ, O], [הם, O], [את,...
# 5440    [[אומר, O], [מזכיר, O], [התק"ם, S-ORG], [,, O]...
# 5441    [[לא, O], [ייתכן, O], [ש, O], [עולה, O], [יבוא...
# 5442    [[לא, O], [ייתכן, O], [ש, O], [הוא, O], [יירד,...
# 5443    [[לכן, O], [קבענו, O], [עיקרון, O], [ש, O], [צ...
# dtype: object

# %%
morph_gold_dev_mentions = nem.sents_to_mentions  (morph_gold_dev_sents  )
morph_gold_train_mentions = nem.sents_to_mentions(morph_gold_train_sents)
morph_gold_test_mentions = nem.sents_to_mentions (morph_gold_test_sents )

morph_gold_test_mentions[:10]
# Out:
# [(5440, 'התק"ם', 'ORG', 1),
#  (5440, 'מוקי צור', 'PER', 1),
#  (5441, 'צה"ל', 'ORG', 1),
#  (5447, 'ה מחלקה ל התיישבות', 'ORG', 1),
#  (5460, 'חגי בז', 'PER', 1),
#  (5460, 'בריה"ם', 'GPE', 1),
#  (5460, 'ה קיבוץ ה ארצי', 'ORG', 1),
#  (5465, 'ה קיבוץ ה דתי', 'ORG', 1),
#  (5465, 'אריה קרול', 'PER', 1),
#  (5466, 'ה תנועה ה קיבוצית', 'ORG', 1)]

# %%
len(morph_gold_train_sents), len(morph_gold_dev_sents), len(morph_gold_test_sents)
# Out:
# (4937, 500, 706)

# %%
len(morph_gold_train), len(morph_gold_dev), len(morph_gold_test)
# Out:
# (127031, 11301, 16828)

# %%
len(morph_gold_train_mentions), len(morph_gold_dev_mentions), len(morph_gold_test_mentions)
# Out:
# (6270, 498, 931)

# %% [markdown]
# ## Evaluate mentions

# %%
def eval_pred_mentions(preds, gold_mentions, gold_sents, drop_from_pred=[], drop_from_gold=[], verbose=True):
    #print(preds_path)
    pred_sents_l = [[i, list(zip(toks, bs))] 
                    for i, (toks, bs) 
                    in zip(gold_sents.index.drop(drop_from_gold), (zip(preds[0][2], preds[0][3]))) 
                    if i not in drop_from_pred]
    toks = [[tok for tok, bs in p[1]] for p in pred_sents_l]
    def subfinder(mylist, pattern):
        matches = []
        for i in range(len(mylist)):
            if mylist[i] == pattern[0] and mylist[i:i+len(pattern)] == pattern:
                matches.append(pattern)
        return matches

    split_mentions = [[x[1].split(' ') for x in gold_mentions if x[0]==i] 
                      for i in gold_sents.index.drop(drop_from_gold)
                      if i not in drop_from_gold]
    present = []
    for spl, tok in zip(split_mentions, toks):
        mid = []
        for ment in spl:
            mid.append(len(subfinder(tok, ment))>0)
        present.append(sum(mid))
    if verbose:
        print([(i, x) for i, x in enumerate(zip(present, [len(spl) for spl in split_mentions])) if x[1]-x[0]>=2])
        #print(toks[231])
        print ('only', round(sum(present)/len(gold_mentions), 2), 'available mentions (due to different segmentation)')
    pred_sents = pd.Series(index=[idx for idx, s in pred_sents_l], data=[s for idx, s in pred_sents_l])
    pred_mentions = nem.sents_to_mentions(pred_sents)
    return nem.evaluate_mentions(gold_mentions, pred_mentions, verbose=verbose)

# %% [markdown]
# ### Evaluate morphemes

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
morph_gold_sents = (o_morph_gold_test_sents, o_morph_gold_dev_sents, o_morph_gold_test_sents)
morph_gold_extra_preds = (morph_gold_test_mentions, morph_gold_dev_mentions, morph_gold_test_mentions)
pred_set = ('gold_test', 'yap_dev', 'yap_test')
drop_from_pred = ([dropped], [], [])
drop_from_gold = ([], [], dropped)
morph_res = []
for ep in sorted(glob.glob('results/new_outputs/*morph*-extra_preds-*')):
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), morph_gold_extra_preds[i], morph_gold_sents[i], drop_from_pred[i], drop_from_gold[i])]
    morph_res.append(res)
# Out:
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 764 found, 395 correct.
# Precision: 0.42
# Recall:    0.52
# F1:        0.47
# FP ex.: ['ה התאחדות שלמה', 'רמקולים השמיעו', 'האקט', 'בניה', 'ש. י. ל. נ']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 368 found, 181 correct.
# Precision: 0.36
# Recall:    0.49
# F1:        0.42
# FP ex.: ['כהונת מושל', 'מערב ה תיכון', 'פורד שמרנים', 'דוחקות', 'ה ארץ']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 713 found, 340 correct.
# Precision: 0.37
# Recall:    0.48
# F1:        0.41
# FP ex.: ['סלוניקי', 'רמקולים השמיעו', 'בניה', 'נוסטלגי', 'ש. י. ל. נ']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 961 found, 541 correct.
# Precision: 0.58
# Recall:    0.56
# F1:        0.57
# FP ex.: ['אוקזר', 'האקט', 'שוהם', 'צילי', 'ה צבא ה סדיר ה כווייתי']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'ויאלי', 'מילאנו', 'לטיום']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 448 found, 227 correct.
# Precision: 0.46
# Recall:    0.51
# F1:        0.48
# FP ex.: ['ה ירושלים', 'גדירות', 'קטמון תקועה', 'פורד שמרנים', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 849 found, 395 correct.
# Precision: 0.42
# Recall:    0.47
# F1:        0.44
# FP ex.: ['ה רפובליקה ה רוסית', 'אוקזר', 'ה הרצליה', 'בית לאדמו"ר ו שיכון', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'ויאלי', 'מילאנו', 'גיילס']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 908 found, 697 correct.
# Precision: 0.75
# Recall:    0.77
# F1:        0.76
# FP ex.: ['כוויית', 'מוצי', 'לזניה', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['שבריאנט', 'ק - ל - מ', 'דן צבר', 'סאברס', 'אנ.בי.איי']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 413 found, 306 correct.
# Precision: 0.61
# Recall:    0.74
# F1:        0.67
# FP ex.: ['ה ירושלים', 'רץ', 'פומפידו חנינה', 'ה ירושלים', 'קטיף']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 822 found, 559 correct.
# Precision: 0.6
# Recall:    0.68
# F1:        0.64
# FP ex.: ['כוויית', 'פיניקס', 'רמת ה שרון', 'מעיין בגבעתיים', 'גביע אופ"א']
# FN ex.: ['מילאנו', 'ישראל', 'לטיום', 'גיילס', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 938 found, 714 correct.
# Precision: 0.77
# Recall:    0.76
# F1:        0.76
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א', 'לה קוצינה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 420 found, 306 correct.
# Precision: 0.61
# Recall:    0.73
# F1:        0.67
# FP ex.: ['ה ירושלים', 'תהילים', 'רץ', 'מריה', 'פורד שמרנים']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'סילבר']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 833 found, 573 correct.
# Precision: 0.62
# Recall:    0.69
# F1:        0.65
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'שובה עין', 'לשניים', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'גיילס', 'לטיום', 'רכסים', 'גבת']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 874 found, 645 correct.
# Precision: 0.69
# Recall:    0.74
# F1:        0.71
# FP ex.: ['ה אדמו"ר', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א', 'לה קוצינה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 450 found, 313 correct.
# Precision: 0.63
# Recall:    0.7
# F1:        0.66
# FP ex.: ['באשר', 'רץ', 'פורד שמרנים', 'ולד', 'פאפון']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 845 found, 560 correct.
# Precision: 0.6
# Recall:    0.66
# F1:        0.63
# FP ex.: ['ה אדמו"ר', 'נעים', 'ה הפועל אום אל פאחם', 'ירושלים', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'לטיום', 'רכסים', 'גבת']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 979 found, 650 correct.
# Precision: 0.7
# Recall:    0.66
# F1:        0.68
# FP ex.: ['1920', 'כיפת ה סלע', '2840', 'ה התאחדות שלמה', 'פנמן']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 484 found, 314 correct.
# Precision: 0.63
# Recall:    0.65
# F1:        0.64
# FP ex.: ['באשר', 'רץ', 'מריה', 'פורד שמרנים', 'שרה סקאיף']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 952 found, 550 correct.
# Precision: 0.59
# Recall:    0.58
# F1:        0.58
# FP ex.: ['ניוקי', 'בית לאדמו"ר ו שיכון', 'בניה', 'שוהם', 'באשדוד']
# FN ex.: ['הרצליה פיתוח', 'לטיום', 'רכסים', 'סאגואירוש', 'פורוורטס שטייר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 899 found, 684 correct.
# Precision: 0.73
# Recall:    0.76
# F1:        0.75
# FP ex.: ['כוויית', 'מוצי', 'לזניה', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ', 'דן צבר']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 417 found, 303 correct.
# Precision: 0.61
# Recall:    0.73
# F1:        0.66
# FP ex.: ['רץ', 'מריה', 'פומפידו חנינה', 'קרן פורד ב 1989', 'קרן רוקפלר ב ה בלאגיו']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'סילבר']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 784 found, 545 correct.
# Precision: 0.59
# Recall:    0.7
# F1:        0.64
# FP ex.: ['שובה עין', 'ה הפועל אום אל פאחם', 'עו', 'כוויית', 'פיניקס']
# FN ex.: ['מילאנו', 'גיילס', 'לטיום', 'רכסים', 'גבת']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 913 found, 691 correct.
# Precision: 0.74
# Recall:    0.76
# F1:        0.75
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'כוויית', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 411 found, 310 correct.
# Precision: 0.62
# Recall:    0.75
# F1:        0.68
# FP ex.: ['ה ירושלים', 'תהילים', 'רץ', 'מריה', 'פורד שמרנים']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 793 found, 543 correct.
# Precision: 0.58
# Recall:    0.68
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'פיניקס', 'רמת ה שרון', 'בולוניה']
# FN ex.: ['הרצליה פיתוח', 'גיילס', 'לטיום', 'רכסים', 'גבת']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 863 found, 482 correct.
# Precision: 0.52
# Recall:    0.56
# F1:        0.54
# FP ex.: ['נאגטס', 'שלשול', 'סלוניקי', 'וילות', 'בוסאני שיחררה']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'לטיום', 'רכסים', 'סאגואירוש']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 392 found, 208 correct.
# Precision: 0.42
# Recall:    0.53
# F1:        0.47
# FP ex.: ['ה ירושלים', 'רץ', 'פורד שמרנים', 'וולסטון', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 830 found, 403 correct.
# Precision: 0.43
# Recall:    0.49
# F1:        0.46
# FP ex.: ['נאגטס', 'שלשול', 'סלוניקי', 'וילות', 'ה הרצליה']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'לטיום', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 959 found, 593 correct.
# Precision: 0.64
# Recall:    0.62
# F1:        0.63
# FP ex.: ['נאגטס', 'רח ה מרי', 'ה התאחדות שלמה', 'אוקזר', 'האקט']
# FN ex.: ['הרצליה פיתוח', 'אנדרלכט', 'טורינו', 'קלניניגרד', 'ק - ל - מ']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 434 found, 242 correct.
# Precision: 0.49
# Recall:    0.56
# F1:        0.52
# FP ex.: ['תהילים', 'גדירות', 'קטמון תקועה', 'רץ', 'פורד שמרנים']
# FN ex.: ['בוסקה', 'קרן פורד', 'ליון', 'הארקין', 'זורז פומפידו']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 841 found, 449 correct.
# Precision: 0.48
# Recall:    0.53
# F1:        0.51
# FP ex.: ['אוקזר', 'סלוניקי', 'בנקס ו ספנסר', 'סאברס', 'איראקליס']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'גיילס', 'לטיום', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 829 found, 646 correct.
# Precision: 0.69
# Recall:    0.78
# F1:        0.73
# FP ex.: ['נאגטס', 'פיניקס', 'רמת ה שרון', 'פורד קאנטו', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 396 found, 300 correct.
# Precision: 0.6
# Recall:    0.76
# F1:        0.67
# FP ex.: ['מריה', 'פורד שמרנים', 'פומפידו חנינה', 'ה ירושלים', 'ה ישראל']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 790 found, 560 correct.
# Precision: 0.6
# Recall:    0.71
# F1:        0.65
# FP ex.: ['נאגטס', 'פיניקס', 'רמת ה שרון', 'פורד קאנטו', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'ויאלי', 'לטיום', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 866 found, 654 correct.
# Precision: 0.7
# Recall:    0.76
# F1:        0.73
# FP ex.: ['פנמן', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א', 'לה קוצינה']
# FN ex.: ['קלניניגרד', 'שבריאנט', 'דן צבר', 'אנ.בי.איי', 'ה וולגה']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 412 found, 302 correct.
# Precision: 0.61
# Recall:    0.73
# F1:        0.66
# FP ex.: ['התלוננה תרזה אודנדל', 'ה ירושלים', 'באשר', 'מריה', 'פורד שמרנים']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'טובייה']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 799 found, 546 correct.
# Precision: 0.59
# Recall:    0.68
# F1:        0.63
# FP ex.: ['ה הפועל אום אל פאחם', 'לטיות', 'פנמן', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['מילאנו', 'ישראל', 'לטיום', 'רכסים', 'גבת']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 843 found, 7 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['ספרטה רוטרדאם', 'ה פועל ירושלים', 'גוזף עליני', 'עירערה', 'זאב זלצר']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 400 found, 184 correct.
# Precision: 0.37
# Recall:    0.46
# F1:        0.41
# FP ex.: ['כהונת מושל', 'חקלאיים הציעה', 'קטמון תקועה', 'רץ', 'ה התאחדות ל עולם טוב']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'זורז פומפידו']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 804 found, 360 correct.
# Precision: 0.39
# Recall:    0.45
# F1:        0.41
# FP ex.: ['מינהל מקרקעי ישראל', 'עשבי מאכל', 'רמקולים השמיעו', 'בוסאני שיחררה', 'קיבלנו ל ה קינוח']
# FN ex.: ['קאמינגס', 'ויאלי', 'מילאנו', 'גיילס', 'לטיום']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 939 found, 10 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['ספרטה רוטרדאם', 'גוזף עליני', 'קארל שאט', 'זאב זלצר', 'שטיינברג']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 425 found, 230 correct.
# Precision: 0.46
# Recall:    0.54
# F1:        0.5
# FP ex.: ['ה מועמדת ה דמוקרטית', 'ה ירושלים', 'גדירות', 'ריצארדס', 'רץ']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 824 found, 413 correct.
# Precision: 0.44
# Recall:    0.5
# F1:        0.47
# FP ex.: ['בברלין', 'אוקזר', 'ה הרצליה', 'איראקליס', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'ויאלי', 'מילאנו', 'גיילס']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 859 found, 8 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['איראקליס', 'ה פועל ירושלים', 'גוזף עליני', 'קארל שאט', 'זאב זלצר']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 387 found, 301 correct.
# Precision: 0.6
# Recall:    0.78
# F1:        0.68
# FP ex.: ['רץ', 'מריה', 'פורד שמרנים', 'ה ירושלים', 'ה ישראל']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 751 found, 528 correct.
# Precision: 0.57
# Recall:    0.7
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'בהרצליה פיתוח', 'פיניקס', 'רמת ה שרון', 'סן אנטוניו']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'ויאלי', 'מילאנו', 'גיילס']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 970 found, 9 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['איראקליס', 'ה פועל ירושלים', 'גוזף עליני', 'קארל שאט', 'זאב זלצר']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 449 found, 324 correct.
# Precision: 0.65
# Recall:    0.72
# F1:        0.68
# FP ex.: ['רץ', 'מריה', 'פורד שמרנים', 'פומפידו חנינה', 'ה ירושלים']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 903 found, 581 correct.
# Precision: 0.62
# Recall:    0.64
# F1:        0.63
# FP ex.: ['ה וותה', 'ה הפועל אום אל פאחם', 'לשניים', 'פנמן', 'נצח']
# FN ex.: ['הרצליה פיתוח', 'גיילס', 'לטיום', 'רכסים', 'רמת ה שרון']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 911 found, 11 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['איראקליס', 'ה פועל ירושלים', 'גוזף עליני', 'גראץ', 'קארל שאט']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 454 found, 315 correct.
# Precision: 0.63
# Recall:    0.69
# F1:        0.66
# FP ex.: ['באשר', 'רץ', 'מריה', 'פומפידו חנינה', 'שרה סקאיף']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 873 found, 565 correct.
# Precision: 0.61
# Recall:    0.65
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'נעים', 'כוויית', '2840']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'ויאלי', 'לטיום', 'רכסים']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 828 found, 11 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['איראקליס', 'ה פועל ירושלים', 'גוזף עליני', 'קארל שאט', 'זאב זלצר']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 406 found, 305 correct.
# Precision: 0.61
# Recall:    0.75
# F1:        0.67
# FP ex.: ['מריה', 'פורד שמרנים', 'ה ירושלים', 'ולד', 'כהן']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 787 found, 538 correct.
# Precision: 0.58
# Recall:    0.68
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'ה הפועל אום אל פאחם', 'פנמן', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'לטיום', 'רכסים', 'סאגואירוש', 'בולי']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 951 found, 10 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['איראקליס', 'ה פועל ירושלים', 'גוזף עליני', 'קארל שאט', 'זאב זלצר']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 449 found, 317 correct.
# Precision: 0.64
# Recall:    0.71
# F1:        0.67
# FP ex.: ['ה ירושלים', 'רץ', 'מריה', 'פומפידו חנינה', 'ה אפגניסטן']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 873 found, 565 correct.
# Precision: 0.61
# Recall:    0.65
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'ה הפועל אום אל פאחם', 'ירושלים', 'בהרצליה פיתוח']
# FN ex.: ['הרצליה פיתוח', 'לטיום', 'גבת', 'חגי בז', 'רמת ה שרון']
# ...
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 654 found, 12 correct.
# Precision: 0.01
# Recall:    0.02
# F1:        0.02
# FP ex.: ['ה פועל ירושלים', 'גוזף עליני', 'אופ"א', 'זאב זלצר', 'עקילוב']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 324 found, 200 correct.
# Precision: 0.4
# Recall:    0.62
# F1:        0.49
# FP ex.: ['רץ', 'פורד שמרנים', 'שרה סקאיף', 'פומפידו חנינה', 'תבוסת בושוויץ']
# FN ex.: ['בוסקה', 'קרן פורד', 'הארקין', 'זורז פומפידו', 'ה']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 616 found, 345 correct.
# Precision: 0.37
# Recall:    0.56
# F1:        0.45
# FP ex.: ['כוויית', 'כיכר', 'פיניקס', 'מרכז ה ארץ', '- סבא']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'גיילס', 'לטיום']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 968 found, 7 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['ספרטה רוטרדאם', 'איראקליס', 'גוזף עליני', 'ה פועל ירושלים', 'גראץ']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 425 found, 238 correct.
# Precision: 0.48
# Recall:    0.56
# F1:        0.52
# FP ex.: ['ריצארדס', 'פורד שמרנים', 'פומפידו חנינה', 'ה ישראל', 'פורד']
# FN ex.: ['בוסקה', 'קרן פורד', 'ליון', 'הארקין', 'זורז פומפידו']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 862 found, 439 correct.
# Precision: 0.47
# Recall:    0.51
# F1:        0.49
# FP ex.: ['טוסקאנה', 'אוקזר', 'פיניקס', 'יעקב', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'גיילס', 'לטיום', 'רכסים']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 866 found, 11 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['איראקליס', 'ה פועל ירושלים', 'גוזף עליני', 'קארל שאט', 'זאב זלצר']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 400 found, 300 correct.
# Precision: 0.6
# Recall:    0.75
# F1:        0.67
# FP ex.: ['מריה', 'שרה סקאיף', 'לטום הארקין', 'כנסת', 'נווה - מונוסון']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 835 found, 575 correct.
# Precision: 0.62
# Recall:    0.69
# F1:        0.65
# FP ex.: ['בתי - משפט ה שלום', 'בהרצליה פיתוח', 'פיניקס', 'מחלקה ל ה מחלקה', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'לטיום', 'רכסים']
# [(2, (0, 2)), (22, (0, 3)), (27, (0, 2)), (29, (0, 3)), (30, (0, 2)), (33, (0, 4)), (34, (0, 2)), (36, (0, 2)), (37, (0, 2)), (38, (0, 3)), (41, (0, 3)), (42, (0, 12)), (43, (0, 6)), (45, (0, 2)), (49, (0, 2)), (52, (0, 3)), (53, (0, 4)), (54, (0, 3)), (55, (0, 6)), (59, (0, 2)), (60, (0, 2)), (64, (0, 3)), (69, (0, 3)), (70, (0, 2)), (80, (0, 2)), (82, (0, 2)), (83, (0, 7)), (84, (0, 2)), (85, (0, 7)), (87, (0, 2)), (90, (0, 2)), (92, (0, 2)), (93, (0, 3)), (94, (0, 3)), (97, (0, 3)), (100, (0, 2)), (104, (0, 2)), (105, (0, 2)), (107, (0, 3)), (112, (0, 4)), (116, (0, 2)), (118, (0, 2)), (120, (0, 2)), (123, (0, 2)), (125, (0, 4)), (128, (0, 2)), (129, (0, 2)), (130, (0, 2)), (131, (0, 2)), (132, (1, 5)), (133, (0, 2)), (134, (0, 4)), (135, (0, 2)), (137, (0, 2)), (138, (0, 2)), (141, (0, 6)), (142, (0, 4)), (144, (0, 3)), (145, (0, 3)), (146, (0, 4)), (147, (0, 2)), (148, (0, 6)), (149, (0, 2)), (150, (0, 2)), (151, (0, 4)), (152, (0, 13)), (153, (0, 2)), (154, (0, 3)), (155, (0, 5)), (156, (0, 2)), (157, (0, 14)), (158, (0, 2)), (159, (0, 4)), (160, (0, 3)), (161, (0, 4)), (162, (0, 3)), (163, (0, 8)), (164, (0, 17)), (165, (0, 4)), (166, (0, 12)), (167, (0, 3)), (168, (0, 3)), (169, (0, 2)), (170, (0, 14)), (171, (0, 4)), (172, (0, 18)), (173, (0, 6)), (175, (0, 2)), (176, (1, 4)), (177, (0, 6)), (178, (0, 2)), (179, (0, 3)), (180, (0, 2)), (181, (0, 2)), (184, (0, 2)), (186, (0, 2)), (187, (0, 2)), (188, (0, 3)), (195, (0, 2)), (197, (0, 7)), (205, (0, 2)), (206, (0, 2)), (209, (0, 2)), (210, (0, 6)), (212, (0, 2)), (215, (0, 2)), (216, (0, 4)), (217, (0, 2)), (221, (0, 2)), (222, (0, 2)), (223, (0, 2)), (225, (0, 9)), (228, (0, 2)), (231, (0, 4)), (233, (0, 4)), (234, (0, 2)), (235, (0, 2)), (236, (0, 2)), (237, (0, 4)), (245, (0, 3)), (256, (0, 3)), (257, (0, 2)), (258, (0, 3)), (259, (0, 2)), (270, (0, 2)), (276, (0, 2)), (277, (0, 2)), (278, (0, 5)), (290, (0, 3)), (291, (0, 2)), (293, (0, 2)), (294, (0, 3)), (300, (0, 2)), (302, (0, 2)), (303, (1, 3)), (306, (0, 2)), (307, (0, 2)), (308, (0, 2)), (309, (0, 2)), (311, (0, 6)), (315, (0, 2)), (322, (0, 2)), (324, (0, 3)), (327, (0, 2)), (328, (0, 6)), (330, (0, 2)), (332, (0, 2)), (333, (0, 3)), (334, (0, 5)), (335, (0, 2)), (336, (0, 8)), (337, (0, 4)), (339, (0, 5)), (340, (0, 2)), (341, (0, 2)), (343, (0, 2)), (348, (0, 2)), (352, (0, 2)), (353, (0, 3)), (356, (0, 4)), (357, (0, 2)), (361, (0, 2)), (367, (0, 4)), (393, (0, 2)), (398, (0, 3)), (402, (0, 2)), (412, (0, 4)), (421, (0, 3)), (422, (0, 2)), (423, (0, 3)), (426, (0, 2)), (427, (1, 3)), (431, (0, 4)), (432, (0, 2)), (433, (1, 4)), (434, (0, 2)), (437, (0, 5)), (438, (0, 2)), (439, (0, 2)), (441, (0, 2)), (442, (0, 3)), (445, (0, 2)), (446, (0, 4)), (448, (0, 2)), (451, (0, 2)), (452, (0, 5)), (455, (0, 4)), (456, (0, 5)), (458, (0, 2)), (460, (0, 2)), (461, (0, 3)), (462, (0, 2)), (463, (0, 2)), (464, (0, 3)), (465, (0, 4)), (466, (0, 6)), (467, (0, 2)), (469, (0, 2)), (472, (0, 4)), (478, (0, 3)), (481, (0, 2)), (485, (0, 3)), (487, (0, 2)), (498, (0, 2)), (501, (0, 2)), (502, (0, 2)), (503, (0, 2)), (505, (0, 2)), (511, (0, 2)), (513, (0, 3)), (515, (0, 3)), (516, (0, 2)), (527, (0, 2)), (528, (0, 4)), (534, (0, 2)), (537, (0, 4)), (547, (0, 4)), (548, (0, 4)), (549, (0, 5)), (551, (0, 2)), (553, (0, 3)), (570, (0, 2)), (572, (0, 2)), (580, (0, 2)), (624, (0, 3)), (662, (0, 3)), (673, (0, 3)), (698, (0, 2))]
# only 0.02 available mentions (due to different segmentation)
# 931 mentions, 909 found, 8 correct.
# Precision: 0.01
# Recall:    0.01
# F1:        0.01
# FP ex.: ['איראקליס', 'ה פועל ירושלים', 'גוזף עליני', 'אופ"א', 'גראץ']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 441 found, 318 correct.
# Precision: 0.64
# Recall:    0.72
# F1:        0.68
# FP ex.: ['באשר', 'מנזר סן סימון', 'פורד שמרנים', 'מריה', 'שרה סקאיף']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 876 found, 560 correct.
# Precision: 0.6
# Recall:    0.64
# F1:        0.62
# FP ex.: ['נאגטס', 'ה הפועל אום אל פאחם', 'פנמן', 'ה ריה"ם', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'לטיום', 'רכסים', 'פורוורטס שטייר']

# %%
defaults = {"use_word": True, "use_pos": False, "embedding_matrix": None, 
"embed_dim": 70, "trainable": True, "input_dropout": False, "stack_lstm": 1,
"epochs": 100, "early_stopping": True, "patience": 20, "min_delta": 0.0001,
"use_char": False, "crf": False, "add_random_embedding": True, "pretrained_embed_dim": 300,
"stack_cross": False, "stack_double": False, "rec_dropout": 0.1,
"validation_split": 0.1}

# %%
morph_conf_gold_dev_res = pickle.load(open('results/new_outputs/treebank_morphemes_conf_res_preds_hist.pkl', 'rb'))
morph_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0] } for i, x in enumerate(morph_conf_gold_dev_res)]
morph_conf_gold_dev_res
# Out:
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False},
#   'results': (51.43603133159269, 39.558232931726906, 44.72190692395005)},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True},
#   'results': (51.01522842639594, 40.36144578313253, 45.06726457399103)},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (73.20675105485233, 69.67871485943775, 71.39917695473251)},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (69.5906432748538, 71.6867469879518, 70.62314540059347)},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (76.0, 57.22891566265061, 65.29209621993127)},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (75.74123989218329, 56.42570281124498, 64.67203682393557)},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False},
#   'results': (59.75, 47.99196787148594, 53.22939866369711)},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True},
#   'results': (55.989583333333336, 43.17269076305221, 48.75283446712018)},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (85.25, 68.47389558232932, 75.94654788418708)},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (79.21478060046189, 68.87550200803213, 73.68421052631578)},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (77.11171662125341, 56.827309236947784, 65.4335260115607)},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (76.8, 57.831325301204814, 65.97938144329896)}]

# %%
conf_i = {x['conf']: x['config'] for x in morph_conf_gold_dev_res}
for r in morph_res:
    r['config'] = conf_i[r['conf']]
    
morph_res = morph_res+morph_conf_gold_dev_res

# %%
for r in morph_res:
    r['unit'] = 'morpheme'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]
morph_res[0]
# Out:
# {'pred_set': 'gold_test',
#  'conf': 0,
#  'results': [42.42749731471536, 51.70157068062827, 46.60766961651917],
#  'config': {'crf': True,
#   'use_pos': False,
#   'use_word': True,
#   'embedding_matrix': None,
#   'embed_dim': 70,
#   'trainable': True,
#   'input_dropout': False,
#   'stack_lstm': 1,
#   'epochs': 100,
#   'early_stopping': True,
#   'patience': 20,
#   'min_delta': 0.0001,
#   'use_char': False,
#   'add_random_embedding': True,
#   'pretrained_embed_dim': 300,
#   'stack_cross': False,
#   'stack_double': False,
#   'rec_dropout': 0.1,
#   'validation_split': 0.1},
#  'unit': 'morpheme'}

# %%
def get_results_df(res):
    dict_res = []
    
    for r in res:
        dr = {}
        dr['pred_set'] = r['pred_set']
        dr['unit'] = r['unit']
        dr['prec'], dr['recall'], dr['f1'] = r['results']
        dr.update(r['config'])
        dict_res.append(dr)
    rdf = pd.DataFrame(dict_res)
    return rdf

rdf = get_results_df(morph_res)
rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  46.607670          False     0.0001        20  ...  51.701571
# 1     100  41.801386          False     0.0001        20  ...  49.184783
# 2     100  41.362530          False     0.0001        20  ...  47.685835
# 3     100  57.188161          False     0.0001        20  ...  56.295525
# 4     100  47.991543          False     0.0001        20  ...  50.669643
#
#   stack_cross  stack_double  stack_lstm  trainable      unit  use_char  \
# 0       False         False           1       True  morpheme     False
# 1       False         False           1       True  morpheme     False
# 2       False         False           1       True  morpheme     False
# 3       False         False           1       True  morpheme     False
# 4       False         False           1       True  morpheme     False
#
#    use_pos  use_word validation_split
# 0    False      True              0.1
# 1    False      True              0.1
# 2    False      True              0.1
# 3     True      True              0.1
# 4     True      True              0.1
#
# [5 rows x 24 columns]

# %%
rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix']).f1.max().unstack()
# Out:
# embedding_matrix                 None  pretrained_token_ft  yap_ft_sg
# pred_set  use_pos use_char
# gold_dev  False   False     44.721907            70.623145  71.399177
#                   True      53.229399            73.684211  75.946548
#           True    False     45.067265            64.672037  65.292096
#                   True      48.752834            65.979381  65.433526
# gold_test False   False     46.607670            68.062827  71.468144
#                   True      53.734671            72.787980  73.409091
#           True    False     57.188161            74.945770  74.754098
#                   True      62.751323            76.404494  75.802066
# yap_dev   False   False     41.801386            67.477876  66.176471
#                   True      48.661800            68.201754  67.168999
#           True    False     51.022605            68.206821  67.115600
#                   True      54.229935            68.426610  68.217054
# yap_test  False   False     41.498559            62.630966  64.787112
#                   True      50.029780            63.944796  65.118913
#           True    False     47.065527            62.993039  63.556851
#                   True      50.677201            64.965986  64.114286

# %% [markdown]
# ### Evaluate tokens

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
tok_gold_sents = (tok_gold_test_sents, tok_gold_dev_sents, tok_gold_test_sents)
tok_gold_extra_preds = (tok_gold_test_mentions, tok_gold_dev_mentions, tok_gold_test_mentions)
pred_set = ('gold_test', 'yap_dev', 'yap_test')

tok_res = []
for ep in sorted(glob.glob('results/new_outputs/*tokens*-extra_preds-*')):
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), tok_gold_extra_preds[i], tok_gold_sents[i])]
    tok_res.append(res)
# Out:
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 877 found, 332 correct.
# Precision: 0.36
# Recall:    0.38
# F1:        0.37
# FP ex.: ['שהסתפק בשלשה', 'נעים', 'סלוניקי', 'דורטמונד', 'בשמינית גמר גביע האלופות']
# FN ex.: ['מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'ישראל', 'גיילס']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 442 found, 178 correct.
# Precision: 0.36
# Recall:    0.4
# F1:        0.38
# FP ex.: ['התורה שלימדת', 'לרוחב מלוא העמוד', 'תועלתניים', 'מאיר כהן', 'המונח שטבע דווייט מקדונלד בקרן פורד']
# FN ex.: ['בוסקה', 'באיובה', 'הארקין', 'זורז פומפידו', 'ה']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 877 found, 332 correct.
# Precision: 0.36
# Recall:    0.38
# F1:        0.37
# FP ex.: ['שהסתפק בשלשה', 'נעים', 'סלוניקי', 'דורטמונד', 'בשמינית גמר גביע האלופות']
# FN ex.: ['מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'ישראל', 'גיילס']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 906 found, 484 correct.
# Precision: 0.52
# Recall:    0.53
# F1:        0.53
# FP ex.: ['בבית היהודי', 'אוקזר', 'החוץ', 'האקט', 'ללידס']
# FN ex.: ['מזרח - פרוסיה', 'גיילס', 'רמת השרון', 'רכסים', 'גבת']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 423 found, 224 correct.
# Precision: 0.45
# Recall:    0.53
# F1:        0.49
# FP ex.: ['רץ', 'לישראל', 'שדות התעופה', 'בהגזת', 'פורד']
# FN ex.: ['בוסקה', 'באיובה', 'זורז פומפידו', 'ה', 'באיובה']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 823 found, 413 correct.
# Precision: 0.44
# Recall:    0.5
# F1:        0.47
# FP ex.: ['בבית היהודי', 'אוקזר', 'החוץ', 'בצורך ברפורמה', 'ברוטב המבוסס']
# FN ex.: ['מזרח - פרוסיה', 'גיילס', 'רמת השרון', 'רכסים', 'גבת']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 962 found, 675 correct.
# Precision: 0.73
# Recall:    0.7
# F1:        0.71
# FP ex.: ['אחים נחום', 'הוולגה', 'בורמור', 'פיניקס', 'מכבי מוביל']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 448 found, 350 correct.
# Precision: 0.7
# Recall:    0.78
# F1:        0.74
# FP ex.: ['רץ', 'בנווה - מונוסון', 'קטיף', 'במדינות הברית', 'שפתיי']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'תנועת המושבים', 'בעין כרם']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 893 found, 623 correct.
# Precision: 0.67
# Recall:    0.7
# F1:        0.68
# FP ex.: ['שובה עין', 'עו', 'אחים נחום', 'הוולגה', 'מכבי מוביל']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 970 found, 684 correct.
# Precision: 0.73
# Recall:    0.71
# F1:        0.72
# FP ex.: ['מקליוולנד', 'פיניקס', 'לה קוצינה', 'טלייריני אלה - מארינרה', 'לוריין']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 457 found, 334 correct.
# Precision: 0.67
# Recall:    0.73
# F1:        0.7
# FP ex.: ['שגורג', 'באיובה', 'קטיף', 'במדינות הברית', 'בהגזת']
# FN ex.: ['זורז פומפידו', 'באיובה', 'תנועת המושבים', 'בעין כרם', 'לסילבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 914 found, 633 correct.
# Precision: 0.68
# Recall:    0.69
# F1:        0.69
# FP ex.: ['מקליוולנד', 'פיניקס', 'פיאבה', 'לה קוצינה', 'טלייריני אלה - מארינרה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 772 found, 546 correct.
# Precision: 0.59
# Recall:    0.71
# F1:        0.64
# FP ex.: ['באזור התעשייה', 'דן בורנשטיין וגוזף', 'ברוז הבלגית', 'פיניקס', 'בולוניה']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'גיילס', 'רמת השרון', 'מקליוולנד']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 382 found, 311 correct.
# Precision: 0.62
# Recall:    0.81
# F1:        0.71
# FP ex.: ['טוד ויטמן', 'ירושלים', 'למחלקת המדינה', 'ישראל', 'מרכז המידע לזכויות']
# FN ex.: ['באיובה', 'הארקין', 'זורז פומפידו', 'ה', 'באיובה']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 772 found, 546 correct.
# Precision: 0.59
# Recall:    0.71
# F1:        0.64
# FP ex.: ['באזור התעשייה', 'דן בורנשטיין וגוזף', 'ברוז הבלגית', 'פיניקס', 'בולוניה']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'גיילס', 'רמת השרון', 'מקליוולנד']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 872 found, 596 correct.
# Precision: 0.64
# Recall:    0.68
# F1:        0.66
# FP ex.: ['טוסקאנה', 'דן בורנשטיין וגוזף', 'בחלקו העליון', 'פנמן', 'צזנה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'ניר ריכליס', 'מזרח - פרוסיה', 'ק - ל - מ']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 450 found, 325 correct.
# Precision: 0.65
# Recall:    0.72
# F1:        0.68
# FP ex.: ['ולאריגה', 'באשר', 'רץ', 'קטיף', 'ברבים']
# FN ex.: ['באיובה', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 872 found, 596 correct.
# Precision: 0.64
# Recall:    0.68
# F1:        0.66
# FP ex.: ['טוסקאנה', 'דן בורנשטיין וגוזף', 'בחלקו העליון', 'פנמן', 'צזנה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'ניר ריכליס', 'מזרח - פרוסיה', 'ק - ל - מ']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 976 found, 685 correct.
# Precision: 0.74
# Recall:    0.7
# F1:        0.72
# FP ex.: ['באזור התעשייה', 'דן בורנשטיין וגוזף', 'עו', 'בחלקו העליון', 'פיניקס']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר', 'פיזה']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 484 found, 345 correct.
# Precision: 0.69
# Recall:    0.71
# F1:        0.7
# FP ex.: ['באשר', 'רץ', 'מנזר סן סימון', 'באיובה', 'מאיר כהן']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 932 found, 637 correct.
# Precision: 0.68
# Recall:    0.68
# F1:        0.68
# FP ex.: ['לשניים', 'באזור התעשייה', 'דן בורנשטיין וגוזף', 'עו', 'בחלקו העליון']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'ניר ריכליס', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 935 found, 658 correct.
# Precision: 0.71
# Recall:    0.7
# F1:        0.71
# FP ex.: ['פיניקס', 'צזנה', 'אינדיאנה', 'לוריין', 'בקלינינגרד']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'מזרח - פרוסיה', 'דן צבר', 'אשקלון אדום']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 442 found, 326 correct.
# Precision: 0.65
# Recall:    0.74
# F1:        0.69
# FP ex.: ['רץ', 'באיובה', 'בממשלת באר', 'מאיר כהן', 'פאפון וטובייה']
# FN ex.: ['זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 858 found, 608 correct.
# Precision: 0.65
# Recall:    0.71
# F1:        0.68
# FP ex.: ['פיניקס', 'צזנה', 'אינדיאנה', 'לוריין', 'בקלינינגרד']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'ניר ריכליס', 'מזרח - פרוסיה', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 656 found, 349 correct.
# Precision: 0.37
# Recall:    0.53
# F1:        0.44
# FP ex.: ['בקר נא במרינדה', 'גן מסוגנן', 'פיניקס', 'טלגם והזמרת וייזל - קפסוטו', 'דן']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'ישראל', 'גיילס', 'מקליוולנד']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 338 found, 186 correct.
# Precision: 0.37
# Recall:    0.55
# F1:        0.44
# FP ex.: ['התורה שלימדת', 'רץ', 'מאיר כהן', 'בשטחים', 'שדות התעופה']
# FN ex.: ['בוסקה', 'באיובה', 'הארקין', 'זורז פומפידו', 'ה']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 656 found, 349 correct.
# Precision: 0.37
# Recall:    0.53
# F1:        0.44
# FP ex.: ['בקר נא במרינדה', 'גן מסוגנן', 'פיניקס', 'טלגם והזמרת וייזל - קפסוטו', 'דן']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'ישראל', 'גיילס', 'מקליוולנד']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 862 found, 501 correct.
# Precision: 0.54
# Recall:    0.58
# F1:        0.56
# FP ex.: ['אוקזר', 'סלוניקי', 'ללידס', 'שוהם', 'מרוסיה']
# FN ex.: ['מזרח - פרוסיה', 'גיילס', 'רמת השרון', 'מקליוולנד', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 411 found, 239 correct.
# Precision: 0.48
# Recall:    0.58
# F1:        0.53
# FP ex.: ['תהילים', 'אורגון', 'שגורג', 'רץ', 'שדות התעופה']
# FN ex.: ['בוסקה', 'באיובה', 'זורז פומפידו', 'ה', 'באיובה']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 777 found, 425 correct.
# Precision: 0.46
# Recall:    0.55
# F1:        0.5
# FP ex.: ['אוקזר', 'סלוניקי', 'ללידס', 'הטכסיים', 'מ -']
# FN ex.: ['מזרח - פרוסיה', 'גיילס', 'רמת השרון', 'מקליוולנד', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 854 found, 641 correct.
# Precision: 0.69
# Recall:    0.75
# F1:        0.72
# FP ex.: ['דן בורנשטיין וגוזף', 'מכבי מוביל', 'פיניקס', 'באור - יהודה', 'אייאקס']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 398 found, 321 correct.
# Precision: 0.64
# Recall:    0.81
# F1:        0.72
# FP ex.: ['סנאטור', 'ירושלים', 'הראל', 'ישראל', 'אילת']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 854 found, 641 correct.
# Precision: 0.69
# Recall:    0.75
# F1:        0.72
# FP ex.: ['דן בורנשטיין וגוזף', 'מכבי מוביל', 'פיניקס', 'באור - יהודה', 'אייאקס']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 829 found, 610 correct.
# Precision: 0.66
# Recall:    0.74
# F1:        0.69
# FP ex.: ['למארסיי', 'דן בורנשטיין וגוזף', 'פנמן', 'פיניקס', 'הלשכה וראשי הוועדים המחוזיים']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'הפועל', 'מזרח - פרוסיה', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 412 found, 322 correct.
# Precision: 0.65
# Recall:    0.78
# F1:        0.71
# FP ex.: ['קטיף', 'שדות התעופה', 'בהגזה', 'שהזדרז', 'במדינות הברית']
# FN ex.: ['ה', 'באיובה', 'תנועת המושבים', 'בעין כרם', 'לסילבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 829 found, 610 correct.
# Precision: 0.66
# Recall:    0.74
# F1:        0.69
# FP ex.: ['למארסיי', 'דן בורנשטיין וגוזף', 'פנמן', 'פיניקס', 'הלשכה וראשי הוועדים המחוזיים']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'הפועל', 'מזרח - פרוסיה', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 741 found, 328 correct.
# Precision: 0.35
# Recall:    0.44
# F1:        0.39
# FP ex.: ['והתמדה', 'ואספרסו', 'מאווריקס', 'חשבונות', 'ההתאחדות עזריקם']
# FN ex.: ['מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'ישראל', 'גיילס']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 385 found, 168 correct.
# Precision: 0.34
# Recall:    0.44
# F1:        0.38
# FP ex.: ['רוקפלר בבלאגיו שבאיטליה', 'לדיאלקטיקה', 'מאיר כהן', 'שדות התעופה', 'השמרן טום']
# FN ex.: ['בוסקה', 'באיובה', 'הארקין', 'זורז פומפידו', 'ה']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 741 found, 328 correct.
# Precision: 0.35
# Recall:    0.44
# F1:        0.39
# FP ex.: ['והתמדה', 'ואספרסו', 'מאווריקס', 'חשבונות', 'ההתאחדות עזריקם']
# FN ex.: ['מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'ישראל', 'גיילס']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 1036 found, 510 correct.
# Precision: 0.55
# Recall:    0.49
# F1:        0.52
# FP ex.: ['לוואדיאקוס', 'אוקזר', 'דריה דה - צוליאנו', 'באדום', 'איראקליס']
# FN ex.: ['מזרח - פרוסיה', 'ישראל', 'גיילס', 'רמת השרון', 'מקליוולנד']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 490 found, 237 correct.
# Precision: 0.47
# Recall:    0.48
# F1:        0.48
# FP ex.: ['תהילים', 'רץ', 'מריה', 'שירותי בריאות', 'שדות התעופה']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 948 found, 421 correct.
# Precision: 0.45
# Recall:    0.44
# F1:        0.45
# FP ex.: ['לוואדיאקוס', 'אוקזר', 'לאיטליה', 'דריה דה - צוליאנו', 'איראקליס']
# FN ex.: ['מזרח - פרוסיה', 'ישראל', 'גיילס', 'רמת השרון', 'מקליוולנד']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 918 found, 683 correct.
# Precision: 0.73
# Recall:    0.74
# F1:        0.74
# FP ex.: ['ברוז הבלגית', 'אוקזר', 'פיניקס', 'הלשכה וראשי הוועדים המחוזיים', 'באור - יהודה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'ק - ל - מ', 'דן צבר', 'בוועדה לבחירת שופטים']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 420 found, 334 correct.
# Precision: 0.67
# Recall:    0.8
# F1:        0.73
# FP ex.: ['רץ', 'פומפידו חנינה', 'קטיף', 'במדינות הברית', 'בהגזת']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 838 found, 618 correct.
# Precision: 0.66
# Recall:    0.74
# F1:        0.7
# FP ex.: ['באזור התעשייה', 'ברוז הבלגית', 'לשניים', 'אוקזר', 'פיניקס']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'ק - ל - מ', 'דן צבר', 'בוועדה לבחירת שופטים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 904 found, 667 correct.
# Precision: 0.72
# Recall:    0.74
# F1:        0.73
# FP ex.: ['מקליוולנד', 'פיניקס', 'בולוניה', 'הלשכה וראשי הוועדים המחוזיים', 'דה פיורלה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר', 'לידס']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 419 found, 335 correct.
# Precision: 0.67
# Recall:    0.8
# F1:        0.73
# FP ex.: ['ירושלים', 'ישראל', 'אילת', 'רץ', 'שפתיי']
# FN ex.: ['זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 819 found, 600 correct.
# Precision: 0.64
# Recall:    0.73
# F1:        0.69
# FP ex.: ['מקליוולנד', 'פיניקס', 'בולוניה', 'הלשכה וראשי הוועדים המחוזיים', 'דה פיורלה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'ניר ריכליס', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 881 found, 612 correct.
# Precision: 0.66
# Recall:    0.69
# F1:        0.68
# FP ex.: ['2840', 'בחלקו העליון', 'הוולגה', 'פיניקס', 'ומבנקים']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 442 found, 333 correct.
# Precision: 0.67
# Recall:    0.75
# F1:        0.71
# FP ex.: ['באשר', 'מאיר כהן', 'קטיף', 'עבודתך', 'היאות']
# FN ex.: ['באיובה', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 881 found, 612 correct.
# Precision: 0.66
# Recall:    0.69
# F1:        0.68
# FP ex.: ['2840', 'בחלקו העליון', 'הוולגה', 'פיניקס', 'ומבנקים']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 749 found, 553 correct.
# Precision: 0.59
# Recall:    0.74
# F1:        0.66
# FP ex.: ['דן בורנשטיין וגוזף', 'פנמן', 'מקליוולנד', 'פיניקס', 'בקלינינגרד']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'רמת השרון', 'מקליוולנד', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 391 found, 308 correct.
# Precision: 0.62
# Recall:    0.79
# F1:        0.69
# FP ex.: ['טוד ויטמן', 'ירושלים', 'באשר', 'ישראל', 'אילת']
# FN ex.: ['באיובה', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 749 found, 553 correct.
# Precision: 0.59
# Recall:    0.74
# F1:        0.66
# FP ex.: ['דן בורנשטיין וגוזף', 'פנמן', 'מקליוולנד', 'פיניקס', 'בקלינינגרד']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'רמת השרון', 'מקליוולנד', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 902 found, 636 correct.
# Precision: 0.68
# Recall:    0.71
# F1:        0.69
# FP ex.: ['אוקזר', 'פיניקס', 'אייאקס', 'פיאבה', 'לוריין']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 422 found, 329 correct.
# Precision: 0.66
# Recall:    0.78
# F1:        0.71
# FP ex.: ['מרכז המידע לזכויות', 'רץ', 'במדינות הברית', 'פורד', 'להרוג']
# FN ex.: ['זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 829 found, 583 correct.
# Precision: 0.63
# Recall:    0.7
# F1:        0.66
# FP ex.: ['בבית היהודי', 'עו', 'אוקזר', 'פיניקס', 'פיאבה']
# FN ex.: ['מזרח - פרוסיה', 'גיילס', 'רמת השרון', 'מקליוולנד', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 888 found, 632 correct.
# Precision: 0.68
# Recall:    0.71
# F1:        0.69
# FP ex.: ['טוסקאנה', 'דן בורנשטיין וגוזף', 'בולוניה', 'צזנה', 'לה קוצינה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'ק - ל - מ', 'קאמינגס', 'דן צבר', 'בוועדה לבחירת שופטים']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 426 found, 327 correct.
# Precision: 0.66
# Recall:    0.77
# F1:        0.71
# FP ex.: ['נא מילוא', 'רץ', 'קטיף', 'במדינות הברית', 'פאפון וטובייה']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 821 found, 577 correct.
# Precision: 0.62
# Recall:    0.7
# F1:        0.66
# FP ex.: ['טוסקאנה', 'דן בורנשטיין וגוזף', 'בולוניה', 'וגולדן סטייט בטאקומה', 'צזנה']
# FN ex.: ['קאמינגס', 'גיילס', 'רמת השרון', 'מקליוולנד', 'רכסים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 867 found, 373 correct.
# Precision: 0.4
# Recall:    0.43
# F1:        0.41
# FP ex.: ['וקריאות שמחה', 'מפולפל', 'רשות', 'פיניקס', 'סלוניקי']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'גיילס', 'רמת השרון', 'מקליוולנד']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 446 found, 203 correct.
# Precision: 0.41
# Recall:    0.46
# F1:        0.43
# FP ex.: ['מרכז המידע לזכויות', 'רץ', 'שרה סקאיף', 'מאיר כהן', 'בטיפולו']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 867 found, 373 correct.
# Precision: 0.4
# Recall:    0.43
# F1:        0.41
# FP ex.: ['וקריאות שמחה', 'מפולפל', 'רשות', 'פיניקס', 'סלוניקי']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'גיילס', 'רמת השרון', 'מקליוולנד']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 1064 found, 503 correct.
# Precision: 0.54
# Recall:    0.47
# F1:        0.5
# FP ex.: ['אוקזר', 'סלוניקי', 'וידרגבורט', 'איראקליס', 'דוקסה']
# FN ex.: ['מזרח - פרוסיה', 'רמת השרון', 'רכסים', 'סאגואירוש', 'וואלווייק']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 492 found, 243 correct.
# Precision: 0.49
# Recall:    0.49
# F1:        0.49
# FP ex.: ['שגורג', 'מרכז המידע לזכויות', 'רץ', 'מריה', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 1005 found, 446 correct.
# Precision: 0.48
# Recall:    0.44
# F1:        0.46
# FP ex.: ['לאיזור הסל', 'אוקזר', 'סלוניקי', 'באירופה', 'וידרגבורט']
# FN ex.: ['מזרח - פרוסיה', 'גיילס', 'רמת השרון', 'רכסים', 'גבת']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 892 found, 646 correct.
# Precision: 0.69
# Recall:    0.72
# F1:        0.71
# FP ex.: ['ברוז הבלגית', 'מכבי מוביל', 'אוקזר', 'פיניקס', 'שפירסם']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 457 found, 348 correct.
# Precision: 0.7
# Recall:    0.76
# F1:        0.73
# FP ex.: ['מרכז המידע לזכויות', 'מאיר כהן', 'קטיף', 'ברבים', 'במדינות הברית']
# FN ex.: ['ה', 'באיובה', 'תנועת המושבים', 'בעין כרם', 'לסילבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 892 found, 646 correct.
# Precision: 0.69
# Recall:    0.72
# F1:        0.71
# FP ex.: ['ברוז הבלגית', 'מכבי מוביל', 'אוקזר', 'פיניקס', 'שפירסם']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 847 found, 627 correct.
# Precision: 0.67
# Recall:    0.74
# F1:        0.71
# FP ex.: ['השופט זוסמן', 'פנמן', 'פיניקס', 'הלשכה וראשי הוועדים המחוזיים', 'צזנה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'ניר ריכליס', 'הפועל', 'ק - ל - מ', 'דן צבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 439 found, 330 correct.
# Precision: 0.66
# Recall:    0.75
# F1:        0.7
# FP ex.: ['ולאריגה', 'באשר', 'רץ', 'מנזר סן סימון', 'קטיף']
# FN ex.: ['באיובה', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 847 found, 627 correct.
# Precision: 0.67
# Recall:    0.74
# F1:        0.71
# FP ex.: ['השופט זוסמן', 'פנמן', 'פיניקס', 'הלשכה וראשי הוועדים המחוזיים', 'צזנה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'ניר ריכליס', 'הפועל', 'ק - ל - מ', 'דן צבר']

# %%
tok_res
# Out:
# [{'pred_set': 'gold_test',
#   'conf': 0,
#   'results': [35.660580021482275, 37.8563283922463, 36.725663716814154]},
#  {'pred_set': 'yap_dev',
#   'conf': 0,
#   'results': [35.671342685370746, 40.27149321266968, 37.832093517534545]},
#  {'pred_set': 'yap_test',
#   'conf': 0,
#   'results': [35.660580021482275, 37.8563283922463, 36.725663716814154]},
#  {'pred_set': 'gold_test',
#   'conf': 1,
#   'results': [51.98711063372718, 53.42163355408388, 52.694610778443106]},
#  {'pred_set': 'yap_dev',
#   'conf': 1,
#   'results': [44.88977955911824, 52.95508274231678, 48.59002169197397]},
#  {'pred_set': 'yap_test',
#   'conf': 1,
#   'results': [44.3609022556391, 50.18226002430134, 47.092360319270234]},
#  {'pred_set': 'gold_test',
#   'conf': 10,
#   'results': [72.50268528464017, 70.16632016632016, 71.31537242472267]},
#  {'pred_set': 'yap_dev',
#   'conf': 10,
#   'results': [70.14028056112225, 78.125, 73.91763463569167]},
#  {'pred_set': 'yap_test',
#   'conf': 10,
#   'results': [66.9172932330827, 69.76483762597985, 68.31140350877193]},
#  {'pred_set': 'gold_test',
#   'conf': 11,
#   'results': [73.46938775510205, 70.51546391752578, 71.9621251972646]},
#  {'pred_set': 'yap_dev',
#   'conf': 11,
#   'results': [66.93386773547094, 73.08533916849015, 69.8744769874477]},
#  {'pred_set': 'yap_test',
#   'conf': 11,
#   'results': [67.99140708915145, 69.25601750547045, 68.6178861788618]},
#  {'pred_set': 'gold_test',
#   'conf': 2,
#   'results': [58.64661654135338, 70.72538860103627, 64.12213740458014]},
#  {'pred_set': 'yap_dev',
#   'conf': 2,
#   'results': [62.32464929859719, 81.41361256544502, 70.60158910329172]},
#  {'pred_set': 'yap_test',
#   'conf': 2,
#   'results': [58.64661654135338, 70.72538860103627, 64.12213740458014]},
#  {'pred_set': 'gold_test',
#   'conf': 3,
#   'results': [64.0171858216971, 68.34862385321101, 66.1120354963949]},
#  {'pred_set': 'yap_dev',
#   'conf': 3,
#   'results': [65.13026052104209, 72.22222222222221, 68.4931506849315]},
#  {'pred_set': 'yap_test',
#   'conf': 3,
#   'results': [64.0171858216971, 68.34862385321101, 66.1120354963949]},
#  {'pred_set': 'gold_test',
#   'conf': 4,
#   'results': [73.57679914070891, 70.1844262295082, 71.84058730991086]},
#  {'pred_set': 'yap_dev',
#   'conf': 4,
#   'results': [69.13827655310621, 71.28099173553719, 70.19328585961343]},
#  {'pred_set': 'yap_test',
#   'conf': 4,
#   'results': [68.42105263157895, 68.34763948497854, 68.38432635534085]},
#  {'pred_set': 'gold_test',
#   'conf': 5,
#   'results': [70.67669172932331, 70.37433155080214, 70.5251875669882]},
#  {'pred_set': 'yap_dev',
#   'conf': 5,
#   'results': [65.33066132264528, 73.7556561085973, 69.28799149840596]},
#  {'pred_set': 'yap_test',
#   'conf': 5,
#   'results': [65.3061224489796, 70.86247086247086, 67.9709334823924]},
#  {'pred_set': 'gold_test',
#   'conf': 6,
#   'results': [37.486573576799145, 53.20121951219512, 43.982356647763076]},
#  {'pred_set': 'yap_dev',
#   'conf': 6,
#   'results': [37.27454909819639, 55.02958579881657, 44.44444444444444]},
#  {'pred_set': 'yap_test',
#   'conf': 6,
#   'results': [37.486573576799145, 53.20121951219512, 43.982356647763076]},
#  {'pred_set': 'gold_test',
#   'conf': 7,
#   'results': [53.81310418904404, 58.12064965197216, 55.88399330730619]},
#  {'pred_set': 'yap_dev',
#   'conf': 7,
#   'results': [47.89579158316633, 58.15085158150851, 52.52747252747252]},
#  {'pred_set': 'yap_test',
#   'conf': 7,
#   'results': [45.64983888292159, 54.69755469755469, 49.765807962529266]},
#  {'pred_set': 'gold_test',
#   'conf': 8,
#   'results': [68.85069817400644, 75.05854800936767, 71.82072829131653]},
#  {'pred_set': 'yap_dev',
#   'conf': 8,
#   'results': [64.32865731462925, 80.65326633165829, 71.57190635451506]},
#  {'pred_set': 'yap_test',
#   'conf': 8,
#   'results': [68.85069817400644, 75.05854800936767, 71.82072829131653]},
#  {'pred_set': 'gold_test',
#   'conf': 9,
#   'results': [65.52094522019334, 73.58262967430639, 69.31818181818183]},
#  {'pred_set': 'yap_dev',
#   'conf': 9,
#   'results': [64.52905811623246, 78.15533980582524, 70.69154774972557]},
#  {'pred_set': 'yap_test',
#   'conf': 9,
#   'results': [65.52094522019334, 73.58262967430639, 69.31818181818183]},
#  {'pred_set': 'gold_test',
#   'conf': 0,
#   'results': [35.23093447905478, 44.26450742240216, 39.23444976076555]},
#  {'pred_set': 'yap_dev',
#   'conf': 0,
#   'results': [33.66733466933868, 43.63636363636363, 38.00904977375565]},
#  {'pred_set': 'yap_test',
#   'conf': 0,
#   'results': [35.23093447905478, 44.26450742240216, 39.23444976076555]},
#  {'pred_set': 'gold_test',
#   'conf': 1,
#   'results': [54.7798066595059, 49.22779922779923, 51.85561769191662]},
#  {'pred_set': 'yap_dev',
#   'conf': 1,
#   'results': [47.49498997995992, 48.36734693877551, 47.927199191102126]},
#  {'pred_set': 'yap_test',
#   'conf': 1,
#   'results': [45.22019334049409, 44.40928270042194, 44.81106971793508]},
#  {'pred_set': 'gold_test',
#   'conf': 10,
#   'results': [73.36197636949517, 74.40087145969498, 73.87777176852353]},
#  {'pred_set': 'yap_dev',
#   'conf': 10,
#   'results': [66.93386773547094, 79.52380952380952, 72.68770402611536]},
#  {'pred_set': 'yap_test',
#   'conf': 10,
#   'results': [66.38023630504833, 73.74701670644392, 69.86998304126625]},
#  {'pred_set': 'gold_test',
#   'conf': 11,
#   'results': [71.64339419978518, 73.78318584070797, 72.6975476839237]},
#  {'pred_set': 'yap_dev',
#   'conf': 11,
#   'results': [67.13426853707415, 79.95226730310262, 72.98474945533769]},
#  {'pred_set': 'yap_test',
#   'conf': 11,
#   'results': [64.4468313641246, 73.26007326007326, 68.57142857142857]},
#  {'pred_set': 'gold_test',
#   'conf': 2,
#   'results': [65.73576799140709, 69.46651532349603, 67.54966887417218]},
#  {'pred_set': 'yap_dev',
#   'conf': 2,
#   'results': [66.73346693386773, 75.3393665158371, 70.77577045696069]},
#  {'pred_set': 'yap_test',
#   'conf': 2,
#   'results': [65.73576799140709, 69.46651532349603, 67.54966887417218]},
#  {'pred_set': 'gold_test',
#   'conf': 3,
#   'results': [59.3984962406015, 73.83177570093457, 65.83333333333333]},
#  {'pred_set': 'yap_dev',
#   'conf': 3,
#   'results': [61.72344689378757, 78.77237851662404, 69.21348314606742]},
#  {'pred_set': 'yap_test',
#   'conf': 3,
#   'results': [59.3984962406015, 73.83177570093457, 65.83333333333333]},
#  {'pred_set': 'gold_test',
#   'conf': 4,
#   'results': [68.31364124597206, 70.50997782705099, 69.39443535188215]},
#  {'pred_set': 'yap_dev',
#   'conf': 4,
#   'results': [65.93186372745491, 77.96208530805687, 71.44408251900109]},
#  {'pred_set': 'yap_test',
#   'conf': 4,
#   'results': [62.620837808807735, 70.32569360675512, 66.25000000000001]},
#  {'pred_set': 'gold_test',
#   'conf': 5,
#   'results': [67.88399570354457, 71.17117117117117, 69.48873007146783]},
#  {'pred_set': 'yap_dev',
#   'conf': 5,
#   'results': [65.53106212424849, 76.76056338028168, 70.70270270270271]},
#  {'pred_set': 'yap_test',
#   'conf': 5,
#   'results': [61.97636949516648, 70.28014616321559, 65.8675799086758]},
#  {'pred_set': 'gold_test',
#   'conf': 6,
#   'results': [40.06444683136412, 43.02191464821223, 41.490545050055616]},
#  {'pred_set': 'yap_dev',
#   'conf': 6,
#   'results': [40.6813627254509, 45.51569506726457, 42.96296296296297]},
#  {'pred_set': 'yap_test',
#   'conf': 6,
#   'results': [40.06444683136412, 43.02191464821223, 41.490545050055616]},
#  {'pred_set': 'gold_test',
#   'conf': 7,
#   'results': [54.02792696025779, 47.274436090225564, 50.42606516290727]},
#  {'pred_set': 'yap_dev',
#   'conf': 7,
#   'results': [48.69739478957916, 49.390243902439025, 49.04137235116045]},
#  {'pred_set': 'yap_test',
#   'conf': 7,
#   'results': [47.90547798066595, 44.37810945273632, 46.074380165289256]},
#  {'pred_set': 'gold_test',
#   'conf': 8,
#   'results': [69.38775510204081, 72.42152466367713, 70.87218869994514]},
#  {'pred_set': 'yap_dev',
#   'conf': 8,
#   'results': [69.73947895791584, 76.14879649890591, 72.80334728033473]},
#  {'pred_set': 'yap_test',
#   'conf': 8,
#   'results': [69.38775510204081, 72.42152466367713, 70.87218869994514]},
#  {'pred_set': 'gold_test',
#   'conf': 9,
#   'results': [67.3469387755102, 74.02597402597402, 70.5286839145107]},
#  {'pred_set': 'yap_dev',
#   'conf': 9,
#   'results': [66.13226452905812, 75.17084282460137, 70.36247334754798]},
#  {'pred_set': 'yap_test',
#   'conf': 9,
#   'results': [67.3469387755102, 74.02597402597402, 70.5286839145107]}]

# %%
tok_conf_gold_dev_res = pickle.load(open('results/new_outputs/treebank_tokens_conf_res_preds_hist.pkl', 'rb'))
tok_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0] } for i, x in enumerate(tok_conf_gold_dev_res)]
tok_conf_gold_dev_res
# Out:
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False},
#   'results': (38.146551724137936, 35.47094188376754, 36.7601246105919)},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True},
#   'results': (51.25858123569794, 44.88977955911824, 47.863247863247864)},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (75.66265060240964, 62.925851703406806, 68.7089715536105)},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (67.56756756756756, 65.13026052104209, 66.32653061224488)},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (67.44639376218323, 69.33867735470942, 68.3794466403162)},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (69.29637526652452, 65.13026052104209, 67.14876033057851)},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False},
#   'results': (53.31412103746398, 37.07414829659319, 43.73522458628841)},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True},
#   'results': (57.45192307692307, 47.89579158316633, 52.24043715846993)},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (76.97841726618705, 64.32865731462925, 70.08733624454148)},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (74.31192660550458, 64.92985971943888, 69.30481283422459)},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (75.6989247311828, 70.54108216432866, 73.02904564315352)},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'results': (71.15384615384616, 66.73346693386773, 68.8728024819028)}]

# %%
conf_i = {x['conf']: x['config'] for x in tok_conf_gold_dev_res}
for r in tok_res:
    r['config'] = conf_i[r['conf']]
    
tok_res = tok_res+tok_conf_gold_dev_res

# %%
for r in tok_res:
    r['unit'] = 'token'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]

# %%
tok_res[0]
# Out:
# {'pred_set': 'gold_test',
#  'conf': 0,
#  'results': [35.660580021482275, 37.8563283922463, 36.725663716814154],
#  'config': {'crf': True,
#   'use_pos': False,
#   'use_word': True,
#   'embedding_matrix': None,
#   'embed_dim': 70,
#   'trainable': True,
#   'input_dropout': False,
#   'stack_lstm': 1,
#   'epochs': 100,
#   'early_stopping': True,
#   'patience': 20,
#   'min_delta': 0.0001,
#   'use_char': False,
#   'add_random_embedding': True,
#   'pretrained_embed_dim': 300,
#   'stack_cross': False,
#   'stack_double': False,
#   'rec_dropout': 0.1,
#   'validation_split': 0.1},
#  'unit': 'token'}

# %%
tok_rdf = get_results_df(tok_res)
tok_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  36.725664          False     0.0001        20  ...  37.856328
# 1     100  37.832094          False     0.0001        20  ...  40.271493
# 2     100  36.725664          False     0.0001        20  ...  37.856328
# 3     100  52.694611          False     0.0001        20  ...  53.421634
# 4     100  48.590022          False     0.0001        20  ...  52.955083
#
#   stack_cross  stack_double  stack_lstm  trainable   unit  use_char  use_pos  \
# 0       False         False           1       True  token     False    False
# 1       False         False           1       True  token     False    False
# 2       False         False           1       True  token     False    False
# 3       False         False           1       True  token     False     True
# 4       False         False           1       True  token     False     True
#
#    use_word validation_split
# 0      True              0.1
# 1      True              0.1
# 2      True              0.1
# 3      True              0.1
# 4      True              0.1
#
# [5 rows x 24 columns]

# %%
rdf = pd.concat([rdf,tok_rdf])

# %%
rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix               None       pretrained_token_ft        \
# unit                       morpheme token            morpheme token
# pred_set  use_pos use_char
# gold_dev  False   False        44.7  36.8                70.6  66.3
#                   True         53.2  43.7                73.7  69.3
#           True    False        45.1  47.9                64.7  67.1
#                   True         48.8  52.2                66.0  68.9
# gold_test False   False        46.6  39.2                68.1  66.1
#                   True         53.7  44.0                72.8  70.5
#           True    False        57.2  52.7                74.9  70.5
#                   True         62.8  55.9                76.4  72.7
# yap_dev   False   False        41.8  38.0                67.5  69.2
#                   True         48.7  44.4                68.2  70.7
#           True    False        51.0  48.6                68.2  70.7
#                   True         54.2  52.5                68.4  73.0
# yap_test  False   False        41.5  39.2                62.6  66.1
#                   True         50.0  44.0                63.9  70.5
#           True    False        47.1  47.1                63.0  68.0
#                   True         50.7  49.8                65.0  68.6
#
# embedding_matrix           token_ft_sg yap_ft_sg
# unit                             token  morpheme
# pred_set  use_pos use_char
# gold_dev  False   False           68.7      71.4
#                   True            70.1      75.9
#           True    False           68.4      65.3
#                   True            73.0      65.4
# gold_test False   False           67.5      71.5
#                   True            71.8      73.4
#           True    False           71.8      74.8
#                   True            73.9      75.8
# yap_dev   False   False           70.8      66.2
#                   True            72.8      67.2
#           True    False           71.4      67.1
#                   True            73.9      68.2
# yap_test  False   False           67.5      64.8
#                   True            71.8      65.1
#           True    False           68.4      63.6
#                   True            69.9      64.1

# %% [markdown]
# ### Evaluate morphemes fixed

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
morph_fixed_gold_sents = (morph_gold_test_sents, morph_gold_dev_sents, morph_gold_test_sents)
pred_set = ('gold_test', 'yap_dev', 'yap_test')

morph_fixed_res = []
for ep in sorted(glob.glob('results/new_outputs/*morphemes_fixed*-extra_preds-*')):
    print(ep)
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), morph_gold_extra_preds[i], morph_fixed_gold_sents[i])]
    morph_fixed_res.append(res)
# Out:
# results/new_outputs/treebank_morphemes_fixed-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 843 found, 438 correct.
# Precision: 0.47
# Recall:    0.52
# F1:        0.49
# FP ex.: ['מינהל מקרקעי ישראל', 'עשבי מאכל', 'רמקולים השמיעו', 'האקט', 'איחד']
# FN ex.: ['קאמינגס', 'ויאלי', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed-0-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 400 found, 184 correct.
# Precision: 0.37
# Recall:    0.46
# F1:        0.41
# FP ex.: ['כהונת מושל', 'חקלאיים הציעה', 'קטמון תקועה', 'רץ', 'ה התאחדות ל עולם טוב']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'זורז פומפידו']
# results/new_outputs/treebank_morphemes_fixed-0-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 804 found, 360 correct.
# Precision: 0.39
# Recall:    0.45
# F1:        0.41
# FP ex.: ['מינהל מקרקעי ישראל', 'עשבי מאכל', 'רמקולים השמיעו', 'בוסאני שיחררה', 'קיבלנו ל ה קינוח']
# FN ex.: ['קאמינגס', 'ויאלי', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 939 found, 572 correct.
# Precision: 0.61
# Recall:    0.61
# F1:        0.61
# FP ex.: ['אוקזר', 'האקט', 'ה קרמלין', 'איראקליס', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed-1-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 425 found, 230 correct.
# Precision: 0.46
# Recall:    0.54
# F1:        0.5
# FP ex.: ['ה מועמדת ה דמוקרטית', 'ה ירושלים', 'גדירות', 'ריצארדס', 'רץ']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# results/new_outputs/treebank_morphemes_fixed-1-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 824 found, 413 correct.
# Precision: 0.44
# Recall:    0.5
# F1:        0.47
# FP ex.: ['בברלין', 'אוקזר', 'ה הרצליה', 'איראקליס', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'ויאלי', 'מילאנו', 'גיילס']
# results/new_outputs/treebank_morphemes_fixed-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 859 found, 669 correct.
# Precision: 0.72
# Recall:    0.78
# F1:        0.75
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'מוצי', 'לזניה', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'כהן', 'שבריאנט', 'מזרח - פרוסיה']
# results/new_outputs/treebank_morphemes_fixed-10-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 387 found, 301 correct.
# Precision: 0.6
# Recall:    0.78
# F1:        0.68
# FP ex.: ['רץ', 'מריה', 'פורד שמרנים', 'ה ירושלים', 'ה ישראל']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed-10-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 751 found, 528 correct.
# Precision: 0.57
# Recall:    0.7
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'בהרצליה פיתוח', 'פיניקס', 'רמת ה שרון', 'סן אנטוניו']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'ויאלי', 'מילאנו', 'גיילס']
# results/new_outputs/treebank_morphemes_fixed-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 970 found, 719 correct.
# Precision: 0.77
# Recall:    0.74
# F1:        0.76
# FP ex.: ['לזניה', 'פנמן', 'אוקזר', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'שבריאנט', 'הרצליה פיתוח', 'דן צבר', 'אנ.בי.איי']
# results/new_outputs/treebank_morphemes_fixed-11-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 449 found, 324 correct.
# Precision: 0.65
# Recall:    0.72
# F1:        0.68
# FP ex.: ['רץ', 'מריה', 'פורד שמרנים', 'פומפידו חנינה', 'ה ירושלים']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs/treebank_morphemes_fixed-11-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 903 found, 581 correct.
# Precision: 0.62
# Recall:    0.64
# F1:        0.63
# FP ex.: ['ה וותה', 'ה הפועל אום אל פאחם', 'לשניים', 'פנמן', 'נצח']
# FN ex.: ['הרצליה פיתוח', 'גיילס', 'לטיום', 'רכסים', 'רמת ה שרון']
# results/new_outputs/treebank_morphemes_fixed-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 911 found, 653 correct.
# Precision: 0.7
# Recall:    0.72
# F1:        0.71
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'נעים', 'רח ה מרי', 'ה התאחדות שלמה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed-2-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 454 found, 315 correct.
# Precision: 0.63
# Recall:    0.69
# F1:        0.66
# FP ex.: ['באשר', 'רץ', 'מריה', 'פומפידו חנינה', 'שרה סקאיף']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed-2-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 873 found, 565 correct.
# Precision: 0.61
# Recall:    0.65
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'נעים', 'כוויית', '2840']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'ויאלי', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 828 found, 628 correct.
# Precision: 0.67
# Recall:    0.76
# F1:        0.71
# FP ex.: ['ה כנסייה ה אורתודוקסית', '1920', 'כוויית', 'ה התאחדות שלמה', 'פנמן']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed-3-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 406 found, 305 correct.
# Precision: 0.61
# Recall:    0.75
# F1:        0.67
# FP ex.: ['מריה', 'פורד שמרנים', 'ה ירושלים', 'ולד', 'כהן']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs/treebank_morphemes_fixed-3-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 787 found, 538 correct.
# Precision: 0.58
# Recall:    0.68
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'ה הפועל אום אל פאחם', 'פנמן', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'לטיום', 'רכסים', 'סאגואירוש', 'בולי']
# results/new_outputs/treebank_morphemes_fixed-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 951 found, 689 correct.
# Precision: 0.74
# Recall:    0.72
# F1:        0.73
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'מוצי', 'בורמור', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'הרצליה פיתוח', 'ק - ל - מ', 'דן צבר']
# results/new_outputs/treebank_morphemes_fixed-4-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 449 found, 317 correct.
# Precision: 0.64
# Recall:    0.71
# F1:        0.67
# FP ex.: ['ה ירושלים', 'רץ', 'מריה', 'פומפידו חנינה', 'ה אפגניסטן']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs/treebank_morphemes_fixed-4-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 873 found, 565 correct.
# Precision: 0.61
# Recall:    0.65
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'ה הפועל אום אל פאחם', 'ירושלים', 'בהרצליה פיתוח']
# FN ex.: ['הרצליה פיתוח', 'לטיום', 'גבת', 'חגי בז', 'רמת ה שרון']
# results/new_outputs/treebank_morphemes_fixed-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 910 found, 681 correct.
# Precision: 0.73
# Recall:    0.75
# F1:        0.74
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'טוסקאנה', 'פנמן', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ', 'קאמינגס']
# results/new_outputs/treebank_morphemes_fixed-5-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 404 found, 290 correct.
# Precision: 0.58
# Recall:    0.72
# F1:        0.64
# FP ex.: ['ה ירושלים', 'רץ', 'פורד שמרנים', 'פומפידו חנינה', 'ה ישראל']
# FN ex.: ['בוסקה', 'ליון', 'הארקין', 'זורז פומפידו', 'ה']
# results/new_outputs/treebank_morphemes_fixed-5-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 827 found, 531 correct.
# Precision: 0.57
# Recall:    0.64
# F1:        0.6
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'ה וותה', 'ה הפועל אום אל פאחם', 'פנמן', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 787 found, 500 correct.
# Precision: 0.54
# Recall:    0.64
# F1:        0.58
# FP ex.: ['עשבי מאכל', 'כוויית', 'טוסקאנה', 'מנות איטלקיות', 'אוקזר']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'מילאנו', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed-6-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 338 found, 202 correct.
# Precision: 0.41
# Recall:    0.6
# F1:        0.48
# FP ex.: ['ה ירושלים', 'אורגון', 'רץ', 'פורד שמרנים', 'ה ירושלים']
# FN ex.: ['בוסקה', 'קרן פורד', 'ליון', 'הארקין', 'זורז פומפידו']
# results/new_outputs/treebank_morphemes_fixed-6-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 748 found, 420 correct.
# Precision: 0.45
# Recall:    0.56
# F1:        0.5
# FP ex.: ['עשבי מאכל', 'נאגטס', 'טוסקאנה', 'כוויית', 'מנות איטלקיות']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'מילאנו', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 946 found, 570 correct.
# Precision: 0.61
# Recall:    0.6
# F1:        0.61
# FP ex.: ['ה התאחדות שלמה', 'לוואדיאקוס', 'אוקזר', 'האקט', 'ה קרמלין']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'מילאנו', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed-7-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 424 found, 250 correct.
# Precision: 0.5
# Recall:    0.59
# F1:        0.54
# FP ex.: ['הנהגת ה פילנטרופואידים', 'ה ירושלים', 'תהילים', 'ה אמבולנס', 'גדירות']
# FN ex.: ['בוסקה', 'קרן פורד', 'ליון', 'הארקין', 'זורז פומפידו']
# results/new_outputs/treebank_morphemes_fixed-7-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 831 found, 425 correct.
# Precision: 0.46
# Recall:    0.51
# F1:        0.48
# FP ex.: ['לוואדיאקוס', 'אוקזר', 'בית לאדמו"ר ו שיכון', 'איראקליס', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 872 found, 667 correct.
# Precision: 0.72
# Recall:    0.76
# F1:        0.74
# FP ex.: ['מדיצי', 'לוואדיאקוס', 'מכבי מוביל', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'כהן', 'שבריאנט', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed-8-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 431 found, 312 correct.
# Precision: 0.63
# Recall:    0.72
# F1:        0.67
# FP ex.: ['מריה', 'פורד שמרנים', 'ה ישראל', 'ולד', 'לטום הארקין']
# FN ex.: ['בוסקה', 'הארקין', 'ה', 'ה קרב על ירושלים', 'סילבר']
# results/new_outputs/treebank_morphemes_fixed-8-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 851 found, 565 correct.
# Precision: 0.61
# Recall:    0.66
# F1:        0.63
# FP ex.: ['ה הפועל אום אל פאחם', 'מכבי מוביל', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'מילאנו', 'לטיום', 'גבת']
# results/new_outputs/treebank_morphemes_fixed-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 851 found, 653 correct.
# Precision: 0.7
# Recall:    0.77
# F1:        0.73
# FP ex.: ['פנמן', 'פיניקס', 'רמת ה שרון', 'בולוניה', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed-9-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 414 found, 311 correct.
# Precision: 0.62
# Recall:    0.75
# F1:        0.68
# FP ex.: ['ה ירושלים', 'מריה', 'פורד שמרנים', 'שרה סקאיף', 'ה ירושלים']
# FN ex.: ['בוסקה', 'קרן פורד', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed-9-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 808 found, 556 correct.
# Precision: 0.6
# Recall:    0.69
# F1:        0.64
# FP ex.: ['ה הפועל אום אל פאחם', 'פנמן', 'פיניקס', 'רמת ה שרון', 'בולוניה']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'לטיום', 'רכסים', 'רמת ה שרון']
# results/new_outputs/treebank_morphemes_fixed2-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 617 found, 365 correct.
# Precision: 0.39
# Recall:    0.59
# F1:        0.47
# FP ex.: ['עשבי מאכל', 'נעים', 'מילאן', 'מנות איטלקיות', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'ויאלי', 'מילאנו', 'גיילס']
# results/new_outputs/treebank_morphemes_fixed2-0-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 306 found, 158 correct.
# Precision: 0.32
# Recall:    0.52
# F1:        0.39
# FP ex.: ['ה ירושלים', 'רץ', 'פומפידו חנינה', 'ה מגדל נחש שפיפון', 'ה תחנה ה מרכזית']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# results/new_outputs/treebank_morphemes_fixed2-0-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 582 found, 304 correct.
# Precision: 0.33
# Recall:    0.52
# F1:        0.4
# FP ex.: ['עשבי מאכל', 'נעים', 'מילאן', 'מנות איטלקיות', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'ויאלי', 'מילאנו', 'גיילס']
# results/new_outputs/treebank_morphemes_fixed2-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 940 found, 549 correct.
# Precision: 0.59
# Recall:    0.58
# F1:        0.59
# FP ex.: ['ה רפובליקה ה רוסית', 'אוקזר', 'האקט', 'בית - משפט ל ערעורים ו בית - ה משפט ה עליון', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# results/new_outputs/treebank_morphemes_fixed2-1-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 431 found, 237 correct.
# Precision: 0.48
# Recall:    0.55
# F1:        0.51
# FP ex.: ['ה מועמדת ה דמוקרטית', 'ה ירושלים', 'גדירות', 'זלי לנקובסקי', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# results/new_outputs/treebank_morphemes_fixed2-1-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 825 found, 410 correct.
# Precision: 0.44
# Recall:    0.5
# F1:        0.47
# FP ex.: ['אוקזר', 'בית לאדמו"ר ו שיכון', 'שוהם', 'צילי', 'עליהן ה יזו']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# results/new_outputs/treebank_morphemes_fixed2-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 914 found, 699 correct.
# Precision: 0.75
# Recall:    0.76
# F1:        0.76
# FP ex.: ['נאגטס', 'כוויית', 'לזניה', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-10-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 405 found, 308 correct.
# Precision: 0.62
# Recall:    0.76
# F1:        0.68
# FP ex.: ['ה ירושלים', 'רץ', 'פורד שמרנים', 'פומפידו חנינה', 'ה ישראל']
# FN ex.: ['בוסקה', 'קרן פורד', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-10-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 819 found, 561 correct.
# Precision: 0.6
# Recall:    0.68
# F1:        0.64
# FP ex.: ['לשניים', 'שובה עין', 'ה הפועל אום אל פאחם', 'עו', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'גיילס', 'לטיום', 'גבת', 'רמת ה שרון']
# results/new_outputs/treebank_morphemes_fixed2-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 960 found, 713 correct.
# Precision: 0.77
# Recall:    0.74
# F1:        0.75
# FP ex.: ['לזניה', 'פנמן', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ', 'דן צבר']
# results/new_outputs/treebank_morphemes_fixed2-11-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 430 found, 311 correct.
# Precision: 0.62
# Recall:    0.72
# F1:        0.67
# FP ex.: ['ה ירושלים', 'תהילים', 'רץ', 'מריה', 'פורד שמרנים']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs/treebank_morphemes_fixed2-11-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 868 found, 572 correct.
# Precision: 0.61
# Recall:    0.66
# F1:        0.64
# FP ex.: ['לשניים', 'שובה עין', 'ה הפועל אום אל פאחם', 'פנמן', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'לטיום', 'גבת', 'פורוורטס שטייר']
# results/new_outputs/treebank_morphemes_fixed2-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 820 found, 645 correct.
# Precision: 0.69
# Recall:    0.79
# F1:        0.74
# FP ex.: ['ה התאחדות שלמה', 'פיניקס', 'גביע אופ"א', 'לה קוצינה', 'בתי כנסת']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-2-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 410 found, 294 correct.
# Precision: 0.59
# Recall:    0.72
# F1:        0.65
# FP ex.: ['מריה', 'פורד שמרנים', 'ה ישראל', 'פורד', 'ולד']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-2-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 807 found, 563 correct.
# Precision: 0.6
# Recall:    0.7
# F1:        0.65
# FP ex.: ['פיניקס', 'מחלקה ל ה מחלקה', 'בולוניה', 'גביע אופ"א', 'לה קוצינה']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'לטיום', 'רכסים', 'גבת']
# results/new_outputs/treebank_morphemes_fixed2-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 774 found, 591 correct.
# Precision: 0.63
# Recall:    0.76
# F1:        0.69
# FP ex.: ['1920', 'ה התאחדות שלמה', 'פנמן', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-3-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 373 found, 289 correct.
# Precision: 0.58
# Recall:    0.77
# F1:        0.66
# FP ex.: ['ירושלים', 'הראל', 'ה ירושלים', 'הארקין', 'מריה']
# FN ex.: ['בוסקה', 'ליון', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-3-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 735 found, 502 correct.
# Precision: 0.54
# Recall:    0.68
# F1:        0.6
# FP ex.: ['1920', 'ה הפועל אום אל פאחם', 'פנמן', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'מילאנו', 'ישראל', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed2-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 879 found, 679 correct.
# Precision: 0.73
# Recall:    0.77
# F1:        0.75
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'מוצי', 'ירושלים', 'ה התאחדות שלמה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-4-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 393 found, 299 correct.
# Precision: 0.6
# Recall:    0.76
# F1:        0.67
# FP ex.: ['תהילים', 'רץ', 'פומפידו חנינה', 'בהגזת', 'לטום הארקין']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-4-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 777 found, 536 correct.
# Precision: 0.58
# Recall:    0.69
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'שובה עין', 'ה הפועל אום אל פאחם', 'בתי - משפט ה שלום', 'ה מילאנו']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'גיילס', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed2-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 963 found, 702 correct.
# Precision: 0.75
# Recall:    0.73
# F1:        0.74
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'לזניה', 'כוויית', 'ה התאחדות שלמה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-5-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 437 found, 309 correct.
# Precision: 0.62
# Recall:    0.71
# F1:        0.66
# FP ex.: ['ה ירושלים', 'רץ', 'מריה', 'פורד שמרנים', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs/treebank_morphemes_fixed2-5-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 876 found, 559 correct.
# Precision: 0.6
# Recall:    0.64
# F1:        0.62
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'ה הפועל אום אל פאחם', 'עור', 'פנמן', 'ה מילאנו']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'גיילס', 'לטיום', 'גבת']
# results/new_outputs/treebank_morphemes_fixed2-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 654 found, 416 correct.
# Precision: 0.45
# Recall:    0.64
# F1:        0.52
# FP ex.: ['כוויית', 'ה התאחדות שלמה', 'כיכר', 'יובנטוס', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed2-6-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 324 found, 200 correct.
# Precision: 0.4
# Recall:    0.62
# F1:        0.49
# FP ex.: ['רץ', 'פורד שמרנים', 'שרה סקאיף', 'פומפידו חנינה', 'תבוסת בושוויץ']
# FN ex.: ['בוסקה', 'קרן פורד', 'הארקין', 'זורז פומפידו', 'ה']
# results/new_outputs/treebank_morphemes_fixed2-6-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 616 found, 345 correct.
# Precision: 0.37
# Recall:    0.56
# F1:        0.45
# FP ex.: ['כוויית', 'כיכר', 'פיניקס', 'מרכז ה ארץ', '- סבא']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed2-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 968 found, 580 correct.
# Precision: 0.62
# Recall:    0.6
# F1:        0.61
# FP ex.: ['רח ה מרי', 'אוקזר', 'פיניקס', 'שוהם', 'ה אינסאלאטה פרגו']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'לטיום', 'רכסים', 'פורוורטס שטייר']
# results/new_outputs/treebank_morphemes_fixed2-7-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 425 found, 238 correct.
# Precision: 0.48
# Recall:    0.56
# F1:        0.52
# FP ex.: ['ריצארדס', 'פורד שמרנים', 'פומפידו חנינה', 'ה ישראל', 'פורד']
# FN ex.: ['בוסקה', 'קרן פורד', 'ליון', 'הארקין', 'זורז פומפידו']
# results/new_outputs/treebank_morphemes_fixed2-7-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 862 found, 439 correct.
# Precision: 0.47
# Recall:    0.51
# F1:        0.49
# FP ex.: ['טוסקאנה', 'אוקזר', 'פיניקס', 'יעקב', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'גיילס', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed2-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 866 found, 673 correct.
# Precision: 0.72
# Recall:    0.78
# F1:        0.75
# FP ex.: ['ה התאחדות שלמה', 'בתי - משפט ה שלום', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-8-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 400 found, 300 correct.
# Precision: 0.6
# Recall:    0.75
# F1:        0.67
# FP ex.: ['מריה', 'שרה סקאיף', 'לטום הארקין', 'כנסת', 'נווה - מונוסון']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-8-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 835 found, 575 correct.
# Precision: 0.62
# Recall:    0.69
# F1:        0.65
# FP ex.: ['בתי - משפט ה שלום', 'בהרצליה פיתוח', 'פיניקס', 'מחלקה ל ה מחלקה', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed2-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 909 found, 659 correct.
# Precision: 0.71
# Recall:    0.72
# F1:        0.72
# FP ex.: ['נאגטס', 'פנמן', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה']
# results/new_outputs/treebank_morphemes_fixed2-9-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 441 found, 318 correct.
# Precision: 0.64
# Recall:    0.72
# F1:        0.68
# FP ex.: ['באשר', 'מנזר סן סימון', 'פורד שמרנים', 'מריה', 'שרה סקאיף']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs/treebank_morphemes_fixed2-9-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 876 found, 560 correct.
# Precision: 0.6
# Recall:    0.64
# F1:        0.62
# FP ex.: ['נאגטס', 'ה הפועל אום אל פאחם', 'פנמן', 'ה ריה"ם', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'לטיום', 'רכסים', 'פורוורטס שטייר']

# %%
from itertools import islice

def get_preds_from_preds(preds, sents=morph_gold_dev_sents, truncate=80):
    i=0
    xtoks = []
    xpreds = []
    for sent in sents:
        t = []
        p = []
        for tok, b in islice(sent, truncate):
            t.append(tok)
            p.append(preds[i])
            i+=1
        xtoks.append(t)
        xpreds.append(p)

    preds_preds = [[None, None, xtoks, xpreds]]
    return preds_preds

# %%
morph_fixed_conf_gold_dev_res_o = pickle.load(open('results/new_outputs/treebank_morphemes_fixed_conf_res_preds_hist.pkl', 'rb'))
morph_fixed_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'conlleval_results': x[1][0], 
      'results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] } 
     for i, x in enumerate(morph_fixed_conf_gold_dev_res_o)]
morph_fixed_conf_gold_dev_res
# Out:
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 411 found, 212 correct.
# Precision: 0.43
# Recall:    0.52
# F1:        0.47
# FP ex.: ['כהונת מושל', 'חקלאיים הציעה', 'כתם חרפה', 'קטמון תקועה', 'רץ']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'זורז פומפידו']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 357 found, 206 correct.
# Precision: 0.41
# Recall:    0.58
# F1:        0.48
# FP ex.: ['ה מועמדת ה דמוקרטית', 'ריצארדס', 'רץ', 'פורד שמרנים', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 460 found, 354 correct.
# Precision: 0.71
# Recall:    0.77
# F1:        0.74
# FP ex.: ['באשר', 'רץ', 'פומפידו חנינה', 'שרה סקאיף', 'מאיר כהן']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 414 found, 341 correct.
# Precision: 0.68
# Recall:    0.82
# F1:        0.75
# FP ex.: ['ירושלים', 'הראל', 'קטיף ה הדרים', 'פורד שמרנים', 'ה קדיש']
# FN ex.: ['זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'קרן מקארתור']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 389 found, 293 correct.
# Precision: 0.59
# Recall:    0.75
# F1:        0.66
# FP ex.: ['רץ', 'פומפידו חנינה', 'קרן פורד ב 1989', 'נווה - מונוסון', 'שפתיי']
# FN ex.: ['קרן פורד', 'אינדיאנה', 'ליון', 'זורז פומפידו', 'ה']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 352 found, 275 correct.
# Precision: 0.55
# Recall:    0.78
# F1:        0.65
# FP ex.: ['הראל', 'אילת', 'רץ', 'הארקין', 'פורד שמרנים']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 346 found, 232 correct.
# Precision: 0.47
# Recall:    0.67
# F1:        0.55
# FP ex.: ['אורגון', 'רץ', 'פורד שמרנים', 'כהונת ה מושלת', 'בן כלבה']
# FN ex.: ['בוסקה', 'קרן פורד', 'ליון', 'הארקין', 'זורז פומפידו']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 368 found, 223 correct.
# Precision: 0.45
# Recall:    0.61
# F1:        0.52
# FP ex.: ['ה מועמדת ה דמוקרטית', 'ה אמבולנס', 'מושל', 'תהילים', 'גדירות']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 427 found, 346 correct.
# Precision: 0.69
# Recall:    0.81
# F1:        0.75
# FP ex.: ['טוד ויטמן', 'הראל', 'ירושלים', 'ואיה', 'קטמון']
# FN ex.: ['הארקין', 'ה', 'ה קרב על ירושלים', 'סילבר', 'ה עולם ה שלישי']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 424 found, 351 correct.
# Precision: 0.7
# Recall:    0.83
# F1:        0.76
# FP ex.: ['ירושלים', 'הראל', 'ניקרגואה', 'אילת', 'קטיף ה הדרים']
# FN ex.: ['קרן פורד', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 332 found, 280 correct.
# Precision: 0.56
# Recall:    0.84
# F1:        0.67
# FP ex.: ['מקרין', 'אילת', 'רץ', 'קרן ה מדע', 'סדאם']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 401 found, 313 correct.
# Precision: 0.63
# Recall:    0.78
# F1:        0.7
# FP ex.: ['רץ', 'פורד שמרנים', 'פומפידו חנינה', 'סן', 'מושל מסצוסטס']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'זורז פומפידו', 'ה']
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False, 'patience': 10},
#   'conlleval_results': (50.96153846153846,
#    42.570281124497996,
#    46.389496717724285),
#   'results': [42.570281124497996, 51.58150851581509, 46.64466446644665]},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True, 'patience': 10},
#   'conlleval_results': (56.94444444444444,
#    41.164658634538156,
#    47.78554778554779),
#   'results': [41.365461847389554, 57.70308123249299, 48.18713450292397]},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (73.18087318087319,
#    70.68273092369478,
#    71.91011235955057),
#   'results': [71.08433734939759, 76.95652173913044, 73.90396659707724]},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (79.2056074766355, 68.07228915662651, 73.2181425485961),
#   'results': [68.47389558232932, 82.3671497584541, 74.78070175438597]},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (71.32530120481928,
#    59.43775100401606,
#    64.84118291347207),
#   'results': [58.835341365461844, 75.32133676092545, 66.06538895152198]},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (75.48209366391184,
#    55.020080321285135,
#    63.64692218350755),
#   'results': [55.22088353413655, 78.125, 64.70588235294117]},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False, 'patience': 10},
#   'conlleval_results': (66.28571428571428,
#    46.58634538152611,
#    54.71698113207547),
#   'results': [46.58634538152611, 67.05202312138728, 54.976303317535546]},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True, 'patience': 10},
#   'conlleval_results': (59.62566844919787,
#    44.77911646586345,
#    51.146788990825684),
#   'results': [44.77911646586345, 60.597826086956516, 51.501154734411095]},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (79.95391705069125,
#    69.67871485943775,
#    74.46351931330472),
#   'results': [69.47791164658635, 81.0304449648712, 74.8108108108108]},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (79.63800904977376,
#    70.68273092369478,
#    74.8936170212766),
#   'results': [70.48192771084338, 82.78301886792453, 76.13882863340564]},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (81.44927536231884,
#    56.42570281124498,
#    66.66666666666667),
#   'results': [56.22489959839358, 84.33734939759037, 67.46987951807229]},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (76.34146341463415,
#    62.85140562248996,
#    68.94273127753304),
#   'results': [62.85140562248996, 78.05486284289277, 69.6329254727475]}]

# %% [raw]
# x = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0],
#       'mention_results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] }
#      for i, x in enumerate(morph_fixed_conf_gold_dev_res_o)]

# %%
conf_i = {x['conf']: x['config'] for x in morph_fixed_conf_gold_dev_res}
for r in morph_fixed_res:
    r['config'] = conf_i[r['conf']]
    
morph_fixed_res = morph_fixed_res+morph_fixed_conf_gold_dev_res

# %%
for r in morph_fixed_res:
    r['unit'] = 'morpheme_fixed'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]

# %%
morph_fixed_res[0]
# Out:
# {'pred_set': 'gold_test',
#  'conf': 0,
#  'results': [47.046186895810955, 51.95729537366548, 49.379932356257044],
#  'config': {'crf': True,
#   'use_pos': False,
#   'patience': 10,
#   'use_word': True,
#   'embedding_matrix': None,
#   'embed_dim': 70,
#   'trainable': True,
#   'input_dropout': False,
#   'stack_lstm': 1,
#   'epochs': 100,
#   'early_stopping': True,
#   'min_delta': 0.0001,
#   'use_char': False,
#   'add_random_embedding': True,
#   'pretrained_embed_dim': 300,
#   'stack_cross': False,
#   'stack_double': False,
#   'rec_dropout': 0.1,
#   'validation_split': 0.1},
#  'unit': 'morpheme_fixed'}

# %%
morph_fixed_rdf = get_results_df(morph_fixed_res)
morph_fixed_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  49.379932          False     0.0001        10  ...  51.957295
# 1     100  40.979955          False     0.0001        10  ...  46.000000
# 2     100  41.498559          False     0.0001        10  ...  44.776119
# 3     100  61.176471          False     0.0001        10  ...  60.915868
# 4     100  49.837486          False     0.0001        10  ...  54.117647
#
#   stack_cross  stack_double  stack_lstm  trainable            unit  use_char  \
# 0       False         False           1       True  morpheme_fixed     False
# 1       False         False           1       True  morpheme_fixed     False
# 2       False         False           1       True  morpheme_fixed     False
# 3       False         False           1       True  morpheme_fixed     False
# 4       False         False           1       True  morpheme_fixed     False
#
#    use_pos  use_word validation_split
# 0    False      True              0.1
# 1    False      True              0.1
# 2    False      True              0.1
# 3     True      True              0.1
# 4     True      True              0.1
#
# [5 rows x 24 columns]

# %%
morph_fixed_rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix                     None pretrained_token_ft      yap_ft_sg
# unit                       morpheme_fixed      morpheme_fixed morpheme_fixed
# pred_set  use_pos use_char
# gold_dev  False   False              46.6                74.8           73.9
#                   True               55.0                76.1           74.8
#           True    False              48.2                64.7           66.1
#                   True               51.5                69.6           67.5
# gold_test False   False              49.4                71.4           73.7
#                   True               58.2                73.3           74.9
#           True    False              61.2                74.1           75.0
#                   True               61.1                75.6           75.8
# yap_dev   False   False              41.0                67.5           66.2
#                   True               48.7                68.2           67.2
#           True    False              51.0                66.1           67.1
#                   True               54.2                68.4           68.2
# yap_test  False   False              41.5                62.6           64.8
#                   True               50.0                63.9           65.1
#           True    False              47.1                61.9           62.8
#                   True               49.0                63.6           64.1

# %% [markdown]
# ### Evaluate morphemes fixed

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
morph_fixed_gold_sents = (morph_gold_test_sents, morph_gold_dev_sents, morph_gold_test_sents)
pred_set = ('gold_test', 'yap_dev', 'yap_test')

morph_fixed2_res = []
for ep in sorted(glob.glob('results/new_outputs/*morphemes_fixed2*-extra_preds-*')):
    print(ep)
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), morph_gold_extra_preds[i], morph_fixed_gold_sents[i])]
    morph_fixed2_res.append(res)
# Out:
# results/new_outputs/treebank_morphemes_fixed2-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 617 found, 365 correct.
# Precision: 0.39
# Recall:    0.59
# F1:        0.47
# FP ex.: ['עשבי מאכל', 'נעים', 'מילאן', 'מנות איטלקיות', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'ויאלי', 'מילאנו', 'גיילס']
# results/new_outputs/treebank_morphemes_fixed2-0-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 306 found, 158 correct.
# Precision: 0.32
# Recall:    0.52
# F1:        0.39
# FP ex.: ['ה ירושלים', 'רץ', 'פומפידו חנינה', 'ה מגדל נחש שפיפון', 'ה תחנה ה מרכזית']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# results/new_outputs/treebank_morphemes_fixed2-0-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 582 found, 304 correct.
# Precision: 0.33
# Recall:    0.52
# F1:        0.4
# FP ex.: ['עשבי מאכל', 'נעים', 'מילאן', 'מנות איטלקיות', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'ויאלי', 'מילאנו', 'גיילס']
# results/new_outputs/treebank_morphemes_fixed2-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 940 found, 549 correct.
# Precision: 0.59
# Recall:    0.58
# F1:        0.59
# FP ex.: ['ה רפובליקה ה רוסית', 'אוקזר', 'האקט', 'בית - משפט ל ערעורים ו בית - ה משפט ה עליון', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# results/new_outputs/treebank_morphemes_fixed2-1-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 431 found, 237 correct.
# Precision: 0.48
# Recall:    0.55
# F1:        0.51
# FP ex.: ['ה מועמדת ה דמוקרטית', 'ה ירושלים', 'גדירות', 'זלי לנקובסקי', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# results/new_outputs/treebank_morphemes_fixed2-1-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 825 found, 410 correct.
# Precision: 0.44
# Recall:    0.5
# F1:        0.47
# FP ex.: ['אוקזר', 'בית לאדמו"ר ו שיכון', 'שוהם', 'צילי', 'עליהן ה יזו']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# results/new_outputs/treebank_morphemes_fixed2-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 914 found, 699 correct.
# Precision: 0.75
# Recall:    0.76
# F1:        0.76
# FP ex.: ['נאגטס', 'כוויית', 'לזניה', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-10-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 405 found, 308 correct.
# Precision: 0.62
# Recall:    0.76
# F1:        0.68
# FP ex.: ['ה ירושלים', 'רץ', 'פורד שמרנים', 'פומפידו חנינה', 'ה ישראל']
# FN ex.: ['בוסקה', 'קרן פורד', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-10-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 819 found, 561 correct.
# Precision: 0.6
# Recall:    0.68
# F1:        0.64
# FP ex.: ['לשניים', 'שובה עין', 'ה הפועל אום אל פאחם', 'עו', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'גיילס', 'לטיום', 'גבת', 'רמת ה שרון']
# results/new_outputs/treebank_morphemes_fixed2-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 960 found, 713 correct.
# Precision: 0.77
# Recall:    0.74
# F1:        0.75
# FP ex.: ['לזניה', 'פנמן', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ', 'דן צבר']
# results/new_outputs/treebank_morphemes_fixed2-11-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 430 found, 311 correct.
# Precision: 0.62
# Recall:    0.72
# F1:        0.67
# FP ex.: ['ה ירושלים', 'תהילים', 'רץ', 'מריה', 'פורד שמרנים']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs/treebank_morphemes_fixed2-11-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 868 found, 572 correct.
# Precision: 0.61
# Recall:    0.66
# F1:        0.64
# FP ex.: ['לשניים', 'שובה עין', 'ה הפועל אום אל פאחם', 'פנמן', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'לטיום', 'גבת', 'פורוורטס שטייר']
# results/new_outputs/treebank_morphemes_fixed2-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 820 found, 645 correct.
# Precision: 0.69
# Recall:    0.79
# F1:        0.74
# FP ex.: ['ה התאחדות שלמה', 'פיניקס', 'גביע אופ"א', 'לה קוצינה', 'בתי כנסת']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-2-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 410 found, 294 correct.
# Precision: 0.59
# Recall:    0.72
# F1:        0.65
# FP ex.: ['מריה', 'פורד שמרנים', 'ה ישראל', 'פורד', 'ולד']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-2-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 807 found, 563 correct.
# Precision: 0.6
# Recall:    0.7
# F1:        0.65
# FP ex.: ['פיניקס', 'מחלקה ל ה מחלקה', 'בולוניה', 'גביע אופ"א', 'לה קוצינה']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'לטיום', 'רכסים', 'גבת']
# results/new_outputs/treebank_morphemes_fixed2-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 774 found, 591 correct.
# Precision: 0.63
# Recall:    0.76
# F1:        0.69
# FP ex.: ['1920', 'ה התאחדות שלמה', 'פנמן', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-3-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 373 found, 289 correct.
# Precision: 0.58
# Recall:    0.77
# F1:        0.66
# FP ex.: ['ירושלים', 'הראל', 'ה ירושלים', 'הארקין', 'מריה']
# FN ex.: ['בוסקה', 'ליון', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-3-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 735 found, 502 correct.
# Precision: 0.54
# Recall:    0.68
# F1:        0.6
# FP ex.: ['1920', 'ה הפועל אום אל פאחם', 'פנמן', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'מילאנו', 'ישראל', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed2-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 879 found, 679 correct.
# Precision: 0.73
# Recall:    0.77
# F1:        0.75
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'מוצי', 'ירושלים', 'ה התאחדות שלמה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-4-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 393 found, 299 correct.
# Precision: 0.6
# Recall:    0.76
# F1:        0.67
# FP ex.: ['תהילים', 'רץ', 'פומפידו חנינה', 'בהגזת', 'לטום הארקין']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-4-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 777 found, 536 correct.
# Precision: 0.58
# Recall:    0.69
# F1:        0.63
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'שובה עין', 'ה הפועל אום אל פאחם', 'בתי - משפט ה שלום', 'ה מילאנו']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'גיילס', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed2-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 963 found, 702 correct.
# Precision: 0.75
# Recall:    0.73
# F1:        0.74
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'לזניה', 'כוויית', 'ה התאחדות שלמה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-5-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 437 found, 309 correct.
# Precision: 0.62
# Recall:    0.71
# F1:        0.66
# FP ex.: ['ה ירושלים', 'רץ', 'מריה', 'פורד שמרנים', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs/treebank_morphemes_fixed2-5-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 876 found, 559 correct.
# Precision: 0.6
# Recall:    0.64
# F1:        0.62
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'ה הפועל אום אל פאחם', 'עור', 'פנמן', 'ה מילאנו']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'גיילס', 'לטיום', 'גבת']
# results/new_outputs/treebank_morphemes_fixed2-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 654 found, 416 correct.
# Precision: 0.45
# Recall:    0.64
# F1:        0.52
# FP ex.: ['כוויית', 'ה התאחדות שלמה', 'כיכר', 'יובנטוס', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed2-6-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 324 found, 200 correct.
# Precision: 0.4
# Recall:    0.62
# F1:        0.49
# FP ex.: ['רץ', 'פורד שמרנים', 'שרה סקאיף', 'פומפידו חנינה', 'תבוסת בושוויץ']
# FN ex.: ['בוסקה', 'קרן פורד', 'הארקין', 'זורז פומפידו', 'ה']
# results/new_outputs/treebank_morphemes_fixed2-6-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 616 found, 345 correct.
# Precision: 0.37
# Recall:    0.56
# F1:        0.45
# FP ex.: ['כוויית', 'כיכר', 'פיניקס', 'מרכז ה ארץ', '- סבא']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs/treebank_morphemes_fixed2-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 968 found, 580 correct.
# Precision: 0.62
# Recall:    0.6
# F1:        0.61
# FP ex.: ['רח ה מרי', 'אוקזר', 'פיניקס', 'שוהם', 'ה אינסאלאטה פרגו']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'לטיום', 'רכסים', 'פורוורטס שטייר']
# results/new_outputs/treebank_morphemes_fixed2-7-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 425 found, 238 correct.
# Precision: 0.48
# Recall:    0.56
# F1:        0.52
# FP ex.: ['ריצארדס', 'פורד שמרנים', 'פומפידו חנינה', 'ה ישראל', 'פורד']
# FN ex.: ['בוסקה', 'קרן פורד', 'ליון', 'הארקין', 'זורז פומפידו']
# results/new_outputs/treebank_morphemes_fixed2-7-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 862 found, 439 correct.
# Precision: 0.47
# Recall:    0.51
# F1:        0.49
# FP ex.: ['טוסקאנה', 'אוקזר', 'פיניקס', 'יעקב', 'שוהם']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'גיילס', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed2-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 866 found, 673 correct.
# Precision: 0.72
# Recall:    0.78
# F1:        0.75
# FP ex.: ['ה התאחדות שלמה', 'בתי - משפט ה שלום', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs/treebank_morphemes_fixed2-8-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 400 found, 300 correct.
# Precision: 0.6
# Recall:    0.75
# F1:        0.67
# FP ex.: ['מריה', 'שרה סקאיף', 'לטום הארקין', 'כנסת', 'נווה - מונוסון']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs/treebank_morphemes_fixed2-8-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 835 found, 575 correct.
# Precision: 0.62
# Recall:    0.69
# F1:        0.65
# FP ex.: ['בתי - משפט ה שלום', 'בהרצליה פיתוח', 'פיניקס', 'מחלקה ל ה מחלקה', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'לטיום', 'רכסים']
# results/new_outputs/treebank_morphemes_fixed2-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 909 found, 659 correct.
# Precision: 0.71
# Recall:    0.72
# F1:        0.72
# FP ex.: ['נאגטס', 'פנמן', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה']
# results/new_outputs/treebank_morphemes_fixed2-9-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 441 found, 318 correct.
# Precision: 0.64
# Recall:    0.72
# F1:        0.68
# FP ex.: ['באשר', 'מנזר סן סימון', 'פורד שמרנים', 'מריה', 'שרה סקאיף']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs/treebank_morphemes_fixed2-9-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 876 found, 560 correct.
# Precision: 0.6
# Recall:    0.64
# F1:        0.62
# FP ex.: ['נאגטס', 'ה הפועל אום אל פאחם', 'פנמן', 'ה ריה"ם', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'לטיום', 'רכסים', 'פורוורטס שטייר']

# %%
morph_fixed2_conf_gold_dev_res_o = pickle.load(open('results/new_outputs/treebank_morphemes_fixed2_conf_res_preds_hist.pkl', 'rb'))
morph_fixed2_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'conlleval_results': x[1][0], 
      'results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] } 
     for i, x in enumerate(morph_fixed2_conf_gold_dev_res_o)]
morph_fixed2_conf_gold_dev_res
# Out:
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 316 found, 184 correct.
# Precision: 0.37
# Recall:    0.58
# F1:        0.45
# FP ex.: ['רץ', 'פומפידו חנינה', 'ה מגדל נחש שפיפון', 'מאיר כהן', 'ה תחנה ה מרכזית']
# FN ex.: ['בוסקה', 'קרן פורד', 'אינדיאנה', 'ליון', 'הארקין']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 452 found, 297 correct.
# Precision: 0.6
# Recall:    0.66
# F1:        0.63
# FP ex.: ['ה מועמדת ה דמוקרטית', 'שרה סקאיף', 'גורג', 'מועמדות מפלגתה ל מושל', 'הרי בראדלו']
# FN ex.: ['קרן פורד', 'אינדיאנה', 'ליון', 'הארקין', 'זורז פומפידו']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 416 found, 327 correct.
# Precision: 0.66
# Recall:    0.79
# F1:        0.72
# FP ex.: ['פורד שמרנים', 'פורד', 'ירושלים', 'שיקאגו', 'אושוויץ']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'סילבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 383 found, 324 correct.
# Precision: 0.65
# Recall:    0.85
# F1:        0.74
# FP ex.: ['ירושלים', 'הראל', 'הארקין', 'קטיף ה הדרים', 'פומפידו חנינה']
# FN ex.: ['ליון', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'טובייה']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 430 found, 364 correct.
# Precision: 0.73
# Recall:    0.85
# F1:        0.78
# FP ex.: ['ירושלים', 'תהילים', 'הראל', 'רץ', 'דה מוין רגיסטר']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'סילבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 461 found, 370 correct.
# Precision: 0.74
# Recall:    0.8
# F1:        0.77
# FP ex.: ['רץ', 'שרה סקאיף', 'הרי בראדלו', 'פורד', 'קרן גון מ']
# FN ex.: ['זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'קרן מקארתור']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 331 found, 229 correct.
# Precision: 0.46
# Recall:    0.69
# F1:        0.55
# FP ex.: ['רץ', 'פורד שמרנים', 'שרה סקאיף', 'פומפידו חנינה', 'תבוסת בושוויץ']
# FN ex.: ['בוסקה', 'קרן פורד', 'הארקין', 'זורז פומפידו', 'ה']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 451 found, 300 correct.
# Precision: 0.6
# Recall:    0.67
# F1:        0.63
# FP ex.: ['ריצארדס', 'פורד שמרנים', 'שרה סקאיף', 'הרי בראדלו', 'פורד']
# FN ex.: ['בוסקה', 'קרן פורד', 'ליון', 'הארקין', 'זורז פומפידו']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 405 found, 338 correct.
# Precision: 0.68
# Recall:    0.83
# F1:        0.75
# FP ex.: ['טוד ויטמן', 'הראל', 'ירושלים', 'אבי ז"ל', 'שרה סקאיף']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 443 found, 356 correct.
# Precision: 0.71
# Recall:    0.8
# F1:        0.76
# FP ex.: ['באשר', 'פורד שמרנים', 'שרה סקאיף', 'הרי בראדלו', 'אתמ']
# FN ex.: ['זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'קרן מקארתור']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 432 found, 368 correct.
# Precision: 0.74
# Recall:    0.85
# F1:        0.79
# FP ex.: ['ירושלים', 'הראל', 'לבנון', 'ישראל', 'רץ']
# FN ex.: ['קרן פורד', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'קרן מקארתור']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 451 found, 374 correct.
# Precision: 0.75
# Recall:    0.83
# F1:        0.79
# FP ex.: ['מרכז ה מידע', 'טוד ויטמן', 'תהילים', 'הראל', 'ניקרגואה']
# FN ex.: ['ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'קרן מקארתור', 'ירושלים ה מערבית']
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False, 'patience': 10},
#   'conlleval_results': (56.44171779141104,
#    36.94779116465863,
#    44.66019417475727),
#   'results': [36.94779116465863, 58.22784810126582, 45.208845208845204]},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True, 'patience': 10},
#   'conlleval_results': (64.14686825053995,
#    59.63855421686747,
#    61.810613943808534),
#   'results': [59.63855421686747, 65.7079646017699, 62.52631578947367]},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (75.86206896551724,
#    66.26506024096386,
#    70.73954983922829),
#   'results': [65.66265060240963, 78.60576923076923, 71.55361050328227]},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (76.77725118483413,
#    65.06024096385542,
#    70.43478260869566),
#   'results': [65.06024096385542, 84.59530026109661, 73.5527809307605]},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (81.53153153153153,
#    72.69076305220884,
#    76.85774946921444),
#   'results': [73.09236947791165, 84.65116279069768, 78.44827586206897]},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (77.03549060542797,
#    74.09638554216868,
#    75.53735926305015),
#   'results': [74.29718875502009, 80.26030368763557, 77.16371220020855]},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False, 'patience': 10},
#   'conlleval_results': (67.95252225519289,
#    45.98393574297189,
#    54.85029940119761),
#   'results': [45.98393574297189, 69.18429003021149, 55.24728588661038]},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True, 'patience': 10},
#   'conlleval_results': (66.29711751662971,
#    60.040160642570285,
#    63.013698630136986),
#   'results': [60.24096385542169, 66.51884700665188, 63.224446786090624]},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (81.77458033573141,
#    68.47389558232932,
#    74.53551912568307),
#   'results': [67.8714859437751, 83.4567901234568, 74.86157253599114]},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (78.24175824175825,
#    71.4859437751004,
#    74.71143756558237),
#   'results': [71.4859437751004, 80.36117381489842, 75.66418703506909]},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (83.14606741573034,
#    74.29718875502009,
#    78.47295864262989),
#   'results': [73.89558232931726, 85.18518518518519, 79.13978494623655]},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300,
#    'patience': 10},
#   'conlleval_results': (80.56155507559394,
#    74.8995983935743,
#    77.62747138397502),
#   'results': [75.1004016064257, 82.92682926829268, 78.81981032665965]}]

# %% [raw]
# x = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0],
#       'mention_results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] }
#      for i, x in enumerate(morph_fixed_conf_gold_dev_res_o)]

# %%
conf_i = {x['conf']: x['config'] for x in morph_fixed2_conf_gold_dev_res}
for r in morph_fixed2_res:
    r['config'] = conf_i[r['conf']]
    
morph_fixed2_res = morph_fixed2_res+morph_fixed2_conf_gold_dev_res

# %%
for r in morph_fixed2_res:
    r['unit'] = 'morpheme_fixed2'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]

# %%
morph_fixed2_rdf = get_results_df(morph_fixed2_res)
morph_fixed2_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  47.157623          False     0.0001        10  ...  59.157212
# 1     100  39.303483          False     0.0001        10  ...  51.633987
# 2     100  40.185063          False     0.0001        10  ...  52.233677
# 3     100  58.685195          False     0.0001        10  ...  58.404255
# 4     100  51.022605          False     0.0001        10  ...  54.988399
#
#   stack_cross  stack_double  stack_lstm  trainable             unit  use_char  \
# 0       False         False           1       True  morpheme_fixed2     False
# 1       False         False           1       True  morpheme_fixed2     False
# 2       False         False           1       True  morpheme_fixed2     False
# 3       False         False           1       True  morpheme_fixed2     False
# 4       False         False           1       True  morpheme_fixed2     False
#
#    use_pos  use_word validation_split
# 0    False      True              0.1
# 1    False      True              0.1
# 2    False      True              0.1
# 3     True      True              0.1
# 4     True      True              0.1
#
# [5 rows x 24 columns]

# %%
morph_fixed2_rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix                      None pretrained_token_ft       yap_ft_sg
# unit                       morpheme_fixed2     morpheme_fixed2 morpheme_fixed2
# pred_set  use_pos use_char
# gold_dev  False   False               45.2                73.6            71.6
#                   True                55.2                75.7            74.9
#           True    False               62.5                77.2            78.4
#                   True                63.2                78.8            79.1
# gold_test False   False               47.2                69.3            73.7
#                   True                52.5                71.6            74.9
#           True    False               58.7                74.1            75.0
#                   True                61.1                75.4            75.8
# yap_dev   False   False               39.3                66.4            64.8
#                   True                48.7                67.7            66.8
#           True    False               51.0                66.1            67.1
#                   True                51.6                67.0            68.2
# yap_test  False   False               40.2                60.3            64.8
#                   True                44.6                62.0            65.1
#           True    False               46.7                61.9            62.8
#                   True                49.0                63.6            64.1

# %% [markdown]
# ### Evaluate tokens fixed

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
pred_set = ('gold_test', 'yap_dev', 'yap_test')

tokens_fixed2_res = []
for ep in sorted(glob.glob('results/new_outputs/*tokens_fixed2*-extra_preds-*')):
    print(ep)
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), tok_gold_extra_preds[i], tok_gold_sents[i])]
    tokens_fixed2_res.append(res)
# Out:
# results/new_outputs/treebank_tokens_fixed2-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 741 found, 328 correct.
# Precision: 0.35
# Recall:    0.44
# F1:        0.39
# FP ex.: ['והתמדה', 'ואספרסו', 'מאווריקס', 'חשבונות', 'ההתאחדות עזריקם']
# FN ex.: ['מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'ישראל', 'גיילס']
# results/new_outputs/treebank_tokens_fixed2-0-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 385 found, 168 correct.
# Precision: 0.34
# Recall:    0.44
# F1:        0.38
# FP ex.: ['רוקפלר בבלאגיו שבאיטליה', 'לדיאלקטיקה', 'מאיר כהן', 'שדות התעופה', 'השמרן טום']
# FN ex.: ['בוסקה', 'באיובה', 'הארקין', 'זורז פומפידו', 'ה']
# results/new_outputs/treebank_tokens_fixed2-0-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 741 found, 328 correct.
# Precision: 0.35
# Recall:    0.44
# F1:        0.39
# FP ex.: ['והתמדה', 'ואספרסו', 'מאווריקס', 'חשבונות', 'ההתאחדות עזריקם']
# FN ex.: ['מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'ישראל', 'גיילס']
# results/new_outputs/treebank_tokens_fixed2-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 1036 found, 510 correct.
# Precision: 0.55
# Recall:    0.49
# F1:        0.52
# FP ex.: ['לוואדיאקוס', 'אוקזר', 'דריה דה - צוליאנו', 'באדום', 'איראקליס']
# FN ex.: ['מזרח - פרוסיה', 'ישראל', 'גיילס', 'רמת השרון', 'מקליוולנד']
# results/new_outputs/treebank_tokens_fixed2-1-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 490 found, 237 correct.
# Precision: 0.47
# Recall:    0.48
# F1:        0.48
# FP ex.: ['תהילים', 'רץ', 'מריה', 'שירותי בריאות', 'שדות התעופה']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'תנועת המושבים']
# results/new_outputs/treebank_tokens_fixed2-1-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 948 found, 421 correct.
# Precision: 0.45
# Recall:    0.44
# F1:        0.45
# FP ex.: ['לוואדיאקוס', 'אוקזר', 'לאיטליה', 'דריה דה - צוליאנו', 'איראקליס']
# FN ex.: ['מזרח - פרוסיה', 'ישראל', 'גיילס', 'רמת השרון', 'מקליוולנד']
# results/new_outputs/treebank_tokens_fixed2-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 918 found, 683 correct.
# Precision: 0.73
# Recall:    0.74
# F1:        0.74
# FP ex.: ['ברוז הבלגית', 'אוקזר', 'פיניקס', 'הלשכה וראשי הוועדים המחוזיים', 'באור - יהודה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'ק - ל - מ', 'דן צבר', 'בוועדה לבחירת שופטים']
# results/new_outputs/treebank_tokens_fixed2-10-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 420 found, 334 correct.
# Precision: 0.67
# Recall:    0.8
# F1:        0.73
# FP ex.: ['רץ', 'פומפידו חנינה', 'קטיף', 'במדינות הברית', 'בהגזת']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# results/new_outputs/treebank_tokens_fixed2-10-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 838 found, 618 correct.
# Precision: 0.66
# Recall:    0.74
# F1:        0.7
# FP ex.: ['באזור התעשייה', 'ברוז הבלגית', 'לשניים', 'אוקזר', 'פיניקס']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'ק - ל - מ', 'דן צבר', 'בוועדה לבחירת שופטים']
# results/new_outputs/treebank_tokens_fixed2-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 904 found, 667 correct.
# Precision: 0.72
# Recall:    0.74
# F1:        0.73
# FP ex.: ['מקליוולנד', 'פיניקס', 'בולוניה', 'הלשכה וראשי הוועדים המחוזיים', 'דה פיורלה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר', 'לידס']
# results/new_outputs/treebank_tokens_fixed2-11-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 419 found, 335 correct.
# Precision: 0.67
# Recall:    0.8
# F1:        0.73
# FP ex.: ['ירושלים', 'ישראל', 'אילת', 'רץ', 'שפתיי']
# FN ex.: ['זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# results/new_outputs/treebank_tokens_fixed2-11-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 819 found, 600 correct.
# Precision: 0.64
# Recall:    0.73
# F1:        0.69
# FP ex.: ['מקליוולנד', 'פיניקס', 'בולוניה', 'הלשכה וראשי הוועדים המחוזיים', 'דה פיורלה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'ניר ריכליס', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# results/new_outputs/treebank_tokens_fixed2-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 881 found, 612 correct.
# Precision: 0.66
# Recall:    0.69
# F1:        0.68
# FP ex.: ['2840', 'בחלקו העליון', 'הוולגה', 'פיניקס', 'ומבנקים']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ']
# results/new_outputs/treebank_tokens_fixed2-2-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 442 found, 333 correct.
# Precision: 0.67
# Recall:    0.75
# F1:        0.71
# FP ex.: ['באשר', 'מאיר כהן', 'קטיף', 'עבודתך', 'היאות']
# FN ex.: ['באיובה', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# results/new_outputs/treebank_tokens_fixed2-2-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 881 found, 612 correct.
# Precision: 0.66
# Recall:    0.69
# F1:        0.68
# FP ex.: ['2840', 'בחלקו העליון', 'הוולגה', 'פיניקס', 'ומבנקים']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'שבריאנט', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ']
# results/new_outputs/treebank_tokens_fixed2-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 749 found, 553 correct.
# Precision: 0.59
# Recall:    0.74
# F1:        0.66
# FP ex.: ['דן בורנשטיין וגוזף', 'פנמן', 'מקליוולנד', 'פיניקס', 'בקלינינגרד']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'רמת השרון', 'מקליוולנד', 'רכסים']
# results/new_outputs/treebank_tokens_fixed2-3-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 391 found, 308 correct.
# Precision: 0.62
# Recall:    0.79
# F1:        0.69
# FP ex.: ['טוד ויטמן', 'ירושלים', 'באשר', 'ישראל', 'אילת']
# FN ex.: ['באיובה', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# results/new_outputs/treebank_tokens_fixed2-3-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 749 found, 553 correct.
# Precision: 0.59
# Recall:    0.74
# F1:        0.66
# FP ex.: ['דן בורנשטיין וגוזף', 'פנמן', 'מקליוולנד', 'פיניקס', 'בקלינינגרד']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'רמת השרון', 'מקליוולנד', 'רכסים']
# results/new_outputs/treebank_tokens_fixed2-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 902 found, 636 correct.
# Precision: 0.68
# Recall:    0.71
# F1:        0.69
# FP ex.: ['אוקזר', 'פיניקס', 'אייאקס', 'פיאבה', 'לוריין']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# results/new_outputs/treebank_tokens_fixed2-4-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 422 found, 329 correct.
# Precision: 0.66
# Recall:    0.78
# F1:        0.71
# FP ex.: ['מרכז המידע לזכויות', 'רץ', 'במדינות הברית', 'פורד', 'להרוג']
# FN ex.: ['זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# results/new_outputs/treebank_tokens_fixed2-4-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 829 found, 583 correct.
# Precision: 0.63
# Recall:    0.7
# F1:        0.66
# FP ex.: ['בבית היהודי', 'עו', 'אוקזר', 'פיניקס', 'פיאבה']
# FN ex.: ['מזרח - פרוסיה', 'גיילס', 'רמת השרון', 'מקליוולנד', 'רכסים']
# results/new_outputs/treebank_tokens_fixed2-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 888 found, 632 correct.
# Precision: 0.68
# Recall:    0.71
# F1:        0.69
# FP ex.: ['טוסקאנה', 'דן בורנשטיין וגוזף', 'בולוניה', 'צזנה', 'לה קוצינה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'ק - ל - מ', 'קאמינגס', 'דן צבר', 'בוועדה לבחירת שופטים']
# results/new_outputs/treebank_tokens_fixed2-5-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 426 found, 327 correct.
# Precision: 0.66
# Recall:    0.77
# F1:        0.71
# FP ex.: ['נא מילוא', 'רץ', 'קטיף', 'במדינות הברית', 'פאפון וטובייה']
# FN ex.: ['הארקין', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# results/new_outputs/treebank_tokens_fixed2-5-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 821 found, 577 correct.
# Precision: 0.62
# Recall:    0.7
# F1:        0.66
# FP ex.: ['טוסקאנה', 'דן בורנשטיין וגוזף', 'בולוניה', 'וגולדן סטייט בטאקומה', 'צזנה']
# FN ex.: ['קאמינגס', 'גיילס', 'רמת השרון', 'מקליוולנד', 'רכסים']
# results/new_outputs/treebank_tokens_fixed2-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 867 found, 373 correct.
# Precision: 0.4
# Recall:    0.43
# F1:        0.41
# FP ex.: ['וקריאות שמחה', 'מפולפל', 'רשות', 'פיניקס', 'סלוניקי']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'גיילס', 'רמת השרון', 'מקליוולנד']
# results/new_outputs/treebank_tokens_fixed2-6-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 446 found, 203 correct.
# Precision: 0.41
# Recall:    0.46
# F1:        0.43
# FP ex.: ['מרכז המידע לזכויות', 'רץ', 'שרה סקאיף', 'מאיר כהן', 'בטיפולו']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'תנועת המושבים']
# results/new_outputs/treebank_tokens_fixed2-6-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 867 found, 373 correct.
# Precision: 0.4
# Recall:    0.43
# F1:        0.41
# FP ex.: ['וקריאות שמחה', 'מפולפל', 'רשות', 'פיניקס', 'סלוניקי']
# FN ex.: ['מזרח - פרוסיה', 'ויאלי', 'גיילס', 'רמת השרון', 'מקליוולנד']
# results/new_outputs/treebank_tokens_fixed2-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 1064 found, 503 correct.
# Precision: 0.54
# Recall:    0.47
# F1:        0.5
# FP ex.: ['אוקזר', 'סלוניקי', 'וידרגבורט', 'איראקליס', 'דוקסה']
# FN ex.: ['מזרח - פרוסיה', 'רמת השרון', 'רכסים', 'סאגואירוש', 'וואלווייק']
# results/new_outputs/treebank_tokens_fixed2-7-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 492 found, 243 correct.
# Precision: 0.49
# Recall:    0.49
# F1:        0.49
# FP ex.: ['שגורג', 'מרכז המידע לזכויות', 'רץ', 'מריה', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'באיובה', 'תנועת המושבים']
# results/new_outputs/treebank_tokens_fixed2-7-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 1005 found, 446 correct.
# Precision: 0.48
# Recall:    0.44
# F1:        0.46
# FP ex.: ['לאיזור הסל', 'אוקזר', 'סלוניקי', 'באירופה', 'וידרגבורט']
# FN ex.: ['מזרח - פרוסיה', 'גיילס', 'רמת השרון', 'רכסים', 'גבת']
# results/new_outputs/treebank_tokens_fixed2-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 892 found, 646 correct.
# Precision: 0.69
# Recall:    0.72
# F1:        0.71
# FP ex.: ['ברוז הבלגית', 'מכבי מוביל', 'אוקזר', 'פיניקס', 'שפירסם']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# results/new_outputs/treebank_tokens_fixed2-8-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 457 found, 348 correct.
# Precision: 0.7
# Recall:    0.76
# F1:        0.73
# FP ex.: ['מרכז המידע לזכויות', 'מאיר כהן', 'קטיף', 'ברבים', 'במדינות הברית']
# FN ex.: ['ה', 'באיובה', 'תנועת המושבים', 'בעין כרם', 'לסילבר']
# results/new_outputs/treebank_tokens_fixed2-8-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 892 found, 646 correct.
# Precision: 0.69
# Recall:    0.72
# F1:        0.71
# FP ex.: ['ברוז הבלגית', 'מכבי מוביל', 'אוקזר', 'פיניקס', 'שפירסם']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'הפועל', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# results/new_outputs/treebank_tokens_fixed2-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 847 found, 627 correct.
# Precision: 0.67
# Recall:    0.74
# F1:        0.71
# FP ex.: ['השופט זוסמן', 'פנמן', 'פיניקס', 'הלשכה וראשי הוועדים המחוזיים', 'צזנה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'ניר ריכליס', 'הפועל', 'ק - ל - מ', 'דן צבר']
# results/new_outputs/treebank_tokens_fixed2-9-extra_preds-1.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 439 found, 330 correct.
# Precision: 0.66
# Recall:    0.75
# F1:        0.7
# FP ex.: ['ולאריגה', 'באשר', 'רץ', 'מנזר סן סימון', 'קטיף']
# FN ex.: ['באיובה', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# results/new_outputs/treebank_tokens_fixed2-9-extra_preds-2.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 847 found, 627 correct.
# Precision: 0.67
# Recall:    0.74
# F1:        0.71
# FP ex.: ['השופט זוסמן', 'פנמן', 'פיניקס', 'הלשכה וראשי הוועדים המחוזיים', 'צזנה']
# FN ex.: ['הרפובליקה האוטונומית של הוולגה', 'ניר ריכליס', 'הפועל', 'ק - ל - מ', 'דן צבר']

# %%
tokens_fixed2_conf_gold_dev_res_o = pickle.load(open('results/new_outputs/treebank_tokens_fixed2_conf_res_preds_hist.pkl', 'rb'))
tokens_fixed2_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'conlleval_results': x[1][0], 
      'results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0], sents=tok_gold_dev_sents), tok_gold_dev_mentions, tok_gold_dev_sents)] } 
     for i, x in enumerate(tokens_fixed2_conf_gold_dev_res_o)]
tokens_fixed2_conf_gold_dev_res
# Out:
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 385 found, 168 correct.
# Precision: 0.34
# Recall:    0.44
# F1:        0.38
# FP ex.: ['רוקפלר בבלאגיו שבאיטליה', 'לדיאלקטיקה', 'מאיר כהן', 'שדות התעופה', 'השמרן טום']
# FN ex.: ['בוסקה', 'באיובה', 'הארקין', 'זורז פומפידו', 'ה']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 500 found, 274 correct.
# Precision: 0.55
# Recall:    0.55
# F1:        0.55
# FP ex.: ['תהילים', 'רץ', 'מריה', 'שרה סקאיף', 'שירותי בריאות']
# FN ex.: ['בוסקה', 'הארקין', 'ה', 'תנועת המושבים', 'לסילבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 442 found, 333 correct.
# Precision: 0.67
# Recall:    0.75
# F1:        0.71
# FP ex.: ['באשר', 'מאיר כהן', 'קטיף', 'עבודתך', 'היאות']
# FN ex.: ['באיובה', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 391 found, 308 correct.
# Precision: 0.62
# Recall:    0.79
# F1:        0.69
# FP ex.: ['טוד ויטמן', 'ירושלים', 'באשר', 'ישראל', 'אילת']
# FN ex.: ['באיובה', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 440 found, 355 correct.
# Precision: 0.71
# Recall:    0.81
# F1:        0.76
# FP ex.: ['מרכז המידע לזכויות', 'רץ', 'שרה סקאיף', 'סן סימון', 'מאיר כהן']
# FN ex.: ['ה', 'באיובה', 'תנועת המושבים', 'בעין כרם', 'לסילבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 450 found, 348 correct.
# Precision: 0.7
# Recall:    0.77
# F1:        0.73
# FP ex.: ['נא מילוא', 'קטיף', 'במדינות הברית', 'לשרי הפנים והעבודה והרווחה', 'איובה']
# FN ex.: ['הארקין', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 446 found, 203 correct.
# Precision: 0.41
# Recall:    0.46
# F1:        0.43
# FP ex.: ['מרכז המידע לזכויות', 'רץ', 'שרה סקאיף', 'מאיר כהן', 'בטיפולו']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 504 found, 278 correct.
# Precision: 0.56
# Recall:    0.55
# F1:        0.55
# FP ex.: ['שגורג', 'מרכז המידע לזכויות', 'שרה סקאיף', 'מאיר כהן', 'בהאג']
# FN ex.: ['בוסקה', 'הארקין', 'ה', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 457 found, 348 correct.
# Precision: 0.7
# Recall:    0.76
# F1:        0.73
# FP ex.: ['מרכז המידע לזכויות', 'מאיר כהן', 'קטיף', 'ברבים', 'במדינות הברית']
# FN ex.: ['ה', 'באיובה', 'תנועת המושבים', 'בעין כרם', 'לסילבר']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 439 found, 330 correct.
# Precision: 0.66
# Recall:    0.75
# F1:        0.7
# FP ex.: ['ולאריגה', 'באשר', 'רץ', 'מנזר סן סימון', 'קטיף']
# FN ex.: ['באיובה', 'זורז פומפידו', 'ה', 'באיובה', 'תנועת המושבים']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 440 found, 360 correct.
# Precision: 0.72
# Recall:    0.82
# F1:        0.77
# FP ex.: ['ירושלים', 'אילת', 'רץ', 'מנזר סן סימון', 'לציון']
# FN ex.: ['הארקין', 'ה', 'באיובה', 'תנועת המושבים', 'בעין כרם']
# []
# only 1.0 available mentions (due to different segmentation)
# 499 mentions, 445 found, 363 correct.
# Precision: 0.73
# Recall:    0.82
# F1:        0.77
# FP ex.: ['טוד ויטמן', 'ירושלים', 'ישראל', 'אילת', 'רץ']
# FN ex.: ['ה', 'באיובה', 'תנועת המושבים', 'בעין כרם', 'לסילבר']
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'crf': True, 'use_pos': False},
#   'conlleval_results': (41.959798994974875,
#    33.46693386773547,
#    37.23522853957636),
#   'results': [33.66733466933868, 43.63636363636363, 38.00904977375565]},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'crf': True, 'use_pos': True},
#   'conlleval_results': (53.606237816764136,
#    55.11022044088176,
#    54.347826086956516),
#   'results': [54.90981963927856, 54.800000000000004, 54.854854854854864]},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (69.23076923076923,
#    66.73346693386773,
#    67.95918367346938),
#   'results': [66.73346693386773, 75.3393665158371, 70.77577045696069]},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (71.22969837587007,
#    61.523046092184366,
#    66.02150537634408),
#   'results': [61.72344689378757, 78.77237851662404, 69.21348314606742]},
#  {'pred_set': 'gold_dev',
#   'conf': 4,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (76.78958785249458, 70.94188376753507, 73.75),
#   'results': [71.14228456913828, 80.68181818181817, 75.61235356762514]},
#  {'pred_set': 'gold_dev',
#   'conf': 5,
#   'config': {'add_random_embedding': False,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (73.73949579831933, 70.34068136272545, 72.0),
#   'results': [69.73947895791584, 77.33333333333333, 73.34035827186513]},
#  {'pred_set': 'gold_dev',
#   'conf': 6,
#   'config': {'use_char': True, 'crf': True, 'use_pos': False},
#   'conlleval_results': (44.469026548672566,
#    40.28056112224449,
#    42.27129337539432),
#   'results': [40.6813627254509, 45.51569506726457, 42.96296296296297]},
#  {'pred_set': 'gold_dev',
#   'conf': 7,
#   'config': {'use_char': True, 'crf': True, 'use_pos': True},
#   'conlleval_results': (54.74308300395256,
#    55.51102204408818,
#    55.12437810945274),
#   'results': [55.71142284569138, 55.158730158730165, 55.43369890329012]},
#  {'pred_set': 'gold_dev',
#   'conf': 8,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (73.13432835820896,
#    68.7374749498998,
#    70.86776859504133),
#   'results': [69.73947895791584, 76.14879649890591, 72.80334728033473]},
#  {'pred_set': 'gold_dev',
#   'conf': 9,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (73.4375, 65.93186372745491, 69.48257655755016),
#   'results': [66.13226452905812, 75.17084282460137, 70.36247334754798]},
#  {'pred_set': 'gold_dev',
#   'conf': 10,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'token_ft_sg',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (78.38427947598254,
#    71.9438877755511,
#    75.02612330198536),
#   'results': [72.14428857715431, 81.81818181818183, 76.67731629392972]},
#  {'pred_set': 'gold_dev',
#   'conf': 11,
#   'config': {'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': True,
#    'embed_dim': 300},
#   'conlleval_results': (79.25764192139738,
#    72.74549098196393,
#    75.86206896551724),
#   'results': [72.74549098196393, 81.57303370786518, 76.90677966101696]}]

# %% [raw]
# x = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0],
#       'mention_results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] }
#      for i, x in enumerate(morph_fixed_conf_gold_dev_res_o)]

# %%
conf_i = {x['conf']: x['config'] for x in tokens_fixed2_conf_gold_dev_res}
for r in tokens_fixed2_res:
    r['config'] = conf_i[r['conf']]
    
tokens_fixed2_res = tokens_fixed2_res+tokens_fixed2_conf_gold_dev_res

# %%
for r in tokens_fixed2_res:
    r['unit'] = 'tokens_fixed2'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]

# %%
tokens_fixed2_rdf = get_results_df(tokens_fixed2_res)
tokens_fixed2_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                  True  True            True         70             None
# 1                  True  True            True         70             None
# 2                  True  True            True         70             None
# 3                  True  True            True         70             None
# 4                  True  True            True         70             None
#
#    epochs         f1  input_dropout  min_delta  patience  ...     recall  \
# 0     100  39.234450          False     0.0001        20  ...  44.264507
# 1     100  38.009050          False     0.0001        20  ...  43.636364
# 2     100  39.234450          False     0.0001        20  ...  44.264507
# 3     100  51.855618          False     0.0001        20  ...  49.227799
# 4     100  47.927199          False     0.0001        20  ...  48.367347
#
#   stack_cross  stack_double  stack_lstm  trainable           unit  use_char  \
# 0       False         False           1       True  tokens_fixed2     False
# 1       False         False           1       True  tokens_fixed2     False
# 2       False         False           1       True  tokens_fixed2     False
# 3       False         False           1       True  tokens_fixed2     False
# 4       False         False           1       True  tokens_fixed2     False
#
#    use_pos  use_word validation_split
# 0    False      True              0.1
# 1    False      True              0.1
# 2    False      True              0.1
# 3     True      True              0.1
# 4     True      True              0.1
#
# [5 rows x 24 columns]

# %%
tokens_fixed2_rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix                    None pretrained_token_ft   token_ft_sg
# unit                       tokens_fixed2       tokens_fixed2 tokens_fixed2
# pred_set  use_pos use_char
# gold_dev  False   False             38.0                69.2          70.8
#                   True              43.0                70.4          72.8
#           True    False             54.9                73.3          75.6
#                   True              55.4                76.9          76.7
# gold_test False   False             39.2                65.8          67.5
#                   True              41.5                70.5          70.9
#           True    False             51.9                69.5          69.4
#                   True              50.4                72.7          73.9
# yap_dev   False   False             38.0                69.2          70.8
#                   True              43.0                70.4          72.8
#           True    False             47.9                70.7          71.4
#                   True              49.0                73.0          72.7
# yap_test  False   False             39.2                65.8          67.5
#                   True              41.5                70.5          70.9
#           True    False             44.8                65.9          66.3
#                   True              46.1                68.6          69.9

# %%
f2rdf = pd.concat([morph_fixed2_rdf,tokens_fixed2_rdf])
f2rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)
# Out:
# embedding_matrix                      None               pretrained_token_ft  \
# unit                       morpheme_fixed2 tokens_fixed2     morpheme_fixed2
# pred_set  use_pos use_char
# gold_dev  False   False               45.2          38.0                73.6
#                   True                55.2          43.0                75.7
#           True    False               62.5          54.9                77.2
#                   True                63.2          55.4                78.8
# gold_test False   False               47.2          39.2                69.3
#                   True                52.5          41.5                71.6
#           True    False               58.7          51.9                74.1
#                   True                61.1          50.4                75.4
# yap_dev   False   False               39.3          38.0                66.4
#                   True                48.7          43.0                67.7
#           True    False               51.0          47.9                66.1
#                   True                51.6          49.0                67.0
# yap_test  False   False               40.2          39.2                60.3
#                   True                44.6          41.5                62.0
#           True    False               46.7          44.8                61.9
#                   True                49.0          46.1                63.6
#
# embedding_matrix                           token_ft_sg       yap_ft_sg
# unit                       tokens_fixed2 tokens_fixed2 morpheme_fixed2
# pred_set  use_pos use_char
# gold_dev  False   False             69.2          70.8            71.6
#                   True              70.4          72.8            74.9
#           True    False             73.3          75.6            78.4
#                   True              76.9          76.7            79.1
# gold_test False   False             65.8          67.5            73.7
#                   True              70.5          70.9            74.9
#           True    False             69.5          69.4            75.0
#                   True              72.7          73.9            75.8
# yap_dev   False   False             69.2          70.8            64.8
#                   True              70.4          72.8            66.8
#           True    False             70.7          71.4            67.1
#                   True              73.0          72.7            68.2
# yap_test  False   False             65.8          67.5            64.8
#                   True              70.5          70.9            65.1
#           True    False             65.9          66.3            62.8
#                   True              68.6          69.9            64.1

# %% [markdown]
# ### Evaluate morphemes stack

# %%
import glob

# %%
#extra_preds = [(X_gold_test, X_pos_gold_test, X_char_gold_test), 
#               (X_yap_dev, X_pos_yap_dev, X_char_yap_dev),
#               (X_yap_test, X_pos_yap_test, X_char_yap_test)]
import re
morph_fixed_gold_sents = (morph_gold_test_sents, morph_gold_dev_sents, morph_gold_test_sents)
pred_set = ('gold_test', 'yap_dev', 'yap_test')

morph_stack_res = []
for ep in sorted(glob.glob('results/new_outputs_stack/*morphemes_stack*-extra_preds-*')):
    print(ep)
    i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
    conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
    res = {'pred_set': pred_set[i], 'conf': conf}
    res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), morph_gold_extra_preds[i], morph_fixed_gold_sents[i])]
    morph_stack_res.append(res)
# Out:
# results/new_outputs_stack/treebank_morphemes_stack-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 908 found, 701 correct.
# Precision: 0.75
# Recall:    0.77
# F1:        0.76
# FP ex.: ['שלום', 'חברת ה תיירות', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה']
# results/new_outputs_stack/treebank_morphemes_stack-0-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 462 found, 332 correct.
# Precision: 0.67
# Recall:    0.72
# F1:        0.69
# FP ex.: ['באשר', 'רץ', 'מריה', 'פורד שמרנים', 'מילוא להתלבט']
# FN ex.: ['בוסקה', 'קרן פורד', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack-0-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 882 found, 601 correct.
# Precision: 0.65
# Recall:    0.68
# F1:        0.66
# FP ex.: ['שלום', 'לטיות', 'חברת ה תיירות', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'כהן', 'שבריאנט', 'מזרח - פרוסיה']
# results/new_outputs_stack/treebank_morphemes_stack-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 901 found, 686 correct.
# Precision: 0.74
# Recall:    0.76
# F1:        0.75
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'פנמן', 'פיניקס', 'רמת ה שרון', 'דן']
# FN ex.: ['קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ', 'דן צבר']
# results/new_outputs_stack/treebank_morphemes_stack-1-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 451 found, 320 correct.
# Precision: 0.64
# Recall:    0.71
# F1:        0.67
# FP ex.: ['מריה', 'פורד שמרנים', 'ה קטיף', 'עין כרם', 'ה ירושלים']
# FN ex.: ['בוסקה', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'קרן מקארתור']
# results/new_outputs_stack/treebank_morphemes_stack-1-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 862 found, 571 correct.
# Precision: 0.61
# Recall:    0.66
# F1:        0.64
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'ה הפועל אום אל פאחם', 'פנמן', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['מילאנו', 'לטיום', 'סאגואירוש', 'כוויית', 'פורוורטס שטייר']
# results/new_outputs_stack/treebank_morphemes_stack-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 906 found, 691 correct.
# Precision: 0.74
# Recall:    0.76
# F1:        0.75
# FP ex.: ['לזניה', 'בורמור', 'רמת ה שרון', 'סן אנטוניו', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'הרצליה פיתוח', 'מזרח - פרוסיה', 'ק - ל - מ']
# results/new_outputs_stack/treebank_morphemes_stack-2-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 423 found, 310 correct.
# Precision: 0.62
# Recall:    0.73
# F1:        0.67
# FP ex.: ['רץ', 'מריה', 'ה ישראל', 'בהגזת', 'ולד']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'קרן מקארתור']
# results/new_outputs_stack/treebank_morphemes_stack-2-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 790 found, 520 correct.
# Precision: 0.56
# Recall:    0.66
# F1:        0.6
# FP ex.: ['מזרח סעודיה', 'אוקזר', 'רמת ה שרון', 'סן אנטוניו', 'צזנה']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'גיילס', 'לטיום', 'גבת']
# results/new_outputs_stack/treebank_morphemes_stack-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 954 found, 727 correct.
# Precision: 0.78
# Recall:    0.76
# F1:        0.77
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'בתי - משפט ה שלום', 'רמת ה שרון', 'גביע אופ"א', 'צזנה']
# FN ex.: ['הרצליה פיתוח', 'הרצליה פיתוח', 'מזרח - פרוסיה', 'ק - ל - מ', 'דן צבר']
# results/new_outputs_stack/treebank_morphemes_stack-3-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 447 found, 306 correct.
# Precision: 0.61
# Recall:    0.68
# F1:        0.65
# FP ex.: ['תהילים', 'רץ', 'מריה', 'ה ירושלים', 'ה ישראל']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack-3-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 870 found, 549 correct.
# Precision: 0.59
# Recall:    0.63
# F1:        0.61
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'שובה עין', 'ה הפועל אום אל פאחם', 'בתי - משפט ה שלום', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'לטיום', 'סאגואירוש', 'כוויית', 'חגי בז']
# results/new_outputs_stack/treebank_morphemes_stack2-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 807 found, 580 correct.
# Precision: 0.62
# Recall:    0.72
# F1:        0.67
# FP ex.: ['טוסקאנה', 'נעים', 'ה התאחדות שלמה', 'בונה', 'ה אנגלי בובי רובסון']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'לטיום', 'רכסים', 'סאגואירוש']
# results/new_outputs_stack/treebank_morphemes_stack2-0-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 407 found, 259 correct.
# Precision: 0.52
# Recall:    0.64
# F1:        0.57
# FP ex.: ['ה ירושלים', 'אורגון', 'רץ', 'מריה', 'וולסטון']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs_stack/treebank_morphemes_stack2-0-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 778 found, 497 correct.
# Precision: 0.53
# Recall:    0.64
# F1:        0.58
# FP ex.: ['טוסקאנה', 'נעים', 'ה הפועל אום אל פאחם', 'עור', 'גרמנית']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'לטיום', 'רכסים', 'גבת']
# results/new_outputs_stack/treebank_morphemes_stack2-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 872 found, 598 correct.
# Precision: 0.64
# Recall:    0.69
# F1:        0.66
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'נעים', 'ה התאחדות שלמה', 'פנמן']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה']
# results/new_outputs_stack/treebank_morphemes_stack2-1-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 441 found, 274 correct.
# Precision: 0.55
# Recall:    0.62
# F1:        0.58
# FP ex.: ['באשר', 'רץ', 'מריה', 'אליקים העצני', 'עין כרם']
# FN ex.: ['בוסקה', 'אינדיאנה', 'ליון', 'הארקין', 'ה']
# results/new_outputs_stack/treebank_morphemes_stack2-1-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 847 found, 512 correct.
# Precision: 0.55
# Recall:    0.6
# F1:        0.58
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'נעים', 'ה הפועל אום אל פאחם', 'פנמן']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# results/new_outputs_stack/treebank_morphemes_stack2-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 891 found, 639 correct.
# Precision: 0.69
# Recall:    0.72
# F1:        0.7
# FP ex.: ['כוויית', 'לוואדיאקוס', 'לזניה', 'בתי - משפט ה שלום', 'אוקזר']
# FN ex.: ['הרצליה פיתוח', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ', 'דן צבר']
# results/new_outputs_stack/treebank_morphemes_stack2-2-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 412 found, 291 correct.
# Precision: 0.58
# Recall:    0.71
# F1:        0.64
# FP ex.: ['תהילים', 'רץ', 'מריה', 'פורד שמרנים', 'פומפידו חנינה']
# FN ex.: ['בוסקה', 'קרן פורד', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs_stack/treebank_morphemes_stack2-2-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 792 found, 493 correct.
# Precision: 0.53
# Recall:    0.62
# F1:        0.57
# FP ex.: ['נאגטס', 'ה הפועל אום אל פאחם', 'עו', 'לוואדיאקוס', 'בתי - משפט ה שלום']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'גיילס', 'לטיום', 'גבת']
# results/new_outputs_stack/treebank_morphemes_stack2-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 937 found, 671 correct.
# Precision: 0.72
# Recall:    0.72
# F1:        0.72
# FP ex.: ['נאגטס', 'ארץ', 'ה התאחדות שלמה', 'פיניקס', 'גביע אופ"א']
# FN ex.: ['קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה', 'ק - ל - מ']
# results/new_outputs_stack/treebank_morphemes_stack2-3-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 443 found, 300 correct.
# Precision: 0.6
# Recall:    0.68
# F1:        0.64
# FP ex.: ['ה ירושלים', 'תהילים', 'ה אמבולנס', 'רץ', 'מריה']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack2-3-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 867 found, 530 correct.
# Precision: 0.57
# Recall:    0.61
# F1:        0.59
# FP ex.: ['ארץ', 'ה הפועל אום אל פאחם', 'פיניקס', 'לנדוי', '- סבא']
# FN ex.: ['מזרח - פרוסיה', 'גיילס', 'לטיום', 'גבת', 'חגי בז']
# results/new_outputs_stack/treebank_morphemes_stack3-0-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 869 found, 684 correct.
# Precision: 0.73
# Recall:    0.79
# F1:        0.76
# FP ex.: ['נאגטס', 'מזרח סעודיה', 'רמת ה שרון', 'גביע אופ"א', 'צזנה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'דן צבר']
# results/new_outputs_stack/treebank_morphemes_stack3-0-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 431 found, 312 correct.
# Precision: 0.63
# Recall:    0.72
# F1:        0.67
# FP ex.: ['מנזר סן סימון', 'מריה', 'שרה סקאיף', 'ה ירושלים', 'מילוא להתלבט']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'טובייה']
# results/new_outputs_stack/treebank_morphemes_stack3-0-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 835 found, 571 correct.
# Precision: 0.61
# Recall:    0.68
# F1:        0.65
# FP ex.: ['מזרח סעודיה', 'בולוניה', 'רמת ה שרון', 'דן', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'לטיום', 'גבת', 'וואלווייק']
# results/new_outputs_stack/treebank_morphemes_stack3-1-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 882 found, 698 correct.
# Precision: 0.75
# Recall:    0.79
# F1:        0.77
# FP ex.: ['נאגטס', 'רמת ה שרון', 'גביע אופ"א', 'לה קוצינה', 'דורטמונד']
# FN ex.: ['קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ', 'דן צבר']
# results/new_outputs_stack/treebank_morphemes_stack3-1-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 444 found, 328 correct.
# Precision: 0.66
# Recall:    0.74
# F1:        0.7
# FP ex.: ['מדינת מינסוטה', 'רץ', 'מריה', 'פורד שמרנים', 'ה ירושלים']
# FN ex.: ['בוסקה', 'הארקין', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack3-1-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 844 found, 595 correct.
# Precision: 0.64
# Recall:    0.7
# F1:        0.67
# FP ex.: ['נאגטס', 'רמת ה שרון', 'גביע אופ"א', 'לה קוצינה', 'דורטמונד']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'כהן', 'שבריאנט', 'ק - ל - מ']
# results/new_outputs_stack/treebank_morphemes_stack3-10-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 928 found, 700 correct.
# Precision: 0.75
# Recall:    0.75
# F1:        0.75
# FP ex.: ['כוויית', 'מוצי', 'בתי - משפט ה שלום', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['קלניניגרד', 'הרצליה פיתוח', 'ק - ל - מ', 'דן צבר', 'אנ.בי.איי']
# results/new_outputs_stack/treebank_morphemes_stack3-10-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 431 found, 296 correct.
# Precision: 0.59
# Recall:    0.69
# F1:        0.64
# FP ex.: ['מריה', 'ה התאחדות ל עולם טוב', 'ה ירושלים', 'בהגזת', 'מילשטיין']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack3-10-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 804 found, 529 correct.
# Precision: 0.57
# Recall:    0.66
# F1:        0.61
# FP ex.: ['ה וותה', 'עו', 'תל אביב', 'בתי - משפט ה שלום', 'רמת ה שרון']
# FN ex.: ['מילאנו', 'גיילס', 'לטיום', 'רכסים', 'גבת']
# results/new_outputs_stack/treebank_morphemes_stack3-11-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 950 found, 697 correct.
# Precision: 0.75
# Recall:    0.73
# F1:        0.74
# FP ex.: ['נאגטס', 'כוויית', 'פיניקס', 'גביע אופ"א', 'לה קוצינה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs_stack/treebank_morphemes_stack3-11-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 434 found, 294 correct.
# Precision: 0.59
# Recall:    0.68
# F1:        0.63
# FP ex.: ['תהילים', 'רץ', 'מריה', 'ה ירושלים', 'מרכז ה מידע ל זכויות ה אדם']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs_stack/treebank_morphemes_stack3-11-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 831 found, 531 correct.
# Precision: 0.57
# Recall:    0.64
# F1:        0.6
# FP ex.: ['בברלין', 'פיניקס', 'מחלקה ל ה מחלקה', 'לנדוי', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'גיילס', 'לטיום', 'גבת', 'חגי בז']
# results/new_outputs_stack/treebank_morphemes_stack3-12-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 955 found, 705 correct.
# Precision: 0.76
# Recall:    0.74
# F1:        0.75
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'כוויית', 'ה ליגה ה לאומית', 'בתי - משפט ה שלום', 'בורמור']
# FN ex.: ['הרצליה פיתוח', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה', 'ק - ל - מ']
# results/new_outputs_stack/treebank_morphemes_stack3-12-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 442 found, 304 correct.
# Precision: 0.61
# Recall:    0.69
# F1:        0.65
# FP ex.: ['תהילים', 'רץ', 'מריה', 'ה ירושלים', 'מרכז ה מידע ל זכויות ה אדם']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack3-12-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 834 found, 521 correct.
# Precision: 0.56
# Recall:    0.62
# F1:        0.59
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'בתי - משפט ה שלום', 'ה מילאנו', 'מחלקה ל ה מחלקה', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs_stack/treebank_morphemes_stack3-13-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 932 found, 707 correct.
# Precision: 0.76
# Recall:    0.76
# F1:        0.76
# FP ex.: ['כוויית', 'מזרח סעודיה', 'רמת ה שרון', 'גביע אופ"א', 'צזנה']
# FN ex.: ['הרצליה פיתוח', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה', 'דן צבר']
# results/new_outputs_stack/treebank_morphemes_stack3-13-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 447 found, 301 correct.
# Precision: 0.6
# Recall:    0.67
# F1:        0.64
# FP ex.: ['ה ירושלים', 'רץ', 'מריה', 'פורד שמרנים', 'בהגזת']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack3-13-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 814 found, 531 correct.
# Precision: 0.57
# Recall:    0.65
# F1:        0.61
# FP ex.: ['ה וותה', 'ה הפועל אום אל פאחם', 'מזרח סעודיה', 'רמת ה שרון', 'לנדוי']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'גיילס', 'לטיום', 'גבת']
# results/new_outputs_stack/treebank_morphemes_stack3-14-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 964 found, 688 correct.
# Precision: 0.74
# Recall:    0.71
# F1:        0.73
# FP ex.: ['לזניה', 'ארץ', 'בורמור', 'סן אנטוניו', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה']
# results/new_outputs_stack/treebank_morphemes_stack3-14-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 431 found, 298 correct.
# Precision: 0.6
# Recall:    0.69
# F1:        0.64
# FP ex.: ['תהילים', 'גדירות', 'רץ', 'מריה', 'ה ירושלים']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack3-14-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 847 found, 529 correct.
# Precision: 0.57
# Recall:    0.62
# F1:        0.6
# FP ex.: ['לשניים', 'ארץ', 'שובה עין', 'ה הפועל אום אל פאחם', 'ה מילאנו']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs_stack/treebank_morphemes_stack3-15-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 937 found, 683 correct.
# Precision: 0.73
# Recall:    0.73
# F1:        0.73
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'בורמור', 'רמת ה שרון', 'גביע אופ"א', 'צזנה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'הרצליה פיתוח', 'ק - ל - מ', 'דן צבר']
# results/new_outputs_stack/treebank_morphemes_stack3-15-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 429 found, 304 correct.
# Precision: 0.61
# Recall:    0.71
# F1:        0.66
# FP ex.: ['גדירות', 'רץ', 'מריה', 'פורד שמרנים', 'ה ישראל']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack3-15-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 829 found, 543 correct.
# Precision: 0.58
# Recall:    0.66
# F1:        0.62
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'ה הפועל אום אל פאחם', 'בולוניה', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'גיילס', 'לטיום', 'גבת', 'כוויית']
# results/new_outputs_stack/treebank_morphemes_stack3-16-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 936 found, 664 correct.
# Precision: 0.71
# Recall:    0.71
# F1:        0.71
# FP ex.: ['נאגטס', 'מוצי', 'ירושלים', 'לזניה', 'בורמור']
# FN ex.: ['הרצליה פיתוח', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס']
# results/new_outputs_stack/treebank_morphemes_stack3-16-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 425 found, 299 correct.
# Precision: 0.6
# Recall:    0.7
# F1:        0.65
# FP ex.: ['תהילים', 'גדירות', 'רץ', 'מריה', 'בהגזת']
# FN ex.: ['בוסקה', 'קרן פורד', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs_stack/treebank_morphemes_stack3-16-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 829 found, 525 correct.
# Precision: 0.56
# Recall:    0.63
# F1:        0.6
# FP ex.: ['לשניים', 'ה הפועל אום אל פאחם', 'ירושלים', 'אוקזר', 'פיניקס']
# FN ex.: ['הרצליה פיתוח', 'קאמינגס', 'גיילס', 'לטיום', 'רכסים']
# results/new_outputs_stack/treebank_morphemes_stack3-17-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 954 found, 690 correct.
# Precision: 0.74
# Recall:    0.72
# F1:        0.73
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'מוצי', 'עור', 'פונגי אלה - קרמה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'דן צבר']
# results/new_outputs_stack/treebank_morphemes_stack3-17-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 449 found, 305 correct.
# Precision: 0.61
# Recall:    0.68
# F1:        0.64
# FP ex.: ['בריאות', 'אנא', 'תהילים', 'רץ', 'מריה']
# FN ex.: ['בוסקה', 'קרן פורד', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs_stack/treebank_morphemes_stack3-17-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 853 found, 545 correct.
# Precision: 0.59
# Recall:    0.64
# F1:        0.61
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'בית לאדמו"ר', 'עו', 'פיניקס', 'מחלקה ל ה מחלקה']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'גיילס', 'לטיום', 'גבת']
# results/new_outputs_stack/treebank_morphemes_stack3-2-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 908 found, 673 correct.
# Precision: 0.72
# Recall:    0.74
# F1:        0.73
# FP ex.: ['נאגטס', 'מכבי מוביל', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה']
# results/new_outputs_stack/treebank_morphemes_stack3-2-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 448 found, 321 correct.
# Precision: 0.64
# Recall:    0.72
# F1:        0.68
# FP ex.: ['אנא', 'באשר', 'רץ', 'מריה', 'רוצים נקמה']
# FN ex.: ['בוסקה', 'קרן פורד', 'הארקין', 'ה', 'ה קרב על ירושלים']
# results/new_outputs_stack/treebank_morphemes_stack3-2-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 869 found, 562 correct.
# Precision: 0.6
# Recall:    0.65
# F1:        0.62
# FP ex.: ['נצח', 'נאגטס', 'ה הפועל אום אל פאחם', 'לטיות', 'מכבי מוביל']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# results/new_outputs_stack/treebank_morphemes_stack3-3-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 899 found, 700 correct.
# Precision: 0.75
# Recall:    0.78
# F1:        0.77
# FP ex.: ['ה רפובליקה ה רוסית', 'פיניקס', 'סן אנטוניו', 'גביע אופ"א', 'צזנה']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs_stack/treebank_morphemes_stack3-3-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 452 found, 323 correct.
# Precision: 0.65
# Recall:    0.71
# F1:        0.68
# FP ex.: ['מנזר סן סימון', 'מריה', 'פומפידו חנינה', 'ה ירושלים', 'הבריקה']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'סילבר']
# results/new_outputs_stack/treebank_morphemes_stack3-3-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 859 found, 585 correct.
# Precision: 0.63
# Recall:    0.68
# F1:        0.65
# FP ex.: ['ה רפובליקה ה רוסית', 'פיניקס', 'סן אנטוניו', 'גביע אופ"א', 'צזנה']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'לטיום', 'בולי', 'מיקי']
# results/new_outputs_stack/treebank_morphemes_stack3-4-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 863 found, 673 correct.
# Precision: 0.72
# Recall:    0.78
# F1:        0.75
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'מוצי', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'דן צבר', 'ה וולגה']
# results/new_outputs_stack/treebank_morphemes_stack3-4-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 434 found, 320 correct.
# Precision: 0.64
# Recall:    0.74
# F1:        0.69
# FP ex.: ['מריה', 'שרה סקאיף', 'ה ירושלים', 'ולד', 'כהן']
# FN ex.: ['בוסקה', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'קרן מקארתור']
# results/new_outputs_stack/treebank_morphemes_stack3-4-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 818 found, 567 correct.
# Precision: 0.61
# Recall:    0.69
# F1:        0.65
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'מוצי', 'ה הפועל אום אל פאחם', 'ה סובייטית ה ליטאית']
# FN ex.: ['מילאנו', 'לטיום', 'רכסים', 'כוויית', 'רמת ה שרון']
# results/new_outputs_stack/treebank_morphemes_stack3-5-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 906 found, 682 correct.
# Precision: 0.73
# Recall:    0.75
# F1:        0.74
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'פיניקס', 'רמת ה שרון', 'דן']
# FN ex.: ['קלניניגרד', 'כהן', 'שבריאנט', 'מזרח - פרוסיה', 'ק - ל - מ']
# results/new_outputs_stack/treebank_morphemes_stack3-5-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 440 found, 325 correct.
# Precision: 0.65
# Recall:    0.74
# F1:        0.69
# FP ex.: ['מנזר סן סימון', 'מריה', 'שרה סקאיף', 'עין כרם', 'ה ירושלים']
# FN ex.: ['בוסקה', 'הארקין', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים']
# results/new_outputs_stack/treebank_morphemes_stack3-5-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 866 found, 560 correct.
# Precision: 0.6
# Recall:    0.65
# F1:        0.62
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'נאגטס', 'בוסטון סלטיקס', 'נצח', 'פיניקס']
# FN ex.: ['מזרח - פרוסיה', 'מילאנו', 'לטיום', 'רכסים', 'וואלווייק']
# results/new_outputs_stack/treebank_morphemes_stack3-6-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 873 found, 677 correct.
# Precision: 0.73
# Recall:    0.78
# F1:        0.75
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'פיניקס', 'רמת ה שרון', 'דן', 'סן אנטוניו']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'מזרח - פרוסיה']
# results/new_outputs_stack/treebank_morphemes_stack3-6-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 443 found, 321 correct.
# Precision: 0.64
# Recall:    0.72
# F1:        0.68
# FP ex.: ['באשר', 'מריה', 'פורד שמרנים', 'ה ירושלים', 'דקר']
# FN ex.: ['בוסקה', 'קרן פורד', 'ה', 'ה קרב על ירושלים', 'טובייה']
# results/new_outputs_stack/treebank_morphemes_stack3-6-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 848 found, 569 correct.
# Precision: 0.61
# Recall:    0.67
# F1:        0.64
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'ה הפועל אום אל פאחם', 'לטיות', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'מילאנו', 'לטיום', 'רכסים']
# results/new_outputs_stack/treebank_morphemes_stack3-7-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 876 found, 636 correct.
# Precision: 0.68
# Recall:    0.73
# F1:        0.7
# FP ex.: ['בתי - משפט ה שלום', 'פיניקס', 'רמת ה שרון', 'דן', 'סן אנטוניו']
# FN ex.: ['הרצליה פיתוח', 'אנדרלכט', 'קלניניגרד', 'שבריאנט', 'מזרח - פרוסיה']
# results/new_outputs_stack/treebank_morphemes_stack3-7-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 427 found, 310 correct.
# Precision: 0.62
# Recall:    0.73
# F1:        0.67
# FP ex.: ['באשר', 'מריה', 'פורד שמרנים', 'בושוויץ', 'ה ישראל']
# FN ex.: ['בוסקה', 'ה', 'ה קרב על ירושלים', 'טובייה', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack3-7-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 861 found, 539 correct.
# Precision: 0.58
# Recall:    0.63
# F1:        0.6
# FP ex.: ['ה הפועל אום אל פאחם', 'לטיות', 'עור', 'בתי - משפט ה שלום', 'בהרצליה פיתוח']
# FN ex.: ['הרצליה פיתוח', 'מזרח - פרוסיה', 'קאמינגס', 'ויאלי', 'מילאנו']
# results/new_outputs_stack/treebank_morphemes_stack3-8-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 896 found, 654 correct.
# Precision: 0.7
# Recall:    0.73
# F1:        0.72
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'עור', 'פיניקס', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'ק - ל - מ']
# results/new_outputs_stack/treebank_morphemes_stack3-8-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 427 found, 315 correct.
# Precision: 0.63
# Recall:    0.74
# F1:        0.68
# FP ex.: ['אנא', 'רץ', 'מריה', 'פורד שמרנים', 'ה ירושלים']
# FN ex.: ['בוסקה', 'קרן פורד', 'הארקין', 'ה', 'ה קרב על ירושלים']
# results/new_outputs_stack/treebank_morphemes_stack3-8-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 860 found, 558 correct.
# Precision: 0.6
# Recall:    0.65
# F1:        0.62
# FP ex.: ['ה כנסייה ה אורתודוקסית', 'ה הפועל אום אל פאחם', 'בהרצליה פיתוח', 'פיניקס', 'רמת ה שרון']
# FN ex.: ['הרצליה פיתוח', 'ויאלי', 'מילאנו', 'גיילס', 'לטיום']
# results/new_outputs_stack/treebank_morphemes_stack3-9-extra_preds-0.pkl
# []
# only 1.0 available mentions (due to different segmentation)
# 931 mentions, 960 found, 717 correct.
# Precision: 0.77
# Recall:    0.75
# F1:        0.76
# FP ex.: ['נאגטס', 'בתי - משפט ה שלום', 'מזרח סעודיה', 'רמת ה שרון', 'גביע אופ"א']
# FN ex.: ['הרצליה פיתוח', 'קלניניגרד', 'שבריאנט', 'הרצליה פיתוח', 'דן צבר']
# results/new_outputs_stack/treebank_morphemes_stack3-9-extra_preds-1.pkl
# [(56, (0, 3)), (127, (2, 4)), (160, (1, 3)), (326, (0, 2))]
# only 0.92 available mentions (due to different segmentation)
# 498 mentions, 439 found, 309 correct.
# Precision: 0.62
# Recall:    0.7
# F1:        0.66
# FP ex.: ['תהילים', 'רץ', 'מריה', 'ה ירושלים', 'בהגזת']
# FN ex.: ['בוסקה', 'זורז פומפידו', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי']
# results/new_outputs_stack/treebank_morphemes_stack3-9-extra_preds-2.pkl
# [(32, (8, 12)), (94, (0, 2)), (131, (4, 6)), (151, (1, 4)), (156, (10, 12)), (158, (1, 3)), (160, (11, 14)), (169, (1, 3)), (215, (7, 9)), (235, (1, 3)), (402, (2, 4)), (446, (3, 5)), (456, (4, 6)), (560, (0, 2))]
# only 0.87 available mentions (due to different segmentation)
# 931 mentions, 850 found, 542 correct.
# Precision: 0.58
# Recall:    0.64
# F1:        0.61
# FP ex.: ['עו', 'בתי - משפט ה שלום', 'מזרח סעודיה', 'ה מילאנו', 'בולוניה']
# FN ex.: ['הרצליה פיתוח', 'מילאנו', 'גיילס', 'לטיום', 'גבת']

# %%
morph_stack_conf_gold_dev_res_o = pickle.load(open('results/new_outputs_stack/treebank_morphemes_stack_conf_res_preds_hist.pkl', 'rb'))
morph_stack_conf_gold_dev_res = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'conlleval_results': x[1][0], 
      'results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] } 
     for i, x in enumerate(morph_stack_conf_gold_dev_res_o)]
morph_stack_conf_gold_dev_res
# Out:
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 456 found, 366 correct.
# Precision: 0.73
# Recall:    0.8
# F1:        0.77
# FP ex.: ['באשר', 'רץ', 'שרה סקאיף', 'מילוא להתלבט', 'דה מוין']
# FN ex.: ['קרן פורד', 'ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'קרן מקארתור']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 449 found, 365 correct.
# Precision: 0.73
# Recall:    0.81
# F1:        0.77
# FP ex.: ['ירושלים', 'רצ"ב', 'ישראל', 'מסצוסטס', 'טובת ה כלל']
# FN ex.: ['ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'ירושלים ה מערבית', 'קטמון']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 452 found, 382 correct.
# Precision: 0.77
# Recall:    0.85
# F1:        0.8
# FP ex.: ['ירושלים', 'מסצוסטס', 'רץ', 'מקארתור', 'קטמון']
# FN ex.: ['ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'ירושלים ה מערבית', 'קטמון']
# []
# only 1.0 available mentions (due to different segmentation)
# 498 mentions, 468 found, 378 correct.
# Precision: 0.76
# Recall:    0.81
# F1:        0.78
# FP ex.: ['תהילים', 'רץ', 'שרה סקאיף', 'הרי בראדלו', 'כאפייה']
# FN ex.: ['ה', 'ה קרב על ירושלים', 'ה עולם ה שלישי', 'ירושלים ה מערבית', 'קטמון']
# [{'pred_set': 'gold_dev',
#   'conf': 0,
#   'config': {'optimizer': 'adam',
#    'output_dropout': True,
#    'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': False,
#    'stack_lstm': 2,
#    'patience': 10},
#   'conlleval_results': (79.91266375545851,
#    73.49397590361446,
#    76.56903765690376),
#   'results': [73.49397590361446, 80.26315789473685, 76.72955974842768]},
#  {'pred_set': 'gold_dev',
#   'conf': 1,
#   'config': {'optimizer': 'adam',
#    'output_dropout': True,
#    'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': False,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': False,
#    'stack_lstm': 2,
#    'patience': 10},
#   'conlleval_results': (79.95594713656388,
#    72.89156626506023,
#    76.26050420168067),
#   'results': [73.29317269076306, 81.29175946547885, 77.08553326293558]},
#  {'pred_set': 'gold_dev',
#   'conf': 2,
#   'config': {'optimizer': 'adam',
#    'output_dropout': True,
#    'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'yap_ft_sg',
#    'trainable': False,
#    'stack_lstm': 2,
#    'patience': 10},
#   'conlleval_results': (84.14096916299559,
#    76.70682730923694,
#    80.25210084033614),
#   'results': [76.70682730923694, 84.51327433628319, 80.42105263157895]},
#  {'pred_set': 'gold_dev',
#   'conf': 3,
#   'config': {'optimizer': 'adam',
#    'output_dropout': True,
#    'add_random_embedding': False,
#    'use_char': True,
#    'crf': True,
#    'use_pos': True,
#    'embedding_matrix': 'pretrained_token_ft',
#    'trainable': False,
#    'stack_lstm': 2,
#    'patience': 10},
#   'conlleval_results': (80.2547770700637, 75.90361445783132, 78.0185758513932),
#   'results': [75.90361445783132, 80.76923076923077, 78.2608695652174]}]

# %% [raw]
# x = [{'pred_set': 'gold_dev', 'conf': i, 'config': x[0], 'results': x[1][0],
#       'mention_results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0]), morph_gold_dev_mentions, o_morph_gold_dev_sents)] }
#      for i, x in enumerate(morph_fixed_conf_gold_dev_res_o)]

# %%
conf_i = {x['conf']: x['config'] for x in morph_stack_conf_gold_dev_res}
for r in morph_stack_res:
    r['config'] = conf_i[r['conf']]
    
morph_stack_res = morph_stack_res+morph_stack_conf_gold_dev_res
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-1ef5a1c218de> in <module>
#       1 conf_i = {x['conf']: x['config'] for x in morph_stack_conf_gold_dev_res}
#       2 for r in morph_stack_res:
# ----> 3     r['config'] = conf_i[r['conf']]
#       4
#       5 morph_stack_res = morph_stack_res+morph_stack_conf_gold_dev_res
#
# KeyError: 10

# %%
for r in morph_stack_res:
    r['unit'] = 'morpheme'
    for key in defaults:
        if key not in r['config']:
            r['config'][key] = defaults[key]

# %%
morph_stack_rdf = get_results_df(morph_stack_res)
morph_stack_rdf.head()

# %%
morph_stack_rdf.fillna('None').groupby(['pred_set', 'use_pos', 'use_char', 'embedding_matrix','unit']).f1.max().unstack(level=[3,4]).round(1)

# %%
def evaluate_run(folder, run_name, gold_sents, gold_mentions, pred_set=('gold_test', 'yap_dev', 'yap_test'), unit='morpheme',
                 orig_preds='gold_dev', orig_gold_mentions=morph_gold_dev_mentions, orig_o_gold_sents=o_morph_gold_dev_sents, corpus='treebank', 
                 defaults=defaults):
    results = []
    for ep in sorted(glob.glob(folder+'*'+run_name+'-*-extra_preds-*')):
        i = int(re.search('extra_preds-(\d)', ep).groups(0)[0])
        conf = int(re.search('(\d+)-extra_preds', ep).groups(0)[0])
        res = {'pred_set': pred_set[i], 'conf': conf}
        res['results'] = [x*100 for x in eval_pred_mentions(pickle.load(open(ep, 'rb')), gold_mentions[i], gold_sents[i], verbose=False)]
        results.append(res)
        
    conf_gold_res_o = pickle.load(open(folder+corpus+'_'+run_name+'_conf_res_preds_hist.pkl', 'rb'))
    conf_gold_res = [{'pred_set': orig_preds, 'conf': i, 'config': x[0], 'conlleval_results': x[1][0], 
          'results': [x*100 for x in eval_pred_mentions(get_preds_from_preds(x[2][0], sents=orig_o_gold_sents), orig_gold_mentions, orig_o_gold_sents, verbose=False)] } 
         for i, x in enumerate(conf_gold_res_o)]

    conf_i = {x['conf']: x['config'] for x in conf_gold_res}
    
    for r in results:
        r['config'] = conf_i[r['conf']]

    results = results+conf_gold_res
    for r in results:
        r['unit'] = unit
        for key in defaults:
            if key not in r['config']:
                r['config'][key] = defaults[key]
    rdf = get_results_df(results)

    return rdf

# %%
ms_rdf = evaluate_run('results/new_outputs_stack/', 'morphemes_stack', morph_fixed_gold_sents, morph_gold_extra_preds)
ms_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim     embedding_matrix  \
# 0                 False  True            True         70            yap_ft_sg
# 1                 False  True            True         70            yap_ft_sg
# 2                 False  True            True         70            yap_ft_sg
# 3                 False  True            True         70  pretrained_token_ft
# 4                 False  True            True         70  pretrained_token_ft
#
#    epochs         f1  input_dropout  min_delta optimizer  ...     recall  \
# 0     100  76.237085          False     0.0001      adam  ...  77.202643
# 1     100  69.166667          False     0.0001      adam  ...  71.861472
# 2     100  66.298952          False     0.0001      adam  ...  68.140590
# 3     100  74.890830          False     0.0001      adam  ...  76.137625
# 4     100  67.439410          False     0.0001      adam  ...  70.953437
#
#    stack_cross  stack_double stack_lstm  trainable      unit  use_char  \
# 0        False         False          2      False  morpheme      True
# 1        False         False          2      False  morpheme      True
# 2        False         False          2      False  morpheme      True
# 3        False         False          2      False  morpheme      True
# 4        False         False          2      False  morpheme      True
#
#    use_pos  use_word  validation_split
# 0    False      True               0.1
# 1    False      True               0.1
# 2    False      True               0.1
# 3    False      True               0.1
# 4    False      True               0.1
#
# [5 rows x 26 columns]

# %%
ms2_rdf = evaluate_run('results/new_outputs_stack/', 'morphemes_stack2', morph_fixed_gold_sents, morph_gold_extra_preds)
ms2_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim     embedding_matrix  \
# 0                 False  True            True         70            yap_ft_sg
# 1                 False  True            True         70            yap_ft_sg
# 2                 False  True            True         70            yap_ft_sg
# 3                 False  True            True         70  pretrained_token_ft
# 4                 False  True            True         70  pretrained_token_ft
#
#    epochs         f1  input_dropout  min_delta optimizer  ...     recall  \
# 0     100  66.743383          False     0.0001      adam  ...  71.871128
# 1     100  57.237569          False     0.0001      adam  ...  63.636364
# 2     100  58.162668          False     0.0001      adam  ...  63.881748
# 3     100  66.333888          False     0.0001      adam  ...  68.577982
# 4     100  58.359957          False     0.0001      adam  ...  62.131519
#
#    stack_cross  stack_double stack_lstm  trainable      unit  use_char  \
# 0        False         False          2       True  morpheme      True
# 1        False         False          2       True  morpheme      True
# 2        False         False          2       True  morpheme      True
# 3        False         False          2       True  morpheme      True
# 4        False         False          2       True  morpheme      True
#
#    use_pos  use_word  validation_split
# 0    False      True               0.1
# 1    False      True               0.1
# 2    False      True               0.1
# 3    False      True               0.1
# 4    False      True               0.1
#
# [5 rows x 26 columns]

# %%
ts_rdf = evaluate_run('results/new_outputs_stack/', 'tokens_stack', tok_gold_sents, tok_gold_extra_preds, unit='token',
                     orig_gold_mentions=tok_gold_dev_mentions, orig_o_gold_sents=tok_gold_dev_sents,)
ts_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim     embedding_matrix  \
# 0                 False  True            True         70          token_ft_sg
# 1                 False  True            True         70          token_ft_sg
# 2                 False  True            True         70          token_ft_sg
# 3                 False  True            True         70  pretrained_token_ft
# 4                 False  True            True         70  pretrained_token_ft
#
#    epochs         f1  input_dropout  min_delta optimizer  ...     recall  \
# 0     100  71.973094          False     0.0001      adam  ...  75.263775
# 1     100  73.134328          False     0.0001      adam  ...  78.132118
# 2     100  71.973094          False     0.0001      adam  ...  75.263775
# 3     100  68.298109          False     0.0001      adam  ...  70.818916
# 4     100  71.382637          False     0.0001      adam  ...  76.728111
#
#    stack_cross  stack_double stack_lstm  trainable   unit  use_char  use_pos  \
# 0        False         False          2      False  token      True    False
# 1        False         False          2      False  token      True    False
# 2        False         False          2      False  token      True    False
# 3        False         False          2      False  token      True    False
# 4        False         False          2      False  token      True    False
#
#    use_word  validation_split
# 0      True               0.1
# 1      True               0.1
# 2      True               0.1
# 3      True               0.1
# 4      True               0.1
#
# [5 rows x 26 columns]

# %%
ts3_rdf = evaluate_run('results/new_outputs_stack/', 'tokens_stack3', tok_gold_sents, tok_gold_extra_preds, unit='token',
                     orig_gold_mentions=tok_gold_dev_mentions, orig_o_gold_sents=tok_gold_dev_sents,)
ts3_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                 False  True            True         70       yap_w2v_sg
# 1                 False  True            True         70       yap_w2v_sg
# 2                 False  True            True         70       yap_w2v_sg
# 3                 False  True            True         70     yap_w2v_cbow
# 4                 False  True            True         70     yap_w2v_cbow
#
#    epochs         f1  input_dropout  min_delta optimizer  ...     recall  \
# 0     100  65.769456          False     0.0001      adam  ...  72.236504
# 1     100  64.228571          False     0.0001      adam  ...  74.734043
# 2     100  65.769456          False     0.0001      adam  ...  72.236504
# 3     100  62.405578          False     0.0001      adam  ...  67.974684
# 4     100  61.936937          False     0.0001      adam  ...  70.694087
#
#    stack_cross  stack_double stack_lstm  trainable   unit  use_char  use_pos  \
# 0        False         False          2      False  token      True    False
# 1        False         False          2      False  token      True    False
# 2        False         False          2      False  token      True    False
# 3        False         False          2      False  token      True    False
# 4        False         False          2      False  token      True    False
#
#    use_word  validation_split
# 0      True               0.1
# 1      True               0.1
# 2      True               0.1
# 3      True               0.1
# 4      True               0.1
#
# [5 rows x 26 columns]

# %%
ms3_rdf = evaluate_run('results/new_outputs_stack/', 'morphemes_stack3', morph_fixed_gold_sents, morph_gold_extra_preds)
ms3_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim embedding_matrix  \
# 0                 False  True            True         70       yap_w2v_sg
# 1                 False  True            True         70       yap_w2v_sg
# 2                 False  True            True         70       yap_w2v_sg
# 3                 False  True            True         70     yap_w2v_cbow
# 4                 False  True            True         70     yap_w2v_cbow
#
#    epochs         f1  input_dropout  min_delta optimizer  ...     recall  \
# 0     100  76.000000          False     0.0001      adam  ...  78.711162
# 1     100  67.168999          False     0.0001      adam  ...  72.389791
# 2     100  64.665912          False     0.0001      adam  ...  68.383234
# 3     100  76.999448          False     0.0001      adam  ...  79.138322
# 4     100  69.639066          False     0.0001      adam  ...  73.873874
#
#    stack_cross  stack_double stack_lstm  trainable      unit  use_char  \
# 0        False         False          2      False  morpheme      True
# 1        False         False          2      False  morpheme      True
# 2        False         False          2      False  morpheme      True
# 3        False         False          2      False  morpheme      True
# 4        False         False          2      False  morpheme      True
#
#    use_pos  use_word  validation_split
# 0    False      True               0.1
# 1    False      True               0.1
# 2    False      True               0.1
# 3    False      True               0.1
# 4    False      True               0.1
#
# [5 rows x 26 columns]

# %%
tat1_rdf = evaluate_run('results/new_outputs_alt_tok/', 'tokens_alt_tok1', tok_gold_sents, tok_gold_extra_preds, unit='token',
                     orig_gold_mentions=tok_gold_dev_mentions, orig_o_gold_sents=tok_gold_dev_sents,)
tat1_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim     embedding_matrix  \
# 0                 False  True            True         70  alt_tok_token_ft_sg
# 1                 False  True            True         70  alt_tok_token_ft_sg
# 2                 False  True            True         70  alt_tok_token_ft_sg
# 3                 False  True            True         70  alt_tok_token_ft_sg
# 4                 False  True            True         70  alt_tok_token_ft_sg
#
#    epochs         f1  input_dropout  min_delta optimizer  ...     recall  \
# 0     100  73.270614          False     0.0001      adam  ...  75.570776
# 1     100  73.673036          False     0.0001      adam  ...  78.329571
# 2     100  73.270614          False     0.0001      adam  ...  75.570776
# 3     100  76.027763          False     0.0001      adam  ...  75.583864
# 4     100  69.871795          False     0.0001      adam  ...  74.828375
#
#    stack_cross  stack_double stack_lstm  trainable   unit  use_char  use_pos  \
# 0        False         False          2      False  token      True    False
# 1        False         False          2      False  token      True    False
# 2        False         False          2      False  token      True    False
# 3        False         False          2      False  token      True     True
# 4        False         False          2      False  token      True     True
#
#    use_word  validation_split
# 0      True               0.1
# 1      True               0.1
# 2      True               0.1
# 3      True               0.1
# 4      True               0.1
#
# [5 rows x 26 columns]

# %%
mat1_rdf = evaluate_run('results/new_outputs_stack/', 'morphemes_alt_tok1', morph_fixed_gold_sents, morph_gold_extra_preds)
mat1_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim   embedding_matrix  \
# 0                 False  True            True         70  alt_tok_yap_ft_sg
# 1                 False  True            True         70  alt_tok_yap_ft_sg
# 2                 False  True            True         70  alt_tok_yap_ft_sg
# 3                 False  True            True         70  alt_tok_yap_ft_sg
# 4                 False  True            True         70  alt_tok_yap_ft_sg
#
#    epochs         f1  input_dropout  min_delta optimizer  ...     recall  \
# 0     100  74.464580          False     0.0001      adam  ...  76.179775
# 1     100  68.862912          False     0.0001      adam  ...  73.137698
# 2     100  63.631316          False     0.0001      adam  ...  65.862069
# 3     100  74.423592          False     0.0001      adam  ...  74.304069
# 4     100  66.023580          False     0.0001      adam  ...  70.804598
#
#    stack_cross  stack_double stack_lstm  trainable      unit  use_char  \
# 0        False         False          2      False  morpheme      True
# 1        False         False          2      False  morpheme      True
# 2        False         False          2      False  morpheme      True
# 3        False         False          2      False  morpheme      True
# 4        False         False          2      False  morpheme      True
#
#    use_pos  use_word  validation_split
# 0    False      True               0.1
# 1    False      True               0.1
# 2    False      True               0.1
# 3     True      True               0.1
# 4     True      True               0.1
#
# [5 rows x 26 columns]

# %% [markdown]
# ### All results

# %%
stack_rdf = pd.concat([ms_rdf,ms2_rdf, ts_rdf, ms3_rdf, ts3_rdf])
stack_rdf.fillna('None').groupby(['pred_set', 'use_pos', 'embedding_matrix','unit']).f1.max().unstack(level=[1,3]).round(1)
# Out:
# use_pos                          False          True
# unit                          morpheme token morpheme token
# pred_set  embedding_matrix
# gold_dev  pretrained_token_ft     77.1  71.4     78.3  78.2
#           token_ft_cbow           75.4  72.1     76.7  76.1
#           token_ft_sg             76.9  73.1     79.4  78.6
#           token_glove             76.8  69.2     78.2  75.6
#           token_w2v_cbow          76.5  69.2     78.3  76.2
#           token_w2v_sg            75.5  70.0     78.2  75.5
#           yap_ft_cbow             75.5  63.8     77.8  73.3
#           yap_ft_sg               76.7  67.6     80.4  72.6
#           yap_glove               75.1  59.2     77.0  70.4
#           yap_w2v_cbow            75.7  61.9     78.7  72.8
#           yap_w2v_sg              76.1  64.2     79.1  71.6
# gold_test pretrained_token_ft     74.9  68.3     77.1  74.9
#           token_ft_cbow           70.4  67.6     71.1  71.5
#           token_ft_sg             75.1  72.0     73.1  74.3
#           token_glove             74.3  66.2     72.6  70.3
#           token_w2v_cbow          75.0  71.7     75.9  73.3
#           token_w2v_sg            76.5  71.0     74.8  74.9
#           yap_ft_cbow             71.6  62.7     73.2  66.1
#           yap_ft_sg               76.2  66.6     75.2  69.2
#           yap_glove               73.2  60.2     74.1  69.0
#           yap_w2v_cbow            77.0  62.4     75.3  66.7
#           yap_w2v_sg              76.0  65.8     75.8  66.4
# yap_dev   pretrained_token_ft     67.4  71.4     64.8  70.8
#           token_ft_cbow           67.0  72.1     64.8  70.2
#           token_ft_sg             68.2  73.1     65.6  70.5
#           token_glove             69.3  69.2     64.2  64.6
#           token_w2v_cbow          68.7  69.2     63.7  65.9
#           token_w2v_sg            68.0  70.0     64.7  66.1
#           yap_ft_cbow             68.1  63.8     64.4  66.2
#           yap_ft_sg               69.2  67.6     67.3  64.5
#           yap_glove               67.9  59.2     63.1  61.2
#           yap_w2v_cbow            69.6  61.9     63.7  61.3
#           yap_w2v_sg              67.2  64.2     66.0  61.5
# yap_test  pretrained_token_ft     63.7  68.3     61.0  67.2
#           token_ft_cbow           60.2  67.6     59.7  65.2
#           token_ft_sg             64.0  72.0     61.7  67.2
#           token_glove             62.3  66.2     59.5  61.9
#           token_w2v_cbow          64.8  71.7     60.9  64.4
#           token_w2v_sg            65.4  71.0     59.0  64.6
#           yap_ft_cbow             62.3  62.7     61.1  61.2
#           yap_ft_sg               66.3  66.6     60.4  61.5
#           yap_glove               62.4  60.2     60.3  59.8
#           yap_w2v_cbow            67.0  62.4     61.0  58.6
#           yap_w2v_sg              64.7  65.8     60.9  57.5

# %%
tat2_rdf = evaluate_run('results/new_outputs_alt_tok/', 'tokens_alt_tok2', tok_gold_sents, tok_gold_extra_preds, unit='token',
                     orig_gold_mentions=tok_gold_dev_mentions, orig_o_gold_sents=tok_gold_dev_sents,)
tat2_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim  \
# 0                 False  True            True         70
# 1                 False  True            True         70
# 2                 False  True            True         70
# 3                 False  True            True         70
# 4                 False  True            True         70
#
#        embedding_matrix  epochs         f1  input_dropout  min_delta  \
# 0    alt_tok_yap_w2v_sg     100  65.950226          False     0.0001
# 1    alt_tok_yap_w2v_sg     100  63.843648          False     0.0001
# 2    alt_tok_yap_w2v_sg     100  65.950226          False     0.0001
# 3  alt_tok_yap_w2v_cbow     100  62.684869          False     0.0001
# 4  alt_tok_yap_w2v_cbow     100  65.333333          False     0.0001
#
#   optimizer  ...     recall  stack_cross  stack_double stack_lstm  trainable  \
# 0      adam  ...  69.653524        False         False          2      False
# 1      adam  ...  69.668246        False         False          2      False
# 2      adam  ...  69.653524        False         False          2      False
# 3      adam  ...  66.626360        False         False          2      False
# 4      adam  ...  73.316708        False         False          2      False
#
#     unit  use_char  use_pos  use_word  validation_split
# 0  token      True    False      True               0.1
# 1  token      True    False      True               0.1
# 2  token      True    False      True               0.1
# 3  token      True    False      True               0.1
# 4  token      True    False      True               0.1
#
# [5 rows x 26 columns]

# %%
mat2_rdf = evaluate_run('results/new_outputs_stack/', 'morphemes_alt_tok2', morph_fixed_gold_sents, morph_gold_extra_preds)
mat2_rdf.head()
# Out:
#    add_random_embedding   crf  early_stopping  embed_dim  \
# 0                 False  True            True         70
# 1                 False  True            True         70
# 2                 False  True            True         70
# 3                 False  True            True         70
# 4                 False  True            True         70
#
#        embedding_matrix  epochs         f1  input_dropout  min_delta  \
# 0    alt_tok_yap_w2v_sg     100  76.655443          False     0.0001
# 1    alt_tok_yap_w2v_sg     100  63.506064          False     0.0001
# 2    alt_tok_yap_w2v_sg     100  65.939115          False     0.0001
# 3  alt_tok_yap_w2v_cbow     100  72.164948          False     0.0001
# 4  alt_tok_yap_w2v_cbow     100  66.242038          False     0.0001
#
#   optimizer  ...     recall  stack_cross  stack_double stack_lstm  trainable  \
# 0      adam  ...  80.258519        False         False          2      False
# 1      adam  ...  70.415648        False         False          2      False
# 2      adam  ...  70.864198        False         False          2      False
# 3      adam  ...  72.916667        False         False          2      False
# 4      adam  ...  70.270270        False         False          2      False
#
#        unit  use_char  use_pos  use_word  validation_split
# 0  morpheme      True    False      True               0.1
# 1  morpheme      True    False      True               0.1
# 2  morpheme      True    False      True               0.1
# 3  morpheme      True    False      True               0.1
# 4  morpheme      True    False      True               0.1
#
# [5 rows x 26 columns]

# %%
at_rdf = pd.concat([mat1_rdf, mat2_rdf, tat1_rdf, tat2_rdf])
at_rdf.fillna('None').groupby(['pred_set', 'use_pos', 'embedding_matrix','unit']).f1.max().unstack(level=[1,3]).round(1)
# Out:
# use_pos                             False          True
# unit                             morpheme token morpheme token
# pred_set  embedding_matrix
# gold_dev  alt_tok_token_ft_cbow      76.0  72.9     78.2  77.8
#           alt_tok_token_ft_sg        76.8  74.7     79.2  79.8
#           alt_tok_token_glove        75.8  69.3     78.8  75.0
#           alt_tok_token_w2v_cbow     74.7  71.0     79.6  75.4
#           alt_tok_token_w2v_sg       76.3  71.2     77.0  76.1
#           alt_tok_yap_ft_cbow        74.3  63.2     76.9  72.8
#           alt_tok_yap_ft_sg          79.0  66.1     80.1  72.0
#           alt_tok_yap_glove          74.3  60.7     77.7  70.5
#           alt_tok_yap_w2v_cbow       74.7  65.3     79.6  71.9
#           alt_tok_yap_w2v_sg         71.7  63.8     79.6  70.1
# gold_test alt_tok_token_ft_cbow      71.6  68.3     72.1  71.5
#           alt_tok_token_ft_sg        73.5  73.3     76.8  76.0
#           alt_tok_token_glove        71.5  67.3     76.2  70.4
#           alt_tok_token_w2v_cbow     72.0  72.4     73.9  71.2
#           alt_tok_token_w2v_sg       74.9  72.7     74.5  73.6
#           alt_tok_yap_ft_cbow        72.9  64.1     72.5  68.1
#           alt_tok_yap_ft_sg          75.6  68.8     75.2  70.1
#           alt_tok_yap_glove          74.1  61.2     74.4  68.8
#           alt_tok_yap_w2v_cbow       72.2  62.7     74.6  69.9
#           alt_tok_yap_w2v_sg         76.7  66.0     73.3  67.3
# yap_dev   alt_tok_token_ft_cbow      69.7  72.9     65.5  70.8
#           alt_tok_token_ft_sg        67.9  74.7     64.7  70.4
#           alt_tok_token_glove        66.9  69.3     64.8  65.3
#           alt_tok_token_w2v_cbow     66.2  71.0     64.9  65.5
#           alt_tok_token_w2v_sg       68.5  71.2     63.6  66.3
#           alt_tok_yap_ft_cbow        66.9  63.2     65.0  65.5
#           alt_tok_yap_ft_sg          70.5  66.1     66.0  62.8
#           alt_tok_yap_glove          67.2  60.7     64.0  61.5
#           alt_tok_yap_w2v_cbow       66.2  65.3     65.0  61.1
#           alt_tok_yap_w2v_sg         63.5  63.8     63.3  58.9
# yap_test  alt_tok_token_ft_cbow      61.8  68.3     59.7  66.9
#           alt_tok_token_ft_sg        63.5  73.3     61.6  69.0
#           alt_tok_token_glove        62.0  67.3     60.5  60.7
#           alt_tok_token_w2v_cbow     61.4  72.4     57.8  63.2
#           alt_tok_token_w2v_sg       65.5  72.7     59.9  63.8
#           alt_tok_yap_ft_cbow        62.8  64.1     61.3  62.7
#           alt_tok_yap_ft_sg          65.8  68.8     62.5  62.4
#           alt_tok_yap_glove          63.0  61.2     60.9  61.0
#           alt_tok_yap_w2v_cbow       62.5  62.7     59.9  62.8
#           alt_tok_yap_w2v_sg         65.9  66.0     57.8  59.4

# %%
at_rdf['embedding_unit'] =   at_rdf.embedding_matrix.apply(lambda x: 'morpheme' if 'yap' in x else 'token')
at_rdf['embedding_method'] = at_rdf.embedding_matrix.apply(lambda x: 'fasttext' if 'ft' in x else 'glove' if 'glove' in x else 'w2v')
at_rdf['embedding_arch'] =   at_rdf.embedding_matrix.apply(lambda x: 'skipgram' if 'sg' in x or 'pre' in x else 'cbow' if 'cbow' in x else 'glove')
at_rdf['tokenization'] =   'alt_tok'

# %%
stack_rdf.groupby(['unit', 'trainable']).f1.mean()
# Out:
# unit      trainable
# morpheme  False        70.105272
#           True         64.364846
# token     False        67.741901
#           True         65.853718
# Name: f1, dtype: float64

# %%
stack_rdf['embedding_unit'] = stack_rdf.embedding_matrix.apply(lambda x: 'morpheme' if 'yap' in x else 'token')
stack_rdf['embedding_method'] = stack_rdf.embedding_matrix.apply(lambda x: 'fasttext' if 'ft' in x else 'glove' if 'glove' in x else 'w2v')
stack_rdf['embedding_arch'] = stack_rdf.embedding_matrix.apply(lambda x: 'skipgram' if 'sg' in x or 'pre' in x else 'cbow' if 'cbow' in x else 'glove')
stack_rdf['tokenization'] =   'orig_tok'

# %%
eval_rdf = pd.concat([stack_rdf[(~stack_rdf.trainable) & (stack_rdf.pred_set.str.contains('dev'))], at_rdf[(~at_rdf.trainable) & (at_rdf.pred_set.str.contains('dev'))]])

# %%
eval_rdf.groupby(['unit', 'embedding_unit']).size()
# Out:
# unit      embedding_unit
# morpheme  morpheme          44
#           token             44
# token     morpheme          40
#           token             48
# dtype: int64

# %%
eval_rdf.embedding_unit.value_counts()
# Out:
# token       92
# morpheme    84
# Name: embedding_unit, dtype: int64

# %%
f2rdf[(f2rdf.use_char) & (f2rdf.pred_set.str.contains('dev')) & (f2rdf.embedding_matrix.isna())].fillna('None').groupby(['pred_set', 'use_pos','unit']).f1.max().unstack().round(2)
# Out:
# unit              morpheme_fixed2  tokens_fixed2
# pred_set use_pos
# gold_dev False              55.25          42.96
#          True               63.22          55.43
# yap_dev  False              48.66          42.96
#          True               51.57          49.04

# %%
(eval_rdf[eval_rdf.embedding_matrix.str.startswith('pre')].groupby(['pred_set', 'use_pos','tokenization', 'unit']).f1.max()
 .unstack().round(2)
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# unit                           morpheme  token       dif
# pred_set use_pos tokenization
# gold_dev False   orig_tok         77.09  71.38 -0.079994
#          True    orig_tok         78.26  78.15 -0.001408
# yap_dev  False   orig_tok         67.44  71.38  0.055198
#          True    orig_tok         64.76  70.83  0.085698

# %%
(eval_rdf[eval_rdf.embedding_matrix.str.contains('ft_sg')].groupby(['pred_set', 'use_pos', 'tokenization', 'unit']).f1.max()
 .unstack().round(2)
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# unit                           morpheme  token       dif
# pred_set use_pos tokenization
# gold_dev False   alt_tok          78.98  74.74 -0.056730
#                  orig_tok         76.86  73.13 -0.051005
#          True    alt_tok          80.08  79.83 -0.003132
#                  orig_tok         80.42  78.61 -0.023025
# yap_dev  False   alt_tok          70.51  74.74  0.056596
#                  orig_tok         69.17  73.13  0.054150
#          True    alt_tok          66.02  70.38  0.061949
#                  orig_tok         67.32  70.46  0.044564

# %%
(eval_rdf.groupby(['pred_set', 'unit', 'embedding_unit']).f1.mean()
 .unstack()
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# embedding_unit      morpheme      token       dif
# pred_set unit
# gold_dev morpheme  76.992049  77.261767  0.003491
#          token     67.691547  74.167540  0.087316
# yap_dev  morpheme  66.226239  66.326293  0.001509
#          token     63.021813  69.755837  0.096537

# %%
(eval_rdf.groupby(['pred_set', 'unit', 'embedding_unit']).f1.mean()
 .unstack()
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# embedding_unit      morpheme      token       dif
# pred_set unit
# gold_dev morpheme  76.992049  77.261767  0.003491
#          token     67.691547  74.167540  0.087316
# yap_dev  morpheme  66.226239  66.326293  0.001509
#          token     63.021813  69.755837  0.096537

# %%
(eval_rdf[~eval_rdf.embedding_matrix.str.contains('pre')].groupby(['pred_set', 'unit', 'embedding_unit',  'tokenization']).f1.max()
 .unstack()
 .assign(dif = lambda x: 1 - x.alt_tok/x.orig_tok))
# Out:
# tokenization                        alt_tok   orig_tok       dif
# pred_set unit     embedding_unit
# gold_dev morpheme morpheme        80.083857  80.421053  0.004193
#                   token           79.627715  79.411765 -0.002719
#          token    morpheme        72.823779  73.298429  0.006476
#                   token           79.833680  78.609062 -0.015579
# yap_dev  morpheme morpheme        70.512821  69.639066 -0.012547
#                   token           69.658120  69.296375 -0.005220
#          token    morpheme        66.079295  67.596567  0.022446
#                   token           74.736842  73.134328 -0.021912

# %%
(eval_rdf[~eval_rdf.embedding_matrix.str.contains('pre')].groupby(['pred_set', 'embedding_method', 'unit', 'use_pos', 'embedding_unit', 'embedding_arch',  'tokenization']).f1.max()
 .unstack()
 .assign(dif = lambda x: 1 - x.alt_tok/x.orig_tok))
# Out:
# tokenization                                                                alt_tok  \
# pred_set embedding_method unit     use_pos embedding_unit embedding_arch
# gold_dev fasttext         morpheme False   morpheme       cbow            74.255319
#                                                           skipgram        78.975454
#                                            token          cbow            76.017131
#                                                           skipgram        76.793249
#                                    True    morpheme       cbow            76.875000
#                                                           skipgram        80.083857
#                                            token          cbow            78.242678
#                                                           skipgram        79.209979
#                           token    False   morpheme       cbow            63.192905
#                                                           skipgram        66.079295
#                                            token          cbow            72.943723
#                                                           skipgram        74.736842
#                                    True    morpheme       cbow            72.823779
#                                                           skipgram        72.025052
#                                            token          cbow            77.766287
#                                                           skipgram        79.833680
#          glove            morpheme False   morpheme       glove           74.250259
#                                            token          glove           75.833333
#                                    True    morpheme       glove           77.742947
#                                            token          glove           78.750000
#                           token    False   morpheme       glove           60.679080
#                                            token          glove           69.287991
#                                    True    morpheme       glove           70.526316
#                                            token          glove           75.025907
#          w2v              morpheme False   morpheme       cbow            74.711438
#                                                           skipgram        71.693989
#                                            token          cbow            74.683544
#                                                           skipgram        76.344086
#                                    True    morpheme       cbow            79.583333
#                                                           skipgram        79.617834
# ...                                                                             ...
# yap_dev  fasttext         token    False   token          cbow            72.943723
#                                                           skipgram        74.736842
#                                    True    morpheme       cbow            65.502183
#                                                           skipgram        62.795699
#                                            token          cbow            70.824524
#                                                           skipgram        70.378151
#          glove            morpheme False   morpheme       glove           67.153285
#                                            token          glove           66.946485
#                                    True    morpheme       glove           64.017186
#                                            token          glove           64.812834
#                           token    False   morpheme       glove           60.679080
#                                            token          glove           69.287991
#                                    True    morpheme       glove           61.488673
#                                            token          glove           65.306122
#          w2v              morpheme False   morpheme       cbow            66.242038
#                                                           skipgram        63.506064
#                                            token          cbow            66.243386
#                                                           skipgram        68.540541
#                                    True    morpheme       cbow            64.957265
#                                                           skipgram        63.318777
#                                            token          cbow            64.893617
#                                                           skipgram        63.626493
#                           token    False   morpheme       cbow            65.333333
#                                                           skipgram        63.843648
#                                            token          cbow            71.030043
#                                                           skipgram        71.229947
#                                    True    morpheme       cbow            61.147903
#                                                           skipgram        58.914729
#                                            token          cbow            65.524625
#                                                           skipgram        66.303162
#
# tokenization                                                               orig_tok  \
# pred_set embedding_method unit     use_pos embedding_unit embedding_arch
# gold_dev fasttext         morpheme False   morpheme       cbow            75.459459
#                                                           skipgram        76.729560
#                                            token          cbow            75.427350
#                                                           skipgram        76.857749
#                                    True    morpheme       cbow            77.846791
#                                                           skipgram        80.421053
#                                            token          cbow            76.726886
#                                                           skipgram        79.411765
#                           token    False   morpheme       cbow            63.758389
#                                                           skipgram        67.596567
#                                            token          cbow            72.114402
#                                                           skipgram        73.134328
#                                    True    morpheme       cbow            73.298429
#                                                           skipgram        72.611465
#                                            token          cbow            76.082474
#                                                           skipgram        78.609062
#          glove            morpheme False   morpheme       glove           75.130073
#                                            token          glove           76.825397
#                                    True    morpheme       glove           77.003122
#                                            token          glove           78.170478
#                           token    False   morpheme       glove           59.174312
#                                            token          glove           69.198312
#                                    True    morpheme       glove           70.378151
#                                            token          glove           75.555556
#          w2v              morpheme False   morpheme       cbow            75.658588
#                                                           skipgram        76.119403
#                                            token          cbow            76.545842
#                                                           skipgram        75.467775
#                                    True    morpheme       cbow            78.698846
#                                                           skipgram        79.127726
# ...                                                                             ...
# yap_dev  fasttext         token    False   token          cbow            72.114402
#                                                           skipgram        73.134328
#                                    True    morpheme       cbow            66.232356
#                                                           skipgram        64.502165
#                                            token          cbow            70.190275
#                                                           skipgram        70.461869
#          glove            morpheme False   morpheme       glove           67.864693
#                                            token          glove           69.296375
#                                    True    morpheme       glove           63.090129
#                                            token          glove           64.155005
#                           token    False   morpheme       glove           59.174312
#                                            token          glove           69.198312
#                                    True    morpheme       glove           61.206897
#                                            token          glove           64.572048
#          w2v              morpheme False   morpheme       cbow            69.639066
#                                                           skipgram        67.168999
#                                            token          cbow            68.669528
#                                                           skipgram        68.000000
#                                    True    morpheme       cbow            63.724435
#                                                           skipgram        65.955176
#                                            token          cbow            63.703704
#                                                           skipgram        64.680851
#                           token    False   morpheme       cbow            61.936937
#                                                           skipgram        64.228571
#                                            token          cbow            69.162996
#                                                           skipgram        69.989166
#                                    True    morpheme       cbow            61.318681
#                                                           skipgram        61.503928
#                                            token          cbow            65.897167
#                                                           skipgram        66.098081
#
# tokenization                                                                   dif
# pred_set embedding_method unit     use_pos embedding_unit embedding_arch
# gold_dev fasttext         morpheme False   morpheme       cbow            0.015957
#                                                           skipgram       -0.029270
#                                            token          cbow           -0.007819
#                                                           skipgram        0.000839
#                                    True    morpheme       cbow            0.012483
#                                                           skipgram        0.004193
#                                            token          cbow           -0.019756
#                                                           skipgram        0.002541
#                           token    False   morpheme       cbow            0.008869
#                                                           skipgram        0.022446
#                                            token          cbow           -0.011500
#                                                           skipgram       -0.021912
#                                    True    morpheme       cbow            0.006476
#                                                           skipgram        0.008076
#                                            token          cbow           -0.022131
#                                                           skipgram       -0.015579
#          glove            morpheme False   morpheme       glove           0.011711
#                                            token          glove           0.012913
#                                    True    morpheme       glove          -0.009608
#                                            token          glove          -0.007414
#                           token    False   morpheme       glove          -0.025429
#                                            token          glove          -0.001296
#                                    True    morpheme       glove          -0.002105
#                                            token          glove           0.007010
#          w2v              morpheme False   morpheme       cbow            0.012519
#                                                           skipgram        0.058138
#                                            token          cbow            0.024329
#                                                           skipgram       -0.011612
#                                    True    morpheme       cbow           -0.011239
#                                                           skipgram       -0.006194
# ...                                                                            ...
# yap_dev  fasttext         token    False   token          cbow           -0.011500
#                                                           skipgram       -0.021912
#                                    True    morpheme       cbow            0.011024
#                                                           skipgram        0.026456
#                                            token          cbow           -0.009036
#                                                           skipgram        0.001188
#          glove            morpheme False   morpheme       glove           0.010483
#                                            token          glove           0.033911
#                                    True    morpheme       glove          -0.014694
#                                            token          glove          -0.010254
#                           token    False   morpheme       glove          -0.025429
#                                            token          glove          -0.001296
#                                    True    morpheme       glove          -0.004604
#                                            token          glove          -0.011368
#          w2v              morpheme False   morpheme       cbow            0.048780
#                                                           skipgram        0.054533
#                                            token          cbow            0.035331
#                                                           skipgram       -0.007949
#                                    True    morpheme       cbow           -0.019346
#                                                           skipgram        0.039973
#                                            token          cbow           -0.018679
#                                                           skipgram        0.016301
#                           token    False   morpheme       cbow           -0.054836
#                                                           skipgram        0.005993
#                                            token          cbow           -0.026995
#                                                           skipgram       -0.017728
#                                    True    morpheme       cbow            0.002785
#                                                           skipgram        0.042098
#                                            token          cbow            0.005653
#                                                           skipgram       -0.003103
#
# [80 rows x 3 columns]

# %%
(eval_rdf[~eval_rdf.embedding_matrix.str.contains('pre')].groupby(['pred_set', 'embedding_method', 'unit', 'use_pos', 'embedding_unit', 'embedding_arch',  'tokenization']).f1.max()
 .unstack()
 .assign(dif = lambda x: 1 - x.alt_tok/x.orig_tok)
 .dif<0).sum() /  (eval_rdf[~eval_rdf.embedding_matrix.str.contains('pre')].groupby(['pred_set', 'embedding_method', 'unit', 'use_pos', 'embedding_unit', 'embedding_arch',  'tokenization']).f1.max()
 .unstack()
 .assign(dif = lambda x: 1 - x.alt_tok/x.orig_tok)
 .dif.notna().sum())
# Out:
# 0.5

# %%
(eval_rdf.groupby(['pred_set', 'embedding_method', 'unit', 'use_pos', 'tokenization', 'embedding_unit']).f1.max()
 .unstack()
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# embedding_unit                                            morpheme      token  \
# pred_set embedding_method unit     use_pos tokenization
# gold_dev fasttext         morpheme False   alt_tok       78.975454  76.793249
#                                            orig_tok      76.729560  77.085533
#                                    True    alt_tok       80.083857  79.209979
#                                            orig_tok      80.421053  79.411765
#                           token    False   alt_tok       66.079295  74.736842
#                                            orig_tok      67.596567  73.134328
#                                    True    alt_tok       72.823779  79.833680
#                                            orig_tok      73.298429  78.609062
#          glove            morpheme False   alt_tok       74.250259  75.833333
#                                            orig_tok      75.130073  76.825397
#                                    True    alt_tok       77.742947  78.750000
#                                            orig_tok      77.003122  78.170478
#                           token    False   alt_tok       60.679080  69.287991
#                                            orig_tok      59.174312  69.198312
#                                    True    alt_tok       70.526316  75.025907
#                                            orig_tok      70.378151  75.555556
#          w2v              morpheme False   alt_tok       74.711438  76.344086
#                                            orig_tok      76.119403  76.545842
#                                    True    alt_tok       79.617834  79.627715
#                                            orig_tok      79.127726  78.341969
#                           token    False   alt_tok       65.333333  71.229947
#                                            orig_tok      64.228571  69.989166
#                                    True    alt_tok       71.871658  76.139979
#                                            orig_tok      72.765957  76.210093
# yap_dev  fasttext         morpheme False   alt_tok       70.512821  69.658120
#                                            orig_tok      69.166667  68.225292
#                                    True    alt_tok       66.023580  65.524625
#                                            orig_tok      67.318132  65.587918
#                           token    False   alt_tok       66.079295  74.736842
#                                            orig_tok      67.596567  73.134328
#                                    True    alt_tok       65.502183  70.824524
#                                            orig_tok      66.232356  70.828848
#          glove            morpheme False   alt_tok       67.153285  66.946485
#                                            orig_tok      67.864693  69.296375
#                                    True    alt_tok       64.017186  64.812834
#                                            orig_tok      63.090129  64.155005
#                           token    False   alt_tok       60.679080  69.287991
#                                            orig_tok      59.174312  69.198312
#                                    True    alt_tok       61.488673  65.306122
#                                            orig_tok      61.206897  64.572048
#          w2v              morpheme False   alt_tok       66.242038  68.540541
#                                            orig_tok      69.639066  68.669528
#                                    True    alt_tok       64.957265  64.893617
#                                            orig_tok      65.955176  64.680851
#                           token    False   alt_tok       65.333333  71.229947
#                                            orig_tok      64.228571  69.989166
#                                    True    alt_tok       61.147903  66.303162
#                                            orig_tok      61.503928  66.098081
#
# embedding_unit                                                dif
# pred_set embedding_method unit     use_pos tokenization
# gold_dev fasttext         morpheme False   alt_tok      -0.028417
#                                            orig_tok      0.004618
#                                    True    alt_tok      -0.011032
#                                            orig_tok     -0.012710
#                           token    False   alt_tok       0.115840
#                                            orig_tok      0.075720
#                                    True    alt_tok       0.087806
#                                            orig_tok      0.067558
#          glove            morpheme False   alt_tok       0.020876
#                                            orig_tok      0.022067
#                                    True    alt_tok       0.012788
#                                            orig_tok      0.014933
#                           token    False   alt_tok       0.124248
#                                            orig_tok      0.144859
#                                    True    alt_tok       0.059974
#                                            orig_tok      0.068524
#          w2v              morpheme False   alt_tok       0.021385
#                                            orig_tok      0.005571
#                                    True    alt_tok       0.000124
#                                            orig_tok     -0.010030
#                           token    False   alt_tok       0.082783
#                                            orig_tok      0.082307
#                                    True    alt_tok       0.056059
#                                            orig_tok      0.045193
# yap_dev  fasttext         morpheme False   alt_tok      -0.012270
#                                            orig_tok     -0.013798
#                                    True    alt_tok      -0.007615
#                                            orig_tok     -0.026380
#                           token    False   alt_tok       0.115840
#                                            orig_tok      0.075720
#                                    True    alt_tok       0.075148
#                                            orig_tok      0.064896
#          glove            morpheme False   alt_tok      -0.003089
#                                            orig_tok      0.020660
#                                    True    alt_tok       0.012276
#                                            orig_tok      0.016598
#                           token    False   alt_tok       0.124248
#                                            orig_tok      0.144859
#                                    True    alt_tok       0.058455
#                                            orig_tok      0.052115
#          w2v              morpheme False   alt_tok       0.033535
#                                            orig_tok     -0.014119
#                                    True    alt_tok      -0.000981
#                                            orig_tok     -0.019702
#                           token    False   alt_tok       0.082783
#                                            orig_tok      0.082307
#                                    True    alt_tok       0.077753
#                                            orig_tok      0.069505

# %%
(eval_rdf.groupby(['embedding_arch', 'unit', 'embedding_unit']).f1.mean()
 .unstack()
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# embedding_unit            morpheme      token       dif
# embedding_arch unit
# cbow           morpheme  71.375316  71.632616  0.003592
#                token     65.837755  71.774403  0.082713
# glove          morpheme  70.781462  71.848738  0.014854
#                token     62.913353  69.679030  0.097098
# skipgram       morpheme  72.127280  71.901277 -0.003143
#                token     66.097268  72.847432  0.092662

# %%
(eval_rdf.groupby(['pred_set', 'unit']).f1.mean()
 .unstack()
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# unit       morpheme      token       dif
# pred_set
# gold_dev  77.126908  71.223907 -0.082879
# yap_dev   66.276266  66.694917  0.006277

# %%
(eval_rdf.groupby(['pred_set', 'embedding_unit', 'use_pos', 'unit']).f1.mean()
 .unstack()
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# unit                              morpheme      token       dif
# pred_set embedding_unit use_pos
# gold_dev morpheme       False    75.423714  63.582304 -0.186238
#                         True     78.560384  71.800790 -0.094144
#          token          False    76.170999  71.490285 -0.065473
#                         True     78.352535  76.844795 -0.019621
# yap_dev  morpheme       False    67.736756  63.582304 -0.065340
#                         True     64.715723  62.461321 -0.036093
#          token          False    67.997696  71.490285  0.048854
#                         True     64.654889  68.021389  0.049492

# %%
(eval_rdf[eval_rdf.embedding_unit==eval_rdf.unit].groupby(['pred_set', 'use_pos', 'unit']).f1.mean()
 .unstack()
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# unit               morpheme      token       dif
# pred_set use_pos
# gold_dev False    75.423714  71.490285 -0.055020
#          True     78.560384  76.844795 -0.022325
# yap_dev  False    67.736756  71.490285  0.052504
#          True     64.715723  68.021389  0.048597

# %%
(eval_rdf[eval_rdf.embedding_unit==eval_rdf.unit].groupby(['pred_set', 'use_pos', 'unit']).f1.max()
 .unstack()
 .assign(dif = lambda x: 1 - x.morpheme/x.token))
# Out:
# unit               morpheme      token       dif
# pred_set use_pos
# gold_dev False    78.975454  74.736842 -0.056714
#          True     80.421053  79.833680 -0.007357
# yap_dev  False    70.512821  74.736842  0.056519
#          True     67.318132  70.828848  0.049566
