# %%
import pandas as pd
import os

# %%
ANNO_FOLDER = 'pilot_annotations'
G1 = 'group1'
G2 = 'group2'
F1 = 'dev_1-100.tsv'
F2 = 'dev_101-200.tsv'
F3 = 'dev_201-300.tsv'
F4 = 'dev_301-400.tsv'
FILES = [F1, F2, F3, F4]

# %%
groups = {}_b
groups[G1] = os.listdir(os.path.join(ANNO_FOLDER, G1))
groups[G2] = os.listdir(os.path.join(ANNO_FOLDER, G2))

groups
# Out:
# {'group1': ['anatb', 'dafnaa', 'shayp', 'sinair', 'tzufa', 'vikab'],
#  'group2': ['nuritg', 'shovals', 'tzipyl', 'vereds', 'yohayg', 'zefs']}

# %%
import re
def get_biose(df):
    ner_bio = df.ner.copy()
    ner_bio[~ner_bio.str.contains('\[|_')] = 'S-' + ner_bio 
    ner_bio = ner_bio.replace('_', 'O')

    RE = '^(?P<type>[A-Z]+)\[(?P<num>\d+)\].*$'
    prev='XXX'
    new = []

    for x in ner_bio.tolist():
        if x.startswith('S') or x=='O':
            new.append(x)
        else:
            typ, num = re.match(RE, x).groups(0)
            if x==prev:
                new.append('I-'+typ)
            else:
                new.append('B-'+typ)

        prev = x
        
    # reverse pass to add Es
    prev='O'
    rev_pass = []
    for x in new[::-1]:
        if((prev=='O' or prev.startswith('B-')) and x.startswith('I-')):
            rev_pass.append(x.replace('I-', 'E-'))
        else:
            rev_pass.append(x)
        prev = x

    biose = rev_pass[::-1]
    
    return biose

# %%
def read_tsv3(path, add_biose=True):
    names = ['sent_tok_num', 'tok_offset', 'token',
             'FEAT_gender', 'FEAT_number', 'FEAT_case', 'FEAT_degree', 'FEAT_transitivity', 
             'FEAT_tense', 'FEAT_mood', 'FEAT_voice', 'FEAT_definiteness', 'FEAT_value', 'FEAT_person', 'FEAT_aspect',
             'pos',
             'ner',
             'lemma',
             'surface_form',
             'dep_type', 'dep_flavor', 'dep_lex_morph_pos', 'dep_arc', 'EXTRA'
            ]
    df = (pd.read_csv(path, sep='\t', skiprows=10, header=None, names=names,
                      comment='#', skip_blank_lines=True, quoting=3)#na_values=['*', '_'])
          .assign(ner_type = lambda x: x.ner.str.split('[', expand=True).iloc[:,0])
          .assign(is_ner = lambda x: x.ner!='_')
          .assign(biose = lambda x: get_biose(x))
         )
    return df
df = read_tsv3(os.path.join(ANNO_FOLDER, G1, 'anatb', F1))
df.head(60)
# Out:
#    sent_tok_num tok_offset    token FEAT_gender FEAT_number FEAT_case  \
# 0           1-1        0-5    עשרות         Fem        Plur         *
# 1           1-2       6-11    אנשים        Masc        Plur         *
# 2           1-3      12-18   מגיעים        Masc        Plur         *
# 3           1-4      19-20        מ           _           _         _
# 4           1-5      21-27   תאילנד           _           _         _
# 5           1-6      28-29        ל           _           _         _
# 6           1-7      30-35    ישראל           _           _         _
# 7           1-8      36-38       כש           *           *       Tem
# 8           1-9      39-41       הם        Masc        Plur         *
# 9          1-10      42-48   נרשמים        Masc        Plur         *
# 10         1-11      49-50        כ           _           _         _
# 11         1-12      51-58  מתנדבים        Masc        Plur         *
# 12         1-13      59-60        ,           _           _         _
# 13         1-14      61-63       אך           _           _         _
# 14         1-15      64-69    למעשה           _           _         _
# 15         1-16      70-76   משמשים        Masc        Plur         *
# 16         1-17      77-83   עובדים        Masc        Plur         *
# 17         1-18      84-90   שכירים        Masc        Plur         *
# 18         1-19      91-96    זולים        Masc        Plur         *
# 19         1-20      96-97        .           _           _         _
# 20          2-1     99-104    תופעה         Fem        Sing         *
# 21          2-2    105-107       זו         Fem        Sing         *
# 22          2-3    108-114   התבררה         Fem        Sing         *
# 23          2-4    115-120    אתמול           _           _         _
# 24          2-5    121-122        ב           _           _         _
# 25          2-6    123-128    וועדת         Fem        Sing         *
# 26          2-7    129-130        ה           *           *         *
# 27          2-8    131-136    עבודה         Fem        Sing         *
# 28          2-9    137-138        ו           _           _         _
# 29         2-10    139-140        ה           *           *         *
# 30         2-11    141-146    רווחה         Fem        Sing         *
# 31         2-12    147-149       של           *           *       Gen
# 32         2-13    150-151        ה           *           *         *
# 33         2-14    152-156     כנסת           _           _         _
# 34         2-15    157-158        ,           _           _         _
# 35         2-16    159-160        ש           _           _         _
# 36         2-17    161-164      דנה         Fem        Sing         *
# 37         2-18    165-166        ב           _           _         _
# 38         2-19    167-171     נושא        Masc        Sing         *
# 39         2-20    172-177    העסקת         Fem        Sing         *
# 40         2-21    178-184   עובדים        Masc        Plur         *
# 41         2-22    185-189     זרים        Masc        Plur         *
# 42         2-23    189-190        .           _           _         _
# 43          3-1    192-196     יו"ר        Masc        Sing         *
# 44          3-2    197-198        ה           *           *         *
# 45          3-3    199-204    וועדה         Fem        Sing         *
# 46          3-4    205-206        ,           _           _         _
# 47          3-5    207-210      ח"כ        Masc        Sing         *
# 48          3-6    211-215     אורה           _           _         _
# 49          3-7    216-220     נמיר           _           _         _
# 50          3-8    221-222        (           _           _         _
# 51          3-9    222-226     מערך           _           _         _
# 52         3-10    226-227        )           _           _         _
# 53         3-11    227-228        ,           _           _         _
# 54         3-12    229-233     טענה         Fem        Sing         *
# 55         3-13    234-236       כי           _           _         _
# 56         3-14    237-238        "           _           _         _
# 57         3-15    238-244   מביאים        Masc        Plur         *
# 58         3-16    245-251   עובדים        Masc        Plur         *
# 59         3-17    252-256     זרים        Masc        Plur         *
#
#    FEAT_degree FEAT_transitivity FEAT_tense FEAT_mood  ...     lemma  \
# 0            *                 *          *         *  ...     עשרות
# 1            *                 *          *         *  ...       איש
# 2            *                 *          *         *  ...      הגיע
# 3            _                 _          _         _  ...         מ
# 4            _                 _          _         _  ...    תאילנד
# 5            _                 _          _         _  ...         ל
# 6            _                 _          _         _  ...     ישראל
# 7            *                 *          *         *  ...        כש
# 8            *                 *          *         *  ...       הוא
# 9            *                 *          *         *  ...      נרשם
# 10           _                 _          _         _  ...         כ
# 11           *                 *          *         *  ...     מתנדב
# 12           _                 _          _         _  ...         ,
# 13           _                 _          _         _  ...        אך
# 14           _                 _          _         _  ...     למעשה
# 15           *                 *          *         *  ...      שימש
# 16           *                 *          *         *  ...      עובד
# 17           *                 *          *         *  ...      שכיר
# 18           *                 *          *         *  ...       זול
# 19           _                 _          _         _  ...         .
# 20           *                 *          *         *  ...     תופעה
# 21           *                 *          *         *  ...        זו
# 22           *                 *       Past         *  ...     התברר
# 23           _                 _          _         _  ...     אתמול
# 24           _                 _          _         _  ...         ב
# 25           *                 *          *         *  ...      ועדה
# 26           *                 *          *         *  ...         ה
# 27           *                 *          *         *  ...     עבודה
# 28           _                 _          _         _  ...         ו
# 29           *                 *          *         *  ...         ה
# 30           *                 *          *         *  ...     רווחה
# 31           *                 *          *         *  ...        של
# 32           *                 *          *         *  ...         ה
# 33           _                 _          _         _  ...      כנסת
# 34           _                 _          _         _  ...         ,
# 35           _                 _          _         _  ...         ש
# 36           *                 *       Past         *  ...        דן
# 37           _                 _          _         _  ...         ב
# 38           *                 *          *         *  ...      נושא
# 39           *                 *          *         *  ...     העסקה
# 40           *                 *          *         *  ...      עובד
# 41           *                 *          *         *  ...        זר
# 42           _                 _          _         _  ...         .
# 43           *                 *          *         *  ...      יו"ר
# 44           *                 *          *         *  ...         ה
# 45           *                 *          *         *  ...      ועדה
# 46           _                 _          _         _  ...         ,
# 47           *                 *          *         *  ...       ח"ך
# 48           _                 _          _         _  ...      אורה
# 49           _                 _          _         _  ...      נמיר
# 50           _                 _          _         _  ...         (
# 51           _                 _          _         _  ...      מערך
# 52           _                 _          _         _  ...         )
# 53           _                 _          _         _  ...         ,
# 54           *                 *       Past         *  ...       טען
# 55           _                 _          _         _  ...        כי
# 56           _                 _          _         _  ...         "
# 57           *                 *          *         *  ...      הביא
# 58           *                 *          *         *  ...      עובד
# 59           *                 *          *         *  ...        זר
#
#     surface_form         dep_type dep_flavor dep_lex_morph_pos dep_arc EXTRA  \
# 0              _           nummod      basic               1-2     NaN   NaN
# 1              _            nsubj      basic               1-3     NaN   NaN
# 2              _             root      basic               1-3     NaN   NaN
# 3    מתאילנד[65]             case      basic               1-5     NaN   NaN
# 4    מתאילנד[65]              obl      basic               1-3     NaN   NaN
# 5     לישראל[66]             case      basic               1-7     NaN   NaN
# 6     לישראל[66]              obl      basic               1-3     NaN   NaN
# 7       כשהם[67]             mark      basic              1-10     NaN   NaN
# 8       כשהם[67]            nsubj      basic              1-10     NaN   NaN
# 9              _            advcl      basic               1-3     NaN   NaN
# 10  כמתנדבים[68]             case      basic              1-12     NaN   NaN
# 11  כמתנדבים[68]              obl      basic              1-10     NaN   NaN
# 12             _            punct      basic              1-10     NaN   NaN
# 13             _               cc      basic              1-16     NaN   NaN
# 14             _           advmod      basic              1-16     NaN   NaN
# 15             _             conj      basic              1-10     NaN   NaN
# 16             _              obj      basic              1-16     NaN   NaN
# 17             _             amod      basic              1-17     NaN   NaN
# 18             _             amod      basic              1-17     NaN   NaN
# 19             _            punct      basic               1-3     NaN   NaN
# 20             _            nsubj      basic               2-3     NaN   NaN
# 21             _             amod      basic               2-1     NaN   NaN
# 22             _             root      basic               2-3     NaN   NaN
# 23             _         obl:tmod      basic               2-3     NaN   NaN
# 24    בוועדת[69]             case      basic               2-6     NaN   NaN
# 25    בוועדת[69]              obl      basic               2-3     NaN   NaN
# 26    העבודה[70]          det:def      basic               2-8     NaN   NaN
# 27    העבודה[70]  compound:smixut      basic               2-6     NaN   NaN
# 28   והרווחה[71]               cc      basic              2-11     NaN   NaN
# 29   והרווחה[71]          det:def      basic              2-11     NaN   NaN
# 30   והרווחה[71]             conj      basic               2-8     NaN   NaN
# 31             _         case:gen      basic              2-14     NaN   NaN
# 32     הכנסת[72]          det:def      basic              2-14     NaN   NaN
# 33     הכנסת[72]        nmod:poss      basic               2-6     NaN   NaN
# 34             _            punct      basic               2-6     NaN   NaN
# 35      שדנה[73]             mark      basic              2-17     NaN   NaN
# 36      שדנה[73]        acl:relcl      basic               2-6     NaN   NaN
# 37     בנושא[74]             case      basic              2-19     NaN   NaN
# 38     בנושא[74]             iobj      basic              2-17     NaN   NaN
# 39             _  compound:smixut      basic              2-19     NaN   NaN
# 40             _  compound:smixut      basic              2-20     NaN   NaN
# 41             _             amod      basic              2-21     NaN   NaN
# 42             _            punct      basic               2-3     NaN   NaN
# 43             _            nsubj      basic              3-12     NaN   NaN
# 44    הוועדה[75]          det:def      basic               3-3     NaN   NaN
# 45    הוועדה[75]  compound:smixut      basic               3-1     NaN   NaN
# 46             _            punct      basic               3-1     NaN   NaN
# 47             _            appos      basic               3-1     NaN   NaN
# 48             _            appos      basic               3-5     NaN   NaN
# 49             _        flat:name      basic               3-6     NaN   NaN
# 50             _            punct      basic               3-9     NaN   NaN
# 51             _            appos      basic               3-5     NaN   NaN
# 52             _            punct      basic               3-9     NaN   NaN
# 53             _            punct      basic               3-1     NaN   NaN
# 54             _             root      basic              3-12     NaN   NaN
# 55             _             mark      basic              3-15     NaN   NaN
# 56             _            punct      basic              3-15     NaN   NaN
# 57             _            ccomp      basic              3-12     NaN   NaN
# 58             _              obj      basic              3-15     NaN   NaN
# 59             _             amod      basic              3-16     NaN   NaN
#
#    ner_type is_ner  biose
# 0         _  False      O
# 1         _  False      O
# 2         _  False      O
# 3         _  False      O
# 4       GPE   True  S-GPE
# 5         _  False      O
# 6       GPE   True  S-GPE
# 7         _  False      O
# 8         _  False      O
# 9         _  False      O
# 10        _  False      O
# 11        _  False      O
# 12        _  False      O
# 13        _  False      O
# 14        _  False      O
# 15        _  False      O
# 16        _  False      O
# 17        _  False      O
# 18        _  False      O
# 19        _  False      O
# 20        _  False      O
# 21        _  False      O
# 22        _  False      O
# 23        _  False      O
# 24        _  False      O
# 25      ORG   True  B-ORG
# 26      ORG   True  I-ORG
# 27      ORG   True  I-ORG
# 28      ORG   True  I-ORG
# 29      ORG   True  I-ORG
# 30      ORG   True  E-ORG
# 31        _  False      O
# 32      ORG   True  B-ORG
# 33      ORG   True  E-ORG
# 34        _  False      O
# 35        _  False      O
# 36        _  False      O
# 37        _  False      O
# 38        _  False      O
# 39        _  False      O
# 40        _  False      O
# 41        _  False      O
# 42        _  False      O
# 43        _  False      O
# 44        _  False      O
# 45        _  False      O
# 46        _  False      O
# 47        _  False      O
# 48      PER   True  B-PER
# 49      PER   True  E-PER
# 50        _  False      O
# 51      ORG   True  S-ORG
# 52        _  False      O
# 53        _  False      O
# 54        _  False      O
# 55        _  False      O
# 56        _  False      O
# 57        _  False      O
# 58        _  False      O
# 59        _  False      O
#
# [60 rows x 27 columns]

# %%
df.ner_type.value_counts()
# Out:
# _      2529
# ORG      82
# GPE      50
# PER      45
# LOC      42
# EVE      20
# FAC       6
# ANG       1
# Name: ner_type, dtype: int64

# %% [markdown]
# ## Cohen Kappa

# %%
annos = {}
for g, members in groups.items():
    annos[g] = {}
    for f in FILES:
        annos[g][f] = {}
        for m in members:
            path = os.path.join(ANNO_FOLDER, g, m, f)
            annos[g][f][m] = read_tsv3(path)

# %%
from sklearn.metrics import cohen_kappa_score
from itertools import combinations

# %%
annos[G1][F1][groups[G1][0]].ner_type.shape, annos[G1][F1][groups[G1][1]].ner_type.shape
# Out:
# ((2775,), (2775,))

# %%
annos[G1][F1][groups[G1][0]].ner_type.unique()
# Out:
# array(['_', 'GPE', 'ORG', 'PER', 'EVE', 'FAC', 'LOC', 'ANG'], dtype=object)

# %%
annos[G1][F1][groups[G1][1]].ner_type.unique()
# Out:
# array(['_', 'GPE', 'ORG', 'PER', 'EVE', 'LOC', 'FAC'], dtype=object)

# %%
cohen_kappa_score(annos[G1][F1][groups[G1][0]].ner_type, annos[G1][F1][groups[G1][1]].ner_type)
# Out:
# 0.8976390901867242

# %%
cohen_kappa_score(annos[G1][F1][groups[G1][0]].is_ner, annos[G1][F1][groups[G1][1]].is_ner)
# Out:
# 0.9158688367640019

# %%
scores = []
for g in groups:
    for f in FILES:
        for a, b in combinations(groups[g], 2):
            type_sc = cohen_kappa_score(annos[g][f][a].ner_type, annos[g][f][b].ner_type)
            bool_sc = cohen_kappa_score(annos[g][f][a].is_ner, annos[g][f][b].is_ner)
            #print(g, f, a, b, sc)
            scores.append((g, f, a, b, type_sc, bool_sc))
scores = pd.DataFrame(scores, columns=['group', 'file', 'a', 'b', 'type_sc', 'bool_sc'])
scores.head()
# Out:
#     group           file      a       b   type_sc   bool_sc
# 0  group1  dev_1-100.tsv  anatb  dafnaa  0.897639  0.915869
# 1  group1  dev_1-100.tsv  anatb   shayp  0.883459  0.905985
# 2  group1  dev_1-100.tsv  anatb  sinair  0.809746  0.859330
# 3  group1  dev_1-100.tsv  anatb   tzufa  0.773987  0.820183
# 4  group1  dev_1-100.tsv  anatb   vikab  0.805374  0.868539

# %%
scores[(scores.a!='nuritg') & (scores.b!='nuritg')].groupby(['group', 'file']).mean()
# Out:
#                          type_sc   bool_sc
# group  file
# group1 dev_1-100.tsv    0.804903  0.857380
#        dev_101-200.tsv  0.891750  0.907298
#        dev_201-300.tsv  0.815467  0.845872
#        dev_301-400.tsv  0.877136  0.914304
# group2 dev_1-100.tsv    0.729188  0.791572
#        dev_101-200.tsv  0.760130  0.817839
#        dev_201-300.tsv  0.781875  0.814547
#        dev_301-400.tsv  0.800863  0.839371

# %% [markdown]
# ## conlleval
# https://github.com/sighsmile/conlleval

# %%
from conlleval import evaluate

evaluate(annos[G1][F1][groups[G1][0]].biose.tolist(), 
         annos[G1][F1][groups[G1][2]].biose.tolist(), 
         verbose=True)
# Out:
# processed 2775 tokens with 110 phrases; found: 111 phrases; correct: 94.
# accuracy:  85.37%; (non-O)
# accuracy:  97.98%; precision:  84.68%; recall:  85.45%; FB1:  85.07
#               ANG: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#               EVE: precision: 100.00%; recall:  20.00%; FB1:  33.33  1
#               FAC: precision:  40.00%; recall: 100.00%; FB1:  57.14  5
#               GPE: precision:  85.71%; recall:  90.00%; FB1:  87.80  42
#               LOC: precision: 100.00%; recall:  83.33%; FB1:  90.91  10
#               ORG: precision:  75.00%; recall:  80.77%; FB1:  77.78  28
#               PER: precision:  96.00%; recall: 100.00%; FB1:  97.96  25
# (84.68468468468468, 85.45454545454545, 85.06787330316742)

# %%
prec, rec, f1 = evaluate(annos[G1][F1][groups[G1][0]].biose.tolist(), 
                         annos[G1][F1][groups[G1][1]].biose.tolist(), 
                         verbose=False) 
prec, rec, f1
# Out:
# (82.4074074074074, 80.9090909090909, 81.651376146789)

# %%
conll_scores = []
for g in groups:
    for f in FILES:
        for a, b in combinations(groups[g], 2):
            prec, rec, f1 = evaluate(annos[g][f][a].biose.tolist(), 
                                     annos[g][f][b].biose.tolist(), 
                                     verbose=False) 
            #print(g, f, a, b, sc)
            conll_scores.append((g, f, a, b, prec, rec, f1))
conll_scores = pd.DataFrame(conll_scores, columns=['group', 'file', 'a', 'b', 'prec', 'rec', 'f1'])
conll_scores.head()
# Out:
#     group           file      a       b       prec        rec         f1
# 0  group1  dev_1-100.tsv  anatb  dafnaa  82.407407  80.909091  81.651376
# 1  group1  dev_1-100.tsv  anatb   shayp  84.684685  85.454545  85.067873
# 2  group1  dev_1-100.tsv  anatb  sinair  71.794872  76.363636  74.008811
# 3  group1  dev_1-100.tsv  anatb   tzufa  68.867925  66.363636  67.592593
# 4  group1  dev_1-100.tsv  anatb   vikab  71.551724  75.454545  73.451327

# %%
conll_scores[(conll_scores.a!='nuritg') & (conll_scores.b!='nuritg')].groupby(['group', 'file']).mean()
# Out:
#                              prec        rec         f1
# group  file
# group1 dev_1-100.tsv    72.358024  73.731377  72.990749
#        dev_101-200.tsv  85.129476  83.252584  84.161336
#        dev_201-300.tsv  73.222315  66.522738  69.235302
#        dev_301-400.tsv  86.752200  83.237341  84.866250
# group2 dev_1-100.tsv    65.136054  68.154908  66.362754
#        dev_101-200.tsv  69.013647  67.789579  67.895156
#        dev_201-300.tsv  64.394644  67.102883  65.613404
#        dev_301-400.tsv  81.371001  82.095879  81.722892

# %% [markdown]
# ## TODO
#
# 1. nested tags - only leaves, only tops, all
