# %% [markdown]
# install https://github.com/cjer/bclm
# install https://github.com/EmilStenstrom/conllu

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
import bclm

# %%
dropped = [5438, 5444, 5445, 5446, 5448, 5449, 5450, 5451, 5453, 5459]
spdf = bclm.read_dataframe('spmrl')

# %%
global_dropped = [spdf[spdf.sent_id==d].global_sent_id.iat[0] for d in dropped]
global_dropped
# Out:
# [5438, 5444, 5445, 5446, 5448, 5449, 5450, 5451, 5453, 5459]

# %%
uddf = bclm.read_dataframe('ud')

# %%
uddf = uddf[(~uddf.global_sent_id.isin(global_dropped))]

# %%
spdf = spdf[(~spdf.global_sent_id.isin(global_dropped))]

# %%
from collections import OrderedDict

# %%
ud_sents = list(uddf.sent_id.unique())

# %%
def get_set_from_sent_id(gsi):
    if gsi>=1 and gsi<=484:
        return 'dev'
    elif gsi>=485 and gsi<=5725:
        return 'train'
    elif gsi>=5726 and gsi<=6216:
        return 'test'
    
uddf['ud_set'] = uddf.sent_id.apply(get_set_from_sent_id)

uddf.groupby(['ud_set']).sent_id.agg(['min', 'max'])
# Out:
#          min   max
# ud_set
# dev        1   484
# test    5726  6216
# train    485  5725

# %%
uddf['set'] = uddf['ud_set']
# Out:
#    sent_id  token_id token_str biose_layer0    upostag  set
# 0        1         1     עשרות            O        NUM  dev
# 1        1         2     אנשים            O       NOUN  dev
# 2        1         3    מגיעים            O       VERB  dev
# 3        1         4   מתאילנד      O^S-GPE  ADP^PROPN  dev
# 4        1         5    לישראל      O^S-GPE  ADP^PROPN  dev

# %% [markdown]
# ## TODO:
# 1. Add text
# 1. calculate roots and edges
# 1. Calculate NER start/stop positions
# 1. Add NER for all layers
# 1. Create dict from df sentence
# 1. Write jsonl
# 1. NOT NOW: add offsets

# %% [markdown]
# ### Add text

# %%
from conllu import parse 
with open('align/ud_fixed.conllu', 'r', encoding='utf8') as f:
    ud_conllu_sents = parse(f.read())

# %%
ud_conllu_sents[1].metadata
# Out:
# OrderedDict([('sent_id', '2'),
#              ('global_sent_id', '2'),
#              ('text',
#               'תופעה זו התבררה אתמול בוועדת העבודה והרווחה של הכנסת, שדנה בנושא העסקת עובדים זרים.'),
#              ('very_similar_sent_id', '{}'),
#              ('duplicate_sent_id', '{}'),
#              ('tokens',
#               'תופעה זו התבררה אתמול בוועדת העבודה והרווחה של הכנסת , שדנה בנושא העסקת עובדים זרים .'),
#              ('set', 'dev')])

# %%
ud_texts = {int(s.metadata['sent_id']): s.metadata['text'] for s in ud_conllu_sents}
len(ud_texts)
# Out:
# 6153

# %%
uddf['text'] = uddf.sent_id.map(ud_texts)
uddf.head().T
# Out:
#                                                                       0  \
# sent_id                                                               1
# id                                                                    1
# form                                                              עשרות
# lemma                                                             עשרות
# upostag                                                             NUM
# xpostag                                                             NUM
# feats                 OrderedDict([('Definite', 'Cons'), ('Gender', ...
# head                                                                  2
# deprel                                                           nummod
# deps                                                                NaN
# misc                                                                NaN
# global_sent_id                                                        1
# token_id                                                              1
# token_str                                                         עשרות
# token_morph_id                                                        0
# binyan                                                              ---
# biose                                                                 O
# ner                                                                   _
# ner_layers                                                            0
# ner_escaped                                                           _
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                          O
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# set                                                                 dev
# ud_set                                                              dev
# biose_only                                                            O
# ner_type                                                           None
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
#
#                                                                       1  \
# sent_id                                                               1
# id                                                                    2
# form                                                              אנשים
# lemma                                                               איש
# upostag                                                            NOUN
# xpostag                                                            NOUN
# feats                 OrderedDict([('Gender', 'Masc'), ('Number', 'P...
# head                                                                  3
# deprel                                                            nsubj
# deps                                                                NaN
# misc                                                                NaN
# global_sent_id                                                        1
# token_id                                                              2
# token_str                                                         אנשים
# token_morph_id                                                        0
# binyan                                                              ---
# biose                                                                 O
# ner                                                                   _
# ner_layers                                                            0
# ner_escaped                                                           _
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                          O
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# set                                                                 dev
# ud_set                                                              dev
# biose_only                                                            O
# ner_type                                                           None
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
#
#                                                                       2  \
# sent_id                                                               1
# id                                                                    3
# form                                                             מגיעים
# lemma                                                              הגיע
# upostag                                                            VERB
# xpostag                                                            VERB
# feats                 OrderedDict([('Gender', 'Masc'), ('HebBinyan',...
# head                                                                  0
# deprel                                                             root
# deps                                                                NaN
# misc                                                                NaN
# global_sent_id                                                        1
# token_id                                                              3
# token_str                                                        מגיעים
# token_morph_id                                                        0
# binyan                                                            HIFIL
# biose                                                                 O
# ner                                                                   _
# ner_layers                                                            0
# ner_escaped                                                           _
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                          O
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# set                                                                 dev
# ud_set                                                              dev
# biose_only                                                            O
# ner_type                                                           None
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
#
#                                                                       3  \
# sent_id                                                               1
# id                                                                    4
# form                                                                  מ
# lemma                                                                 מ
# upostag                                                             ADP
# xpostag                                                             ADP
# feats                                                               NaN
# head                                                                  5
# deprel                                                             case
# deps                                                                NaN
# misc                                                                NaN
# global_sent_id                                                        1
# token_id                                                              4
# token_str                                                       מתאילנד
# token_morph_id                                                        0
# binyan                                                              ---
# biose                                                                 O
# ner                                                                   _
# ner_layers                                                            0
# ner_escaped                                                           _
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                          O
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# set                                                                 dev
# ud_set                                                              dev
# biose_only                                                            O
# ner_type                                                           None
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
#
#                                                                       4
# sent_id                                                               1
# id                                                                    5
# form                                                             תאילנד
# lemma                                                            תאילנד
# upostag                                                           PROPN
# xpostag                                                           PROPN
# feats                                                               NaN
# head                                                                  3
# deprel                                                              obl
# deps                                                                NaN
# misc                                                                NaN
# global_sent_id                                                        1
# token_id                                                              4
# token_str                                                       מתאילנד
# token_morph_id                                                        1
# binyan                                                              ---
# biose                                                             S-GPE
# ner                                                                 GPE
# ner_layers                                                            1
# ner_escaped                                                         GPE
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                      S-GPE
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# set                                                                 dev
# ud_set                                                              dev
# biose_only                                                            S
# ner_type                                                            GPE
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...

# %%
from conllu import parse 
with open('align/spmrl_fixed.conllu', 'r', encoding='utf8') as f:
    sp_conllu_sents = parse(f.read())

# %%
sp_conllu_sents[1].metadata
# Out:
# OrderedDict([('sent_id', '2'),
#              ('global_sent_id', '2'),
#              ('text_from_ud',
#               'תופעה זו התבררה אתמול בוועדת העבודה והרווחה של הכנסת, שדנה בנושא העסקת עובדים זרים.'),
#              ('very_similar_sent_id', '{}'),
#              ('duplicate_sent_id', '{}'),
#              ('set', 'dev')])

# %%
sp_texts = {int(s.metadata['sent_id']): s.metadata['text_from_ud'] for s in sp_conllu_sents}
len(sp_texts)
# Out:
# 6153

# %%
spdf['text'] = spdf.sent_id.map(sp_texts)
spdf.head().T
# Out:
#                                                                       0  \
# id                                                                    1
# form                                                              עשרות
# lemma                                                               עשר
# upostag                                                             CDT
# xpostag                                                             CDT
# feats                                                       gen=F|num=P
# token_id                                                              1
# sent_id                                                               1
# token_str                                                         עשרות
# global_sent_id                                                        1
# token_morph_id                                                        0
# binyan                                                              ---
# biose                                                                 O
# ner_layers                                                            0
# ner                                                                   _
# head                                                                  2
# deprel                                                              num
# deps                                                                  _
# misc                                                                  _
# ner_escaped                                                           _
# set                                                                 dev
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                          O
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
#
#                                                                       1  \
# id                                                                    2
# form                                                              אנשים
# lemma                                                               איש
# upostag                                                              NN
# xpostag                                                              NN
# feats                                                       gen=M|num=P
# token_id                                                              2
# sent_id                                                               1
# token_str                                                         אנשים
# global_sent_id                                                        1
# token_morph_id                                                        0
# binyan                                                              ---
# biose                                                                 O
# ner_layers                                                            0
# ner                                                                   _
# head                                                                  3
# deprel                                                             subj
# deps                                                                  _
# misc                                                                  _
# ner_escaped                                                           _
# set                                                                 dev
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                          O
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
#
#                                                                       2  \
# id                                                                    3
# form                                                             מגיעים
# lemma                                                              הגיע
# upostag                                                              BN
# xpostag                                                              BN
# feats                                 gen=M|num=P|per=A|HebBinyan=HIFIL
# token_id                                                              3
# sent_id                                                               1
# token_str                                                        מגיעים
# global_sent_id                                                        1
# token_morph_id                                                        0
# binyan                                                            HIFIL
# biose                                                                 O
# ner_layers                                                            0
# ner                                                                   _
# head                                                                  0
# deprel                                                             ROOT
# deps                                                                  _
# misc                                                                  _
# ner_escaped                                                           _
# set                                                                 dev
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                          O
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
#
#                                                                       3  \
# id                                                                    4
# form                                                                  מ
# lemma                                                                 מ
# upostag                                                     PREPOSITION
# xpostag                                                     PREPOSITION
# feats                                                                 _
# token_id                                                              4
# sent_id                                                               1
# token_str                                                       מתאילנד
# global_sent_id                                                        1
# token_morph_id                                                        0
# binyan                                                              ---
# biose                                                                 O
# ner_layers                                                            0
# ner                                                                   _
# head                                                                  3
# deprel                                                          prepmod
# deps                                                                  _
# misc                                                                  _
# ner_escaped                                                           _
# set                                                                 dev
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                          O
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
#
#                                                                       4
# id                                                                    5
# form                                                             תאילנד
# lemma                                                            תאילנד
# upostag                                                             NNP
# xpostag                                                             NNP
# feats                                                                 _
# token_id                                                              4
# sent_id                                                               1
# token_str                                                       מתאילנד
# global_sent_id                                                        1
# token_morph_id                                                        1
# binyan                                                              ---
# biose                                                             S-GPE
# ner_layers                                                            1
# ner                                                                 GPE
# head                                                                  4
# deprel                                                             pobj
# deps                                                                  _
# misc                                                                  _
# ner_escaped                                                         GPE
# set                                                                 dev
# duplicate_sent_id                                                   NaN
# very_similar_sent_id                                                NaN
# biose_layer0                                                      S-GPE
# biose_layer1                                                          O
# biose_layer2                                                          O
# biose_layer3                                                          O
# text                  עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...

# %%
def get_edges(df):
    return (df
            .rename(columns={'head': 'source', 
                             'id': 'destination', 
                             'deprel': 'relation'})[['source', 'destination', 'relation']]
            .to_dict('records'))

def get_roots(df):
    return [int(x) for x in list(df[(df['head']==0) | (df.deprel.str.lower()=='root')].id.unique())]

def get_overlapping_entities(df, col='biose_layer0', priority=0):
    mentions = []
    current_mention= None
    for i, r in df.iterrows():
        bio = r[col][0]
        if bio!='O':
            cat = r[col].split('-')[1]
        else:
            cat = '-'
        if bio=='S':
            mentions.append({'first': int(r['id']),
                             'last': int(r['id']),
                             'label': cat, 
                             'priority': priority})
            current_mention= None
        if bio=='B':
            current_mention = {'first': int(r['id']), 
                               'last': int(r['id']), 
                               'label': cat,
                               'priority': priority}

#         if bio=='I' and current_mention is not None:
#             pass
        
        if bio=='E' and current_mention is not None:
            current_mention['last'] = int(r['id'])
            mentions.append(current_mention)
            current_mention= None
        if bio=='O':
            current_mention = None
    return mentions
    
def get_sentence_dict(df):
    df = df.sort_values('id')
    d = {}
    d['id'] = int(df.sent_id.iat[0])
    d['text'] = df.text.iat[0]
    s = {}
    s['words'] = df.form.tolist()
    s['raw'] = s['words']
    s['startOffsets'] = []
    s['endOffsets'] = []
    s['tags'] = df.upostag.tolist()
    s['lemmas'] = df.lemma.tolist()
    s['chunks'] = []
    edges = get_edges(df)
    roots = get_roots(df)
    universal_basic = {'edges': edges, 'roots': roots}
    s['graphs'] = {'universal-basic': universal_basic,
                   'universal_enhanced': {'edges': [], 'roots': []}}
    s['metadata'] =  {
                'sentParagraphOffsets': []
            },
    ents = (get_overlapping_entities(df, 'biose_layer0', 0) 
            + get_overlapping_entities(df, 'biose_layer1', 1) 
            + get_overlapping_entities(df, 'biose_layer2', 2) 
            + get_overlapping_entities(df, 'biose_layer3', 3))
    s['overlappingEntities'] = ents
    d['sentences'] = [s,]
    d['metadata'] = {'paragraph_': d['text'], 
                     'section': df.set.iat[0]}
    d['gold_relations']= [],
    d['gold_events']= [],
    d['corefChains']= {'rawMentions': []}
    return d

# %%
get_sentence_dict(uddf[uddf.sent_id==1])
# Out:
# {'id': 1,
#  'text': 'עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים כמתנדבים, אך למעשה משמשים עובדים שכירים זולים.',
#  'sentences': [{'words': ['עשרות',
#     'אנשים',
#     'מגיעים',
#     'מ',
#     'תאילנד',
#     'ל',
#     'ישראל',
#     'כש',
#     'הם',
#     'נרשמים',
#     'כ',
#     'מתנדבים',
#     ',',
#     'אך',
#     'למעשה',
#     'משמשים',
#     'עובדים',
#     'שכירים',
#     'זולים',
#     '.'],
#    'raw': ['עשרות',
#     'אנשים',
#     'מגיעים',
#     'מ',
#     'תאילנד',
#     'ל',
#     'ישראל',
#     'כש',
#     'הם',
#     'נרשמים',
#     'כ',
#     'מתנדבים',
#     ',',
#     'אך',
#     'למעשה',
#     'משמשים',
#     'עובדים',
#     'שכירים',
#     'זולים',
#     '.'],
#    'startOffsets': [],
#    'endOffsets': [],
#    'tags': ['NUM',
#     'NOUN',
#     'VERB',
#     'ADP',
#     'PROPN',
#     'ADP',
#     'PROPN',
#     'SCONJ',
#     'PRON',
#     'VERB',
#     'ADP',
#     'NOUN',
#     'PUNCT',
#     'CCONJ',
#     'ADV',
#     'VERB',
#     'NOUN',
#     'ADJ',
#     'ADJ',
#     'PUNCT'],
#    'lemmas': ['עשרות',
#     'איש',
#     'הגיע',
#     'מ',
#     'תאילנד',
#     'ל',
#     'ישראל',
#     'כש',
#     'הוא',
#     'נרשם',
#     'כ',
#     'מתנדב',
#     ',',
#     'אך',
#     'למעשה',
#     'שימש',
#     'עובד',
#     'שכיר',
#     'זול',
#     '.'],
#    'chunks': [],
#    'graphs': {'universal-basic': {'edges': [{'source': 2,
#        'destination': 1,
#        'relation': 'nummod'},
#       {'source': 3, 'destination': 2, 'relation': 'nsubj'},
#       {'source': 0, 'destination': 3, 'relation': 'root'},
#       {'source': 5, 'destination': 4, 'relation': 'case'},
#       {'source': 3, 'destination': 5, 'relation': 'obl'},
#       {'source': 7, 'destination': 6, 'relation': 'case'},
#       {'source': 3, 'destination': 7, 'relation': 'obl'},
#       {'source': 10, 'destination': 8, 'relation': 'mark'},
#       {'source': 10, 'destination': 9, 'relation': 'nsubj'},
#       {'source': 3, 'destination': 10, 'relation': 'advcl'},
#       {'source': 12, 'destination': 11, 'relation': 'case'},
#       {'source': 10, 'destination': 12, 'relation': 'obl'},
#       {'source': 10, 'destination': 13, 'relation': 'punct'},
#       {'source': 16, 'destination': 14, 'relation': 'cc'},
#       {'source': 16, 'destination': 15, 'relation': 'advmod'},
#       {'source': 10, 'destination': 16, 'relation': 'conj'},
#       {'source': 16, 'destination': 17, 'relation': 'obj'},
#       {'source': 17, 'destination': 18, 'relation': 'amod'},
#       {'source': 17, 'destination': 19, 'relation': 'amod'},
#       {'source': 3, 'destination': 20, 'relation': 'punct'}],
#      'roots': [3]},
#     'universal_enhanced': {'edges': [], 'roots': []}},
#    'metadata': ({'sentParagraphOffsets': []},),
#    'overlappingEntities': [{'first': 5,
#      'last': 5,
#      'label': 'GPE',
#      'priority': 0},
#     {'first': 7, 'last': 7, 'label': 'GPE', 'priority': 0}]}],
#  'metadata': {'paragraph_': 'עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים כמתנדבים, אך למעשה משמשים עובדים שכירים זולים.',
#   'section': 'dev'},
#  'gold_relations': ([],),
#  'gold_events': ([],),
#  'corefChains': {'rawMentions': []}}

# %%
get_sentence_dict(spdf[spdf.sent_id==1])
# Out:
# {'id': 1,
#  'text': 'עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים כמתנדבים, אך למעשה משמשים עובדים שכירים זולים.',
#  'sentences': [{'words': ['עשרות',
#     'אנשים',
#     'מגיעים',
#     'מ',
#     'תאילנד',
#     'ל',
#     'ישראל',
#     'כש',
#     'הם',
#     'נרשמים',
#     'כ',
#     'מתנדבים',
#     ',',
#     'אך',
#     'למעשה',
#     'משמשים',
#     'עובדים',
#     'שכירים',
#     'זולים',
#     '.'],
#    'raw': ['עשרות',
#     'אנשים',
#     'מגיעים',
#     'מ',
#     'תאילנד',
#     'ל',
#     'ישראל',
#     'כש',
#     'הם',
#     'נרשמים',
#     'כ',
#     'מתנדבים',
#     ',',
#     'אך',
#     'למעשה',
#     'משמשים',
#     'עובדים',
#     'שכירים',
#     'זולים',
#     '.'],
#    'startOffsets': [],
#    'endOffsets': [],
#    'tags': ['CDT',
#     'NN',
#     'BN',
#     'PREPOSITION',
#     'NNP',
#     'PREPOSITION',
#     'NNP',
#     'TEMP',
#     'PRP',
#     'BN',
#     'PREPOSITION',
#     'NN',
#     'yyCM',
#     'CC',
#     'RB',
#     'BN',
#     'NN',
#     'JJ',
#     'JJ',
#     'yyDOT'],
#    'lemmas': ['עשר',
#     'איש',
#     'הגיע',
#     'מ',
#     'תאילנד',
#     'ל',
#     'ישראל',
#     'כש',
#     'הוא',
#     'נרשם',
#     'כ',
#     'מתנדב',
#     '_',
#     'אך',
#     'למעשה',
#     'שימש',
#     'עובד',
#     'שכיר',
#     'זול',
#     '_'],
#    'chunks': [],
#    'graphs': {'universal-basic': {'edges': [{'source': 2,
#        'destination': 1,
#        'relation': 'num'},
#       {'source': 3, 'destination': 2, 'relation': 'subj'},
#       {'source': 0, 'destination': 3, 'relation': 'ROOT'},
#       {'source': 3, 'destination': 4, 'relation': 'prepmod'},
#       {'source': 4, 'destination': 5, 'relation': 'pobj'},
#       {'source': 3, 'destination': 6, 'relation': 'prepmod'},
#       {'source': 6, 'destination': 7, 'relation': 'pobj'},
#       {'source': 3, 'destination': 8, 'relation': 'comp'},
#       {'source': 10, 'destination': 9, 'relation': 'subj'},
#       {'source': 14, 'destination': 10, 'relation': 'conj'},
#       {'source': 10, 'destination': 11, 'relation': 'prepmod'},
#       {'source': 11, 'destination': 12, 'relation': 'pobj'},
#       {'source': 14, 'destination': 13, 'relation': 'punct'},
#       {'source': 8, 'destination': 14, 'relation': 'advcl'},
#       {'source': 16, 'destination': 15, 'relation': 'advmod'},
#       {'source': 14, 'destination': 16, 'relation': 'conj'},
#       {'source': 16, 'destination': 17, 'relation': 'obj'},
#       {'source': 17, 'destination': 18, 'relation': 'amod'},
#       {'source': 17, 'destination': 19, 'relation': 'amod'},
#       {'source': 3, 'destination': 20, 'relation': 'punct'}],
#      'roots': [3]},
#     'universal_enhanced': {'edges': [], 'roots': []}},
#    'metadata': ({'sentParagraphOffsets': []},),
#    'overlappingEntities': [{'first': 5,
#      'last': 5,
#      'label': 'GPE',
#      'priority': 0},
#     {'first': 7, 'last': 7, 'label': 'GPE', 'priority': 0}]}],
#  'metadata': {'paragraph_': 'עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים כמתנדבים, אך למעשה משמשים עובדים שכירים זולים.',
#   'section': 'dev'},
#  'gold_relations': ([],),
#  'gold_events': ([],),
#  'corefChains': {'rawMentions': []}}

# %%
all_dicts = [get_sentence_dict(uddf[uddf.sent_id==i]) for i in sorted(list(uddf.sent_id.unique()))]

# %%
import jsonlines

with jsonlines.open('data/hebtb_ud.ann.jsonl', mode='w') as writer:
    for d in all_dicts:
        writer.write(d)

# %%
sp_all_dicts = [get_sentence_dict(spdf[spdf.sent_id==i]) for i in sorted(list(spdf.sent_id.unique()))]

# %%
import jsonlines

with jsonlines.open('data/hebtb_spmrl.ann.jsonl', mode='w') as writer:
    for d in sp_all_dicts:
        writer.write(d)
