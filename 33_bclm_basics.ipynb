# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
import bclm

# %%
spdf = bclm.read_dataframe('spmrl')

# %%
spdf.groupby('set').sent_id.agg([min, max])
# Out:
#         min   max
# set
# dev       1   500
# test   5438  6153
# train   501  5437

# %%
dropped = [5438, 5444, 5445, 5446, 5448, 5449, 5450, 5451, 5453, 5459]
spdf = spdf[(~spdf.sent_id.isin(dropped))]

# %%
dev = spdf[spdf.set=='dev']

# %%
spdf.head().T
# Out:
#                                 0            1  \
# id                              1            2
# form                        עשרות        אנשים
# lemma                         עשר          איש
# upostag                       CDT           NN
# xpostag                       CDT           NN
# feats                 gen=F|num=P  gen=M|num=P
# token_id                        1            2
# sent_id                         1            1
# token_str                   עשרות        אנשים
# global_sent_id                  1            1
# token_morph_id                  0            0
# binyan                        ---          ---
# biose                           O            O
# ner_layers                      0            0
# ner                             _            _
# head                            2            3
# deprel                        num         subj
# deps                            _            _
# misc                            _            _
# ...

# %% [markdown]
# ## Morpheme Sentences

# %%
dev_morph_sents = bclm.get_sentences_list(dev, fields=['token_id', 'token_str', 'form', 'biose_layer0'])
dev_morph_sents
# Out:
# sent_id
# 1      [[1, עשרות, עשרות, O], [2, אנשים, אנשים, O], [...
# 2      [[1, תופעה, תופעה, O], [2, זו, זו, O], [3, התב...
# 3      [[1, יו"ר, יו"ר, O], [2, הוועדה, ה, O], [2, הו...
# 4      [[1, מצד, מ, O], [1, מצד, צד, O], [2, אחד, אחד...
# 5      [[1, נמיר, נמיר, S-PER], [2, הודיעה, הודיעה, O...
#                              ...
# 496    [[1, מוות, מוות, O], [2, לערבים, ל, O], [2, לע...
# 497    [[1, קשה, קשה, O], [2, להוציא, להוציא, O], [3,...
# 498    [[1, עכשיו, עכשיו, O], [2, קוראים, קוראים, O],...
# 499    [[1, תם, תם, O], [2, מסע, מסע, O], [3, ההלוויי...
# 500    [[1, מתחיל, מתחיל, O], [2, מסע, מסע, O], [3, ה...
# Length: 500, dtype: object

# %% [markdown]
# ## Token-Multi Sentences

# %%
dev_multi = bclm.get_token_df(dev, fields = ['biose_layer0'])
dev_multi.head()
# Out:
#    sent_id  token_id token_str biose_layer0  set
# 0        1         1     עשרות            O  dev
# 1        1         2     אנשים            O  dev
# 2        1         3    מגיעים            O  dev
# 3        1         4   מתאילנד      O^S-GPE  dev
# 4        1         5    לישראל      O^S-GPE  dev

# %%
bclm.get_sentences_list(dev_multi, fields=['token_id', 'token_str', 'biose_layer0'])
# Out:
# sent_id
# 1      [[1, עשרות, O], [2, אנשים, O], [3, מגיעים, O],...
# 2      [[1, תופעה, O], [2, זו, O], [3, התבררה, O], [4...
# 3      [[1, יו"ר, O], [2, הוועדה, O^O], [3, ,, O], [4...
# 4      [[1, מצד, O^O], [2, אחד, O], [3, רוצה, O], [4,...
# 5      [[1, נמיר, S-PER], [2, הודיעה, O], [3, כי, O],...
#                              ...
# 496    [[1, מוות, O], [2, לערבים, O^O^O], [3, ,, O], ...
# 497    [[1, קשה, O], [2, להוציא, O], [3, את, O], [4, ...
# 498    [[1, עכשיו, O], [2, קוראים, O], [3, את, O], [4...
# 499    [[1, תם, O], [2, מסע, O], [3, ההלווייה, O^O], ...
# 500    [[1, מתחיל, O], [2, מסע, O], [3, הנקמה, O^O], ...
# Length: 500, dtype: object

# %% [markdown]
# ## Token-Single Sentences

# %%
dev_single = bclm.get_token_df(dev, fields = [], biose=['biose_layer0'])
dev_single.head()
# Out:
# /home/nlp/danb/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#    sent_id  token_id token_str biose_layer0  set
# 0        1         1     עשרות            O  dev
# 1        1         2     אנשים            O  dev
# 2        1         3    מגיעים            O  dev
# 3        1         4   מתאילנד        S-GPE  dev
# 4        1         5    לישראל        S-GPE  dev

# %%
bclm.get_sentences_list(dev_single, fields=['token_id', 'token_str', 'biose_layer0'])
# Out:
# sent_id
# 1      [[1, עשרות, O], [2, אנשים, O], [3, מגיעים, O],...
# 2      [[1, תופעה, O], [2, זו, O], [3, התבררה, O], [4...
# 3      [[1, יו"ר, O], [2, הוועדה, O], [3, ,, O], [4, ...
# 4      [[1, מצד, O], [2, אחד, O], [3, רוצה, O], [4, ה...
# 5      [[1, נמיר, S-PER], [2, הודיעה, O], [3, כי, O],...
#                              ...
# 496    [[1, מוות, O], [2, לערבים, O], [3, ,, O], [4, ...
# 497    [[1, קשה, O], [2, להוציא, O], [3, את, O], [4, ...
# 498    [[1, עכשיו, O], [2, קוראים, O], [3, את, O], [4...
# 499    [[1, תם, O], [2, מסע, O], [3, ההלווייה, O], [4...
# 500    [[1, מתחיל, O], [2, מסע, O], [3, הנקמה, O], [4...
# Length: 500, dtype: object

# %% [markdown]
# ## UD

# %%
df = bclm.read_dataframe('ud')

# %%
df.head().T
# Out:
#                                                                       0  \
# sent_id                                                               1
# id                                                                    1
# form                                                              עשרות
# lemma                                                             עשרות
# upostag                                                             NUM
# xpostag                                                             NUM
# feats                 OrderedDict([('Definite', 'Cons'), ('Gender', ...
# head                                                                  2
# deprel                                                           nummod
# deps                                                                NaN
# misc                                                                NaN
# global_sent_id                                                        1
# ...

# %%
df.dtypes
# Out:
# sent_id                   int64
# id                        int64
# form                     object
# lemma                    object
# upostag                  object
# xpostag                  object
# feats                    object
# head                      int64
# deprel                   object
# deps                    float64
# misc                     object
# global_sent_id            int64
# token_id                  int64
# token_str                object
# token_morph_id            int64
# binyan                   object
# biose                    object
# ner                      object
# ner_layers                int64
# ner_escaped              object
# duplicate_sent_id        object
# very_similar_sent_id     object
# biose_layer0             object
# biose_layer1             object
# biose_layer2             object
# biose_layer3             object
# set                      object
# dtype: object

# %%
df.head().T
# Out:
#                                                                       0  \
# sent_id                                                               1
# id                                                                    1
# form                                                              עשרות
# lemma                                                             עשרות
# upostag                                                             NUM
# xpostag                                                             NUM
# feats                 OrderedDict([('Definite', 'Cons'), ('Gender', ...
# head                                                                  2
# deprel                                                           nummod
# deps                                                                NaN
# misc                                                                NaN
# global_sent_id                                                        1
# ...

# %%
df.groupby('set').sent_id.agg([min, max])
# Out:
#         min   max
# set
# dev       1   500
# test   5501  6216
# train   501  5500

# %%
df.groupby('set').sent_id.nunique()
# Out:
# set
# dev       500
# test      716
# train    4937
# Name: sent_id, dtype: int64

# %%
df.to_csv('align/uddf_fixed.csv.gz', index=False, compression='gzip')
