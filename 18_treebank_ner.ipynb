# %%
import pandas as pd
from conllu import parse

# %%
from collections import OrderedDict

def get_conllu_df(path, remove_duplicates=False, remove_very_similar=False):
    with open(path, 'r', encoding='utf8') as f:
        sp_conllu = parse(f.read())
    fixed = []
    dup_to_remove = set()
    very_sim_to_remove = set()
    for tl in sp_conllu:
        if (remove_duplicates and int(tl.metadata['sent_id']) in dup_to_remove 
            or remove_very_similar and int(tl.metadata['sent_id']) in very_sim_to_remove):
            print ('skipped', tl.metadata['sent_id'])
            continue
        for tok in tl:
            t = OrderedDict(tok)
            if type(t['id']) is not tuple:
                if t['feats'] is not None:
                    t.update({'feats_'+f: v for f, v in t['feats'].items()})
                del(t['feats'])
                if t['misc'] is not None:
                    t.update({'misc_'+f: v for f, v in t['misc'].items()})
                del(t['misc'])
                t.update(tl.metadata)
                fixed.append(t)
            if remove_duplicates:
                dup_to_remove = dup_to_remove | set(eval(tl.metadata['duplicate_sent_id']))
            if remove_very_similar:
                very_sim_to_remove = dup_to_remove | set(eval(tl.metadata['very_similar_sent_id']))

    df = (pd.DataFrame(fixed)
          .assign(sent_id = lambda x: x.sent_id.astype(int))
          .assign(global_sent_id = lambda x: x.global_sent_id.astype(int))
          .assign(misc_token_id = lambda x: x.misc_token_id.astype(int))

         )
    return df

        
spdf = get_conllu_df('align/spmrl_fixed.conllu', remove_duplicates=True)
# Out:
# skipped 5438
# skipped 5444
# skipped 5445
# skipped 5446
# skipped 5448
# skipped 5449
# skipped 5450
# skipped 5451
# skipped 5453
# skipped 5459

# %%
spdf[['biose_only', 'ner_type']] = spdf.misc_biose.str.split('-', expand=True)

# %%
spdf.head().T
# Out:
#                                                                       0  \
# id                                                                    1
# form                                                              עשרות
# lemma                                                               עשר
# upostag                                                             CDT
# xpostag                                                             CDT
# head                                                                  2
# deprel                                                              num
# deps                                                               None
# feats_gen                                                             F
# feats_num                                                             P
# misc_biose                                                            O
# misc_ner_escaped                                                   None
# misc_token_id                                                         1
# misc_token_str                                                    עשרות
# sent_id                                                               1
# global_sent_id                                                        1
# text_from_ud          עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# very_similar_sent_id                                                 {}
# duplicate_sent_id                                                    {}
# tokens                עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# set                                                                 dev
# feats_per                                                           NaN
# feats_HebBinyan                                                     NaN
# feats_tense                                                         NaN
# feats_suf_gen                                                       NaN
# feats_suf_num                                                       NaN
# feats_suf_per                                                       NaN
# misc_MISC                                                           NaN
# feats_polar                                                         NaN
# biose_only                                                            O
# ner_type                                                           None
#
#                                                                       1  \
# id                                                                    2
# form                                                              אנשים
# lemma                                                               איש
# upostag                                                              NN
# xpostag                                                              NN
# head                                                                  3
# deprel                                                             subj
# deps                                                               None
# feats_gen                                                             M
# feats_num                                                             P
# misc_biose                                                            O
# misc_ner_escaped                                                   None
# misc_token_id                                                         2
# misc_token_str                                                    אנשים
# sent_id                                                               1
# global_sent_id                                                        1
# text_from_ud          עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# very_similar_sent_id                                                 {}
# duplicate_sent_id                                                    {}
# tokens                עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# set                                                                 dev
# feats_per                                                           NaN
# feats_HebBinyan                                                     NaN
# feats_tense                                                         NaN
# feats_suf_gen                                                       NaN
# feats_suf_num                                                       NaN
# feats_suf_per                                                       NaN
# misc_MISC                                                           NaN
# feats_polar                                                         NaN
# biose_only                                                            O
# ner_type                                                           None
#
#                                                                       2  \
# id                                                                    3
# form                                                             מגיעים
# lemma                                                              הגיע
# upostag                                                              BN
# xpostag                                                              BN
# head                                                                  0
# deprel                                                             ROOT
# deps                                                               None
# feats_gen                                                             M
# feats_num                                                             P
# misc_biose                                                            O
# misc_ner_escaped                                                   None
# misc_token_id                                                         3
# misc_token_str                                                   מגיעים
# sent_id                                                               1
# global_sent_id                                                        1
# text_from_ud          עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# very_similar_sent_id                                                 {}
# duplicate_sent_id                                                    {}
# tokens                עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# set                                                                 dev
# feats_per                                                             A
# feats_HebBinyan                                                   HIFIL
# feats_tense                                                         NaN
# feats_suf_gen                                                       NaN
# feats_suf_num                                                       NaN
# feats_suf_per                                                       NaN
# misc_MISC                                                           NaN
# feats_polar                                                         NaN
# biose_only                                                            O
# ner_type                                                           None
#
#                                                                       3  \
# id                                                                    4
# form                                                                  מ
# lemma                                                                 מ
# upostag                                                     PREPOSITION
# xpostag                                                     PREPOSITION
# head                                                                  3
# deprel                                                          prepmod
# deps                                                               None
# feats_gen                                                           NaN
# feats_num                                                           NaN
# misc_biose                                                            O
# misc_ner_escaped                                                   None
# misc_token_id                                                         4
# misc_token_str                                                  מתאילנד
# sent_id                                                               1
# global_sent_id                                                        1
# text_from_ud          עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# very_similar_sent_id                                                 {}
# duplicate_sent_id                                                    {}
# tokens                עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# set                                                                 dev
# feats_per                                                           NaN
# feats_HebBinyan                                                     NaN
# feats_tense                                                         NaN
# feats_suf_gen                                                       NaN
# feats_suf_num                                                       NaN
# feats_suf_per                                                       NaN
# misc_MISC                                                           NaN
# feats_polar                                                         NaN
# biose_only                                                            O
# ner_type                                                           None
#
#                                                                       4
# id                                                                    5
# form                                                             תאילנד
# lemma                                                            תאילנד
# upostag                                                             NNP
# xpostag                                                             NNP
# head                                                                  4
# deprel                                                             pobj
# deps                                                               None
# feats_gen                                                           NaN
# feats_num                                                           NaN
# misc_biose                                                        S-GPE
# misc_ner_escaped                                                    GPE
# misc_token_id                                                         4
# misc_token_str                                                  מתאילנד
# sent_id                                                               1
# global_sent_id                                                        1
# text_from_ud          עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# very_similar_sent_id                                                 {}
# duplicate_sent_id                                                    {}
# tokens                עשרות אנשים מגיעים מתאילנד לישראל כשהם נרשמים ...
# set                                                                 dev
# feats_per                                                           NaN
# feats_HebBinyan                                                     NaN
# feats_tense                                                         NaN
# feats_suf_gen                                                       NaN
# feats_suf_num                                                       NaN
# feats_suf_per                                                       NaN
# misc_MISC                                                           NaN
# feats_polar                                                         NaN
# biose_only                                                            S
# ner_type                                                            GPE

# %%
spdf.groupby('set').sent_id.nunique()
# Out:
# set
# dev       500
# test      706
# train    4937
# Name: sent_id, dtype: int64

# %%
spdf.dtypes
# Out:
# id                       int64
# form                    object
# lemma                   object
# upostag                 object
# xpostag                 object
# head                     int64
# deprel                  object
# deps                    object
# feats_gen               object
# feats_num               object
# misc_biose              object
# misc_ner_escaped        object
# misc_token_id            int64
# misc_token_str          object
# sent_id                  int64
# global_sent_id           int64
# text_from_ud            object
# very_similar_sent_id    object
# duplicate_sent_id       object
# tokens                  object
# set                     object
# feats_per               object
# feats_HebBinyan         object
# feats_tense             object
# feats_suf_gen           object
# feats_suf_num           object
# feats_suf_per           object
# misc_MISC               object
# feats_polar             object
# biose_only              object
# ner_type                object
# dtype: object

# %%
spdf.ner_type.value_counts()
# Out:
# ORG    6370
# PER    3937
# GPE    2248
# LOC     910
# FAC     503
# WOA     405
# EVE     209
# DUC      69
# ANG      43
# Name: ner_type, dtype: int64

# %%
(spdf
          .groupby(['sent_id', 'misc_token_id', 'misc_token_str']).apply(lambda x: ','.join(x.biose_only.tolist())))
# Out:
# sent_id  misc_token_id  misc_token_str
# 1        1              עשרות                 O
#          2              אנשים                 O
#          3              מגיעים                O
#          4              מתאילנד             O,S
#          5              לישראל              O,S
#          6              כשהם                O,O
#          7              נרשמים                O
#          8              כמתנדבים            O,O
#          9              ,                     O
#          10             אך                    O
#          11             למעשה                 O
#          12             משמשים                O
#          13             עובדים                O
#          14             שכירים                O
#          15             זולים                 O
#          16             .                     O
# 2        1              תופעה                 O
#          2              זו                    O
#          3              התבררה                O
#          4              אתמול                 O
#          5              בוועדת              O,B
#          6              העבודה              I,I
#          7              והרווחה           I,I,E
#          8              של                    O
#          9              הכנסת               B,E
#          10             ,                     O
#          11             שדנה                O,O
#          12             בנושא               O,O
#          13             העסקת                 O
#          14             עובדים                O
#                                           ...
# 6150     17             כלל                   O
#          18             למנה                O,O
#          19             זו                    O
#          20             .                     O
# 6151     1              כמו                   O
#          2              שיעולים               O
#          3              ,                     O
#          4              שלשול                 O
#          5              וחום                O,O
#          6              .                     O
# 6152     1              הוריהם                O
#          2              האמינו                O
#          3              ברפואה            O,O,O
#          4              המודרנית            O,O
#          5              והרופאים          O,O,O
#          6              המליצו                O
#          7              על                    O
#          8              פאראצטמול             S
#          9              ,                     O
#          10             תרופה                 O
#          11             דמוית                 O
#          12             אספירין               S
#          13             .                     O
# 6153     1              העצה                O,O
#          2              היתה                  O
#          3              טובה                  O
#          4              אך                    O
#          5              לא                    O
#          6              התרופה              O,O
#          7              .                     O
# Length: 114654, dtype: object

# %%
def get_token_biose(df):
    def _single_token_conversion(tok):
        all_bio = tok.biose_only.tolist()
        all_typ = set(tok.ner_type.dropna().tolist())
        if len(all_typ)>1:
            return 'O'
        if 'S' in all_bio:
            new_bio = 'S'
        elif 'B' in all_bio and 'E' in all_bio:
            new_bio = 'S'
        elif 'B' in all_bio:
            new_bio = 'B'
        elif 'E' in all_bio:
            new_bio = 'E'
        elif 'I' in all_bio:
            new_bio = 'I'
        else:
            return 'O'
        return new_bio+'-'+all_typ.pop()
    
    df = (spdf
          .groupby(['sent_id', 'misc_token_id', 'misc_token_str'])
          .apply(_single_token_conversion)
          .reset_index().rename(columns={0:'biose'})
         )
    return df
    
tok_ner = get_token_biose(spdf)

# %%
tok_ner.head()
# Out:
#    sent_id  misc_token_id misc_token_str  biose
# 0        1              1          עשרות      O
# 1        1              2          אנשים      O
# 2        1              3         מגיעים      O
# 3        1              4        מתאילנד  S-GPE
# 4        1              5         לישראל  S-GPE

# %%
tok_ner.head(30)
# Out:
#     sent_id  misc_token_id misc_token_str  biose
# 0         1              1          עשרות      O
# 1         1              2          אנשים      O
# 2         1              3         מגיעים      O
# 3         1              4        מתאילנד  S-GPE
# 4         1              5         לישראל  S-GPE
# 5         1              6           כשהם      O
# 6         1              7         נרשמים      O
# 7         1              8       כמתנדבים      O
# 8         1              9              ,      O
# 9         1             10             אך      O
# 10        1             11          למעשה      O
# 11        1             12         משמשים      O
# 12        1             13         עובדים      O
# 13        1             14         שכירים      O
# 14        1             15          זולים      O
# 15        1             16              .      O
# 16        2              1          תופעה      O
# 17        2              2             זו      O
# 18        2              3         התבררה      O
# 19        2              4          אתמול      O
# 20        2              5         בוועדת  B-ORG
# 21        2              6         העבודה  I-ORG
# 22        2              7        והרווחה  E-ORG
# 23        2              8             של      O
# 24        2              9          הכנסת  S-ORG
# 25        2             10              ,      O
# 26        2             11           שדנה      O
# 27        2             12          בנושא      O
# 28        2             13          העסקת      O
# 29        2             14         עובדים      O

# %%
spdf.columns[spdf.columns.str.startswith('feats')]
# Out:
# Index(['feats_gen', 'feats_num', 'feats_per', 'feats_HebBinyan', 'feats_tense',
#        'feats_suf_gen', 'feats_suf_num', 'feats_suf_per', 'feats_polar'],
#       dtype='object')

# %%
from tqdm import tqdm
# Create and register a new `tqdm` instance with `pandas`
# (can use tqdm_gui, optional kwargs, etc.)
tqdm.pandas()

# %%
#**{'upostag': ','.join(x.upostag.tolist())}
features = (spdf
            .groupby(['sent_id', 'misc_token_id', 'misc_token_str'])
            .progress_apply(lambda x: pd.Series({f: ','.join(x[f].fillna('').tolist()) for f in spdf.columns[spdf.columns.str.startswith('feats')]}
            ))
           )
# Out:
# 100%|██████████| 114654/114654 [07:48<00:00, 244.90it/s]

# %%
features.head(50)
# Out:
#                                      feats_gen feats_num feats_per  \
# sent_id misc_token_id misc_token_str
# 1       1             עשרות                  F         P
#         2             אנשים                  M         P
#         3             מגיעים                 M         P         A
#         4             מתאילנד                ,         ,         ,
#         5             לישראל                 ,         ,         ,
#         6             כשהם                  ,M        ,P        ,3
#         7             נרשמים                 M         P         A
#         8             כמתנדבים              ,M        ,P         ,
#         9             ,
#         10            אך
#         11            למעשה
#         12            משמשים                 M         P         A
#         13            עובדים                 M         P
#         14            שכירים                 M         P
#         15            זולים                  M         P
#         16            .
# 2       1             תופעה                  F         S
#         2             זו                     F         S         3
#         3             התבררה                 F         S         3
#         4             אתמול
#         5             בוועדת                ,F        ,S         ,
#         6             העבודה                ,F        ,S         ,
#         7             והרווחה              ,,F       ,,S        ,,
#         8             של
#         9             הכנסת                  ,         ,         ,
#         10            ,
#         11            שדנה                  ,F        ,S        ,3
#         12            בנושא                 ,M        ,S         ,
#         13            העסקת                  F         S
#         14            עובדים                 M         P
#         15            זרים                   M         P
#         16            .
# 3       1             יו"ר                   M         S
#         2             הוועדה                ,F        ,S         ,
#         3             ,
#         4             ח"כ                    M         S
#         5             אורה
#         6             נמיר
#         7             (
#         8             מערך
#         9             )
#         10            ,
#         11            טענה                   F         S         3
#         12            כי
#         13            "
#         14            מביאים                 M         P         A
#         15            עובדים                 M         P
#         16            זרים                   M         P
#         17            לישראל                 ,         ,         ,
#         18            על
#
#                                      feats_HebBinyan feats_tense  \
# sent_id misc_token_id misc_token_str
# 1       1             עשרות
#         2             אנשים
#         3             מגיעים                   HIFIL
#         4             מתאילנד                      ,           ,
#         5             לישראל                       ,           ,
#         6             כשהם                         ,           ,
#         7             נרשמים                   NIFAL
#         8             כמתנדבים                     ,           ,
#         9             ,
#         10            אך
#         11            למעשה
#         12            משמשים                    PIEL
#         13            עובדים
#         14            שכירים
#         15            זולים
#         16            .
# 2       1             תופעה
#         2             זו
#         3             התבררה                 HITPAEL        PAST
#         4             אתמול
#         5             בוועדת                       ,           ,
#         6             העבודה                       ,           ,
#         7             והרווחה                     ,,          ,,
#         8             של
#         9             הכנסת                        ,           ,
#         10            ,
#         11            שדנה                     ,PAAL       ,PAST
#         12            בנושא                        ,           ,
#         13            העסקת
#         14            עובדים
#         15            זרים
#         16            .
# 3       1             יו"ר
#         2             הוועדה                       ,           ,
#         3             ,
#         4             ח"כ
#         5             אורה
#         6             נמיר
#         7             (
#         8             מערך
#         9             )
#         10            ,
#         11            טענה                      PAAL        PAST
#         12            כי
#         13            "
#         14            מביאים                   HIFIL
#         15            עובדים
#         16            זרים
#         17            לישראל                       ,           ,
#         18            על
#
#                                      feats_suf_gen feats_suf_num  \
# sent_id misc_token_id misc_token_str
# 1       1             עשרות
#         2             אנשים
#         3             מגיעים
#         4             מתאילנד                    ,             ,
#         5             לישראל                     ,             ,
#         6             כשהם                       ,             ,
#         7             נרשמים
#         8             כמתנדבים                   ,             ,
#         9             ,
#         10            אך
#         11            למעשה
#         12            משמשים
#         13            עובדים
#         14            שכירים
#         15            זולים
#         16            .
# 2       1             תופעה
#         2             זו
#         3             התבררה
#         4             אתמול
#         5             בוועדת                     ,             ,
#         6             העבודה                     ,             ,
#         7             והרווחה                   ,,            ,,
#         8             של
#         9             הכנסת                      ,             ,
#         10            ,
#         11            שדנה                       ,             ,
#         12            בנושא                      ,             ,
#         13            העסקת
#         14            עובדים
#         15            זרים
#         16            .
# 3       1             יו"ר
#         2             הוועדה                     ,             ,
#         3             ,
#         4             ח"כ
#         5             אורה
#         6             נמיר
#         7             (
#         8             מערך
#         9             )
#         10            ,
#         11            טענה
#         12            כי
#         13            "
#         14            מביאים
#         15            עובדים
#         16            זרים
#         17            לישראל                     ,             ,
#         18            על
#
#                                      feats_suf_per feats_polar
# sent_id misc_token_id misc_token_str
# 1       1             עשרות
#         2             אנשים
#         3             מגיעים
#         4             מתאילנד                    ,           ,
#         5             לישראל                     ,           ,
#         6             כשהם                       ,           ,
#         7             נרשמים
#         8             כמתנדבים                   ,           ,
#         9             ,
#         10            אך
#         11            למעשה
#         12            משמשים
#         13            עובדים
#         14            שכירים
#         15            זולים
#         16            .
# 2       1             תופעה
#         2             זו
#         3             התבררה
#         4             אתמול
#         5             בוועדת                     ,           ,
#         6             העבודה                     ,           ,
#         7             והרווחה                   ,,          ,,
#         8             של
#         9             הכנסת                      ,           ,
#         10            ,
#         11            שדנה                       ,           ,
#         12            בנושא                      ,           ,
#         13            העסקת
#         14            עובדים
#         15            זרים
#         16            .
# 3       1             יו"ר
#         2             הוועדה                     ,           ,
#         3             ,
#         4             ח"כ
#         5             אורה
#         6             נמיר
#         7             (
#         8             מערך
#         9             )
#         10            ,
#         11            טענה
#         12            כי
#         13            "
#         14            מביאים
#         15            עובדים
#         16            זרים
#         17            לישראל                     ,           ,
#         18            על

# %%
upos_form_lemma_deprel = (spdf
            .groupby(['sent_id', 'misc_token_id', 'misc_token_str'])
            .progress_apply(lambda x: pd.Series({'upostag': ','.join(x.upostag.tolist()),
                                                 'form': ','.join(x.form.tolist()),
                                                 'lemma': ','.join(x.lemma.tolist()),
                                                 'deprel': ','.join(x.deprel.tolist()),}
            ))
           )
# Out:
# 100%|██████████| 114654/114654 [01:24<00:00, 1350.86it/s]

# %%
tokens_ner_with_upos_feats = pd.concat([tok_ner.set_index(['sent_id', 'misc_token_id', 'misc_token_str']), upos_form_lemma_deprel, features], axis=1)
tokens_ner_with_upos_feats = (tokens_ner_with_upos_feats
                              .reset_index()
                              .set_index(['sent_id', 'misc_token_id', 'misc_token_str'])
                              .sort_index()
                              .assign(set = lambda x: x.index.get_level_values('sent_id').map(spdf[['sent_id', 'set']].drop_duplicates().set_index('sent_id')['set']))
                             )
tokens_ner_with_upos_feats.head()
# Out:
#                                       biose          upostag      form  \
# sent_id misc_token_id misc_token_str
# 1       1             עשרות               O              CDT     עשרות
#         2             אנשים               O               NN     אנשים
#         3             מגיעים              O               BN    מגיעים
#         4             מתאילנד         S-GPE  PREPOSITION,NNP  מ,תאילנד
#         5             לישראל          S-GPE  PREPOSITION,NNP   ל,ישראל
#
#                                          lemma        deprel feats_gen  \
# sent_id misc_token_id misc_token_str
# 1       1             עשרות                עשר           num         F
#         2             אנשים                איש          subj         M
#         3             מגיעים              הגיע          ROOT         M
#         4             מתאילנד         מ,תאילנד  prepmod,pobj         ,
#         5             לישראל           ל,ישראל  prepmod,pobj         ,
#
#                                      feats_num feats_per feats_HebBinyan  \
# sent_id misc_token_id misc_token_str
# 1       1             עשרות                  P
#         2             אנשים                  P
#         3             מגיעים                 P         A           HIFIL
#         4             מתאילנד                ,         ,               ,
#         5             לישראל                 ,         ,               ,
#
#                                      feats_tense feats_suf_gen feats_suf_num  \
# sent_id misc_token_id misc_token_str
# 1       1             עשרות
#         2             אנשים
#         3             מגיעים
#         4             מתאילנד                  ,             ,             ,
#         5             לישראל                   ,             ,             ,
#
#                                      feats_suf_per feats_polar  set
# sent_id misc_token_id misc_token_str
# 1       1             עשרות                                     dev
#         2             אנשים                                     dev
#         3             מגיעים                                    dev
#         4             מתאילנד                    ,           ,  dev
#         5             לישראל                     ,           ,  dev

# %%
tokens_ner_with_upos_feats.deprel.value_counts()
# Out:
# punct                      17683
# prepmod,pobj                8542
# gobj                        6106
# subj                        5416
# conj                        5159
# ROOT                        5037
# prepmod                     4245
# def,gobj                    4235
# amod                        3912
# advmod                      3658
# pobj                        3600
# nn                          2873
# def,amod                    2859
# obj                         2827
# prepmod,def,pobj            2586
# def,subj                    1935
# rcmod,relcomp               1856
# xcomp                       1664
# acc                         1604
# posspmod                    1432
# def,pobj                    1242
# ccomp                       1182
# hd                          1128
# comp                        1100
# neg                         1053
# det                         1024
# dep                          915
# cop                          821
# appos                        807
# relcomp                      792
#                            ...
# ccomp,conj,acc,obj             1
# cc,punct,hd                    1
# ccomp,mod                      1
# obj,obj                        1
# cc,def,amod                    1
# comp,ccomp,def,pobj            1
# mwe,conj,def,pobj              1
# quantmod,number                1
# prepomod,pobj                  1
# ccomp,punct,def,subj           1
# appos,mwe                      1
# ROOT,prepmod,hd                1
# nn,number                      1
# pobj,nn                        1
# xcomp,dep,def,pobj             1
# def,number                     1
# prepmod,punct,pobj,pobj        1
# comp,ROOT,pobj                 1
# rcmod,punct,subj               1
# pobj,def,dep                   1
# ccomp,parataxis                1
# def,rcmod                      1
# nn,dep,pobj                    1
# obj,conj,pobj                  1
# pobj,parataxis,def,pobj        1
# cc,advcl                       1
# gobj,number                    1
# amod,dep                       1
# def,vmod                       1
# comp,dep,pobj                  1
# Name: deprel, Length: 740, dtype: int64

# %%
tn = tokens_ner_with_upos_feats

# %%
import os
yap_output_dir = 'new_yap_outputs'

os.mkdir(yap_output_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-20-7606f5fbbd93> in <module>
#       2 yap_output_dir = 'new_yap_outputs'
#       3
# ----> 4 os.mkdir(yap_output_dir)
#
# FileExistsError: [Errno 17] File exists: 'new_yap_outputs'

# %%
def get_token_output(s):
    return '\n'.join(s.misc_token_str.tolist())+'\n\n'

def write_tokens_to_file(tok_df, corp_set, output_path):
    with open(output_path, 'w') as of:
        for sent in tok_df[tok_df.set==corp_set].reset_index().groupby('sent_id').apply(get_token_output):
            of.write(sent)


write_tokens_to_file(tn, 'dev', os.path.join(yap_output_dir, 'spmrl_dev_tokens.txt'))
write_tokens_to_file(tn, 'test', os.path.join(yap_output_dir, 'spmrl_test_tokens.txt'))
write_tokens_to_file(tn, 'train', os.path.join(yap_output_dir, 'spmrl_train_tokens.txt'))

# %%
yap_path = '/home/dan/yapproj/src/yap/yap'

# %%
# !export GOPATH=/home/dan/yapproj

# %%
# !{yap_path}
# Out:
# /home/dan/yapproj/src/yap/yap - invoke yap as a standalone app or as an api server
#
# Commands:
#
#     api         start api server
#     dep         runs dependency training/parsing
#     hebma       run lexicon-based morphological analyzer on raw input
#     joint       runs joint morpho-syntactic training and parsing
#     ma          run data-driven morphological analyzer on raw input
#     md          runs standalone morphological disambiguation training and parsing
#
# Use "/home/dan/yapproj/src/yap/yap help <command>" for more information about a command.

# %%
# !{yap_path} hebma -raw new_yap_outputs/spmrl_dev_tokens.txt -out new_yap_outputs/spmrl_dev.lattices
# Out:
# 2019/07/16 15:36:33.927689 GOMAXPROCS:	40
# 2019/07/16 15:36:33.927743
# 2019/07/16 15:36:33.927787 Configuration
# 2019/07/16 15:36:33.927795 Heb Lexicon:		/home/dan/yapproj/src/yap/data/bgulex/bgupreflex_withdef.utf8.hr
# 2019/07/16 15:36:33.927800 Heb Prefix:		/home/dan/yapproj/src/yap/data/bgulex/bgulex.utf8.hr
# 2019/07/16 15:36:33.927803 OOV Strategy:	Const:NNP
# 2019/07/16 15:36:33.927807 xliter8 out:		false
# 2019/07/16 15:36:33.927810
# 2019/07/16 15:36:33.927813 Raw Input:		new_yap_outputs/spmrl_dev_tokens.txt
# 2019/07/16 15:36:33.927817 Output:		new_yap_outputs/spmrl_dev.lattices
# 2019/07/16 15:36:33.927821
# 2019/07/16 15:36:33.927825 Reading Morphological Analyzer BGU Prefixes
# 2019/07/16 15:36:33.928370 Found 102 tokens in lexicon file: /home/dan/yapproj/src/yap/data/bgulex/bgupreflex_withdef.utf8.hr
# 2019/07/16 15:36:33.928398 Loaded 101 prefixes from lexicon
# 2019/07/16 15:36:33.928401 Reading Morphological Analyzer BGU Lexicon
# 2019/07/16 15:36:37.798498 Found 514852 tokens in lexicon file: /home/dan/yapproj/src/yap/data/bgulex/bgulex.utf8.hr
# 2019/07/16 15:36:37.994859 Loaded 514852 tokens from lexicon
# 2019/07/16 15:36:37.994878
# 2019/07/16 15:36:37.996024 Running Hebrew Morphological Analysis
# 2019/07/16 15:36:38.314642 Analyzed 8531 occurences of 3995 unique tokens
# 2019/07/16 15:36:38.314661 Encountered 143 occurences of 96 unknown tokens

# %%
# !{yap_path} joint -in new_yap_outputs/spmrl_dev.lattices -os new_yap_outputs/spmrl_dev_seg.conll -om new_yap_outputs/spmrl_dev_map.conll -oc new_yap_outputs/spmrl_dev_dep.conll
# Out:
# 2019/07/16 15:36:38.514859 GOMAXPROCS:	40
# 2019/07/16 15:36:38.514912
# 2019/07/16 15:36:38.514968 *** CONFIGURATION ***
# 2019/07/16 15:36:38.514978 Beam:             	Standard Beam [Not Aligned & Not Averaged]
# 2019/07/16 15:36:38.515001 Transition System:	Joint Morpho-Syntactic [MD:Morpheme-Based Morphological Disambiguator, ArcSys:Arc Zeager (zpar acl '11) [a.k.a. ArcZEager]] - Strategy: ArcGreedy
# 2019/07/16 15:36:38.515012 Transition Oracle:	Joint Morpho-Syntactic - Strategy: ArcGreedy
# 2019/07/16 15:36:38.515018 Iterations:		1
# 2019/07/16 15:36:38.515022 Beam Size:		64
# 2019/07/16 15:36:38.515026 Beam Concurrent:	true
# 2019/07/16 15:36:38.515029 Parameter Func:	Funcs_Main_POS_Both_Prop
# 2019/07/16 15:36:38.515033 Use Lemmas:		false
# 2019/07/16 15:36:38.515037 Use POP:		true
# 2019/07/16 15:36:38.515040 Infuse Gold Dev:	false
# 2019/07/16 15:36:38.515044 Limit (thousands):	0
# 2019/07/16 15:36:38.515047 Use CoNLL-U:		false
# 2019/07/16 15:36:38.515051
# 2019/07/16 15:36:38.515054 Features File:	jointzeager.yaml
# 2019/07/16 15:36:38.515067 Labels File:		hebtb.labels.conf
# 2019/07/16 15:36:38.515081
# 2019/07/16 15:36:38.515085 Data
# 2019/07/16 15:36:38.515089 Test file  (ambig.  lattice):	new_yap_outputs/spmrl_dev.lattices
# 2019/07/16 15:36:38.515097 Out (disamb.) file:			new_yap_outputs/spmrl_dev_dep.conll
# 2019/07/16 15:36:38.515102 Out (segmt.) file:			new_yap_outputs/spmrl_dev_seg.conll
# 2019/07/16 15:36:38.515109 Out (mapping.) file:			new_yap_outputs/spmrl_dev_map.conll
# 2019/07/16 15:36:38.515166
# 2019/07/16 15:36:38.515175 Setup enumerations
# 2019/07/16 15:36:38.515266 ETrans Len is 96
# 2019/07/16 15:36:38.515459
# 2019/07/16 15:36:38.515464 Loading features
# 2019/07/16 15:36:38.516089 Loading MD transition dependent feature group Past Morphemes Unigram
# 2019/07/16 15:36:38.516132 Loading MD transition dependent feature group Past Morphemes Bigram
# 2019/07/16 15:36:38.516194 Loading MD transition dependent feature group Past Morphemes Trigram
# 2019/07/16 15:36:38.516239 Loading MD transition dependent feature group Next Morphemes Unigram
# 2019/07/16 15:36:38.516256 Loading MD transition dependent feature group Next Morphemes Bigram
# 2019/07/16 15:36:38.516303 Loading POP transition dependent feature group POP
# 2019/07/16 15:36:38.516322 Loading Lexical transition dependent feature group Lexical
# 2019/07/16 15:36:38.516349 Loading Arc transition dependent feature group ZhangNivre11
# 2019/07/16 15:36:38.516625
# 2019/07/16 15:36:38.516638 Using Family HEBTB of Main_POS_Types [ [ADVERB BN BNT CD CDT JJ JJT NN NNP NNT RB VB] ]
# 2019/07/16 15:36:38.516643
# 2019/07/16 15:36:38.516647 Found model file /home/dan/yapproj/src/yap/data/joint_arc_zeager_model_temp_i33.b64  ... loading model
# 2019/07/16 15:37:06.011872 Loaded model
# 2019/07/16 15:37:06.011900
# 2019/07/16 15:37:06.011904 *** PARSING ***
# 2019/07/16 15:37:06.011928 Parsing test
# 2019/07/16 15:37:06.011939 Reading ambiguous lattices from new_yap_outputs/spmrl_dev.lattices
# 2019/07/16 15:37:06.191629 Read 500 ambiguous lattices from new_yap_outputs/spmrl_dev.lattices
# 2019/07/16 15:37:06.191645 Converting lattice format to internal structure
# 2019/07/16 15:37:07.047729 Parsing instance 0
# 2019/07/16 15:37:07.168706 Parsing instance 1
# 2019/07/16 15:37:07.296775 Parsing instance 2
# 2019/07/16 15:37:07.482655 Parsing instance 3
# 2019/07/16 15:37:07.686699 Parsing instance 4
# 2019/07/16 15:37:07.910159 Parsing instance 5
# 2019/07/16 15:37:08.160700 Parsing instance 6
# 2019/07/16 15:37:08.341913 Parsing instance 7
# 2019/07/16 15:37:08.722268 Parsing instance 8
# 2019/07/16 15:37:08.815154 Parsing instance 9
# 2019/07/16 15:37:09.060442 Parsing instance 10
# 2019/07/16 15:37:09.203877 Parsing instance 11
# 2019/07/16 15:37:09.301538 Parsing instance 12
# 2019/07/16 15:37:09.547895 Parsing instance 13
# 2019/07/16 15:37:09.952015 Parsing instance 14
# 2019/07/16 15:37:10.062268 Parsing instance 15
# 2019/07/16 15:37:10.160955 Parsing instance 16
# 2019/07/16 15:37:10.247887 Parsing instance 17
# 2019/07/16 15:37:10.342866 Parsing instance 18
# 2019/07/16 15:37:10.515074 Parsing instance 19
# 2019/07/16 15:37:10.640173 Parsing instance 20
# 2019/07/16 15:37:10.723780 Parsing instance 21
# 2019/07/16 15:37:10.817638 Parsing instance 22
# 2019/07/16 15:37:11.813544 Parsing instance 23
# 2019/07/16 15:37:11.992045 Parsing instance 24
# 2019/07/16 15:37:12.335699 Parsing instance 25
# 2019/07/16 15:38:32.098456 Parsing instance 486
# 2019/07/16 15:38:32.239323 Parsing instance 487
# 2019/07/16 15:38:32.365683 Parsing instance 488
# 2019/07/16 15:38:32.489920 Parsing instance 489
# 2019/07/16 15:38:32.507912 Parsing instance 490
# 2019/07/16 15:38:32.796117 Parsing instance 491
# 2019/07/16 15:38:33.217162 Parsing instance 492
# 2019/07/16 15:38:33.683819 Parsing instance 493
# 2019/07/16 15:38:33.764381 Parsing instance 494
# 2019/07/16 15:38:33.784608 Parsing instance 495
# 2019/07/16 15:38:33.870116 Parsing instance 496
# 2019/07/16 15:38:33.988041 Parsing instance 497
# 2019/07/16 15:38:34.046098 Parsing instance 498
# 2019/07/16 15:38:34.061693 Parsing instance 499
# 2019/07/16 15:38:34.079599 PARSE Total Time: 1m27.031868169s
# 2019/07/16 15:38:34.079620 Converting 500 to conll
# 2019/07/16 15:38:34.079626 Writing to output file
# 2019/07/16 15:38:34.122568 Wrote 500 in conll format to new_yap_outputs/spmrl_dev_dep.conll
# 2019/07/16 15:38:34.122580 Writing to segmentation file
# 2019/07/16 15:38:34.175316 Wrote 500 in segmentation format to new_yap_outputs/spmrl_dev_seg.conll
# 2019/07/16 15:38:34.175324 Writing to mapping file
# 2019/07/16 15:38:34.391078 Wrote 500 in mapping format to new_yap_outputs/spmrl_dev_map.conll
# 2019/07/16 15:38:34.391085 Writing to gold segmentation file

# %%
# !{yap_path} hebma -raw new_yap_outputs/spmrl_test_tokens.txt -out new_yap_outputs/spmrl_test.lattices
# Out:
# 2019/07/16 15:38:34.816859 GOMAXPROCS:	40
# 2019/07/16 15:38:34.816936
# 2019/07/16 15:38:34.816994 Configuration
# 2019/07/16 15:38:34.817002 Heb Lexicon:		/home/dan/yapproj/src/yap/data/bgulex/bgupreflex_withdef.utf8.hr
# 2019/07/16 15:38:34.817010 Heb Prefix:		/home/dan/yapproj/src/yap/data/bgulex/bgulex.utf8.hr
# 2019/07/16 15:38:34.817017 OOV Strategy:	Const:NNP
# 2019/07/16 15:38:34.817023 xliter8 out:		false
# 2019/07/16 15:38:34.817029
# 2019/07/16 15:38:34.817035 Raw Input:		new_yap_outputs/spmrl_test_tokens.txt
# 2019/07/16 15:38:34.817042 Output:		new_yap_outputs/spmrl_test.lattices
# 2019/07/16 15:38:34.817048
# 2019/07/16 15:38:34.817054 Reading Morphological Analyzer BGU Prefixes
# 2019/07/16 15:38:34.818071 Found 102 tokens in lexicon file: /home/dan/yapproj/src/yap/data/bgulex/bgupreflex_withdef.utf8.hr
# 2019/07/16 15:38:34.818128 Loaded 101 prefixes from lexicon
# 2019/07/16 15:38:34.818137 Reading Morphological Analyzer BGU Lexicon
# 2019/07/16 15:38:39.103918 Found 514852 tokens in lexicon file: /home/dan/yapproj/src/yap/data/bgulex/bgulex.utf8.hr
# 2019/07/16 15:38:39.290328 Loaded 514852 tokens from lexicon
# 2019/07/16 15:38:39.290342
# 2019/07/16 15:38:39.291989 Running Hebrew Morphological Analysis
# 2019/07/16 15:38:39.774402 Analyzed 12619 occurences of 5487 unique tokens
# 2019/07/16 15:38:39.774415 Encountered 525 occurences of 412 unknown tokens

# %%
# !{yap_path} joint -in new_yap_outputs/spmrl_test.lattices -os new_yap_outputs/spmrl_test_seg.conll -om new_yap_outputs/spmrl_test_map.conll -oc new_yap_outputs/spmrl_test_dep.conll
# Out:
# 2019/07/16 15:38:39.994705 GOMAXPROCS:	40
# 2019/07/16 15:38:39.994751
# 2019/07/16 15:38:39.994776 *** CONFIGURATION ***
# 2019/07/16 15:38:39.994784 Beam:             	Standard Beam [Not Aligned & Not Averaged]
# 2019/07/16 15:38:39.994799 Transition System:	Joint Morpho-Syntactic [MD:Morpheme-Based Morphological Disambiguator, ArcSys:Arc Zeager (zpar acl '11) [a.k.a. ArcZEager]] - Strategy: ArcGreedy
# 2019/07/16 15:38:39.994806 Transition Oracle:	Joint Morpho-Syntactic - Strategy: ArcGreedy
# 2019/07/16 15:38:39.994811 Iterations:		1
# 2019/07/16 15:38:39.994817 Beam Size:		64
# 2019/07/16 15:38:39.994822 Beam Concurrent:	true
# 2019/07/16 15:38:39.994827 Parameter Func:	Funcs_Main_POS_Both_Prop
# 2019/07/16 15:38:39.994832 Use Lemmas:		false
# 2019/07/16 15:38:39.994838 Use POP:		true
# 2019/07/16 15:38:39.994843 Infuse Gold Dev:	false
# 2019/07/16 15:38:39.994848 Limit (thousands):	0
# 2019/07/16 15:38:39.994852 Use CoNLL-U:		false
# 2019/07/16 15:38:39.994857
# 2019/07/16 15:38:39.994861 Features File:	jointzeager.yaml
# 2019/07/16 15:38:39.994879 Labels File:		hebtb.labels.conf
# 2019/07/16 15:38:39.994893
# 2019/07/16 15:38:39.994898 Data
# 2019/07/16 15:38:39.994903 Test file  (ambig.  lattice):	new_yap_outputs/spmrl_test.lattices
# 2019/07/16 15:38:39.994911 Out (disamb.) file:			new_yap_outputs/spmrl_test_dep.conll
# 2019/07/16 15:38:39.994916 Out (segmt.) file:			new_yap_outputs/spmrl_test_seg.conll
# 2019/07/16 15:38:39.994922 Out (mapping.) file:			new_yap_outputs/spmrl_test_map.conll
# 2019/07/16 15:38:39.994978
# 2019/07/16 15:38:39.994984 Setup enumerations
# 2019/07/16 15:38:39.995089 ETrans Len is 96
# 2019/07/16 15:38:39.995279
# 2019/07/16 15:38:39.995284 Loading features
# 2019/07/16 15:38:39.995840 Loading MD transition dependent feature group Past Morphemes Unigram
# 2019/07/16 15:38:39.995883 Loading MD transition dependent feature group Past Morphemes Bigram
# 2019/07/16 15:38:39.995971 Loading MD transition dependent feature group Past Morphemes Trigram
# 2019/07/16 15:38:39.996044 Loading MD transition dependent feature group Next Morphemes Unigram
# 2019/07/16 15:38:39.996065 Loading MD transition dependent feature group Next Morphemes Bigram
# 2019/07/16 15:38:39.996161 Loading POP transition dependent feature group POP
# 2019/07/16 15:38:39.996184 Loading Lexical transition dependent feature group Lexical
# 2019/07/16 15:38:39.996205 Loading Arc transition dependent feature group ZhangNivre11
# 2019/07/16 15:38:39.996595
# 2019/07/16 15:38:39.996612 Using Family HEBTB of Main_POS_Types [ [ADVERB BN BNT CD CDT JJ JJT NN NNP NNT RB VB] ]
# 2019/07/16 15:38:39.996618
# 2019/07/16 15:38:39.996622 Found model file /home/dan/yapproj/src/yap/data/joint_arc_zeager_model_temp_i33.b64  ... loading model
# 2019/07/16 15:39:06.440475 Loaded model
# 2019/07/16 15:39:06.440525
# 2019/07/16 15:39:06.440529 *** PARSING ***
# 2019/07/16 15:39:06.440532 Parsing test
# 2019/07/16 15:39:06.440605 Reading ambiguous lattices from new_yap_outputs/spmrl_test.lattices
# 2019/07/16 15:39:06.664424 Read 706 ambiguous lattices from new_yap_outputs/spmrl_test.lattices
# 2019/07/16 15:39:06.664439 Converting lattice format to internal structure
# 2019/07/16 15:39:07.903969 Parsing instance 0
# 2019/07/16 15:39:08.167188 Parsing instance 1
# 2019/07/16 15:39:08.298260 Parsing instance 2
# 2019/07/16 15:39:08.384021 Parsing instance 3
# 2019/07/16 15:39:08.504256 Parsing instance 4
# 2019/07/16 15:39:08.580189 Parsing instance 5
# 2019/07/16 15:39:08.711405 Parsing instance 6
# 2019/07/16 15:39:08.835391 Parsing instance 7
# 2019/07/16 15:39:08.898217 Parsing instance 8
# 2019/07/16 15:39:08.919719 Parsing instance 9
# 2019/07/16 15:39:08.983574 Parsing instance 10
# 2019/07/16 15:39:09.093710 Parsing instance 11
# 2019/07/16 15:39:09.439522 Parsing instance 12
# 2019/07/16 15:39:09.632938 Parsing instance 13
# 2019/07/16 15:39:09.692873 Parsing instance 14
# 2019/07/16 15:39:09.760828 Parsing instance 15
# 2019/07/16 15:39:09.850272 Parsing instance 16
# 2019/07/16 15:39:10.683859 Parsing instance 17
# 2019/07/16 15:39:10.865184 Parsing instance 18
# 2019/07/16 15:39:11.016928 Parsing instance 19
# 2019/07/16 15:39:11.458155 Parsing instance 20
# 2019/07/16 15:39:11.479138 Parsing instance 21
# 2019/07/16 15:39:11.507762 Parsing instance 22
# 2019/07/16 15:39:11.540575 Parsing instance 23
# 2019/07/16 15:39:11.818703 Parsing instance 24
# 2019/07/16 15:39:11.938518 Parsing instance 25
# 2019/07/16 15:39:12.000882 Parsing instance 26
# 2019/07/16 15:39:12.078405 Parsing instance 27
# 2019/07/16 15:39:12.269197 Parsing instance 28
# 2019/07/16 15:39:12.366691 Parsing instance 29
# 2019/07/16 15:39:12.436766 Parsing instance 30
# 2019/07/16 15:39:12.508184 Parsing instance 31
# 2019/07/16 15:39:12.570143 Parsing instance 32
# 2019/07/16 15:39:13.038837 Parsing instance 33
# 2019/07/16 15:39:13.136818 Parsing instance 34
# 2019/07/16 15:39:13.326559 Parsing instance 35
# 2019/07/16 15:39:13.581645 Parsing instance 36
# 2019/07/16 15:39:13.637403 Parsing instance 37
# 2019/07/16 15:39:13.755244 Parsing instance 38
# 2019/07/16 15:39:13.768927 Parsing instance 39
# 2019/07/16 15:39:13.954032 Parsing instance 40
# 2019/07/16 15:39:14.264727 Parsing instance 41
# 2019/07/16 15:39:14.318358 Parsing instance 42
# 2019/07/16 15:39:14.499472 Parsing instance 43
# 2019/07/16 15:39:14.697684 Parsing instance 44
# 2019/07/16 15:41:02.617897 Parsing instance 621
# 2019/07/16 15:41:03.086111 Parsing instance 622
# 2019/07/16 15:41:03.194087 Parsing instance 623
# 2019/07/16 15:41:03.250995 Parsing instance 624
# 2019/07/16 15:41:03.416174 Parsing instance 625
# 2019/07/16 15:41:03.477071 Parsing instance 626
# 2019/07/16 15:41:03.565558 Parsing instance 627
# 2019/07/16 15:41:03.652460 Parsing instance 628
# 2019/07/16 15:41:03.956709 Parsing instance 629
# 2019/07/16 15:41:04.483678 Parsing instance 630
# 2019/07/16 15:41:04.680028 Parsing instance 631
# 2019/07/16 15:41:04.710510 Parsing instance 632
# 2019/07/16 15:41:04.895645 Parsing instance 633
# 2019/07/16 15:41:05.196052 Parsing instance 634
# 2019/07/16 15:41:05.477840 Parsing instance 635
# 2019/07/16 15:41:05.541013 Parsing instance 636
# 2019/07/16 15:41:05.894665 Parsing instance 637
# 2019/07/16 15:41:05.942320 Parsing instance 638
# 2019/07/16 15:41:06.065166 Parsing instance 639
# 2019/07/16 15:41:06.113792 Parsing instance 640
# 2019/07/16 15:41:06.190398 Parsing instance 641
# 2019/07/16 15:41:06.358894 Parsing instance 642
# 2019/07/16 15:41:06.547673 Parsing instance 643
# 2019/07/16 15:41:06.940094 Parsing instance 644
# 2019/07/16 15:41:07.020825 Parsing instance 645
# 2019/07/16 15:41:07.146553 Parsing instance 646
# 2019/07/16 15:41:07.303979 Parsing instance 647
# 2019/07/16 15:41:07.366620 Parsing instance 648
# 2019/07/16 15:41:07.529184 Parsing instance 649
# 2019/07/16 15:41:07.736700 Parsing instance 650
# 2019/07/16 15:41:07.753659 Parsing instance 651
# 2019/07/16 15:41:08.093312 Parsing instance 652
# 2019/07/16 15:41:08.367830 Parsing instance 653
# 2019/07/16 15:41:08.543047 Parsing instance 654
# 2019/07/16 15:41:08.575437 Parsing instance 655
# 2019/07/16 15:41:08.639105 Parsing instance 656
# 2019/07/16 15:41:08.782515 Parsing instance 657
# 2019/07/16 15:41:09.182394 Parsing instance 658
# 2019/07/16 15:41:09.678560 Parsing instance 659
# 2019/07/16 15:41:09.789039 Parsing instance 660
# 2019/07/16 15:41:10.008065 Parsing instance 661
# 2019/07/16 15:41:10.424404 Parsing instance 662
# 2019/07/16 15:41:10.524491 Parsing instance 663
# 2019/07/16 15:41:10.821787 Parsing instance 664
# 2019/07/16 15:41:10.960911 Parsing instance 665
# 2019/07/16 15:41:11.034361 Parsing instance 666
# 2019/07/16 15:41:11.182580 Parsing instance 667
# 2019/07/16 15:41:11.311725 Parsing instance 668
# 2019/07/16 15:41:11.475698 Parsing instance 669
# 2019/07/16 15:41:11.800878 Parsing instance 670
# 2019/07/16 15:41:11.924812 Parsing instance 671
# 2019/07/16 15:41:12.067527 Parsing instance 672
# 2019/07/16 15:41:12.196945 Parsing instance 673
# 2019/07/16 15:41:12.239693 Parsing instance 674
# 2019/07/16 15:41:12.318908 Parsing instance 675
# 2019/07/16 15:41:12.388000 Parsing instance 676
# 2019/07/16 15:41:12.425433 Parsing instance 677
# 2019/07/16 15:41:12.592989 Parsing instance 678
# 2019/07/16 15:41:12.638444 Parsing instance 679
# 2019/07/16 15:41:12.749129 Parsing instance 680
# 2019/07/16 15:41:12.810780 Parsing instance 681
# 2019/07/16 15:41:12.937335 Parsing instance 682
# 2019/07/16 15:41:13.363171 Parsing instance 683
# 2019/07/16 15:41:13.437744 Parsing instance 684
# 2019/07/16 15:41:13.501683 Parsing instance 685
# 2019/07/16 15:41:13.639339 Parsing instance 686
# 2019/07/16 15:41:13.675125 Parsing instance 687
# 2019/07/16 15:41:13.791991 Parsing instance 688
# 2019/07/16 15:41:14.503517 Parsing instance 689
# 2019/07/16 15:41:14.862406 Parsing instance 690
# 2019/07/16 15:41:15.029052 Parsing instance 691
# 2019/07/16 15:41:15.151337 Parsing instance 692
# 2019/07/16 15:41:15.531821 Parsing instance 693
# 2019/07/16 15:41:15.652855 Parsing instance 694
# 2019/07/16 15:41:15.852492 Parsing instance 695
# 2019/07/16 15:41:15.984946 Parsing instance 696
# 2019/07/16 15:41:16.262022 Parsing instance 697
# 2019/07/16 15:41:16.465245 Parsing instance 698
# 2019/07/16 15:41:16.601121 Parsing instance 699
# 2019/07/16 15:41:17.113785 Parsing instance 700
# 2019/07/16 15:41:17.268283 Parsing instance 701
# 2019/07/16 15:41:17.416211 Parsing instance 702
# 2019/07/16 15:41:17.560142 Parsing instance 703
# 2019/07/16 15:41:17.597846 Parsing instance 704
# 2019/07/16 15:41:17.686654 Parsing instance 705
# 2019/07/16 15:41:17.732977 PARSE Total Time: 2m9.829014985s
# 2019/07/16 15:41:17.732998 Converting 706 to conll
# 2019/07/16 15:41:17.733002 Writing to output file
# 2019/07/16 15:41:17.793830 Wrote 706 in conll format to new_yap_outputs/spmrl_test_dep.conll
# 2019/07/16 15:41:17.793842 Writing to segmentation file
# 2019/07/16 15:41:17.857347 Wrote 706 in segmentation format to new_yap_outputs/spmrl_test_seg.conll
# 2019/07/16 15:41:17.857355 Writing to mapping file
# 2019/07/16 15:41:18.134385 Wrote 706 in mapping format to new_yap_outputs/spmrl_test_map.conll
# 2019/07/16 15:41:18.134399 Writing to gold segmentation file

# %%
tn[tn.set=='test'].reset_index().sent_id.unique()
# Out:
# array([5439, 5440, 5441, 5442, 5443, 5447, 5452, 5454, 5455, 5456, 5457,
#        5458, 5460, 5461, 5462, 5463, 5464, 5465, 5466, 5467, 5468, 5469,
#        5470, 5471, 5472, 5473, 5474, 5475, 5476, 5477, 5478, 5479, 5480,
#        5481, 5482, 5483, 5484, 5485, 5486, 5487, 5488, 5489, 5490, 5491,
#        5492, 5493, 5494, 5495, 5496, 5497, 5498, 5499, 5500, 5501, 5502,
#        5503, 5504, 5505, 5506, 5507, 5508, 5509, 5510, 5511, 5512, 5513,
#        5514, 5515, 5516, 5517, 5518, 5519, 5520, 5521, 5522, 5523, 5524,
#        5525, 5526, 5527, 5528, 5529, 5530, 5531, 5532, 5533, 5534, 5535,
#        5536, 5537, 5538, 5539, 5540, 5541, 5542, 5543, 5544, 5545, 5546,
#        5547, 5548, 5549, 5550, 5551, 5552, 5553, 5554, 5555, 5556, 5557,
#        5558, 5559, 5560, 5561, 5562, 5563, 5564, 5565, 5566, 5567, 5568,
#        5569, 5570, 5571, 5572, 5573, 5574, 5575, 5576, 5577, 5578, 5579,
#        5580, 5581, 5582, 5583, 5584, 5585, 5586, 5587, 5588, 5589, 5590,
#        5591, 5592, 5593, 5594, 5595, 5596, 5597, 5
086, 6087, 6088, 6089, 6090, 6091, 6092, 6093, 6094, 6095, 6096,
#        6097, 6098, 6099, 6100, 6101, 6102, 6103, 6104, 6105, 6106, 6107,
#        6108, 6109, 6110, 6111, 6112, 6113, 6114, 6115, 6116, 6117, 6118,
#        6119, 6120, 6121, 6122, 6123, 6124, 6125, 6126, 6127, 6128, 6129,
#        6130, 6131, 6132, 6133, 6134, 6135, 6136, 6137, 6138, 6139, 6140,
#        6141, 6142, 6143, 6144, 6145, 6146, 6147, 6148, 6149, 6150, 6151,
#        6152, 6153])

# %%
def make_conll_df(path, add_head_stuff=False):
    # CoNLL file is tab delimeted with no quoting
    # quoting=3 is csv.QUOTE_NONE
    df = (pd.read_csv(path, sep='\t', header=None, quoting=3, comment='#',
                names = ['id', 'form', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc'])
                # add sentence labels
                .assign(sent = lambda x: (x.id==1).cumsum())
                # replace bad root dependency tags
                .replace({'DEPREL': {'prd': 'ROOT'}})
               )
    
    if add_head_stuff:
        df = df.merge(df[['ID', 'FORM', 'sent', 'UPOS']].rename(index=str, columns={'FORM': 'head_form', 'UPOS': 'head_upos'}).set_index(['sent', 'ID']),
               left_on=['sent', 'HEAD'], right_index=True, how='left')
    return df

def read_lattices(path):
    df = (pd.read_csv(path, sep='\t', header=None, quoting=3, 
                names = ['ID1', 'ID2', 'form', 'lemma', 'upostag', 'xpostag', 'feats', 'token_id'])
                # add sentence labels
                .assign(sent = lambda x: (x.ID1==0).cumsum())
               )
    return df

flatten = lambda l: [item for sublist in l for item in sublist]

def get_yap_output_df(tokens_path, dep_path, map_path):
    tokens = dict(flatten([[(str(j+1)+'_'+str(i+1), tok) for i, tok in enumerate(sent.split('\n'))]
              for j, sent in 
              enumerate(open(os.path.join(yap_output_dir, tokens_path), 'r').read().split('\n\n'))]))
    lattices = read_lattices(map_path)
    dep = make_conll_df(dep_path)
    df = (pd.concat([dep, lattices.token_id], axis=1)
          .assign(sent_tok = lambda x: x.sent.astype(str) + '_' + x.token_id.astype(str))
          .assign(token_str = lambda x: x.sent_tok.map(tokens))
          .drop('sent_tok', axis=1))
    return df


yap_dev = get_yap_output_df('spmrl_dev_tokens.txt', 'new_yap_outputs/spmrl_dev_dep.conll', 'new_yap_outputs/spmrl_dev_map.conll')
yap_test = get_yap_output_df('spmrl_test_tokens.txt', 'new_yap_outputs/spmrl_test_dep.conll', 'new_yap_outputs/spmrl_test_map.conll')

# %%
yap_dev_tok = (yap_dev
            .groupby(['sent', 'token_id', 'token_str'])
            .apply(lambda x: pd.Series({ 'upostag': ','.join(x.upostag.fillna('').tolist()),
                                         'form': ','.join(x.form.fillna('').tolist()),
                                         'lemma': ','.join(x.lemma.fillna('').tolist()),
                                         'feats': ','.join(x.feats.fillna('').tolist()),
                                         'deprel': ','.join(x.deprel.fillna('').tolist()),}
            ))
           )

# %%
yap_test_tok = (yap_test
            .groupby(['sent', 'token_id', 'token_str'])
            .apply(lambda x: pd.Series({ 'upostag': ','.join(x.upostag.fillna('').tolist()),
                                         'form': ','.join(x.form.fillna('').tolist()),
                                         'lemma': ','.join(x.lemma.fillna('').tolist()),
                                         'feats': ','.join(x.feats.fillna('').tolist()),
                                         'deprel': ','.join(x.deprel.fillna('').tolist()),}
            ))
           )

# %%
import numpy as np

# %%
dev_sent_id_map = tn[tn.set=='dev'].reset_index().sent_id.drop_duplicates().reset_index().drop('index', axis=1)['sent_id']
dev_sent_id_map.index = dev_sent_id_map.index+1
test_sent_id_map = tn[tn.set=='test'].reset_index().sent_id.drop_duplicates().reset_index().drop('index', axis=1)['sent_id']
test_sent_id_map.index = test_sent_id_map.index+1
yap_dev_tok = (yap_dev_tok
               .reset_index()
               .assign(sent_id = lambda x: x['sent'].map(dev_sent_id_map))
               .set_index(['sent', 'token_id', 'token_str']))
yap_test_tok = (yap_test_tok.reset_index()
               .assign(sent_id = lambda x: x.sent.map(test_sent_id_map))
               .set_index(['sent', 'token_id', 'token_str']))

# %%
yap_dev_tok
# Out:
#                                     upostag         form      lemma  \
# sent token_id token_str
# 1    1        עשרות                     CDT        עשרות        עשר
#      2        אנשים                      NN        אנשים        איש
#      3        מגיעים                     BN       מגיעים       הגיע
#      4        מתאילנד       PREPOSITION,NNP     מ,תאילנד   מ,תאילנד
#      5        לישראל                    NNP       לישראל     לישראל
#      6        כשהם                 TEMP,PRP        כש,הם     כש,הוא
#      7        נרשמים                     BN       נרשמים       נרשם
#      8        כמתנדבים   PREPOSITION,DEF,NN  כ,ה,מתנדבים  כ,ה,מתנדב
#      9        ,                        yyCM            ,
#      10       אך                         CC           אך         אך
#      11       למעשה                      RB        למעשה      למעשה
#      12       משמשים                     BN       משמשים       שימש
#      13       עובדים                     NN       עובדים       עובד
#      14       שכירים                     JJ       שכירים       שכיר
#      15       זולים                      JJ        זולים        זול
#      16       .                       yyDOT            .
# 2    1        תופעה                      NN        תופעה      תופעה
#      2        זו                        PRP           זו         זו
#      3        התבררה                     VB       התבררה      התברר
#      4        אתמול                      RB        אתמול      אתמול
#      5        בוועדת        PREPOSITION,NNT      ב,וועדת     ב,ועדה
#      6        העבודה                 DEF,NN      ה,עבודה    ה,עבודה
#      7        והרווחה           CONJ,DEF,NN    ו,ה,רווחה  ו,ה,רווחה
#      8        של                        POS           של         של
#      9        הכנסת                 DEF,NNP       ה,כנסת     ה,כנסת
#      10       ,                        yyCM            ,
#      11       שדנה                   REL,BN        ש,דנה       ש,דן
#      12       בנושא         PREPOSITION,NNT       ב,נושא     ב,נושא
#      13       העסקת                     NNT        העסקת      העסקה
#      14       עובדים                     NN       עובדים       עובד
# ...                                     ...          ...        ...
# 497  7        קדישא                     NNP        קדישא      קדישא
#      8        ורק                   CONJ,RB         ו,רק       ו,רק
#      9        תוך                        IN          תוך        תוך
#      10       דחיפות                     NN       דחיפות      דחיפה
#      11       וצעקות                CONJ,NN      ו,צעקות     ו,צעקה
#      12       הורדה                      VB        הורדה       הורד
#      13       גופתו                      NN        גופתו       גופה
#      14       של                        POS           של         של
#      15       מאיר                      BNT         מאיר       אייר
#      16       כהנא                      NNP         כהנא       כהנא
#      17       אל                         IN           אל         אל
#      18       הקבר                   DEF,NN        ה,קבר      ה,קבר
#      19       .                       yyDOT            .
# 498  1        עכשיו                      RB        עכשיו      עכשיו
#      2        קוראים                     BN       קוראים        קרא
#      3        את                         AT           את         את
#      4        הקדיש                  DEF,NN       ה,קדיש     ה,קדיש
#      5        ,                        yyCM            ,
#      6        והקהל             CONJ,DEF,NN      ו,ה,קהל    ו,ה,קהל
#      7        עונה                       BN         עונה        ענה
#      8        אמן                        NN          אמן        אמן
#      9        .                       yyDOT            .
# 499  1        תם                         VB           תם         תם
#      2        מסע                       NNT          מסע        מסע
#      3        ההלווייה               DEF,NN    ה,הלווייה   ה,הלוויה
#      4        .                       yyDOT            .
# 500  1        מתחיל                     BNT        מתחיל     התחייל
#      2        מסע                       NNT          מסע        מסע
#      3        הנקמה                  DEF,NN       ה,נקמה     ה,נקמה
#      4        .                       yyDOT            .
#
#                                                              feats  \
# sent token_id token_str
# 1    1        עשרות                                    gen=F|num=P
#      2        אנשים                                    gen=M|num=P
#      3        מגיעים                             gen=M|num=P|per=A
#      4        מתאילנד                                 ,gen=F|num=S
#      5        לישראל                             gen=F|gen=M|num=S
#      6        כשהם                              ,gen=M|num=P|per=3
#      7        נרשמים                             gen=M|num=P|per=A
#      8        כמתנדבים                               ,,gen=M|num=P
#      9        ,
#      10       אך
#      11       למעשה
#      12       משמשים                             gen=M|num=P|per=A
#      13       עובדים                                   gen=M|num=P
#      14       שכירים                                   gen=M|num=P
#      15       זולים                                    gen=M|num=P
#      16       .
# 2    1        תופעה                                    gen=F|num=S
#      2        זו                                 gen=F|num=S|per=3
#      3        התבררה                  gen=F|num=S|per=3|tense=PAST
#      4        אתמול
#      5        בוועדת                                  ,gen=F|num=S
#      6        העבודה                                  ,gen=F|num=S
#      7        והרווחה                                ,,gen=F|num=S
#      8        של
#      9        הכנסת                                   ,gen=F|num=S
#      10       ,
#      11       שדנה                              ,gen=F|num=S|per=A
#      12       בנושא                                   ,gen=M|num=S
#      13       העסקת                                    gen=F|num=S
#      14       עובדים                                   gen=M|num=P
# ...                                                            ...
# 497  7        קדישא
#      8        ורק                                                ,
#      9        תוך
#      10       דחיפות                                   gen=F|num=P
#      11       וצעקות                                  ,gen=F|num=P
#      12       הורדה                   gen=F|num=S|per=3|tense=PAST
#      13       גופתו      gen=F|num=S|suf_gen=M|suf_num=S|suf_per=3
#      14       של
#      15       מאיר                               gen=M|num=S|per=A
#      16       כהנא                                     gen=M|num=S
#      17       אל
#      18       הקבר                                    ,gen=M|num=S
#      19       .
# 498  1        עכשיו
#      2        קוראים                             gen=M|num=P|per=A
#      3        את
#      4        הקדיש                                   ,gen=M|num=S
#      5        ,
#      6        והקהל                                  ,,gen=M|num=S
#      7        עונה                               gen=F|num=S|per=A
#      8        אמן                                      gen=M|num=S
#      9        .
# 499  1        תם                      gen=M|num=S|per=3|tense=PAST
#      2        מסע                                      gen=M|num=S
#      3        ההלווייה                                ,gen=F|num=S
#      4        .
# 500  1        מתחיל                              gen=M|num=S|per=A
#      2        מסע                                      gen=M|num=S
#      3        הנקמה                                   ,gen=F|num=S
#      4        .
#
#                                    deprel  sent_id
# sent token_id token_str
# 1    1        עשרות                   num        1
#      2        אנשים                  subj        1
#      3        מגיעים                 conj        1
#      4        מתאילנד           comp,pobj        1
#      5        לישראל                   nn        1
#      6        כשהם             ccomp,subj        1
#      7        נרשמים                ccomp        1
#      8        כמתנדבים   prepmod,def,pobj        1
#      9        ,                     punct        1
#      10       אך                     ROOT        1
#      11       למעשה                advmod        1
#      12       משמשים                 conj        1
#      13       עובדים                  obj        1
#      14       שכירים                 amod        1
#      15       זולים                  amod        1
#      16       .                     punct        1
# 2    1        תופעה                  subj        2
#      2        זו                     amod        2
#      3        התבררה                 ROOT        2
#      4        אתמול                  tmod        2
#      5        בוועדת         prepmod,pobj        2
#      6        העבודה             def,conj        2
#      7        והרווחה       gobj,def,conj        2
#      8        של                  prepmod        2
#      9        הכנסת              def,gobj        2
#      10       ,                     punct        2
#      11       שדנה          rcmod,relcomp        2
#      12       בנושא             comp,pobj        2
#      13       העסקת                  gobj        2
#      14       עובדים                 gobj        2
# ...                                   ...      ...
# 497  7        קדישא                    nn      497
#      8        ורק             prepmod,mod      497
#      9        תוך                    conj      497
#      10       דחיפות                 conj      497
#      11       וצעקות            pobj,conj      497
#      12       הורדה                  ROOT      497
#      13       גופתו                  subj      497
#      14       של                 posspmod      497
#      15       מאיר                   gobj      497
#      16       כהנא                   gobj      497
#      17       אל                     comp      497
#      18       הקבר               def,pobj      497
#      19       .                     punct      497
# 498  1        עכשיו                advmod      498
#      2        קוראים                 conj      498
#      3        את                      obj      498
#      4        הקדיש                def,hd      498
#      5        ,                     punct      498
#      6        והקהל         ROOT,def,subj      498
#      7        עונה                   conj      498
#      8        אמן                     obj      498
#      9        .                     punct      498
# 499  1        תם                     ROOT      499
#      2        מסע                    subj      499
#      3        ההלווייה           def,gobj      499
#      4        .                     punct      499
# 500  1        מתחיל                  ROOT      500
#      2        מסע                    gobj      500
#      3        הנקמה              def,gobj      500
#      4        .                     punct      500
#
# [8531 rows x 6 columns]

# %%
spdf_fixed = pd.read_csv('align/spdf_fixed.csv.gz', compression='gzip')
spdf_fixed.feats.value_counts()
# Out:
# _                                                             84836
# gen=M|num=S                                                   20013
# gen=F|num=S                                                   13239
# gen=M|num=P                                                    7805
# gen=F|num=P                                                    3754
# gen=M|num=S|per=3                                              2498
# gen=F|gen=M|num=S                                              1719
# gen=F|num=S|per=3                                              1384
# gen=M|num=P|per=3                                               934
# tense=TOINFINITIVE|HebBinyan=PAAL                               801
# gen=M|num=S|per=3|tense=PAST|HebBinyan=PAAL                     777
# gen=M|num=S|per=A|HebBinyan=PAAL                                734
# tense=TOINFINITIVE|HebBinyan=HIFIL                              675
# tense=TOINFINITIVE|HebBinyan=PIEL                               576
# gen=M|num=S|suf_gen=M|suf_num=S|suf_per=3                       571
# gen=M|num=P|per=A|HebBinyan=PAAL                                554
# gen=M|num=S|per=3|tense=PAST|HebBinyan=HIFIL                    496
# gen=F|num=S|suf_gen=M|suf_num=S|suf_per=3                       486
# gen=M|num=S|per=3|tense=PAST|HebBinyan=NIFAL                    424
# gen=F|gen=M|num=P|per=3|tense=PAST|HebBinyan=PAAL               391
# gen=M|num=S|per=3|tense=PAST|HebBinyan=PIEL                     359
# gen=M|num=S|per=A                                               314
# gen=F|num=S|per=A|HebBinyan=PAAL                                310
# gen=M|num=S|per=3|tense=PAST                                    301
# gen=M|num=S|per=A|HebBinyan=HIFIL                               272
# gen=F|gen=M|num=P|per=3|tense=PAST|HebBinyan=HIFIL              265
# gen=F|gen=M|num=S|per=1                                         265
# gen=F|num=S|per=3|tense=PAST|HebBinyan=HIFIL                    236
# gen=F|gen=M|num=P|per=3                                         236
# gen=F|gen=M|num=P|per=3|tense=PAST|HebBinyan=NIFAL              231
#                                                               ...
# gen=M|num=S|per=2|tense=PAST|HebBinyan=HITPAEL                    1
# gen=F|gen=M|num=S|per=1|tense=PAST|HebBinyan=PUAL                 1
# gen=M|num=S|per=2|tense=IMPERATIVE|HebBinyan=HIFIL                1
# gen=M|num=P|suf_gen=M|suf_num=P|suf_per=2                         1
# gen=F|gen=M|num=S|suf_gen=M|suf_num=S|suf_per=3                   1
# gen=M|num=P|per=2|polar=pos|tense=PAST                            1
# gen=M|num=P|per=2|tense=PAST                                      1
# gen=M|num=S|per=2|tense=FUTURE|HebBinyan=PUAL                     1
# gen=F|gen=M|num=P|per=1|tense=FUTURE|HebBinyan=HUFAL              1
# gen=F|gen=M|num=S|per=A                                           1
# gen=F|gen=M|num=P|suf_gen=F|suf_num=S|suf_per=2                   1
# gen=F|gen=M|num=P|per=2|tense=IMPERATIVE|HebBinyan=HITPAEL        1
# gen=F|num=S|per=3|HebBinyan=PIEL                                  1
# gen=F|gen=M|num=P|per=2|tense=IMPERATIVE|HebBinyan=NIFAL          1
# gen=F|gen=M|num=S|per=2                                           1
# gen=F|num=P|per=3|tense=FUTURE                                    1
# gen=M|num=P|suf_gen=M|suf_num=D|suf_per=3                         1
# gen=F|num=P|per=3|tense=FUTURE|HebBinyan=PIEL                     1
# gen=M|num=P|suf_gen=M|suf_num=S|suf_per=2                         1
# gen=F|num=P|per=3|tense=FUTURE|HebBinyan=PAAL                     1
# gen=F|num=P|per=3|polar=neg|tense=BEINONI                         1
# suf_gen=M|suf_num=S|per=3                                         1
# gen=F|num=S|per=2|tense=PAST                                      1
# gen=F|num=S|suf_gen=M|suf_num=P|suf_per=2                         1
# gen=F|gen=M|num=S|per=1|polar=pos|tense=PAST                      1
# gen=F|num=S|per=2|tense=IMPERATIVE|HebBinyan=PAAL                 1
# gen=F|gen=M|num=P|per=2|tense=FUTURE|HebBinyan=HIFIL              1
# gen=F|num=P|tense=BEINONI                                         1
# gen=M|num=P|per=3|tense=FUTURE|HebBinyan=PIEL                     1
# num=S|suf_gen=F|suf_num=S|suf_per=3                               1
# Name: feats, Length: 258, dtype: int64

# %%
uddf_fixed = pd.read_csv('align/uddf_fixed.csv.gz', compression='gzip')
uddf_fixed.feats.value_counts()
# Out:
# OrderedDict([('PronType', 'Art')])                                                                                                                                               16431
# OrderedDict([('Gender', 'Masc'), ('Number', 'Sing')])                                                                                                                            14701
# OrderedDict([('Gender', 'Fem'), ('Number', 'Sing')])                                                                                                                              9957
# OrderedDict([('Gender', 'Masc'), ('Number', 'Plur')])                                                                                                                             5736
# OrderedDict([('Definite', 'Cons'), ('Gender', 'Masc'), ('Number', 'Sing')])                                                                                                       4051
# OrderedDict([('Gender', 'Fem'), ('Number', 'Plur')])                                                                                                                              2820
# OrderedDict([('Definite', 'Cons'), ('Gender', 'Fem'), ('Number', 'Sing')])                                                                                                        2583
# OrderedDict([('Case', 'Gen')])                                                                                                                                                    2334
# OrderedDict([('Case', 'Acc')])                                                                                                                                                    1998
# OrderedDict([('Definite', 'Cons'), ('Gender', 'Masc'), ('Number', 'Plur')])                                                                                                       1958
# OrderedDict([('Case', 'Gen'), ('Gender', 'Masc'), ('Number', 'Sing'), ('Person', '3'), ('PronType', 'Prs')])                                                                      1344
# OrderedDict([('Gender', 'Masc'), ('Number', 'Sing'), ('Person', '3'), ('PronType', 'Prs')])                                                                                       1249
# OrderedDict([('Definite', 'Def'), ('Gender', 'Masc'), ('Number', 'Sing')])                                                                                                        1005
# OrderedDict([('Polarity', 'Neg')])                                                                                                                                                1001
# OrderedDict([('Definite', 'Cons')])                                                                                                                                                958
# OrderedDict([('HebSource', 'ConvUncertainHead')])                                                                                                                                  895
# OrderedDict([('Definite', 'Def'), ('Gender', 'Fem'), ('Number', 'Sing')])                                                                                                          876
# OrderedDict([('Definite', 'Cons'), ('Gender', 'Fem'), ('Number', 'Plur')])                                                                                                         873
# OrderedDict([('HebBinyan', 'PAAL'), ('VerbForm', 'Inf'), ('Voice', 'Act')])                                                                                                        771
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'PAAL'), ('Number', 'Sing'), ('Person', '3'), ('Tense', 'Past'), ('Voice', 'Act')])                                                 770
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'PAAL'), ('Number', 'Sing'), ('Person', '1,2,3'), ('VerbForm', 'Part'), ('Voice', 'Act')])                                          706
# OrderedDict([('HebBinyan', 'HIFIL'), ('VerbForm', 'Inf'), ('Voice', 'Act')])                                                                                                       652
# OrderedDict([('Gender', 'Masc'), ('Number', 'Plur'), ('Person', '3'), ('PronType', 'Prs')])                                                                                        566
# OrderedDict([('HebBinyan', 'PIEL'), ('VerbForm', 'Inf'), ('Voice', 'Act')])                                                                                                        539
# OrderedDict([('Gender', 'Fem'), ('Number', 'Sing'), ('Person', '3'), ('PronType', 'Prs')])                                                                                         526
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'PAAL'), ('Number', 'Plur'), ('Person', '1,2,3'), ('VerbForm', 'Part'), ('Voice', 'Act')])                                          522
# OrderedDict([('Case', 'Gen'), ('Gender', 'Fem'), ('Number', 'Sing'), ('Person', '3'), ('PronType', 'Prs')])                                                                        497
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'HIFIL'), ('Number', 'Sing'), ('Person', '3'), ('Tense', 'Past'), ('Voice', 'Act')])                                                493
# OrderedDict([('Case', 'Gen'), ('Gender', 'Masc'), ('Number', 'Plur'), ('Person', '3'), ('PronType', 'Prs')])                                                                       481
# OrderedDict([('Abbr', 'Yes')])                                                                                                                                                     426
#                                                                                                                                                                                  ...
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'PIEL'), ('Number', 'Plur'), ('Person', '2'), ('Tense', 'Past'), ('Voice', 'Act')])                                                   1
# OrderedDict([('Gender', 'Fem'), ('HebBinyan', 'PUAL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '1,2,3'), ('VerbForm', 'Part'), ('Voice', 'Pass')])        1
# OrderedDict([('Gender', 'Fem'), ('HebBinyan', 'HIFIL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '1,2,3'), ('VerbForm', 'Part'), ('Voice', 'Act')])        1
# OrderedDict([('Gender', 'Fem'), ('HebBinyan', 'PAAL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '3'), ('Tense', 'Past'), ('Voice', 'Act')])                1
# OrderedDict([('Definite', 'Cons'), ('Gender', 'Masc'), ('HebSource', 'ConvUncertainLabel'), ('Number', 'Plur')])                                                                     1
# OrderedDict([('Gender', 'Fem'), ('HebSource', 'ConvUncertainLabel'), ('Number', 'Sing'), ('Person', '3'), ('PronType', 'Dem')])                                                      1
# OrderedDict([('Gender', 'Fem'), ('Number', 'Plur'), ('VerbForm', 'Part'), ('VerbType', 'Mod')])                                                                                      1
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'HUFAL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '3'), ('Tense', 'Past'), ('Voice', 'Pass')])             1
# OrderedDict([('Gender', 'Fem'), ('Number', 'Sing'), ('Person', '2'), ('Tense', 'Past')])                                                                                             1
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'PUAL'), ('Number', 'Sing'), ('Person', '2'), ('Tense', 'Fut'), ('Voice', 'Pass')])                                                   1
# OrderedDict([('Gender', 'Fem,Masc'), ('HebBinyan', 'HUFAL'), ('Number', 'Plur'), ('Person', '1'), ('Tense', 'Fut'), ('Voice', 'Pass')])                                              1
# OrderedDict([('Gender', 'Fem'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '3'), ('Polarity', 'Pos'), ('VerbForm', 'Part'), ('VerbType', 'Cop')])            1
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'HITPAEL'), ('Number', 'Sing'), ('Person', '2'), ('Tense', 'Fut')])                                                                   1
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'PUAL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '3'), ('Tense', 'Fut'), ('Voice', 'Pass')])               1
# OrderedDict([('Case', 'Acc'), ('Gender', 'Fem,Masc'), ('Number', 'Sing'), ('Person', '1'), ('PronType', 'Prs')])                                                                     1
# OrderedDict([('Gender', 'Fem,Masc'), ('HebBinyan', 'HIFIL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Plur'), ('Person', '3'), ('Tense', 'Fut'), ('Voice', 'Act')])           1
# OrderedDict([('Gender', 'Fem'), ('HebBinyan', 'PIEL'), ('Number', 'Sing'), ('Person', '3'), ('VerbForm', 'Part'), ('Voice', 'Act')])                                                 1
# OrderedDict([('Gender', 'Fem'), ('HebBinyan', 'NIFAL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Plur'), ('Person', '1,2,3'), ('VerbForm', 'Part'), ('Voice', 'Mid')])        1
# OrderedDict([('Gender', 'Fem'), ('HebBinyan', 'NIFAL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '3'), ('Tense', 'Past'), ('Voice', 'Mid')])               1
# OrderedDict([('Case', 'Acc'), ('Gender', 'Masc'), ('Number', 'Plur'), ('Person', '2'), ('PronType', 'Prs')])                                                                         1
# OrderedDict([('Gender', 'Fem,Masc'), ('HebBinyan', 'HIFIL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '1'), ('Tense', 'Fut'), ('Voice', 'Act')])           1
# OrderedDict([('Gender', 'Masc'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '3'), ('Tense', 'Past'), ('VerbType', 'Mod')])                                   1
# OrderedDict([('Gender', 'Masc'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Plur'), ('Person', '1,2,3'), ('VerbType', 'Mod')])                                                  1
# OrderedDict([('Gender', 'Fem'), ('HebBinyan', 'PIEL'), ('Number', 'Plur'), ('Person', '3'), ('Tense', 'Fut'), ('Voice', 'Act')])                                                     1
# OrderedDict([('Gender', 'Fem'), ('HebBinyan', 'HIFIL'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '3'), ('Tense', 'Fut'), ('Voice', 'Act')])                1
# OrderedDict([('Gender', 'Fem'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Sing'), ('Person', '3'), ('PronType', 'Prs'), ('Reflex', 'Yes')])                                    1
# OrderedDict([('Gender', 'Masc'), ('HebExistential', 'True'), ('Mood', 'Imp'), ('Number', 'Sing'), ('Person', '2'), ('Polarity', 'Pos')])                                             1
# OrderedDict([('Gender', 'Masc'), ('HebSource', 'ConvUncertainHead'), ('Number', 'Plur'), ('Person', '3'), ('Polarity', 'Neg'), ('VerbForm', 'Part'), ('VerbType', 'Cop')])           1
# OrderedDict([('Gender', 'Masc'), ('HebBinyan', 'HIFIL'), ('Mood', 'Imp'), ('Number', 'Sing'), ('Person', '2'), ('Voice', 'Act')])                                                    1
# OrderedDict([('Definite', 'Cons'), ('Gender', 'Fem'), ('HebBinyan', 'HITPAEL'), ('Number', 'Plur'), ('Person', '1,2,3'), ('VerbForm', 'Part')])                                      1
# Name: feats, Length: 480, dtype: int64
