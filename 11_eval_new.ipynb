# %% [markdown]
# # New valuation for realistic run with morphology
# 1. Create a set of mentions from every sentence: sent_pred_set, sent_true_set
#    1. add numbering to mentions if they are the same
# 1. Join sets with sentence identifer: pred_set, true_set
# 1. Precision: intersection(pred_set, true_set) / true_set
# 1. Recall: intersection(pred_set, true_set) / pred_set

# %% [markdown]
# ## Prepare corpus

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('paper')
sns.set_style('white')

# %%
from conlleval import evaluate

# %%
df = (pd.read_csv('curation.csv.gz')
      .assign(sent=lambda x: x.file+'_'+x.sent.astype(str)))

# %%
df.head()
# Out:
#   sent_tok_num tok_offset   token FEAT_gender FEAT_number FEAT_case  \
# 0          1-1        0-5   עשרות         Fem        Plur         *
# 1          1-2       6-11   אנשים        Masc        Plur         *
# 2          1-3      12-18  מגיעים        Masc        Plur         *
# 3          1-4      19-20       מ           _           _         _
# 4          1-5      21-27  תאילנד           _           _         _
#
#   FEAT_degree FEAT_transitivity FEAT_tense FEAT_mood  ... dep_flavor  \
# 0           *                 *          *         *  ...      basic
# 1           *                 *          *         *  ...      basic
# 2           *                 *          *         *  ...      basic
# 3           _                 _          _         _  ...      basic
# 4           _                 _          _         _  ...      basic
#
#   dep_lex_morph_pos dep_arc EXTRA             sent ner_layers ner_type is_ner  \
# 0               1-2     NaN   NaN  dev_1-100.tsv_1          0        _  False
# 1               1-3     NaN   NaN  dev_1-100.tsv_1          0        _  False
# 2               1-3     NaN   NaN  dev_1-100.tsv_1          0        _  False
# 3               1-5     NaN   NaN  dev_1-100.tsv_1          0        _  False
# 4               1-3     NaN   NaN  dev_1-100.tsv_1          1      GPE   True
#
#    biose           file
# 0      O  dev_1-100.tsv
# 1      O  dev_1-100.tsv
# 2      O  dev_1-100.tsv
# 3      O  dev_1-100.tsv
# 4  S-GPE  dev_1-100.tsv
#
# [5 rows x 30 columns]

# %%
df.head().T
# Out:
#                                                         0  \
# sent_tok_num                                          1-1
# tok_offset                                            0-5
# token                                               עשרות
# FEAT_gender                                           Fem
# FEAT_number                                          Plur
# FEAT_case                                               *
# FEAT_degree                                             *
# FEAT_transitivity                                       *
# FEAT_tense                                              *
# FEAT_mood                                               *
# FEAT_voice                                              *
# FEAT_definiteness                                       *
# FEAT_value         Definite=Cons\|Gender=Fem\|Number=Plur
# FEAT_person                                             *
# FEAT_aspect                                             *
# pos                                                   NUM
# ner                                                     _
# lemma                                               עשרות
# surface_form                                            _
# dep_type                                           nummod
# dep_flavor                                          basic
# dep_lex_morph_pos                                     1-2
# dep_arc                                               NaN
# EXTRA                                                 NaN
# sent                                      dev_1-100.tsv_1
# ner_layers                                              0
# ner_type                                                _
# is_ner                                              False
# biose                                                   O
# file                                        dev_1-100.tsv
#
#                                           1  \
# sent_tok_num                            1-2
# tok_offset                             6-11
# token                                 אנשים
# FEAT_gender                            Masc
# FEAT_number                            Plur
# FEAT_case                                 *
# FEAT_degree                               *
# FEAT_transitivity                         *
# FEAT_tense                                *
# FEAT_mood                                 *
# FEAT_voice                                *
# FEAT_definiteness                         *
# FEAT_value         Gender=Masc\|Number=Plur
# FEAT_person                               *
# FEAT_aspect                               *
# pos                                    NOUN
# ner                                       _
# lemma                                   איש
# surface_form                              _
# dep_type                              nsubj
# dep_flavor                            basic
# dep_lex_morph_pos                       1-3
# dep_arc                                 NaN
# EXTRA                                   NaN
# sent                        dev_1-100.tsv_1
# ner_layers                                0
# ner_type                                  _
# is_ner                                False
# biose                                     O
# file                          dev_1-100.tsv
#
#                                                                    2  \
# sent_tok_num                                                     1-3
# tok_offset                                                     12-18
# token                                                         מגיעים
# FEAT_gender                                                     Masc
# FEAT_number                                                     Plur
# FEAT_case                                                          *
# FEAT_degree                                                        *
# FEAT_transitivity                                                  *
# FEAT_tense                                                         *
# FEAT_mood                                                          *
# FEAT_voice                                                       Act
# FEAT_definiteness                                                  *
# FEAT_value         Gender=Masc\|HebBinyan=HIFIL\|Number=Plur\|Per...
# FEAT_person                                                    1,2,3
# FEAT_aspect                                                        *
# pos                                                             VERB
# ner                                                                _
# lemma                                                           הגיע
# surface_form                                                       _
# dep_type                                                        root
# dep_flavor                                                     basic
# dep_lex_morph_pos                                                1-3
# dep_arc                                                          NaN
# EXTRA                                                            NaN
# sent                                                 dev_1-100.tsv_1
# ner_layers                                                         0
# ner_type                                                           _
# is_ner                                                         False
# biose                                                              O
# file                                                   dev_1-100.tsv
#
#                                  3                4
# sent_tok_num                   1-4              1-5
# tok_offset                   19-20            21-27
# token                            מ           תאילנד
# FEAT_gender                      _                _
# FEAT_number                      _                _
# FEAT_case                        _                _
# FEAT_degree                      _                _
# FEAT_transitivity                _                _
# FEAT_tense                       _                _
# FEAT_mood                        _                _
# FEAT_voice                       _                _
# FEAT_definiteness                _                _
# FEAT_value                       _                _
# FEAT_person                      _                _
# FEAT_aspect                      _                _
# pos                            ADP            PROPN
# ner                              _              GPE
# lemma                            מ           תאילנד
# surface_form           מתאילנד[84]      מתאילנד[84]
# dep_type                      case              obl
# dep_flavor                   basic            basic
# dep_lex_morph_pos              1-5              1-3
# dep_arc                        NaN              NaN
# EXTRA                          NaN              NaN
# sent               dev_1-100.tsv_1  dev_1-100.tsv_1
# ner_layers                       0                1
# ner_type                         _              GPE
# is_ner                       False             True
# biose                            O            S-GPE
# file                 dev_1-100.tsv    dev_1-100.tsv

# %%
x=df
sents = x.groupby('sent')[['token', 'biose', 'ner_type']].apply(lambda x: x.values.tolist())
sents[:5]
# Out:
# sent
# dev_1-100.tsv_1      [[עשרות, O, _], [אנשים, O, _], [מגיעים, O, _],...
# dev_1-100.tsv_10     [[ישראל, B-PER, PER], [ארד, E-PER, PER], [,, O...
# dev_1-100.tsv_100    [[טום, B-PER, PER], [הארקין, E-PER, PER], [ה, ...
# dev_1-100.tsv_11     [[ח"כ, O, _], [אלי, B-PER, PER], [דיין, E-PER,...
# dev_1-100.tsv_12     [[חברות, O, _], [ה, O, _], [מעסיקות, O, _], [ע...
# dtype: object

# %% [markdown]
# ## Create set of mentions from every sentence

# %%
sents_fixed = list(zip(list(sents.index), [[(tok, bio[0], cat) for tok, bio, cat in sent] for sent in sents]))

sents_fixed[:2]
# Out:
# [('dev_1-100.tsv_1',
#   [('עשרות', 'O', '_'),
#    ('אנשים', 'O', '_'),
#    ('מגיעים', 'O', '_'),
#    ('מ', 'O', '_'),
#    ('תאילנד', 'S', 'GPE'),
#    ('ל', 'O', '_'),
#    ('ישראל', 'S', 'GPE'),
#    ('כש', 'O', '_'),
#    ('הם', 'O', '_'),
#    ('נרשמים', 'O', '_'),
#    ('כ', 'O', '_'),
#    ('מתנדבים', 'O', '_'),
#    (',', 'O', '_'),
#    ('אך', 'O', '_'),
#    ('למעשה', 'O', '_'),
#    ('משמשים', 'O', '_'),
#    ('עובדים', 'O', '_'),
#    ('שכירים', 'O', '_'),
#    ('זולים', 'O', '_'),
#    ('.', 'O', '_')]),
#  ('dev_1-100.tsv_10',
#   [('ישראל', 'B', 'PER'),
#    ('ארד', 'E', 'PER'),
#    (',', 'O', '_'),
#    ('סמנכ"ל', 'O', '_'),
#    ('ה', 'B', 'ORG'),
#    ('ביטוח', 'I', 'ORG'),
#    ('ה', 'I', 'ORG'),
#    ('לאומי', 'E', 'ORG'),
#    (',', 'O', '_'),
#    ('אמר', 'O', '_'),
#    ('כי', 'O', '_'),
#    ('ממלא', 'O', '_'),
#    ('מקום', 'O', '_'),
#    ('שר', 'O', '_'),
#    ('ה', 'B', 'ORG'),
#    ('עבודה', 'I', 'ORG'),
#    ('ו', 'I', 'ORG'),
#    ('ה', 'I', 'ORG'),
#    ('רווחה', 'E', 'ORG'),
#    (',', 'O', '_'),
#    ('דוד', 'B', 'PER'),
#    ('מגן', 'E', 'PER'),
#    (',', 'O', '_'),
#    ('הקים', 'O', '_'),
#    ('ועדה', 'O', '_'),
#    ('בין', 'O', '_'),
#    ('-', 'O', '_'),
#    ('משרדית', 'O', '_'),
#    (',', 'O', '_'),
#    ('ש', 'O', '_'),
#    ('המליצה', 'O', '_'),
#    ('להגדיל', 'O', '_'),
#    ('ב', 'O', '_'),
#    ('אופן', 'O', '_'),
#    ('משמעותי', 'O', '_'),
#    ('את', 'O', '_'),
#    ('ה', 'O', '_'),
#    ('קנסות', 'O', '_'),
#    ('ל', 'O', '_'),
#    ('ה_', 'O', '_'),
#    ('מעסיקים', 'O', '_'),
#    ('.', 'O', '_')])]

# %%
from collections import defaultdict
from itertools import islice

def sent_to_mentions_dict(sent, sent_id, truncate=80):
    mentions = defaultdict(lambda: 0)
    current_mention= None
    current_cat = None
    for tok, bio, cat in islice(sent, truncate):
        if bio=='S':
            mentions[(sent_id, tok, cat)]+=1
        if bio=='B':
            current_mention = [tok]
            current_cat = cat
        if bio=='I' and current_mention is not None:
            current_mention.append(tok)
        if bio=='E' and current_mention is not None:
            current_mention.append(tok)
            mentions[(sent_id, ' '.join(current_mention), current_cat)]+=1
        if bio=='O':
            current_mention = None
            current_cat = None
    return mentions
ments = [sent_to_mentions_dict(sent, sent_id) for sent_id, sent in sents_fixed]

# %%
ments[:5]
# Out:
# [defaultdict(<function __main__.sent_to_mentions_dict.<locals>.<lambda>()>,
#              {('dev_1-100.tsv_1', 'תאילנד', 'GPE'): 1,
#               ('dev_1-100.tsv_1', 'ישראל', 'GPE'): 1}),
#  defaultdict(<function __main__.sent_to_mentions_dict.<locals>.<lambda>()>,
#              {('dev_1-100.tsv_10', 'ישראל ארד', 'PER'): 1,
#               ('dev_1-100.tsv_10', 'ה ביטוח ה לאומי', 'ORG'): 1,
#               ('dev_1-100.tsv_10', 'ה עבודה ו ה רווחה', 'ORG'): 1,
#               ('dev_1-100.tsv_10', 'דוד מגן', 'PER'): 1}),
#  defaultdict(<function __main__.sent_to_mentions_dict.<locals>.<lambda>()>,
#              {('dev_1-100.tsv_100', 'טום הארקין', 'PER'): 1,
#               ('dev_1-100.tsv_100', 'טום טקי', 'PER'): 1,
#               ('dev_1-100.tsv_100', 'ה מפרץ ה פרסי', 'LOC'): 1}),
#  defaultdict(<function __main__.sent_to_mentions_dict.<locals>.<lambda>()>,
#              {('dev_1-100.tsv_11', 'אלי דיין', 'PER'): 1,
#               ('dev_1-100.tsv_11', 'מערך', 'ORG'): 1}),
#  defaultdict(<function __main__.sent_to_mentions_dict.<locals>.<lambda>()>,
#              {})]

# %%
def get_ment_set(ments):
    ment_set = []
    for ment in ments:
        for k, val in ment.items():
            for i in range(val):
                ment_set.append((k[0], k[1], k[2], i+1))
    return ment_set
ment_set = ment_set[:5]

# %%
def sents_to_mentions(sents):
    sents_fixed = zip(list(sents.index), [[(tok, bio[0], cat) for tok, bio, cat in sent] for sent in sents])
    ments = [sent_to_mentions_dict(sent, sent_id) for sent_id, sent in sents_fixed]
    ment_set = get_ment_set(ments)
    return ment_set

# %%
import pickle
with open('treebank_results_2_test25.pkl', 'rb') as f:
    tb_results = pickle.load(f)
len(tb_results)
# Out:
# 8

# %%
all_preds = [r[2] for r in tb_results]
all_preds[0][0][:20]
# Out:
# ['O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-PER',
#  'E-PER',
#  'O',
#  'O',
#  'B-ORG',
#  'I-ORG',
#  'I-ORG',
#  'I-ORG',
#  'I-ORG',
#  'E-ORG',
#  'O',
#  'O',
#  'O']

# %%
from sklearn.model_selection import train_test_split

splits = [train_test_split(range(len(sents)), 
                           sents, test_size=0.25, 
                           random_state=42+i) 
          for i in range(3)]

# %%
sum([len(s)-80 for s in splits[0][3] if len(s)>80])
# Out:
# 138

# %%
sum(len(s) for s in splits[0][3]), len(all_preds[0][0])
# Out:
# (39576, 39438)

# %%
def get_sents_with_pred_tags(splits, preds, truncate=80):
    sents_preds = []
    for split, pred in zip(splits, preds):
        spl_preds = []
        test_sents = split[3]
        
        i=0
        for sent in test_sents:
            new_sent = []
            for tok, bio, cat in islice(sent, truncate):
                pred_tag = pred[i].split('-')
                pred_bio = pred_tag[0]
                if len(pred_tag)>1:
                    pred_cat = pred_tag[1]
                else:
                    pred_cat = '_'
                new_sent.append((tok, pred_bio, pred_cat))
                i+=1
            spl_preds.append(new_sent)
        spl_preds = pd.Series(spl_preds, index=test_sents.index)
        sents_preds.append(spl_preds)
    return sents_preds

all_sents_preds = [get_sents_with_pred_tags(splits, preds) for preds in all_preds]

# %%
splits_sents = [sents.iloc[split[1]] for split in splits]
splits_ments = [sents_to_mentions(ss) for ss in splits_sents]
all_ments_preds = [[sents_to_mentions(sp) for sp in sents_preds] for sents_preds in all_sents_preds]

# %%
splits_ments[0][:10]
# Out:
# [('train_1801-1900.tsv_97', 'גדעון שור', 'PER', 1),
#  ('train_2501-2600.tsv_79', 'אלן מקויסט', 'PER', 1),
#  ('train_2501-2600.tsv_79', 'ריינגרס', 'ORG', 1),
#  ('train_4101-4200.tsv_81', 'רוסיה', 'GPE', 1),
#  ('train_1001-1100.tsv_28', 'מוסקווה', 'GPE', 1),
#  ('train_1001-1100.tsv_28', 'בלניגרד', 'GPE', 1),
#  ('train_1601-1700.tsv_42', 'משטרת לייפציג', 'ORG', 1),
#  ('train_1501-1600.tsv_42', 'ארה"ב', 'GPE', 1),
#  ('train_1501-1600.tsv_42', 'ה_ מפרץ', 'LOC', 1),
#  ('train_1501-1600.tsv_42', 'מלחמת ה עולם ה שנייה', 'EVE', 1)]

# %%
all_ments_preds[0][0][:10]
# Out:
# [('train_1801-1900.tsv_97', 'גדעון שור', 'PER', 1),
#  ('train_1801-1900.tsv_97', 'מחלקת ה הסברה ב ה_ בנק', 'ORG', 1),
#  ('train_2501-2600.tsv_79', 'אלן מקויסט', 'PER', 1),
#  ('train_4101-4200.tsv_81', 'רוסיה', 'GPE', 1),
#  ('train_1001-1100.tsv_28', 'מוסקווה', 'GPE', 1),
#  ('train_1601-1700.tsv_42', 'משטרת לייפציג', 'ORG', 1),
#  ('train_1501-1600.tsv_42', 'ארה"ב', 'GPE', 1),
#  ('train_1501-1600.tsv_42', 'ה_ מפרץ צבא', 'ORG', 1),
#  ('train_1501-1600.tsv_42', 'מלחמת ה עולם ה שנייה', 'ORG', 1),
#  ('train_5701-5725.tsv_22', 'עדי גורדון', 'PER', 1)]

# %%
def evaluate_mentions(true_ments, pred_ments):
        t, p = set(true_ments), set(pred_ments)
        correct = p.intersection(t)
        prec = len(correct) / len(t)
        recall = len(correct) / len(p)
        f1 = 2*prec*recall/(prec+recall)
        print('Precision:', round(prec, 2))
        print('Recall:   ', round(recall, 2))
        print('F1:       ', round(f1, 2))
        print('FP ex.:', [e[1] for e in list(p-t)[:5]])
        print('FN ex.:', [e[1] for e in list(t-p)[:5]])
        return prec, recall, f1
for ments_preds in all_ments_preds:
    for t, p in zip(splits_ments, ments_preds):
        print(len(t), 'mentions,', len(p), 'found,', len(set(p).intersection(set(t))), 'correct.')
        evaluate_mentions(t, p)
# Out:
# 1893 mentions, 1574 found, 1084 correct.
# Precision: 0.57
# Recall:    0.69
# F1:        0.63
# FP ex.: ['ה מועצה ל ענף ה לול להנהיג תלושים', 'סאלם איסמעיל מובארק לכדי נזיפה', '73', 'ה_ גליל', 'אוצר']
# FN ex.: ['ואליום', 'אוסישקין', 'סומייל', 'אולפני מ - ג', 'לשכת עורכי - ה דין']
# 1905 mentions, 1712 found, 1174 correct.
# Precision: 0.62
# Recall:    0.69
# F1:        0.65
# FP ex.: ['רולטה התכוננו', 'בנק ל פיתוח ה תעשייה', 'אופטימי', 'שורת ה הספדים', 'אירופה']
# FN ex.: ['האפט את האפט', 'אוסישקין', 'אושוויץ', 'בקעה', 'ה רשות ל שיתוף פעולה']
# 1982 mentions, 1786 found, 1222 correct.
# Precision: 0.62
# Recall:    0.68
# F1:        0.65
# FP ex.: ['קלן', 'יעקבי התראיין', 'סייף', 'הובסו', 'מדליק נר נשמה']
# FN ex.: ['אינדיאנה', 'האפט את האפט', 'ה ספרייה ה לאומית', 'דורטמונד', 'ימק"א']
# 1893 mentions, 1794 found, 1341 correct.
# Precision: 0.71
# Recall:    0.75
# F1:        0.73
# FP ex.: ['לאומי', 'ה_ גליל', 'אירופה', 'אוצר', 'ניו - יורק']
# FN ex.: ['ואליום', 'אוסישקין', 'סומייל', 'אולפני מ - ג', 'לשכת עורכי - ה דין']
# 1905 mentions, 1732 found, 1309 correct.
# Precision: 0.69
# Recall:    0.76
# F1:        0.72
# FP ex.: ['או"ם', 'אתיופיה', 'ה_ בית ה לבן', 'אשי', 'כניסת פועלים']
# FN ex.: ['האפט את האפט', 'אוסישקין', 'אושוויץ', 'בקעה', 'ה רשות ל שיתוף פעולה']
# 1982 mentions, 1894 found, 1411 correct.
# Precision: 0.71
# Recall:    0.74
# F1:        0.73
# FP ex.: ['כפר סבא', 'שוהם', 'אשי', 'ה_ פועל', 'סע']
# FN ex.: ['אינדיאנה', 'האפט את האפט', 'ה ספרייה ה לאומית', 'גדי קידר', 'דורטמונד']
# 1893 mentions, 1813 found, 1479 correct.
# Precision: 0.78
# Recall:    0.82
# F1:        0.8
# FP ex.: ['חייכן', 'ה_ פועל', 'ישראל', 'מתיאוס', 'בית ל ה_ אדמו"ר']
# FN ex.: ['ואליום', 'אולפני מ - ג', 'לשכת עורכי - ה דין', 'בית ה חולים שיפא', 'איחוד ה מרכז ה לאומי']
# 1905 mentions, 1797 found, 1457 correct.
# Precision: 0.76
# Recall:    0.81
# F1:        0.79
# FP ex.: ['ה רפובליקה ה סוציאליסטית ה סובייטית', 'ה משטרה', 'בנק ל פיתוח ה תעשייה', 'פלורנטיני', 'אברדין']
# FN ex.: ['האפט את האפט', 'תדמור', 'פנטסיה על נושא רומנטי', 'ימק"א', 'צומת יגור']
# 1982 mentions, 1744 found, 1467 correct.
# Precision: 0.74
# Recall:    0.84
# F1:        0.79
# FP ex.: ['טובול', 'פלורנטיני', 'שוהם', 'וורן', 'וייט']
# FN ex.: ['האפט את האפט', 'ה ספרייה ה לאומית', 'לשכת עורכי - ה דין', 'ימק"א', 'ה משטרה']
# 1893 mentions, 1827 found, 1528 correct.
# Precision: 0.81
# Recall:    0.84
# F1:        0.82
# FP ex.: ['שיקאגו', 'ה_ מערב', 'מתיאוס', 'רצועה', 'ה_ משטרה']
# FN ex.: ['אולפני מ - ג', 'לשכת עורכי - ה דין', 'ה משטרה', 'בית ה חולים שיפא', 'משרד ה בריאות']
# 1905 mentions, 1786 found, 1503 correct.
# Precision: 0.79
# Recall:    0.84
# F1:        0.81
# FP ex.: ['ה חאן', 'קריית חיים', 'בית ל ה_ אדמו"ר', 'ירושלים', 'ה ברית']
# FN ex.: ['האפט את האפט', 'תדמור', 'פנטסיה על נושא רומנטי', 'ימק"א', 'ה מזרח ה תיכון']
# 1982 mentions, 1871 found, 1577 correct.
# Precision: 0.8
# Recall:    0.84
# F1:        0.82
# FP ex.: ['טובול', 'וייט', 'ה_ מערב', 'ה ארץ', 'שייח רדואן']
# FN ex.: ['אינדיאנה', 'האפט את האפט', 'ה ספרייה ה לאומית', 'ימק"א', 'רמן']
# 1893 mentions, 1424 found, 1155 correct.
# Precision: 0.61
# Recall:    0.81
# F1:        0.7
# FP ex.: ['ה מועצה ל ענף ה לול להנהיג תלושים', 'שיפולי ה גבעה', 'ישראל', 'בוסקה חופשיים', 'יאמרו מראדונה']
# FN ex.: ['ואליום', 'אוסישקין', 'סומייל', 'אולפני מ - ג', 'לשכת עורכי - ה דין']
# 1905 mentions, 1628 found, 1203 correct.
# Precision: 0.63
# Recall:    0.74
# F1:        0.68
# FP ex.: ['אופטימי', 'שורת ה הספדים', 'קולונל א - שמיירי', 'אירופה', 'אגף ה חקירות']
# FN ex.: ['האפט את האפט', 'אוסישקין', 'אושוויץ', 'בקעה', 'ה רשות ל שיתוף פעולה']
# 1982 mentions, 1946 found, 1387 correct.
# Precision: 0.7
# Recall:    0.71
# F1:        0.71
# FP ex.: ['שוהם', 'עלי ס.', 'אוצר', 'סודאן', 'תקציבים אומללים']
# FN ex.: ['האפט את האפט', 'ה ספרייה ה לאומית', 'דורטמונד', 'רמן', 'ה משטרה']
# 1893 mentions, 1851 found, 1407 correct.
# Precision: 0.74
# Recall:    0.76
# F1:        0.75
# FP ex.: ['פ. ס.', 'ה מועצה ל ענף ה לול להנהיג תלושים', 'אגף ה חקירות', 'קזחסטן', 'פייגינס']
# FN ex.: ['ואליום', 'אוסישקין', 'סומייל', 'אולפני מ - ג', 'לשכת עורכי - ה דין']
# 1905 mentions, 1919 found, 1424 correct.
# Precision: 0.75
# Recall:    0.74
# F1:        0.74
# FP ex.: ['בנק ל פיתוח ה תעשייה', 'אתיופיה', 'ה ארץ', 'אשי', 'שורת ה הספדים']
# FN ex.: ['האפט את האפט', 'אוסישקין', 'אושוויץ', 'בקעה', 'תדמור']
# 1982 mentions, 1886 found, 1472 correct.
# Precision: 0.74
# Recall:    0.78
# F1:        0.76
# FP ex.: ['שוהם', 'סע', 'ה_ גליל', 'אוצר', 'אגף ה חקירות']
# FN ex.: ['אינדיאנה', 'האפט את האפט', 'ה ספרייה ה לאומית', 'דורטמונד', 'ימק"א']
# 1893 mentions, 1804 found, 1533 correct.
# Precision: 0.81
# Recall:    0.85
# F1:        0.83
# FP ex.: ['שיקאגו', 'ה_ פועל', 'ה_ מערב', 'ה משטר ה פאשיסטי', 'ה_ איסט סייד']
# FN ex.: ['ואליום', 'אוסישקין', 'אולפני מ - ג', 'ה משטרה', 'בית ה חולים שיפא']
# 1905 mentions, 1884 found, 1545 correct.
# Precision: 0.81
# Recall:    0.82
# F1:        0.82
# FP ex.: ['קריית חיים', 'פלורנטיני', 'נבון', 'אשי', 'ה ארץ']
# FN ex.: ['האפט את האפט', 'תדמור', 'פנטסיה על נושא רומנטי', 'ימק"א', 'צומת יגור']
# 1982 mentions, 1921 found, 1637 correct.
# Precision: 0.83
# Recall:    0.85
# F1:        0.84
# FP ex.: ['שלום', 'פלורנטיני', 'שוהם', 'וייט', 'איאבק']
# FN ex.: ['ה ספרייה ה לאומית', 'לשכת עורכי - ה דין', 'ה משטרה', 'כך', 'בית ה חולים שיפא']
# 1893 mentions, 1857 found, 1595 correct.
# Precision: 0.84
# Recall:    0.86
# F1:        0.85
# FP ex.: ['שיפולי ה גבעה', 'ה_ עננים', 'ה_ מערב', 'מתיאוס', 'מרד ה נעורים']
# FN ex.: ['גלאזגו', 'פיירו', 'לשכת עורכי - ה דין', 'אולפני מ - ג', 'בניין ה טלוויזיה']
# 1905 mentions, 1810 found, 1542 correct.
# Precision: 0.81
# Recall:    0.85
# F1:        0.83
# FP ex.: ['פטוציני', 'טירת ה כרמל', 'מכללת עמל', 'ה משטרה', 'אשי']
# FN ex.: ['האפט את האפט', 'תדמור', 'פנטסיה על נושא רומנטי', 'ימק"א', 'צומת יגור']
# 1982 mentions, 1909 found, 1642 correct.
# Precision: 0.83
# Recall:    0.86
# F1:        0.84
# FP ex.: ['שוהם', 'וייט', 'ה_ מערב', 'ה ארץ', 'סלע']
# FN ex.: ['אינדיאנה', 'האפט את האפט', 'עין כרם', 'ה ספרייה ה לאומית', 'איילות']

# %% [markdown]
# ## Ru
