# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
import bclm

# %%
dropped = [5438, 5444, 5445, 5446, 5448, 5449, 5450, 5451, 5453, 5459]
spdf = bclm.read_dataframe('spmrl', subset='dev')

# %% [raw]
# global_dropped = [spdf[spdf.sent_id==d].global_sent_id.iat[0] for d in dropped]
# global_dropped

# %%
uddf = bclm.read_dataframe('ud', subset='dev')

# %% [raw]
# uddf = uddf[(~uddf.global_sent_id.isin(global_dropped))]

# %%
from collections import OrderedDict

# %%
ud_sents = list(uddf.sent_id.unique())

# %% [markdown]
# ## Matching sents (dev, train , test)

# %%
import re 
sent_id_re = re.compile('# sent_id = (\d+)')

import bz2
def get_sent_ids_lat(path):
    sent_ids = []
    with bz2.open(path, 'rt', encoding='utf-8') as f:
        for line in f:
            if line[0]=='#':
                sid = sent_id_re.match(line)
                if sid:
                    sent_id =  int(sid.group(1))
                sent_ids.append(sent_id)
    return sent_ids

dev_sent_ids = get_sent_ids_lat('../UL_Hebrew-HTB/he_htb-ud-dev.heblex.conllul.bz2')

# %%
print(f'dev: {min(dev_sent_ids)}-{max(dev_sent_ids)}')
# Out:
# dev: 1-484

# %%
uddf.groupby(['set']).sent_id.agg(['min', 'max'])
# Out:
#      min  max
# set
# dev    1  500

# %%
def get_set_from_sent_id(gsi):
    if gsi>=min(dev_sent_ids) and gsi<=max(dev_sent_ids):
        return 'dev'
    
uddf['ud_set'] = uddf.sent_id.apply(get_set_from_sent_id)

uddf.groupby(['ud_set']).sent_id.agg(['min', 'max'])
# Out:
#         min  max
# ud_set
# dev       1  484

# %%
import re
def get_biose(df):
    ner_bio = df.ner.copy()
    ner_bio[~ner_bio.str.contains('\[|_')] = 'S-' + ner_bio 
    ner_bio = ner_bio.replace('_', 'O')

    RE = '^(?P<type>[A-Z]+)\[(?P<num>\d+)\].*$'
    prev='XXX'
    new = []

    for x in ner_bio.tolist():
        if x.startswith('S') or x=='O':
            new.append(x)
        else:
            typ, num = re.match(RE, x).groups(0)
            if x==prev:
                new.append('I-'+typ)
            else:
                new.append('B-'+typ)

        prev = x
        
    # reverse pass to add Es
    prev='O'
    rev_pass = []
    for x in new[::-1]:
        if((prev=='O' or prev.startswith('B-')) and x.startswith('I-')):
            rev_pass.append(x.replace('I-', 'E-'))
        else:
            rev_pass.append(x)
        prev = x

    biose = rev_pass[::-1]
    
    return biose

# %%
def read_tsv3(path, add_biose=True):
    names = ['sent_tok_num', 'tok_offset', 'token',
              'FEAT_gender', 'FEAT_number', 'FEAT_case', 'FEAT_degree', 'FEAT_transitivity',
              'FEAT_tense', 'FEAT_mood', 'FEAT_voice', 'FEAT_definiteness', 'FEAT_value', 'FEAT_person', 'FEAT_aspect',
              'pos',
              'ner',
              'lemma',
              'surface_form',
              'dep_type', 'dep_flavor', 'dep_lex_morph_pos', 'dep_arc', 'EXTRA'
            ]
    df = (pd.read_csv(path, sep='\t', skiprows=10, header=None, names=names,
                      comment='#', skip_blank_lines=True, quoting=3)#na_values=['*', '_'])
          .assign(ner_type = lambda x: x.ner.str.split('[', expand=True).iloc[:,0])
          .assign(is_ner = lambda x: x.ner!='_')
          #.assign(biose = lambda x: get_biose(x))
         )
    return df

# %%
from ner_transforms import *

# %% [markdown]
# ## fixes

# %%
df = read_tsv3('data/pilot_annotations/group1/anatb/dev_1-100.tsv')
df.head()
# Out:
#   sent_tok_num tok_offset   token FEAT_gender FEAT_number FEAT_case  \
# 0          1-1        0-5   עשרות         Fem        Plur         *
# 1          1-2       6-11   אנשים        Masc        Plur         *
# 2          1-3      12-18  מגיעים        Masc        Plur         *
# 3          1-4      19-20       מ           _           _         _
# 4          1-5      21-27  תאילנד           _           _         _
#
#   FEAT_degree FEAT_transitivity FEAT_tense FEAT_mood  ...  ner   lemma  \
# 0           *                 *          *         *  ...    _   עשרות
# 1           *                 *          *         *  ...    _     איש
# 2           *                 *          *         *  ...    _    הגיע
# 3           _                 _          _         _  ...    _       מ
# 4           _                 _          _         _  ...  GPE  תאילנד
#
#   surface_form dep_type dep_flavor dep_lex_morph_pos dep_arc EXTRA ner_type  \
# 0            _   nummod      basic               1-2     NaN   NaN        _
# 1            _    nsubj      basic               1-3     NaN   NaN        _
# 2            _     root      basic               1-3     NaN   NaN        _
# 3  מתאילנד[65]     case      basic               1-5     NaN   NaN        _
# 4  מתאילנד[65]      obl      basic               1-3     NaN   NaN      GPE
#
#   is_ner
# 0  False
# 1  False
# 2  False
# 3  False
# 4   True
#
# [5 rows x 26 columns]

# %% [raw]
# def apply_fixes(name, df):
#     if name=='train_485-600.conllu':
#         df.loc[df.sent_tok_num=='85-15', 'ner'] = 'ORG[81]|GPE[82]'

# %% [markdown]
# ## Read all sents for A,B

# %%
import os
from collections import defaultdict 
groups = {}
for folder in os.scandir('data/pilot_annotations/'):
    if '.ipynb' in folder.name:
        continue
    group = folder.name
    groups[group] = defaultdict(list)
    for tat_folder in os.scandir(folder):
        if '.ipynb' in tat_folder.name:
            continue
        tat = tat_folder.name
        for file in os.scandir(tat_folder):
            if '.ipynb' in file.name:
                continue
            print (file.path)
            first_sent_id = int(file.name.split('.')[0].split('_')[1].split('-')[0])
            df = read_tsv3(file.path)
            #apply_fixes(folder.name, df)
            df[['sent_id','id']] = df.sent_tok_num.str.split('-',expand=True).astype(int)

            df['sent_id'] = df.sent_id + first_sent_id - 1
            df['file'] = folder.name
            layers = get_all_layers_biose(df)
            df = df.merge(layers, how='left', on=['sent_id', 'id'])
            groups[group][tat].append(df)
        
for group in groups:
    for tat in groups[group]:
        groups[group][tat] = pd.concat(groups[group][tat], sort=False)
        groups[group][tat] = groups[group][tat].sort_values(by=['sent_id', 'id'])
# Out:
# data/pilot_annotations/group1/anatb/dev_1-100.tsv
# data/pilot_annotations/group1/anatb/dev_101-200.tsv
# data/pilot_annotations/group1/anatb/dev_201-300.tsv
# data/pilot_annotations/group1/anatb/dev_301-400.tsv
# data/pilot_annotations/group1/dafnaa/dev_1-100.tsv
# data/pilot_annotations/group1/dafnaa/dev_101-200.tsv
# data/pilot_annotations/group1/dafnaa/dev_201-300.tsv
# data/pilot_annotations/group1/dafnaa/dev_301-400.tsv
# data/pilot_annotations/group1/shayp/dev_1-100.tsv
# data/pilot_annotations/group1/shayp/dev_101-200.tsv
# data/pilot_annotations/group1/shayp/dev_201-300.tsv
# data/pilot_annotations/group1/shayp/dev_301-400.tsv
# data/pilot_annotations/group1/sinair/dev_1-100.tsv
# data/pilot_annotations/group1/sinair/dev_101-200.tsv
# data/pilot_annotations/group1/sinair/dev_201-300.tsv
# data/pilot_annotations/group1/sinair/dev_301-400.tsv
# data/pilot_annotations/group1/tzufa/dev_1-100.tsv
# data/pilot_annotations/group1/tzufa/dev_101-200.tsv
# data/pilot_annotations/group1/tzufa/dev_201-300.tsv
# data/pilot_annotations/group1/tzufa/dev_301-400.tsv
# data/pilot_annotations/group1/vikab/dev_1-100.tsv
# data/pilot_annotations/group1/vikab/dev_101-200.tsv
# data/pilot_annotations/group1/vikab/dev_201-300.tsv
# data/pilot_annotations/group1/vikab/dev_301-400.tsv
# data/pilot_annotations/group2/nuritg/dev_1-100.tsv
# data/pilot_annotations/group2/nuritg/dev_101-200.tsv
# data/pilot_annotations/group2/nuritg/dev_201-300.tsv
# data/pilot_annotations/group2/nuritg/dev_301-400.tsv
# data/pilot_annotations/group2/shovals/dev_1-100.tsv
# data/pilot_annotations/group2/shovals/dev_101-200.tsv
# data/pilot_annotations/group2/shovals/dev_201-300.tsv
# data/pilot_annotations/group2/shovals/dev_301-400.tsv
# data/pilot_annotations/group2/tzipyl/dev_1-100.tsv
# data/pilot_annotations/group2/tzipyl/dev_101-200.tsv
# data/pilot_annotations/group2/tzipyl/dev_201-300.tsv
# data/pilot_annotations/group2/tzipyl/dev_301-400.tsv
# data/pilot_annotations/group2/vereds/dev_1-100.tsv
# data/pilot_annotations/group2/vereds/dev_101-200.tsv
# data/pilot_annotations/group2/vereds/dev_201-300.tsv
# data/pilot_annotations/group2/vereds/dev_301-400.tsv
# data/pilot_annotations/group2/yohayg/dev_1-100.tsv
# data/pilot_annotations/group2/yohayg/dev_101-200.tsv
# data/pilot_annotations/group2/yohayg/dev_201-300.tsv
# data/pilot_annotations/group2/yohayg/dev_301-400.tsv
# data/pilot_annotations/group2/zefs/dev_1-100.tsv
# data/pilot_annotations/group2/zefs/dev_101-200.tsv
# data/pilot_annotations/group2/zefs/dev_201-300.tsv
# data/pilot_annotations/group2/zefs/dev_301-400.tsv

# %%
groups['group1']['anatb'].tail().T
# Out:
#                           2244  \
# sent_tok_num            100-27
# tok_offset           9555-9559
# token                     _של_
# FEAT_gender                  _
# FEAT_number                  _
# FEAT_case                    _
# FEAT_degree                  _
# FEAT_transitivity            _
# FEAT_tense                   _
# FEAT_mood                    _
# FEAT_voice                   _
# FEAT_definiteness            _
# FEAT_value                   _
# FEAT_person                  _
# FEAT_aspect                  _
# pos                        ADP
# ner                          _
# lemma                       של
# surface_form       העמדתו[513]
# dep_type              case:gen
# dep_flavor               basic
# dep_lex_morph_pos       100-28
# dep_arc                    NaN
# EXTRA                      NaN
# ner_type                     _
# is_ner                   False
# sent_id                    400
# id                          27
# file                    group1
# biose_layer0                 O
# biose_layer1                 O
#
#                                                                 2245  \
# sent_tok_num                                                  100-28
# tok_offset                                                 9560-9564
# token                                                           _הוא
# FEAT_gender                                                     Masc
# FEAT_number                                                     Sing
# FEAT_case                                                        Gen
# FEAT_degree                                                        *
# FEAT_transitivity                                                  *
# FEAT_tense                                                         *
# FEAT_mood                                                          *
# FEAT_voice                                                         *
# FEAT_definiteness                                                  *
# FEAT_value         Case=Gen\|Gender=Masc\|Number=Sing\|Person=3\|...
# FEAT_person                                                        3
# FEAT_aspect                                                        *
# pos                                                             PRON
# ner                                                                _
# lemma                                                            הוא
# surface_form                                             העמדתו[513]
# dep_type                                                   nmod:poss
# dep_flavor                                                     basic
# dep_lex_morph_pos                                             100-26
# dep_arc                                                          NaN
# EXTRA                                                            NaN
# ner_type                                                           _
# is_ner                                                         False
# sent_id                                                          400
# id                                                                28
# file                                                          group1
# biose_layer0                                                       O
# biose_layer1                                                       O
#
#                         2246                      2247       2248
# sent_tok_num          100-29                    100-30     100-31
# tok_offset         9565-9566                 9567-9570  9571-9572
# token                      ל                       דין          .
# FEAT_gender                _                      Masc          _
# FEAT_number                _                      Sing          _
# FEAT_case                  _                         *          _
# FEAT_degree                _                         *          _
# FEAT_transitivity          _                         *          _
# FEAT_tense                 _                         *          _
# FEAT_mood                  _                         *          _
# FEAT_voice                 _                         *          _
# FEAT_definiteness          _                         *          _
# FEAT_value                 _  Gender=Masc\|Number=Sing          _
# FEAT_person                _                         *          _
# FEAT_aspect                _                         *          _
# pos                      ADP                      NOUN      PUNCT
# ner                        _                         _          _
# lemma                      ל                       דין          .
# surface_form       לדין[514]                 לדין[514]          _
# dep_type                case                      nmod      punct
# dep_flavor             basic                     basic      basic
# dep_lex_morph_pos     100-30                    100-26      100-3
# dep_arc                  NaN                       NaN        NaN
# EXTRA                    NaN                       NaN        NaN
# ner_type                   _                         _          _
# is_ner                 False                     False      False
# sent_id                  400                       400        400
# id                        29                        30         31
# file                  group1                    group1     group1
# biose_layer0               O                         O          O
# biose_layer1               O                         O          O

# %% [markdown]
# ## align with UD curation output files

# %%
for group in groups:
    for tat in groups[group]:
        print(group, tat, groups[group][tat].shape)
# Out:
# group1 anatb (9904, 31)
# group1 dafnaa (9904, 30)
# group1 shayp (9904, 32)
# group1 sinair (9904, 31)
# group1 tzufa (9904, 30)
# group1 vikab (9904, 31)
# group2 nuritg (9904, 30)
# group2 shovals (9904, 30)
# group2 tzipyl (9904, 32)
# group2 vereds (9904, 31)
# group2 yohayg (9904, 31)
# group2 zefs (9904, 31)

# %%
uddf = uddf[uddf.sent_id<=400]
uddf.shape
# Out:
# (9908, 28)

# %%
sent_diff = groups['group1']['anatb'].groupby('sent_id').size()[groups['group1']['anatb'].groupby('sent_id').size()!=uddf.groupby('sent_id').size()]
sent_diff
# Out:
# sent_id
# 147     8
# 228    52
# 291     9
# 311    13
# dtype: int64

# %%
for group, tators in groups.items():
    for tat, annos in tators.items():
        print(tat)
        #print(annos.loc[(annos.sent_id.isin(sent_diff.index)) & (annos.ner!='_'), ['sent_id', 'id', 'token', 'ner']])
        print(annos.loc[(annos.sent_id.isin(sent_diff.index)) & (annos.ner!='_'), :].sent_tok_num.unique())
# Out:
# anatb
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-10'
#  '11-11' '11-12']
# dafnaa
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']
# shayp
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23']
# sinair
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']
# tzufa
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']
# vikab
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']
# nuritg
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']
# shovals
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']
# tzipyl
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']
# vereds
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']
# yohayg
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']
# zefs
# ['28-13' '28-14' '28-16' '28-17' '28-19' '28-20' '28-22' '28-23' '11-9'
#  '11-10' '11-11' '11-12']

# %%
uddf[uddf.sent_id.isin(sent_diff.index[3:4])]
# Out:
#       sent_id  id    form  lemma upostag xpostag  \
# 7983      311   1     הוא    הוא    PRON    PRON
# 7984      311   2     היה    היה     AUX     AUX
# 7985      311   3   אפילו  אפילו     ADV     ADV
# 7986      311   4   מסוגל  מסוגל     AUX     AUX
# 7987      311   5  לראותו    ראה    VERB    VERB
# 7988      311   6      את     את     ADP     ADP
# 7989      311   7    _הוא    הוא    PRON    PRON
# 7990      311   8    מכהן   כיהן    VERB    VERB
# 7991      311   9       ב      ב     ADP     ADP
# 7992      311  10      ה_      ה     DET     DET
# 7993      311  11     בית    בית    NOUN    NOUN
# 7994      311  12       ה      ה     DET     DET
# 7995      311  13     לבן    לבן     ADJ     ADJ
# 7996      311  14       .      .   PUNCT   PUNCT
#
#                                                   feats  head   deprel  deps  \
# 7983  OrderedDict([('Gender', 'Masc'), ('Number', 'S...     4    nsubj   NaN
# 7984  OrderedDict([('Gender', 'Masc'), ('Number', 'S...     4      cop   NaN
# 7985                                                NaN     4   advmod   NaN
# 7986  OrderedDict([('Gender', 'Masc'), ('Number', 'S...     5      aux   NaN
# 7987  OrderedDict([('HebBinyan', 'PAAL'), ('VerbForm...     0     root   NaN
# 7988                     OrderedDict([('Case', 'Acc')])     7     case   NaN
# 7989  OrderedDict([('Case', 'Acc'), ('Gender', 'Masc...     5      obj   NaN
# 7990  OrderedDict([('Gender', 'Masc'), ('HebBinyan',...     7      acl   NaN
# 7991                                                NaN    11     case   NaN
# 7992                 OrderedDict([('PronType', 'Art')])    11  det:def   NaN
# 7993  OrderedDict([('Gender', 'Masc'), ('Number', 'S...     8      obl   NaN
# 7994                 OrderedDict([('PronType', 'Art')])    13  det:def   NaN
# 7995  OrderedDict([('Gender', 'Masc'), ('Number', 'S...    11     amod   NaN
# 7996                                                NaN     4    punct   NaN
#
#       ... ner_layers  ner_escaped  duplicate_sent_id very_similar_sent_id  \
# 7983  ...          0            _                NaN                  NaN
# 7984  ...          0            _                NaN                  NaN
# 7985  ...          0            _                NaN                  NaN
# 7986  ...          0            _                NaN                  NaN
# 7987  ...          0            _                NaN                  NaN
# 7988  ...          0            _                NaN                  NaN
# 7989  ...          0            _                NaN                  NaN
# 7990  ...          0            _                NaN                  NaN
# 7991  ...          0            _                NaN                  NaN
# 7992  ...          1       FAC[9]                NaN                  NaN
# 7993  ...          1       FAC[9]                NaN                  NaN
# 7994  ...          1       FAC[9]                NaN                  NaN
# 7995  ...          1       FAC[9]                NaN                  NaN
# 7996  ...          0            _                NaN                  NaN
#
#       biose_layer0 biose_layer1 biose_layer2 biose_layer3  set ud_set
# 7983             O            O            O            O  dev    dev
# 7984             O            O            O            O  dev    dev
# 7985             O            O            O            O  dev    dev
# 7986             O            O            O            O  dev    dev
# 7987             O            O            O            O  dev    dev
# 7988             O            O            O            O  dev    dev
# 7989             O            O            O            O  dev    dev
# 7990             O            O            O            O  dev    dev
# 7991             O            O            O            O  dev    dev
# 7992         B-FAC            O            O            O  dev    dev
# 7993         I-FAC            O            O            O  dev    dev
# 7994         I-FAC            O            O            O  dev    dev
# 7995         E-FAC            O            O            O  dev    dev
# 7996             O            O            O            O  dev    dev
#
# [14 rows x 28 columns]

# %%
groups['group1']['anatb'][groups['group1']['anatb'].sent_id.isin(sent_diff.index[3:4])]
# Out:
#     sent_tok_num tok_offset   token FEAT_gender FEAT_number FEAT_case  \
# 325         11-1  1403-1406     הוא        Masc        Sing         *
# 326         11-2  1407-1410     היה        Masc        Sing         *
# 327         11-3  1411-1416   אפילו           _           _         _
# 328         11-4  1417-1422   מסוגל        Masc        Sing         *
# 329         11-5  1423-1429  לראותו           *           *         *
# 330         11-6  1430-1434    _הוא        Masc        Sing       Acc
# 331         11-7  1435-1439    מכהן        Masc        Sing         *
# 332         11-8  1440-1441       ב           _           _         _
# 333         11-9  1442-1444      ה_           *           *         *
# 334        11-10  1445-1448     בית        Masc        Sing         *
# 335        11-11  1449-1450       ה           *           *         *
# 336        11-12  1451-1454     לבן        Masc        Sing         *
# 337        11-13  1455-1456       .           _           _         _
#
#     FEAT_degree FEAT_transitivity FEAT_tense FEAT_mood  ... dep_lex_morph_pos  \
# 325           *                 *          *         *  ...              11-4
# 326           *                 *       Past         *  ...              11-4
# 327           _                 _          _         _  ...              11-4
# 328           *                 *          *         *  ...              11-4
# 329           *                 *          *         *  ...              11-4
# 330           *                 *          *         *  ...              11-5
# 331           *                 *          *         *  ...              11-6
# 332           _                 _          _         _  ...             11-10
# 333           *                 *          *         *  ...             11-10
# 334           *                 *          *         *  ...              11-7
# 335           *                 *          *         *  ...             11-12
# 336           *                 *          *         *  ...             11-10
# 337           _                 _          _         _  ...              11-4
#
#     dep_arc EXTRA ner_type is_ner sent_id  id    file biose_layer0  \
# 325     NaN   NaN        _  False     311   1  group1            O
# 326     NaN   NaN        _  False     311   2  group1            O
# 327     NaN   NaN        _  False     311   3  group1            O
# 328     NaN   NaN        _  False     311   4  group1            O
# 329     NaN   NaN        _  False     311   5  group1            O
# 330     NaN   NaN        _  False     311   6  group1            O
# 331     NaN   NaN        _  False     311   7  group1            O
# 332     NaN   NaN        _  False     311   8  group1            O
# 333     NaN   NaN        _  False     311   9  group1            O
# 334     NaN   NaN      ORG   True     311  10  group1        B-ORG
# 335     NaN   NaN      ORG   True     311  11  group1        I-ORG
# 336     NaN   NaN      ORG   True     311  12  group1        E-ORG
# 337     NaN   NaN        _  False     311  13  group1            O
#
#     biose_layer1
# 325            O
# 326            O
# 327            O
# 328            O
# 329            O
# 330            O
# 331            O
# 332            O
# 333            O
# 334            O
# 335            O
# 336            O
# 337            O
#
# [13 rows x 31 columns]

# %%
for group in groups:
    for tat in groups[group]:
         groups[group][tat] =  groups[group][tat].reset_index(drop=True)

# %%
uddf.columns
# Out:
# Index(['sent_id', 'id', 'form', 'lemma', 'upostag', 'xpostag', 'feats', 'head',
#        'deprel', 'deps', 'misc', 'global_sent_id', 'token_id', 'token_str',
#        'token_morph_id', 'binyan', 'biose', 'ner', 'ner_layers', 'ner_escaped',
#        'duplicate_sent_id', 'very_similar_sent_id', 'biose_layer0',
#        'biose_layer1', 'biose_layer2', 'biose_layer3', 'set', 'ud_set'],
#       dtype='object')

# %%
uddf = uddf[uddf.sent_id<=400]
uddf.shape
# Out:
# (9908, 28)

# %%
keep_cols = ['sent_id', 'id', 'form', 'lemma', 'upostag', 'xpostag', 'feats', 'head',
       'deprel', 'deps', 'misc', 'global_sent_id', 'token_id', 'token_str',
       'token_morph_id', 'binyan', 
       'duplicate_sent_id', 'very_similar_sent_id', 'set', 'ud_set']
def merge_uddf(uddf, df):
    keep_cols = ['sent_id', 'id', 'form', 'lemma', 'upostag', 'xpostag', 'feats', 'head',
       'deprel', 'deps', 'misc', 'global_sent_id', 'token_id', 'token_str',
       'token_morph_id', 'binyan', 
       'duplicate_sent_id', 'very_similar_sent_id', 'set', 'ud_set']
    tat_cols = ['ner', 'ner_type', 'is_ner', 'biose_layer0']
    for i in range(4):
        if 'biose_layer'+str(i+1) in df.columns:
            tat_cols.append('biose_layer'+str(i+1))
    n = pd.concat([uddf[keep_cols], df[tat_cols]], axis=1)
    return n, keep_cols+tat_cols

# %%
uddf_tofix = uddf[(uddf.sent_id.isin(sent_diff.index))][keep_cols]

# %%
uddf_tofix.shape
# Out:
# (86, 20)

# %%
uddf_ok = uddf[~(uddf.sent_id.isin(sent_diff.index))].reset_index(drop=True)

# %%
merged = {}
for group, tators in groups.items():
    print(group)
    merged[group] = {}
    for tat, annos in tators.items():
        print(tat)
        annos_ok = annos[~(annos.sent_id.isin(sent_diff.index))].reset_index(drop=True)
        a, all_cols = merge_uddf(uddf_ok, annos_ok)
        biose_cols = [c for c in all_cols if 'biose_layer' in c]
        a = a[all_cols]
        annos_tofix = annos[(annos.sent_id.isin(sent_diff.index)) 
                         & (annos.ner!='_')][['sent_id', 'token', 'ner', 'ner_type', 'is_ner'] +biose_cols].rename(columns={'token': 'form'})
        a_missing = uddf_tofix.merge(annos_tofix, how='left', on=['sent_id', 'form'])[all_cols]
        a = pd.concat([a, a_missing])
        a = a.sort_values(['sent_id', 'id']).reset_index(drop=True)
        a = a[a.sent_id.notna()]
        a[['ner', 'ner_type']] = a[['ner', 'ner_type']].fillna('_')
        a['is_ner'] = a['is_ner'].fillna(False)
        for i in range(4):
            if 'biose_layer'+str(i) in a.columns:
                a['biose_layer'+str(i)] = a['biose_layer'+str(i)].fillna('O')
            else:
                a['biose_layer'+str(i)] = 'O'
        merged[group][tat] = a
# Out:
# group1
# anatb
# dafnaa
# shayp
# sinair
# tzufa
# vikab
# group2
# nuritg
# shovals
# tzipyl
# vereds
# yohayg
# zefs

# %%
merged['group1']['anatb'].shape
# Out:
# (9908, 27)

# %% [markdown]
# ## Create variant files for each

# %%
aliases = {'dafnaa': 'a', 
           'zefs': 'b'}
i = 0
for group in groups:
    for tat in groups[group]:
        if tat not in aliases:
            aliases[tat] = chr(ord('c')+i)
            i+=1
aliases
# Out:
# {'dafnaa': 'a',
#  'zefs': 'b',
#  'anatb': 'c',
#  'shayp': 'd',
#  'sinair': 'e',
#  'tzufa': 'f',
#  'vikab': 'g',
#  'nuritg': 'h',
#  'shovals': 'i',
#  'tzipyl': 'j',
#  'vereds': 'k',
#  'yohayg': 'l'}

# %%
import os
out_folder = 'data/ud_ner/pilot_annotations/'

def write_ncrf_file(sents, file_name, keep_pos=False, bioul=False, dummy_o=False):
    if keep_pos:
        file_name += '_pos'
    if dummy_o:
        file_name += '_dummy_o'
    if bioul:
        suffix = '.bioul'
    else:
        suffix = '.bmes'
    with open(os.path.join(out_folder, file_name+suffix), 'w', encoding='utf8') as of:
        for sent in sents:
            for fields in sent: 
                new_pos = '[POS]'+fields[1]
                line = fields[0]
                if keep_pos:
                    line += ' ' + new_pos
                if len(fields)==3:
                    tag = fields[2]
                    if bioul:
                        tag = tag.replace('E-', 'L-').replace('S-', 'U-')
                    if dummy_o:
                        tag = 'O'
                    line += ' ' + tag
                of.write(line+'\n')
            of.write('\n')

# %%
import os
nested_out_folder = 'data/ud_ner/pilot_annotations/nested'

def write_nested_file(sents, file_name):
    suffix = '.bmes'
    with open(os.path.join(nested_out_folder, file_name+suffix), 'w', encoding='utf8') as of:
        for sent in sents:
            for fields in sent: 
                line = ' '.join(fields)
                of.write(line+'\n')
            of.write('\n')

# %%
1==1
# Out:
# True

# %%
for group in merged:
    for name, a in merged[group].items():
        alias = aliases[name]
        
        #morph
        sents = bclm.get_sentences_list(a, fields=['form', 'upostag', 'biose_layer0'])
        write_ncrf_file(sents, f'{group}_{alias}_morph_dev_1-400')
        
        #token-multi
        a_biose_concat = bclm.get_token_df(a, fields = ['biose_layer0', 'upostag'])
        sents = bclm.get_sentences_list(a_biose_concat  , fields=['token_str', 'upostag', 'biose_layer0'])
        write_ncrf_file(sents, f'{group}_{alias}_token-multi_dev_1-400')

        #token-single
        a_biose_fix = bclm.get_token_df(a, fields = ['upostag'], biose=['biose_layer0'])
        sents = bclm.get_sentences_list(a_biose_fix  , fields=['token_str', 'upostag', 'biose_layer0'])
        write_ncrf_file(sents, f'{group}_{alias}_token-single_dev_1-400')
        
        # === nested ===
        #morph
        fields = ['form', 'biose_layer0', 'biose_layer1', 'biose_layer2', 'biose_layer3']
        sents =   bclm.get_sentences_list(a, fields=fields)
        write_nested_file(sents, f'{group}_{alias}_morph_dev_1-400')
        
        #token-multi
        fields = ['token_str', 'biose_layer0', 'biose_layer1', 'biose_layer2', 'biose_layer3']
        a_biose_concat = bclm.get_token_df(a, fields = fields[1:])
        sents = bclm.get_sentences_list(a_biose_concat  , fields=fields)
        write_nested_file(sents, f'{group}_{alias}_token-multi_dev_1-400')
        
        #token-single
        a_biose_fix = bclm.get_token_df(a, fields = ['upostag'], biose=fields[1:])
        sents = bclm.get_sentences_list(a_biose_fix  , fields=fields)
        write_nested_file(sents, f'{group}_{alias}_token-single_dev_1-400')
